# %%
# | default_exp utils.validators

# %% [markdown]
# # Validation utils

# %% [markdown]
# :::{admonition}
# Utilities for validations
# :::

# %% [markdown]
# ## Imports

# %% [markdown]
# Python modules

# %%
# | export
import logging
import re

# %% [markdown]
# ## Logger

# %%
# | export


logger = logging.getLogger("newrelic_sb_sdk")

# %% [markdown]
# ## Constants

# %%
# | export
USER_KEY_PATTERN: re.Pattern = re.compile("NRAK-[A-Z0-9]{27}")

# %% [markdown]
# ## Functions

# %%
# | export


def validate_user_key(user_key: str) -> bool:
    match: re.Match[str] | None = re.match(USER_KEY_PATTERN, user_key)

    return bool(match)
