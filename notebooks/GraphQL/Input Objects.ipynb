# %%
# | default_exp graphql.input_objects

# %%
# | export
# pylint: disable=duplicate-code,unused-import,too-many-lines,disallowed-name

# %% [markdown]
# # NerdGraph Input Object Types

# %% [markdown]
# ## Imports

# %% [markdown]
# Third-party modules

# %%
# | export
import sgqlc.types
import sgqlc.types.datetime

# %% [markdown]
# `newrelic_sb_sdk` module

# %%
# | export
from newrelic_sb_sdk.graphql import nerdgraph

# %%
# | export
from newrelic_sb_sdk.graphql.enums import (
    AgentApplicationBrowserLoader,
    AgentApplicationSegmentsListType,
    AgentApplicationSettingsBrowserLoaderInput,
    AgentApplicationSettingsMobileSessionReplayModeInput,
    AgentApplicationSettingsNetworkFilterMode,
    AgentApplicationSettingsRecordSqlEnum,
    AgentApplicationSettingsSessionTraceModeInput,
    AgentApplicationSettingsThresholdTypeEnum,
    AgentApplicationSettingsTracer,
    AiDecisionsIncidentSelect,
    AiDecisionsIssuePriority,
    AiDecisionsRuleSource,
    AiDecisionsRuleType,
    AiDecisionsVertexClass,
    AiIssuesIncidentState,
    AiIssuesIssueMutingState,
    AiIssuesIssueState,
    AiNotificationsAuthType,
    AiNotificationsChannelFields,
    AiNotificationsChannelStatus,
    AiNotificationsChannelType,
    AiNotificationsDestinationFields,
    AiNotificationsDestinationType,
    AiNotificationsEmailVerificationStatus,
    AiNotificationsEntityScopeTypeInput,
    AiNotificationsProduct,
    AiNotificationsSortOrder,
    AiNotificationsSuggestionFilterType,
    AiNotificationsUnverifiedEmailsFields,
    AiNotificationsVariableFields,
    AiNotificationsVariableType,
    AiTopologyCollectorVertexClass,
    AiWorkflowsDestinationType,
    AiWorkflowsFilterType,
    AiWorkflowsMutingRulesHandling,
    AiWorkflowsNotificationTrigger,
    AiWorkflowsOperator,
    AlertsActionOnMutingRuleWindowEnded,
    AlertsAsNrqlSourceProduct,
    AlertsCompoundConditionSortDirection,
    AlertsCompoundConditionSortKey,
    AlertsDayOfWeek,
    AlertsFillOption,
    AlertsIncidentPreference,
    AlertsMutingRuleConditionGroupOperator,
    AlertsMutingRuleConditionOperator,
    AlertsMutingRuleScheduleRepeat,
    AlertsNrqlBaselineDirection,
    AlertsNrqlConditionPriority,
    AlertsNrqlConditionTermsOperator,
    AlertsNrqlConditionThresholdOccurrences,
    AlertsNrqlDynamicConditionTermsOperator,
    AlertsNrqlSignalSeasonality,
    AlertsNrqlStaticConditionValueFunction,
    AlertsOpsGenieDataCenterRegion,
    AlertsSignalAggregationMethod,
    AlertsViolationTimeLimit,
    AlertsWebhookCustomPayloadType,
    ApiAccessIngestKeyType,
    ApiAccessKeyType,
    AuthorizationManagementGranteeTypeEnum,
    AuthorizationManagementIamParentScopeTypeEnum,
    ChangeTrackingDeploymentType,
    ChangeTrackingValidationFlag,
    CloudCostIntelligenceIntegrationFilterOperator,
    CloudMetricCollectionMode,
    DashboardAlertSeverity,
    DashboardLiveUrlAuthType,
    DashboardLiveUrlType,
    DashboardPermissions,
    DashboardVariableReplacementStrategy,
    DashboardVariableType,
    DataAccessPolicyAssignedStatus,
    DataAccessPolicySortKey,
    DataAccessPolicySortOrder,
    DataSourceGapsGapTypeIdentifier,
    EdgeComplianceTypeCode,
    EdgeDataSourceGroupUpdateType,
    EdgeProviderRegion,
    EdgeSpanAttributeKeyOperator,
    EdgeSpanAttributeValueOperator,
    EdgeTraceFilterAction,
    EntityAlertSeverity,
    EntityInfrastructureIntegrationType,
    EntityManagementAiToolParameterType,
    EntityManagementAiToolType,
    EntityManagementCategoryScopeType,
    EntityManagementEncodingName,
    EntityManagementEntityScope,
    EntityManagementExternalOwnerType,
    EntityManagementHostingPlatform,
    EntityManagementIncidentTimelineSource,
    EntityManagementIssueType,
    EntityManagementLicenseName,
    EntityManagementMcpAuthType,
    EntityManagementMcpTransport,
    EntityManagementSyncGroupRuleConditionType,
    EntityManagementTeamExternalIntegrationType,
    EntityManagementTextSplitterType,
    EntityRelationshipEdgeDirection,
    EntityRelationshipEdgeType,
    EntitySearchQueryBuilderDomain,
    EntitySearchQueryBuilderType,
    EntitySearchSortCriteria,
    EntityType,
    ErrorsInboxDirection,
    ErrorsInboxErrorGroupSortOrderField,
    ErrorsInboxErrorGroupState,
    ErrorsInboxEventSource,
    ErrorsInboxResourceType,
    FleetControlEntityScope,
    FleetControlManagedEntityType,
    FleetControlOperatingSystemType,
    InstallationInstallStateType,
    InstallationRecipeStatusType,
    LogConfigurationsDataPartitionRuleMatchingOperator,
    LogConfigurationsDataPartitionRuleRetentionPolicyType,
    LogConfigurationsObfuscationMethod,
    LogConfigurationsParsingRuleSource,
    MachineLearningEncodingName,
    MachineLearningFilterByKeys,
    MachineLearningOperator,
    MachineLearningTextSplitterType,
    MetricNormalizationCustomerRuleAction,
    MultiTenantAuthorizationGranteeTypeEnum,
    MultiTenantAuthorizationGrantScopeEnum,
    MultiTenantAuthorizationGrantSortEnum,
    MultiTenantAuthorizationRoleScopeEnum,
    MultiTenantAuthorizationRoleSortEnum,
    MultiTenantAuthorizationRoleTypeEnum,
    MultiTenantAuthorizationSortDirectionEnum,
    MultiTenantIdentityCapability,
    MultiTenantIdentitySortDirection,
    MultiTenantIdentitySortKeyEnum,
    MultiTenantIdentityUserSortKey,
    NerdpackSubscriptionModel,
    NerdpackVersionFilterFallback,
    NerdStorageScope,
    NerdStorageVaultActorScope,
    Nr1CatalogSearchComponentType,
    Nr1CatalogSearchResultType,
    NrqlDropRulesAction,
    OrganizationAccountShareSortDirectionEnum,
    OrganizationAccountShareSortKeyEnum,
    OrganizationAccountSortDirectionEnum,
    OrganizationAccountSortKeyEnum,
    OrganizationAccountStatus,
    OrganizationMembersOrganizationMemberType,
    OrganizationOrganizationCreateJobStatusEnum,
    OrganizationProvisioningUnit,
    OrganizationRegionCodeEnum,
    OrganizationSharingMode,
    OrganizationSortDirectionEnum,
    OrganizationSortKeyEnum,
    SecretsManagementScopeType,
    SecretsManagementSortDirection,
    SecretsManagementSortKey,
    ServiceLevelEventsQuerySelectFunction,
    ServiceLevelObjectiveRollingTimeWindowUnit,
    SessionsClientType,
    SortBy,
    StreamingExportPayloadCompression,
    SyntheticsBrowser,
    SyntheticsDevice,
    SyntheticsDeviceOrientation,
    SyntheticsDeviceType,
    SyntheticsMonitorDowntimeDayOfMonthOrdinal,
    SyntheticsMonitorDowntimeWeekDays,
    SyntheticsMonitorPeriod,
    SyntheticsMonitorStatus,
    SyntheticsStepType,
    SystemIdentityIdentitySortFieldKey,
    SystemIdentityIdentityType,
    SystemIdentitySortOrder,
    UserManagementGroupSortKey,
    UserManagementRequestedTierName,
    UserManagementSortDirection,
    UserManagementTypeEnum,
    WhatsNewContentType,
    WorkflowAutomationScopeType,
    WorkflowAutomationWorkflowLogLevel,
    WorkflowAutomationWorkflowRunScopeType,
    WorkloadGroupRemainingEntitiesRuleBy,
    WorkloadRollupStrategy,
    WorkloadRuleThresholdType,
    WorkloadStatusValueInput,
)

# %%
# | export
from newrelic_sb_sdk.graphql.scalars import (
    ID,
    AgentApplicationSettingsCustomJsConfiguration,
    AgentApplicationSettingsErrorCollectorHttpStatus,
    Boolean,
    ChangeTrackingRawCustomAttributesMap,
    DashboardWidgetRawConfiguration,
    Date,
    DateTime,
    EntityGuid,
    EpochMilliseconds,
    EpochSeconds,
    ErrorsInboxRawEvent,
    Float,
    InstallationRawMetadata,
    Int,
    LogConfigurationsLogDataPartitionName,
    Milliseconds,
    NaiveDateTime,
    NerdpackTagName,
    Nrql,
    Seconds,
    SecureValue,
    SemVer,
    String,
    WorkflowAutomationRawWorkflowInputValue,
)

# %% [markdown]
# ## Definitions

# %% [markdown]
# ### Constants

# %%
# | export
__docformat__ = "markdown"

# %% [markdown]
# ### Input object types

# %% [markdown]
# #### 1. `AccountManagementCreateInput`

# %% [markdown]
# Attributes for creating an account.
#
#
# Available input fields:
#
#
#
# * `name` : The name of the account.
# * `organizationId` : The id of the managed organization where the account will be created.
# * `regionCode` : The data center region for the account

# %%
# | export
class AccountManagementCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "organization_id", "region_code")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    organization_id = sgqlc.types.Field(ID, graphql_name="organizationId")

    region_code = sgqlc.types.Field(String, graphql_name="regionCode")

# %% [markdown]
# #### 2. `AccountManagementUpdateInput`

# %% [markdown]
# The attributes for updating an account.
#
#
# Available input fields:
#
#
#
# * `id` : The ID for the account being updated.
# * `name` : The new account name.

# %%
# | export
class AccountManagementUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name")
    id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="id")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 3. `AgentApplicationBrowserSettingsInput`

# %% [markdown]
# Configure additional browser settings here.
#
#
# Available input fields:
#
#
#
# * `cookiesEnabled` : Configure session tracking. The default is enabled: true.
# * `distributedTracingEnabled` : Configure distributed tracing in browser apps. The default is enabled: true.
# * `loaderType` : Determines which browser loader is configured. The default is "SPA".

# %%
# | export
class AgentApplicationBrowserSettingsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cookies_enabled", "distributed_tracing_enabled", "loader_type")
    cookies_enabled = sgqlc.types.Field(Boolean, graphql_name="cookiesEnabled")

    distributed_tracing_enabled = sgqlc.types.Field(
        Boolean, graphql_name="distributedTracingEnabled"
    )

    loader_type = sgqlc.types.Field(
        AgentApplicationBrowserLoader, graphql_name="loaderType"
    )

# %% [markdown]
# #### 4. `AgentApplicationSegmentsBrowserSegmentAllowListInput`

# %% [markdown]
# The allow list that you would like to modify.
#
#
# Available input fields:
#
#
#
# * `segments` : A case sensitive list of url segments. The list cannot exceed 8192 characters in total. Each segment must be less than 100 characters.

# %%
# | export
class AgentApplicationSegmentsBrowserSegmentAllowListInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("segments",)
    segments = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)), graphql_name="segments"
    )

# %% [markdown]
# #### 5. `AgentApplicationSegmentsSegmentAllowListFilters`

# %% [markdown]
# Filter the allow lists by fields specified in this object.
#
#
# Available input fields:
#
#
#
# * `listType` : INTERNAL or USER. Defaults to USER

# %%
# | export
class AgentApplicationSegmentsSegmentAllowListFilters(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("list_type",)
    list_type = sgqlc.types.Field(
        AgentApplicationSegmentsListType, graphql_name="listType"
    )

# %% [markdown]
# #### 6. `AgentApplicationSettingsApmConfigInput`

# %% [markdown]
# Provides fields to set general APM application settings.
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The desired target for the APDEX measurement of this application.
# * `useServerSideConfig` : Sets if installed agents should override local settings with ones set here.

# %%
# | export
class AgentApplicationSettingsApmConfigInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("apdex_target", "use_server_side_config")
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    use_server_side_config = sgqlc.types.Field(
        Boolean, graphql_name="useServerSideConfig"
    )

# %% [markdown]
# #### 7. `AgentApplicationSettingsApplicationExitInfoInput`

# %% [markdown]
# Config data collection for application exits.
#
#
# Available input fields:
#
#
#
# * `enabled` : Enables collection of application exit info.

# %%
# | export
class AgentApplicationSettingsApplicationExitInfoInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled",)
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

# %% [markdown]
# #### 8. `AgentApplicationSettingsBrowserAjaxInput`

# %% [markdown]
# Configuration settings related to how a browser agent handles Ajax requests.
#
#
# Available input fields:
#
#
#
# * `denyList` : A list of host destinations that will not record AjaxRequest events when requested.

# %%
# | export
class AgentApplicationSettingsBrowserAjaxInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("deny_list",)
    deny_list = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="denyList"
    )

# %% [markdown]
# #### 9. `AgentApplicationSettingsBrowserConfigInput`

# %% [markdown]
# Provides fields to set general browser application settings.
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The desired target for the APDEX measurement of this application.

# %%
# | export
class AgentApplicationSettingsBrowserConfigInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("apdex_target",)
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

# %% [markdown]
# #### 10. `AgentApplicationSettingsBrowserConsentModeInput`

# %% [markdown]
# Browser consent mode configuration for privacy compliance.
#
#
# Available input fields:
#
#
#
# * `enabled` : Enable or disable browser consent mode for privacy compliance and consent management platform integration.

# %%
# | export
class AgentApplicationSettingsBrowserConsentModeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled",)
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

# %% [markdown]
# #### 11. `AgentApplicationSettingsBrowserDistributedTracingInput`

# %% [markdown]
# Configure distributed traces from within browser apps.
#
#
# Available input fields:
#
#
#
# * `allowedOrigins` : Supplies allowed origins for distributed tracing in browser.
# * `corsEnabled` : Enables CORS for distributed tracing in browser.
# * `corsUseNewrelicHeader` : Enables the use of the `newrelic` header for CORS requests with distributed tracing. [See Docs](https://docs.newrelic.com/docs/browser/new-relic-browser/browser-pro-features/browser-data-distributed-tracing/#cors) for more information.
# * `corsUseTracecontextHeaders` : Enables CORS to use tracecontext headers for distributed tracing in browser.
# * `enabled` : Enables distributed tracing in browser.
# * `excludeNewrelicHeader` : Enables the `newrelic` header to be excluded in distributed tracing in browser.

# %%
# | export
class AgentApplicationSettingsBrowserDistributedTracingInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "allowed_origins",
        "cors_enabled",
        "cors_use_newrelic_header",
        "cors_use_tracecontext_headers",
        "enabled",
        "exclude_newrelic_header",
    )
    allowed_origins = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="allowedOrigins"
    )

    cors_enabled = sgqlc.types.Field(Boolean, graphql_name="corsEnabled")

    cors_use_newrelic_header = sgqlc.types.Field(
        Boolean, graphql_name="corsUseNewrelicHeader"
    )

    cors_use_tracecontext_headers = sgqlc.types.Field(
        Boolean, graphql_name="corsUseTracecontextHeaders"
    )

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    exclude_newrelic_header = sgqlc.types.Field(
        Boolean, graphql_name="excludeNewrelicHeader"
    )

# %% [markdown]
# #### 12. `AgentApplicationSettingsBrowserMonitoringInput`

# %% [markdown]
# Set browser monitoring application settings.
#
#
# Available input fields:
#
#
#
# * `ajax` : Configuration settings related to how a browser agent handles Ajax requests.
# * `distributedTracing` : Configure distributed traces from within browser apps.
# * `loader` : Determines which browser loader will be configured.
# * `pinnedVersion` : Specify the semantic version of the browser agent that you would like your app to use. Leave this blank to use the most recent version. Use 'x' in place of a numeric digit to represent the latest release within the version range. For example, '1.x.x'
# * `privacy` : Browser monitoring's page load timing feature can track sessions by using cookies that contain a simple session identifier.

# %%
# | export
class AgentApplicationSettingsBrowserMonitoringInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "ajax",
        "distributed_tracing",
        "loader",
        "pinned_version",
        "privacy",
    )
    ajax = sgqlc.types.Field(
        AgentApplicationSettingsBrowserAjaxInput, graphql_name="ajax"
    )

    distributed_tracing = sgqlc.types.Field(
        AgentApplicationSettingsBrowserDistributedTracingInput,
        graphql_name="distributedTracing",
    )

    loader = sgqlc.types.Field(
        AgentApplicationSettingsBrowserLoaderInput, graphql_name="loader"
    )

    pinned_version = sgqlc.types.Field(String, graphql_name="pinnedVersion")

    privacy = sgqlc.types.Field(
        "AgentApplicationSettingsBrowserPrivacyInput", graphql_name="privacy"
    )

# %% [markdown]
# #### 13. `AgentApplicationSettingsBrowserPerformanceInput`

# %% [markdown]
# Browser Performance configuration
#
#
# Available input fields:
#
#
#
# * `captureDetail` : Capture detail enabled.
# * `captureMarks` : Capture mark enabled.
# * `captureMeasures` : Capture measures enabled.

# %%
# | export
class AgentApplicationSettingsBrowserPerformanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("capture_detail", "capture_marks", "capture_measures")
    capture_detail = sgqlc.types.Field(Boolean, graphql_name="captureDetail")

    capture_marks = sgqlc.types.Field(Boolean, graphql_name="captureMarks")

    capture_measures = sgqlc.types.Field(Boolean, graphql_name="captureMeasures")

# %% [markdown]
# #### 14. `AgentApplicationSettingsBrowserPrivacyInput`

# %% [markdown]
# Browser monitoring's page load timing feature can track sessions by using cookies that contain a simple session identifier.
#
#
# Available input fields:
#
#
#
# * `cookiesEnabled` : If enabled, enables cookies.

# %%
# | export
class AgentApplicationSettingsBrowserPrivacyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cookies_enabled",)
    cookies_enabled = sgqlc.types.Field(Boolean, graphql_name="cookiesEnabled")

# %% [markdown]
# #### 15. `AgentApplicationSettingsErrorCollectorInput`

# %% [markdown]
# The error collector captures information about uncaught exceptions and sends them to New Relic for viewing. For more information about what these settings do and which ones are applicable for your application, please see https://docs.newrelic.com for more information about agent configuration for your language agent.
#
#
# Available input fields:
#
#
#
# * `enabled` : Enables error collector.
# * `expectedErrorClasses` : Prevents specified exception classes from affecting error rate or Apdex score while still reporting the errors to APM.
# * `expectedErrorCodes` : An array of individual HTTP status codes to be marked as expected and thus prevented from affecting error rate or Apdex score.
# * `ignoredErrorClasses` : Specified exception class names will be ignored and will not affect error rate or Apdex score, or be reported to APM.
# * `ignoredErrorCodes` : An array of individual HTTP status codes that should not be treated as errors.

# %%
# | export
class AgentApplicationSettingsErrorCollectorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "enabled",
        "expected_error_classes",
        "expected_error_codes",
        "ignored_error_classes",
        "ignored_error_codes",
    )
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    expected_error_classes = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)),
        graphql_name="expectedErrorClasses",
    )

    expected_error_codes = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AgentApplicationSettingsErrorCollectorHttpStatus)
        ),
        graphql_name="expectedErrorCodes",
    )

    ignored_error_classes = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)),
        graphql_name="ignoredErrorClasses",
    )

    ignored_error_codes = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AgentApplicationSettingsErrorCollectorHttpStatus)
        ),
        graphql_name="ignoredErrorCodes",
    )

# %% [markdown]
# #### 16. `AgentApplicationSettingsIgnoredStatusCodeRuleInput`

# %% [markdown]
# Input data that maps ignore status codes associated with different hosts.
#
#
# Available input fields:
#
#
#
# * `hosts` : An array of hosts to apply the status code rule to.
# * `statusCodes` : An array of status codes to be be ignored on these hosts.

# %%
# | export
class AgentApplicationSettingsIgnoredStatusCodeRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("hosts", "status_codes")
    hosts = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="hosts",
    )

    status_codes = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="statusCodes",
    )

# %% [markdown]
# #### 17. `AgentApplicationSettingsJfrInput`

# %% [markdown]
# In the Java agent (v8.0.0 or later), the Java Flight Recorder can be turned on to collect additional information about the application. This setting cannot be updated for non-java agents.
#
#
# Available input fields:
#
#
#
# * `enabled` : Whether or not JFR is enabled.

# %%
# | export
class AgentApplicationSettingsJfrInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled",)
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

# %% [markdown]
# #### 18. `AgentApplicationSettingsMaskInputOptionsInput`

# %% [markdown]
# Mask specific kinds of input options as *.
#
#
# Available input fields:
#
#
#
# * `color` : Mask 'color' input type.
# * `date` : Mask 'date' input type.
# * `datetimeLocal` : Mask 'datetime_local' input type.
# * `email` : Mask 'email' input type.
# * `month` : Mask 'month' input type.
# * `number` : Mask 'number' input type.
# * `range` : Mask 'range' input type.
# * `search` : Mask 'search' input type.
# * `select` : Mask 'select' input type.
# * `tel` : Mask 'tel' input type.
# * `text` : Mask 'text' input type.
# * `textArea` : Mask 'textarea' input type.
# * `time` : Mask 'time' input type.
# * `url` : Mask 'url' input type.
# * `week` : Mask 'week' input type.

# %%
# | export
class AgentApplicationSettingsMaskInputOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "color",
        "date",
        "datetime_local",
        "email",
        "month",
        "number",
        "range",
        "search",
        "select",
        "tel",
        "text",
        "text_area",
        "time",
        "url",
        "week",
    )
    color = sgqlc.types.Field(Boolean, graphql_name="color")

    date = sgqlc.types.Field(Boolean, graphql_name="date")

    datetime_local = sgqlc.types.Field(Boolean, graphql_name="datetimeLocal")

    email = sgqlc.types.Field(Boolean, graphql_name="email")

    month = sgqlc.types.Field(Boolean, graphql_name="month")

    number = sgqlc.types.Field(Boolean, graphql_name="number")

    range = sgqlc.types.Field(Boolean, graphql_name="range")

    search = sgqlc.types.Field(Boolean, graphql_name="search")

    select = sgqlc.types.Field(Boolean, graphql_name="select")

    tel = sgqlc.types.Field(Boolean, graphql_name="tel")

    text = sgqlc.types.Field(Boolean, graphql_name="text")

    text_area = sgqlc.types.Field(Boolean, graphql_name="textArea")

    time = sgqlc.types.Field(Boolean, graphql_name="time")

    url = sgqlc.types.Field(Boolean, graphql_name="url")

    week = sgqlc.types.Field(Boolean, graphql_name="week")

# %% [markdown]
# #### 19. `AgentApplicationSettingsMobileSessionReplayInput`

# %% [markdown]
# Mobile Session Replay configuration.
#
#
# Available input fields:
#
#
#
# * `customMaskingRules` : Rules to mask or unmask specific components or views. These rules override other masking settings.
# * `enabled` : Mobile Session Replay enabled.
# * `errorSamplingRate` : Percentage from 0-10 specifying how many of all user sessions that contain errors should be recorded.
# * `maskAllImages` : Replace all images with placeholder
# * `maskAllUserTouches` : Ignore all user input from recording
# * `maskApplicationText` : Mask all application text content as *
# * `maskUserInputText` : Mask all input text content as *
# * `mode` : Toggle between default masking settings and custom masking settings.
# * `samplingRate` : Percentage from 0-10 specifying how many of all user sessions should be recorded.

# %%
# | export
class AgentApplicationSettingsMobileSessionReplayInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "custom_masking_rules",
        "enabled",
        "error_sampling_rate",
        "mask_all_images",
        "mask_all_user_touches",
        "mask_application_text",
        "mask_user_input_text",
        "mode",
        "sampling_rate",
    )
    custom_masking_rules = sgqlc.types.Field(
        AgentApplicationSettingsCustomJsConfiguration, graphql_name="customMaskingRules"
    )

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    error_sampling_rate = sgqlc.types.Field(Float, graphql_name="errorSamplingRate")

    mask_all_images = sgqlc.types.Field(Boolean, graphql_name="maskAllImages")

    mask_all_user_touches = sgqlc.types.Field(
        Boolean, graphql_name="maskAllUserTouches"
    )

    mask_application_text = sgqlc.types.Field(
        Boolean, graphql_name="maskApplicationText"
    )

    mask_user_input_text = sgqlc.types.Field(Boolean, graphql_name="maskUserInputText")

    mode = sgqlc.types.Field(
        AgentApplicationSettingsMobileSessionReplayModeInput, graphql_name="mode"
    )

    sampling_rate = sgqlc.types.Field(Float, graphql_name="samplingRate")

# %% [markdown]
# #### 20. `AgentApplicationSettingsMobileSettingsInput`

# %% [markdown]
# A configuration object to enable mobile log reporting
#
#
# Available input fields:
#
#
#
# * `applicationExitInfo` : Config data collection for application exits.
# * `mobileSessionReplay` : Mobile Session Replay configuration.
# * `networkSettings` : Input arguments for network settings.
# * `useCrashReports` : Sets if application should use crash report or not for mobile settings.

# %%
# | export
class AgentApplicationSettingsMobileSettingsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "application_exit_info",
        "mobile_session_replay",
        "network_settings",
        "use_crash_reports",
    )
    application_exit_info = sgqlc.types.Field(
        AgentApplicationSettingsApplicationExitInfoInput,
        graphql_name="applicationExitInfo",
    )

    mobile_session_replay = sgqlc.types.Field(
        AgentApplicationSettingsMobileSessionReplayInput,
        graphql_name="mobileSessionReplay",
    )

    network_settings = sgqlc.types.Field(
        "AgentApplicationSettingsNetworkSettingsInput", graphql_name="networkSettings"
    )

    use_crash_reports = sgqlc.types.Field(Boolean, graphql_name="useCrashReports")

# %% [markdown]
# #### 21. `AgentApplicationSettingsNetworkAliasesInput`

# %% [markdown]
# Input data that maps hosts to alias names for grouping and identification purposes.
#
#
# Available input fields:
#
#
#
# * `alias` : An alternative name that can be used to reference the hostnames.
# * `hosts` : A list of hostnames to associate with an alias.

# %%
# | export
class AgentApplicationSettingsNetworkAliasesInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("alias", "hosts")
    alias = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="alias")

    hosts = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="hosts",
    )

# %% [markdown]
# #### 22. `AgentApplicationSettingsNetworkSettingsInput`

# %% [markdown]
# Configure mobile network settings here.
#
#
# Available input fields:
#
#
#
# * `aliases` : Input data that maps hosts to alias names for grouping and identification purposes.
# * `filterMode` : Configuration setting to apply either the show or hide strategy for network filtering.
# * `hideList` : A list of hostnames that would be applied to our filter settings when the filterMode is 'HIDE.'
# * `ignoredStatusCodeRules` : Input data that maps ignore status codes associated with different hosts.
# * `showList` : A list of hostnames that would be applied to our filter settings when the filterMode is 'SHOW.'

# %%
# | export
class AgentApplicationSettingsNetworkSettingsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aliases",
        "filter_mode",
        "hide_list",
        "ignored_status_code_rules",
        "show_list",
    )
    aliases = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AgentApplicationSettingsNetworkAliasesInput)
        ),
        graphql_name="aliases",
    )

    filter_mode = sgqlc.types.Field(
        AgentApplicationSettingsNetworkFilterMode, graphql_name="filterMode"
    )

    hide_list = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="hideList"
    )

    ignored_status_code_rules = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AgentApplicationSettingsIgnoredStatusCodeRuleInput)
        ),
        graphql_name="ignoredStatusCodeRules",
    )

    show_list = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="showList"
    )

# %% [markdown]
# #### 23. `AgentApplicationSettingsSessionReplayInput`

# %% [markdown]
# Session Replay configuration.
#
#
# Available input fields:
#
#
#
# * `autoStart` : When true, Session Replay will activate normally (this is the default). If set to false, Session Replay will not record automatically, but the agent will allow recording to be turned on via it's API. Please see [here](https://docs.newrelic.com/docs/browser/new-relic-browser/browser-apis/start/) for more details.
# * `blockSelector` : String to configure which selector should be blocked
# * `collectFonts` : Indicates whether the agent will serialize fonts for collection without public asset url.
# * `enabled` : Session Replay enabled.
# * `errorSamplingRate` : Percentage from 0-10 specifying how many of all user sessions that contain errors should be recorded.
# * `fixStylesheets` : Agent session replay asset fetching.
# * `inlineImages` : Indicates whether the agent will serialize images for collection without public asset url
# * `inlineStylesheet` : Indicates whether the agent will serialize css for collection without public asset url.
# * `maskAllInputs` : Mask all input content as *
# * `maskInputOptions` : Mask specific kinds of input options as *.
# * `maskTextSelector` : String to configure which selector should be masked.
# * `preload` : This setting in Session Replay allows users to capture replays of the initial page load for enhanced analysis when using automatic start.
# * `samplingRate` : Percentage from 0-10 specifying how many of all user sessions should be recorded.

# %%
# | export
class AgentApplicationSettingsSessionReplayInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "auto_start",
        "block_selector",
        "collect_fonts",
        "enabled",
        "error_sampling_rate",
        "fix_stylesheets",
        "inline_images",
        "inline_stylesheet",
        "mask_all_inputs",
        "mask_input_options",
        "mask_text_selector",
        "preload",
        "sampling_rate",
    )
    auto_start = sgqlc.types.Field(Boolean, graphql_name="autoStart")

    block_selector = sgqlc.types.Field(String, graphql_name="blockSelector")

    collect_fonts = sgqlc.types.Field(Boolean, graphql_name="collectFonts")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    error_sampling_rate = sgqlc.types.Field(Float, graphql_name="errorSamplingRate")

    fix_stylesheets = sgqlc.types.Field(Boolean, graphql_name="fixStylesheets")

    inline_images = sgqlc.types.Field(Boolean, graphql_name="inlineImages")

    inline_stylesheet = sgqlc.types.Field(Boolean, graphql_name="inlineStylesheet")

    mask_all_inputs = sgqlc.types.Field(Boolean, graphql_name="maskAllInputs")

    mask_input_options = sgqlc.types.Field(
        AgentApplicationSettingsMaskInputOptionsInput, graphql_name="maskInputOptions"
    )

    mask_text_selector = sgqlc.types.Field(String, graphql_name="maskTextSelector")

    preload = sgqlc.types.Field(Boolean, graphql_name="preload")

    sampling_rate = sgqlc.types.Field(Float, graphql_name="samplingRate")

# %% [markdown]
# #### 24. `AgentApplicationSettingsSessionTraceInput`

# %% [markdown]
# Session Trace configuration
#
#
# Available input fields:
#
#
#
# * `enabled` : Session Trace enabled.
# * `errorSamplingRate` : Percentage from 0-100 specifying how many of all user sessions that contain errors should be recorded.
# * `mode` : Default (fixed_rate) or custom (probabilistic) option used to collect session traces.
# * `samplingRate` : Percentage from 0-100 specifying how many of all user sessions should be recorded.

# %%
# | export
class AgentApplicationSettingsSessionTraceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled", "error_sampling_rate", "mode", "sampling_rate")
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    error_sampling_rate = sgqlc.types.Field(Float, graphql_name="errorSamplingRate")

    mode = sgqlc.types.Field(
        AgentApplicationSettingsSessionTraceModeInput, graphql_name="mode"
    )

    sampling_rate = sgqlc.types.Field(Float, graphql_name="samplingRate")

# %% [markdown]
# #### 25. `AgentApplicationSettingsSlowSqlInput`

# %% [markdown]
# In APM, when transaction traces are collected, there may be additional Slow query data available.
#
#
# Available input fields:
#
#
#
# * `enabled` : Whether or not slow_sql is enabled.

# %%
# | export
class AgentApplicationSettingsSlowSqlInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled",)
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

# %% [markdown]
# #### 26. `AgentApplicationSettingsThreadProfilerInput`

# %% [markdown]
# Settings for the thread profiler.
#
#
# Available input fields:
#
#
#
# * `enabled` : Is thread profiling enabled for this application?

# %%
# | export
class AgentApplicationSettingsThreadProfilerInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled",)
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

# %% [markdown]
# #### 27. `AgentApplicationSettingsTracerTypeInput`

# %% [markdown]
# Input object for setting the type of tracing performed.
#
#
# Available input fields:
#
#
#
# * `value` : The type of tracing being done.

# %%
# | export
class AgentApplicationSettingsTracerTypeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("value",)
    value = sgqlc.types.Field(AgentApplicationSettingsTracer, graphql_name="value")

# %% [markdown]
# #### 28. `AgentApplicationSettingsTransactionTracerInput`

# %% [markdown]
# Fields related to transaction traces and data collection for traces.
#
#
# Available input fields:
#
#
#
# * `captureMemcacheKeys` : DEPRECATED: Please use capture_memcache_keys on parent type
# * `enabled` : If true, this enables the transaction tracer feature, enabling collection of transaction traces.
# * `explainEnabled` : If true, enables the collection of explain plans in transaction traces. This setting will also apply to explain plans in slow SQL traces if slow_sql.explain_enabled is not set separately.
# * `explainThresholdType` : Relevant only when explain_enabled is true. Can be set to automatic configuration (APDEX_F) or manual (see explainThresholdValue).
# * `explainThresholdValue` : Threshold (in seconds) above which the agent will collect explain plans. Relevant only when explain_enabled is true and explainThresholdType is set to VALUE.
# * `logSql` : Set to true to enable logging of queries to the agent log file instead of uploading to New Relic. Queries are logged using the record_sql mode.
# * `recordSql` : Obfuscation level for SQL queries reported in transaction trace nodes.
# * `stackTraceThreshold` : Specify a threshold in seconds. The agent includes stack traces in transaction trace nodes when the stack trace duration exceeds this threshold.
# * `transactionThresholdType` : Relevant only when transaction tracer is enabled. Can be set to automatic configuration (APDEX_F) or manual (see TransactionThresholdValue).
# * `transactionThresholdValue` : Threshold (in seconds) that transactions with a duration longer than this threshold are eligible for transaction traces.  Relevant only when transaction tracer is enabled and transaction_threshold_type is set to VALUE.

# %%
# | export
class AgentApplicationSettingsTransactionTracerInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "capture_memcache_keys",
        "enabled",
        "explain_enabled",
        "explain_threshold_type",
        "explain_threshold_value",
        "log_sql",
        "record_sql",
        "stack_trace_threshold",
        "transaction_threshold_type",
        "transaction_threshold_value",
    )
    capture_memcache_keys = sgqlc.types.Field(
        Boolean, graphql_name="captureMemcacheKeys"
    )

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    explain_enabled = sgqlc.types.Field(Boolean, graphql_name="explainEnabled")

    explain_threshold_type = sgqlc.types.Field(
        AgentApplicationSettingsThresholdTypeEnum, graphql_name="explainThresholdType"
    )

    explain_threshold_value = sgqlc.types.Field(
        Seconds, graphql_name="explainThresholdValue"
    )

    log_sql = sgqlc.types.Field(Boolean, graphql_name="logSql")

    record_sql = sgqlc.types.Field(
        AgentApplicationSettingsRecordSqlEnum, graphql_name="recordSql"
    )

    stack_trace_threshold = sgqlc.types.Field(
        Seconds, graphql_name="stackTraceThreshold"
    )

    transaction_threshold_type = sgqlc.types.Field(
        AgentApplicationSettingsThresholdTypeEnum,
        graphql_name="transactionThresholdType",
    )

    transaction_threshold_value = sgqlc.types.Field(
        Seconds, graphql_name="transactionThresholdValue"
    )

# %% [markdown]
# #### 29. `AgentApplicationSettingsUpdateInput`

# %% [markdown]
# The new settings to use - leave blank any settings you do not wish to modify.
#
# While all settings can be specified here, some may not affect your installed agents, depending on the language agent and the current version installed. Note: not all settings of your agent are available to be set server-side.
#
# Please see docs.newrelic.com for more information about the capabilities of individual agents.
#
# [Go agent configuration](https://docs.newrelic.com/docs/agents/go-agent/configuration/go-agent-configuration/)
#
# [Java agent configuration](https://docs.newrelic.com/docs/agents/java-agent/configuration/java-agent-configuration-config-file/)
#
# [.Net agent configuration](https://docs.newrelic.com/docs/agents/net-agent/configuration/net-agent-configuration/)
#
# [nodejs agent configuration](https://docs.newrelic.com/docs/agents/nodejs-agent/installation-configuration/nodejs-agent-configuration/)
#
# [PHP agent configuration](https://docs.newrelic.com/docs/agents/php-agent/configuration/php-agent-configuration/)
#
# [Python agent configuration](https://docs.newrelic.com/docs/agents/python-agent/configuration/python-agent-configuration/)
#
# [Ruby agent configuration](https://docs.newrelic.com/docs/agents/ruby-agent/configuration/ruby-agent-configuration/)
#
#
# Available input fields:
#
#
#
# * `alias` : The new name for the application.
# * `apmConfig` : Provides fields to set general APM application settings.
# * `browserConfig` : Provides fields to set general browser application settings.
# * `browserConsentMode` : Browser consent mode configuration for privacy compliance and consent management platform integration.
# * `browserMonitoring` : Provides fields to set browser monitoring application settings.
# * `browserPerformance` : Browser Performance configuration.
# * `captureMemcacheKeys` : Enable or disable the capture of memcache keys
# * `errorCollector` : Captures information about uncaught exceptions and sends them to New Relic for viewing.
# * `jfr` : In the Java Agent (v8.0.0 or later), it can collect additional data with the Java Flight Recorder enabled.
# * `mobileSettings` : Input object for mobile settings.
# * `name` : DEPRECATED: Use `alias` to set a new name for the application.
# * `sessionReplay` : Fields for session replay config
# * `sessionTrace` : Session Trace configuration.
# * `slowSql` : In APM, when transaction traces are collected, there may be additional Slow query data available.
# * `threadProfiler` : Settings for the thread profiler.
# * `tracerType` : Input object for setting the type of tracing performed.
# * `transactionTracer` : Transaction tracer settings related to APM applications.

# %%
# | export
class AgentApplicationSettingsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "alias",
        "apm_config",
        "browser_config",
        "browser_consent_mode",
        "browser_monitoring",
        "browser_performance",
        "capture_memcache_keys",
        "error_collector",
        "jfr",
        "mobile_settings",
        "name",
        "session_replay",
        "session_trace",
        "slow_sql",
        "thread_profiler",
        "tracer_type",
        "transaction_tracer",
    )
    alias = sgqlc.types.Field(String, graphql_name="alias")

    apm_config = sgqlc.types.Field(
        AgentApplicationSettingsApmConfigInput, graphql_name="apmConfig"
    )

    browser_config = sgqlc.types.Field(
        AgentApplicationSettingsBrowserConfigInput, graphql_name="browserConfig"
    )

    browser_consent_mode = sgqlc.types.Field(
        AgentApplicationSettingsBrowserConsentModeInput,
        graphql_name="browserConsentMode",
    )

    browser_monitoring = sgqlc.types.Field(
        AgentApplicationSettingsBrowserMonitoringInput, graphql_name="browserMonitoring"
    )

    browser_performance = sgqlc.types.Field(
        AgentApplicationSettingsBrowserPerformanceInput,
        graphql_name="browserPerformance",
    )

    capture_memcache_keys = sgqlc.types.Field(
        Boolean, graphql_name="captureMemcacheKeys"
    )

    error_collector = sgqlc.types.Field(
        AgentApplicationSettingsErrorCollectorInput, graphql_name="errorCollector"
    )

    jfr = sgqlc.types.Field(AgentApplicationSettingsJfrInput, graphql_name="jfr")

    mobile_settings = sgqlc.types.Field(
        AgentApplicationSettingsMobileSettingsInput, graphql_name="mobileSettings"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    session_replay = sgqlc.types.Field(
        AgentApplicationSettingsSessionReplayInput, graphql_name="sessionReplay"
    )

    session_trace = sgqlc.types.Field(
        AgentApplicationSettingsSessionTraceInput, graphql_name="sessionTrace"
    )

    slow_sql = sgqlc.types.Field(
        AgentApplicationSettingsSlowSqlInput, graphql_name="slowSql"
    )

    thread_profiler = sgqlc.types.Field(
        AgentApplicationSettingsThreadProfilerInput, graphql_name="threadProfiler"
    )

    tracer_type = sgqlc.types.Field(
        AgentApplicationSettingsTracerTypeInput, graphql_name="tracerType"
    )

    transaction_tracer = sgqlc.types.Field(
        AgentApplicationSettingsTransactionTracerInput, graphql_name="transactionTracer"
    )

# %% [markdown]
# #### 30. `AgentEnvironmentFilter`

# %% [markdown]
# A filter that can be applied to filter results.
#
#
# Available input fields:
#
#
#
# * `contains` : A string to filter results that includes this string anywhere. Case insensitive.
# * `doesNotContain` : A string to filter out results that includes this string anywhere. Case insensitive.
# * `equals` : A string to filter results that are exactly as the string provided. Case sensitive.
# * `startsWith` : A string to filter results that starts with this string. Case insensitive.

# %%
# | export
class AgentEnvironmentFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "does_not_contain", "equals", "starts_with")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    does_not_contain = sgqlc.types.Field(String, graphql_name="doesNotContain")

    equals = sgqlc.types.Field(String, graphql_name="equals")

    starts_with = sgqlc.types.Field(String, graphql_name="startsWith")

# %% [markdown]
# #### 31. `AiDecisionsAllInput`

# %% [markdown]
# Input type for All expression
#
#
# Available input fields:
#
#
#
# * `children` : Children expressions.

# %%
# | export
class AiDecisionsAllInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("children",)
    children = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AiDecisionsRuleExpressionInput"))
        ),
        graphql_name="children",
    )

# %% [markdown]
# #### 32. `AiDecisionsAndInput`

# %% [markdown]
# Input type for And expression
#
#
# Available input fields:
#
#
#
# * `left` : Left child expression.
# * `right` : Right child expression.

# %%
# | export
class AiDecisionsAndInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsRuleExpressionInput"), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsRuleExpressionInput"), graphql_name="right"
    )

# %% [markdown]
# #### 33. `AiDecisionsAttributeExistsInput`

# %% [markdown]
# Input type for AttributeExists expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsAttributeExistsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident",)
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

# %% [markdown]
# #### 34. `AiDecisionsCategoricalClusteringInput`

# %% [markdown]
# Input type for CategoricalClustering expression
#
#
# Available input fields:
#
#
#
# * `threshold` : Threshold for comparison.

# %%
# | export
class AiDecisionsCategoricalClusteringInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("threshold",)
    threshold = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="threshold")

# %% [markdown]
# #### 35. `AiDecisionsFixedContainsInput`

# %% [markdown]
# Input type for FixedContains expression
#
#
# Available input fields:
#
#
#
# * `container` : Incident selector to be used in comparison.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedContainsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("container", "value")
    container = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="container"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 36. `AiDecisionsFixedCosineDistanceInput`

# %% [markdown]
# Input type for FixedCosineDistance expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `maxDistance` : Maximum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedCosineDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "max_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 37. `AiDecisionsFixedEndsWithInput`

# %% [markdown]
# Input type for FixedEndsWith expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedEndsWithInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 38. `AiDecisionsFixedEqualInput`

# %% [markdown]
# Input type for FixedEqual expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 39. `AiDecisionsFixedFuzzyScoreInput`

# %% [markdown]
# Input type for FixedFuzzyScore expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minDistance` : Minimum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedFuzzyScoreInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="minDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 40. `AiDecisionsFixedFuzzyWuzzyAdaptiveRatioInput`

# %% [markdown]
# Input type for FixedFuzzyWuzzyAdaptiveRatio expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedFuzzyWuzzyAdaptiveRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_similarity", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 41. `AiDecisionsFixedFuzzyWuzzyPartialRatioInput`

# %% [markdown]
# Input type for FixedFuzzyWuzzyPartialRatio expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedFuzzyWuzzyPartialRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_similarity", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 42. `AiDecisionsFixedFuzzyWuzzyRatioInput`

# %% [markdown]
# Input type for FixedFuzzyWuzzyRatio expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedFuzzyWuzzyRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_similarity", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 43. `AiDecisionsFixedFuzzyWuzzyTokenSetRatioInput`

# %% [markdown]
# Input type for FixedFuzzyWuzzyTokenSetRatio expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedFuzzyWuzzyTokenSetRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_similarity", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 44. `AiDecisionsFixedGreaterThanInput`

# %% [markdown]
# Input type for FixedGreaterThan expression
#
#
# Available input fields:
#
#
#
# * `compared` : Value to be used in comparison.
# * `incident` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsFixedGreaterThanInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("compared", "incident")
    compared = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="compared")

    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

# %% [markdown]
# #### 45. `AiDecisionsFixedGreaterThanOrEqualInput`

# %% [markdown]
# Input type for FixedGreaterThanOrEqual expression
#
#
# Available input fields:
#
#
#
# * `compared` : Value to be used in comparison.
# * `incident` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsFixedGreaterThanOrEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("compared", "incident")
    compared = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="compared")

    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

# %% [markdown]
# #### 46. `AiDecisionsFixedHammingDistanceInput`

# %% [markdown]
# Input type for FixedHammingDistance expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `maxDistance` : Maximum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedHammingDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "max_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="maxDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 47. `AiDecisionsFixedJaccardDistanceInput`

# %% [markdown]
# Input type for FixedJaccardDistance expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `maxDistance` : Maximum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedJaccardDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "max_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 48. `AiDecisionsFixedJaroWinklerInput`

# %% [markdown]
# Input type for FixedJaroWinkler expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minDistance` : Minimum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedJaroWinklerInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 49. `AiDecisionsFixedLessThanInput`

# %% [markdown]
# Input type for FixedLessThan expression
#
#
# Available input fields:
#
#
#
# * `compared` : Value to be used in comparison.
# * `incident` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsFixedLessThanInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("compared", "incident")
    compared = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="compared")

    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

# %% [markdown]
# #### 50. `AiDecisionsFixedLessThanOrEqualInput`

# %% [markdown]
# Input type for FixedLessThanOrEqual expression
#
#
# Available input fields:
#
#
#
# * `compared` : Value to be used in comparison.
# * `incident` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsFixedLessThanOrEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("compared", "incident")
    compared = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="compared")

    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

# %% [markdown]
# #### 51. `AiDecisionsFixedLevenshteinInput`

# %% [markdown]
# Input type for FixedLevenshtein expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `maxDistance` : Maximum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedLevenshteinInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "max_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="maxDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 52. `AiDecisionsFixedLongestCommonSubsequenceDistanceInput`

# %% [markdown]
# Input type for FixedLongestCommonSubsequenceDistance expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `maxDistance` : Maximum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedLongestCommonSubsequenceDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "max_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 53. `AiDecisionsFixedNumericalEqualInput`

# %% [markdown]
# Input type for FixedNumericalEqual expression
#
#
# Available input fields:
#
#
#
# * `compared` : Value to be used in comparison.
# * `incident` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsFixedNumericalEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("compared", "incident")
    compared = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="compared")

    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

# %% [markdown]
# #### 54. `AiDecisionsFixedRegularExpressionInput`

# %% [markdown]
# Input type for FixedRegularExpression expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedRegularExpressionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 55. `AiDecisionsFixedSoundExInput`

# %% [markdown]
# Input type for FixedSoundEx expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `minDistance` : Minimum distance threshold.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedSoundExInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "min_distance", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    min_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="minDistance"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 56. `AiDecisionsFixedStartsWithInput`

# %% [markdown]
# Input type for FixedStartsWith expression
#
#
# Available input fields:
#
#
#
# * `incident` : Incident selector to be used in comparison.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsFixedStartsWithInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident", "value")
    incident = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsIncidentObjectInput"), graphql_name="incident"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 57. `AiDecisionsIncidentObjectInput`

# %% [markdown]
# Represents an attribute of an incident.
#
#
# Available input fields:
#
#
#
# * `attribute` : Attribute to process of selected incident.
# * `select` : Incident to select.

# %%
# | export
class AiDecisionsIncidentObjectInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute", "select")
    attribute = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="attribute"
    )

    select = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentSelect), graphql_name="select"
    )

# %% [markdown]
# #### 58. `AiDecisionsNotInput`

# %% [markdown]
# Input type for Not expression
#
#
# Available input fields:
#
#
#
# * `child` : Child expression.

# %%
# | export
class AiDecisionsNotInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("child",)
    child = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsRuleExpressionInput"), graphql_name="child"
    )

# %% [markdown]
# #### 59. `AiDecisionsOneInput`

# %% [markdown]
# Input type for One expression
#
#
# Available input fields:
#
#
#
# * `children` : Children expressions.

# %%
# | export
class AiDecisionsOneInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("children",)
    children = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AiDecisionsRuleExpressionInput"))
        ),
        graphql_name="children",
    )

# %% [markdown]
# #### 60. `AiDecisionsOrInput`

# %% [markdown]
# Input type for Or expression
#
#
# Available input fields:
#
#
#
# * `left` : Left child expression.
# * `right` : Right child expression.

# %%
# | export
class AiDecisionsOrInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsRuleExpressionInput"), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsRuleExpressionInput"), graphql_name="right"
    )

# %% [markdown]
# #### 61. `AiDecisionsOverrideConfigurationInput`

# %% [markdown]
# Configuration for overriding properties of issues created by merges.
#
#
# Available input fields:
#
#
#
# * `description` : Description merged issues should take.
# * `priority` : Priority merged issues should take.
# * `title` : Title merged issues should take.

# %%
# | export
class AiDecisionsOverrideConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "priority", "title")
    description = sgqlc.types.Field(String, graphql_name="description")

    priority = sgqlc.types.Field(AiDecisionsIssuePriority, graphql_name="priority")

    title = sgqlc.types.Field(String, graphql_name="title")

# %% [markdown]
# #### 62. `AiDecisionsRelativeCommonPrefixInput`

# %% [markdown]
# Input type for RelativeCommonPrefix expression
#
#
# Available input fields:
#
#
#
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsRelativeCommonPrefixInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("value",)
    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 63. `AiDecisionsRelativeContainsInput`

# %% [markdown]
# Input type for RelativeContains expression
#
#
# Available input fields:
#
#
#
# * `contained` : Incident selector to be used in comparison.
# * `container` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsRelativeContainsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contained", "container")
    contained = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="contained"
    )

    container = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="container"
    )

# %% [markdown]
# #### 64. `AiDecisionsRelativeCosineDistanceInput`

# %% [markdown]
# Input type for RelativeCosineDistance expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `maxDistance` : Maximum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeCosineDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "max_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 65. `AiDecisionsRelativeEndsWithInput`

# %% [markdown]
# Input type for RelativeEndsWith expression
#
#
# Available input fields:
#
#
#
# * `contained` : Incident selector to be used in comparison.
# * `container` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsRelativeEndsWithInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contained", "container")
    contained = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="contained"
    )

    container = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="container"
    )

# %% [markdown]
# #### 66. `AiDecisionsRelativeEqualInput`

# %% [markdown]
# Input type for RelativeEqual expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 67. `AiDecisionsRelativeFuzzyScoreInput`

# %% [markdown]
# Input type for RelativeFuzzyScore expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minDistance` : Minimum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeFuzzyScoreInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="minDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 68. `AiDecisionsRelativeFuzzyWuzzyAdaptiveRatioInput`

# %% [markdown]
# Input type for RelativeFuzzyWuzzyAdaptiveRatio expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeFuzzyWuzzyAdaptiveRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_similarity", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 69. `AiDecisionsRelativeFuzzyWuzzyPartialRatioInput`

# %% [markdown]
# Input type for RelativeFuzzyWuzzyPartialRatio expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeFuzzyWuzzyPartialRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_similarity", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 70. `AiDecisionsRelativeFuzzyWuzzyRatioInput`

# %% [markdown]
# Input type for RelativeFuzzyWuzzyRatio expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeFuzzyWuzzyRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_similarity", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 71. `AiDecisionsRelativeFuzzyWuzzyTokenSetRatioInput`

# %% [markdown]
# Input type for RelativeFuzzyWuzzyTokenSetRatio expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minSimilarity` : Minimum similarity threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeFuzzyWuzzyTokenSetRatioInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_similarity", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_similarity = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minSimilarity"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 72. `AiDecisionsRelativeGreaterThanInput`

# %% [markdown]
# Input type for RelativeGreaterThan expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeGreaterThanInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 73. `AiDecisionsRelativeGreaterThanOrEqualInput`

# %% [markdown]
# Input type for RelativeGreaterThanOrEqual expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeGreaterThanOrEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 74. `AiDecisionsRelativeHammingDistanceInput`

# %% [markdown]
# Input type for RelativeHammingDistance expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `maxDistance` : Maximum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeHammingDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "max_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="maxDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 75. `AiDecisionsRelativeJaccardDistanceInput`

# %% [markdown]
# Input type for RelativeJaccardDistance expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `maxDistance` : Maximum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeJaccardDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "max_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 76. `AiDecisionsRelativeJaroWinklerInput`

# %% [markdown]
# Input type for RelativeJaroWinkler expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minDistance` : Minimum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeJaroWinklerInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="minDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 77. `AiDecisionsRelativeLessThanInput`

# %% [markdown]
# Input type for RelativeLessThan expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeLessThanInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 78. `AiDecisionsRelativeLessThanOrEqualInput`

# %% [markdown]
# Input type for RelativeLessThanOrEqual expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeLessThanOrEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 79. `AiDecisionsRelativeLevenshteinInput`

# %% [markdown]
# Input type for RelativeLevenshtein expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `maxDistance` : Maximum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeLevenshteinInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "max_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="maxDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 80. `AiDecisionsRelativeLongestCommonSubsequenceDistanceInput`

# %% [markdown]
# Input type for RelativeLongestCommonSubsequenceDistance expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `maxDistance` : Maximum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeLongestCommonSubsequenceDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "max_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 81. `AiDecisionsRelativeNumericalEqualInput`

# %% [markdown]
# Input type for RelativeNumericalEqual expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeNumericalEqualInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 82. `AiDecisionsRelativeRegularExpressionInput`

# %% [markdown]
# Input type for RelativeRegularExpression expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `right` : Right operand of comparison.
# * `value` : Value to be used in comparison.

# %%
# | export
class AiDecisionsRelativeRegularExpressionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "right", "value")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 83. `AiDecisionsRelativeSoundExInput`

# %% [markdown]
# Input type for RelativeSoundEx expression
#
#
# Available input fields:
#
#
#
# * `left` : Left operand of comparison.
# * `minDistance` : Minimum distance threshold.
# * `right` : Right operand of comparison.

# %%
# | export
class AiDecisionsRelativeSoundExInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("left", "min_distance", "right")
    left = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="left"
    )

    min_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="minDistance"
    )

    right = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="right"
    )

# %% [markdown]
# #### 84. `AiDecisionsRelativeStartsWithInput`

# %% [markdown]
# Input type for RelativeStartsWith expression
#
#
# Available input fields:
#
#
#
# * `contained` : Incident selector to be used in comparison.
# * `container` : Incident selector to be used in comparison.

# %%
# | export
class AiDecisionsRelativeStartsWithInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contained", "container")
    contained = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="contained"
    )

    container = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsIncidentObjectInput), graphql_name="container"
    )

# %% [markdown]
# #### 85. `AiDecisionsRelativeTopologicallyDependentInput`

# %% [markdown]
# Input type for RelativeTopologicallyDependent expression
#
#
# Available input fields:
#
#
#
# * `from` : From Vertex Id.
# * `graphId` : Graph Id.
# * `maxHops` : Maximum number of hops
# * `requiredAttributes` : Required Vertex Attributes
# * `requiredClasses` : Required Vertex Classes
# * `to` : To Vertex Id.

# %%
# | export
class AiDecisionsRelativeTopologicallyDependentInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "from_",
        "graph_id",
        "max_hops",
        "required_attributes",
        "required_classes",
        "to",
    )
    from_ = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(ID))),
        graphql_name="from",
    )

    graph_id = sgqlc.types.Field(ID, graphql_name="graphId")

    max_hops = sgqlc.types.Field(Int, graphql_name="maxHops")

    required_attributes = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="requiredAttributes",
    )

    required_classes = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(AiDecisionsVertexClass))
        ),
        graphql_name="requiredClasses",
    )

    to = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(ID))),
        graphql_name="to",
    )

# %% [markdown]
# #### 86. `AiDecisionsRuleBlueprint`

# %% [markdown]
# Blueprint for rule creation.
#
#
# Available input fields:
#
#
#
# * `correlationWindowLength` : Length of the window in which incidents are compared.
# * `creator` : Creator of rule.
# * `description` : Description of rule.
# * `minCorrelationThreshold` : Number of correlations within a window required to merge issues.
# * `name` : Name of rule.
# * `overrideConfiguration` : Configuration to allow rule to override issue properties.
# * `ruleExpression` : Expression to use to compare incidents.
# * `ruleType` : Type of rule.
# * `source` : Creation source of rule.

# %%
# | export
class AiDecisionsRuleBlueprint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "correlation_window_length",
        "creator",
        "description",
        "min_correlation_threshold",
        "name",
        "override_configuration",
        "rule_expression",
        "rule_type",
        "source",
    )
    correlation_window_length = sgqlc.types.Field(
        Milliseconds, graphql_name="correlationWindowLength"
    )

    creator = sgqlc.types.Field(String, graphql_name="creator")

    description = sgqlc.types.Field(String, graphql_name="description")

    min_correlation_threshold = sgqlc.types.Field(
        Int, graphql_name="minCorrelationThreshold"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    override_configuration = sgqlc.types.Field(
        AiDecisionsOverrideConfigurationInput, graphql_name="overrideConfiguration"
    )

    rule_expression = sgqlc.types.Field(
        sgqlc.types.non_null("AiDecisionsRuleExpressionInput"),
        graphql_name="ruleExpression",
    )

    rule_type = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsRuleType), graphql_name="ruleType"
    )

    source = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsRuleSource), graphql_name="source"
    )

# %% [markdown]
# #### 87. `AiDecisionsRuleExpressionInput`

# %% [markdown]
# Rule expression input
#
#
# Available input fields:
#
#
#
# * `all` : Input type for All expression
# * `and` : Input type for And expression
# * `attributeExists` : Input type for AttributeExists expression
# * `categoricalClustering` : Input type for CategoricalClustering expression
# * `fixedContains` : Input type for FixedContains expression
# * `fixedCosineDistance` : Input type for FixedCosineDistance expression
# * `fixedEndsWith` : Input type for FixedEndsWith expression
# * `fixedEqual` : Input type for FixedEqual expression
# * `fixedFuzzyScore` : Input type for FixedFuzzyScore expression
# * `fixedFuzzyWuzzyAdaptiveRatio` : Input type for FixedFuzzyWuzzyAdaptiveRatio expression
# * `fixedFuzzyWuzzyPartialRatio` : Input type for FixedFuzzyWuzzyPartialRatio expression
# * `fixedFuzzyWuzzyRatio` : Input type for FixedFuzzyWuzzyRatio expression
# * `fixedFuzzyWuzzyTokenSetRatio` : Input type for FixedFuzzyWuzzyTokenSetRatio expression
# * `fixedGreaterThan` : Input type for FixedGreaterThan expression
# * `fixedGreaterThanOrEqual` : Input type for FixedGreaterThanOrEqual expression
# * `fixedHammingDistance` : Input type for FixedHammingDistance expression
# * `fixedJaccardDistance` : Input type for FixedJaccardDistance expression
# * `fixedJaroWinkler` : Input type for FixedJaroWinkler expression
# * `fixedLessThan` : Input type for FixedLessThan expression
# * `fixedLessThanOrEqual` : Input type for FixedLessThanOrEqual expression
# * `fixedLevenshtein` : Input type for FixedLevenshtein expression
# * `fixedLongestCommonSubsequenceDistance` : Input type for FixedLongestCommonSubsequenceDistance expression
# * `fixedNumericalEqual` : Input type for FixedNumericalEqual expression
# * `fixedRegularExpression` : Input type for FixedRegularExpression expression
# * `fixedSoundEx` : Input type for FixedSoundEx expression
# * `fixedStartsWith` : Input type for FixedStartsWith expression
# * `not` : Input type for Not expression
# * `one` : Input type for One expression
# * `or` : Input type for Or expression
# * `relativeCommonPrefix` : Input type for RelativeCommonPrefix expression
# * `relativeContains` : Input type for RelativeContains expression
# * `relativeCosineDistance` : Input type for RelativeCosineDistance expression
# * `relativeEndsWith` : Input type for RelativeEndsWith expression
# * `relativeEqual` : Input type for RelativeEqual expression
# * `relativeFuzzyScore` : Input type for RelativeFuzzyScore expression
# * `relativeFuzzyWuzzyAdaptiveRatio` : Input type for RelativeFuzzyWuzzyAdaptiveRatio expression
# * `relativeFuzzyWuzzyPartialRatio` : Input type for RelativeFuzzyWuzzyPartialRatio expression
# * `relativeFuzzyWuzzyRatio` : Input type for RelativeFuzzyWuzzyRatio expression
# * `relativeFuzzyWuzzyTokenSetRatio` : Input type for RelativeFuzzyWuzzyTokenSetRatio expression
# * `relativeGreaterThan` : Input type for RelativeGreaterThan expression
# * `relativeGreaterThanOrEqual` : Input type for RelativeGreaterThanOrEqual expression
# * `relativeHammingDistance` : Input type for RelativeHammingDistance expression
# * `relativeJaccardDistance` : Input type for RelativeJaccardDistance expression
# * `relativeJaroWinkler` : Input type for RelativeJaroWinkler expression
# * `relativeLessThan` : Input type for RelativeLessThan expression
# * `relativeLessThanOrEqual` : Input type for RelativeLessThanOrEqual expression
# * `relativeLevenshtein` : Input type for RelativeLevenshtein expression
# * `relativeLongestCommonSubsequenceDistance` : Input type for RelativeLongestCommonSubsequenceDistance expression
# * `relativeNumericalEqual` : Input type for RelativeNumericalEqual expression
# * `relativeRegularExpression` : Input type for RelativeRegularExpression expression
# * `relativeSoundEx` : Input type for RelativeSoundEx expression
# * `relativeStartsWith` : Input type for RelativeStartsWith expression
# * `relativeTopologicallyDependent` : Input type for RelativeTopologicallyDependent expression
# * `wholeCosineDistance` : Input type for WholeCosineDistance expression
# * `wholeJaccardSimilarity` : Input type for WholeJaccardSimilarity expression

# %%
# | export
class AiDecisionsRuleExpressionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "all",
        "and_",
        "attribute_exists",
        "categorical_clustering",
        "fixed_contains",
        "fixed_cosine_distance",
        "fixed_ends_with",
        "fixed_equal",
        "fixed_fuzzy_score",
        "fixed_fuzzy_wuzzy_adaptive_ratio",
        "fixed_fuzzy_wuzzy_partial_ratio",
        "fixed_fuzzy_wuzzy_ratio",
        "fixed_fuzzy_wuzzy_token_set_ratio",
        "fixed_greater_than",
        "fixed_greater_than_or_equal",
        "fixed_hamming_distance",
        "fixed_jaccard_distance",
        "fixed_jaro_winkler",
        "fixed_less_than",
        "fixed_less_than_or_equal",
        "fixed_levenshtein",
        "fixed_longest_common_subsequence_distance",
        "fixed_numerical_equal",
        "fixed_regular_expression",
        "fixed_sound_ex",
        "fixed_starts_with",
        "not_",
        "one",
        "or_",
        "relative_common_prefix",
        "relative_contains",
        "relative_cosine_distance",
        "relative_ends_with",
        "relative_equal",
        "relative_fuzzy_score",
        "relative_fuzzy_wuzzy_adaptive_ratio",
        "relative_fuzzy_wuzzy_partial_ratio",
        "relative_fuzzy_wuzzy_ratio",
        "relative_fuzzy_wuzzy_token_set_ratio",
        "relative_greater_than",
        "relative_greater_than_or_equal",
        "relative_hamming_distance",
        "relative_jaccard_distance",
        "relative_jaro_winkler",
        "relative_less_than",
        "relative_less_than_or_equal",
        "relative_levenshtein",
        "relative_longest_common_subsequence_distance",
        "relative_numerical_equal",
        "relative_regular_expression",
        "relative_sound_ex",
        "relative_starts_with",
        "relative_topologically_dependent",
        "whole_cosine_distance",
        "whole_jaccard_similarity",
    )
    all = sgqlc.types.Field(AiDecisionsAllInput, graphql_name="all")

    and_ = sgqlc.types.Field(AiDecisionsAndInput, graphql_name="and")

    attribute_exists = sgqlc.types.Field(
        AiDecisionsAttributeExistsInput, graphql_name="attributeExists"
    )

    categorical_clustering = sgqlc.types.Field(
        AiDecisionsCategoricalClusteringInput, graphql_name="categoricalClustering"
    )

    fixed_contains = sgqlc.types.Field(
        AiDecisionsFixedContainsInput, graphql_name="fixedContains"
    )

    fixed_cosine_distance = sgqlc.types.Field(
        AiDecisionsFixedCosineDistanceInput, graphql_name="fixedCosineDistance"
    )

    fixed_ends_with = sgqlc.types.Field(
        AiDecisionsFixedEndsWithInput, graphql_name="fixedEndsWith"
    )

    fixed_equal = sgqlc.types.Field(
        AiDecisionsFixedEqualInput, graphql_name="fixedEqual"
    )

    fixed_fuzzy_score = sgqlc.types.Field(
        AiDecisionsFixedFuzzyScoreInput, graphql_name="fixedFuzzyScore"
    )

    fixed_fuzzy_wuzzy_adaptive_ratio = sgqlc.types.Field(
        AiDecisionsFixedFuzzyWuzzyAdaptiveRatioInput,
        graphql_name="fixedFuzzyWuzzyAdaptiveRatio",
    )

    fixed_fuzzy_wuzzy_partial_ratio = sgqlc.types.Field(
        AiDecisionsFixedFuzzyWuzzyPartialRatioInput,
        graphql_name="fixedFuzzyWuzzyPartialRatio",
    )

    fixed_fuzzy_wuzzy_ratio = sgqlc.types.Field(
        AiDecisionsFixedFuzzyWuzzyRatioInput, graphql_name="fixedFuzzyWuzzyRatio"
    )

    fixed_fuzzy_wuzzy_token_set_ratio = sgqlc.types.Field(
        AiDecisionsFixedFuzzyWuzzyTokenSetRatioInput,
        graphql_name="fixedFuzzyWuzzyTokenSetRatio",
    )

    fixed_greater_than = sgqlc.types.Field(
        AiDecisionsFixedGreaterThanInput, graphql_name="fixedGreaterThan"
    )

    fixed_greater_than_or_equal = sgqlc.types.Field(
        AiDecisionsFixedGreaterThanOrEqualInput, graphql_name="fixedGreaterThanOrEqual"
    )

    fixed_hamming_distance = sgqlc.types.Field(
        AiDecisionsFixedHammingDistanceInput, graphql_name="fixedHammingDistance"
    )

    fixed_jaccard_distance = sgqlc.types.Field(
        AiDecisionsFixedJaccardDistanceInput, graphql_name="fixedJaccardDistance"
    )

    fixed_jaro_winkler = sgqlc.types.Field(
        AiDecisionsFixedJaroWinklerInput, graphql_name="fixedJaroWinkler"
    )

    fixed_less_than = sgqlc.types.Field(
        AiDecisionsFixedLessThanInput, graphql_name="fixedLessThan"
    )

    fixed_less_than_or_equal = sgqlc.types.Field(
        AiDecisionsFixedLessThanOrEqualInput, graphql_name="fixedLessThanOrEqual"
    )

    fixed_levenshtein = sgqlc.types.Field(
        AiDecisionsFixedLevenshteinInput, graphql_name="fixedLevenshtein"
    )

    fixed_longest_common_subsequence_distance = sgqlc.types.Field(
        AiDecisionsFixedLongestCommonSubsequenceDistanceInput,
        graphql_name="fixedLongestCommonSubsequenceDistance",
    )

    fixed_numerical_equal = sgqlc.types.Field(
        AiDecisionsFixedNumericalEqualInput, graphql_name="fixedNumericalEqual"
    )

    fixed_regular_expression = sgqlc.types.Field(
        AiDecisionsFixedRegularExpressionInput, graphql_name="fixedRegularExpression"
    )

    fixed_sound_ex = sgqlc.types.Field(
        AiDecisionsFixedSoundExInput, graphql_name="fixedSoundEx"
    )

    fixed_starts_with = sgqlc.types.Field(
        AiDecisionsFixedStartsWithInput, graphql_name="fixedStartsWith"
    )

    not_ = sgqlc.types.Field(AiDecisionsNotInput, graphql_name="not")

    one = sgqlc.types.Field(AiDecisionsOneInput, graphql_name="one")

    or_ = sgqlc.types.Field(AiDecisionsOrInput, graphql_name="or")

    relative_common_prefix = sgqlc.types.Field(
        AiDecisionsRelativeCommonPrefixInput, graphql_name="relativeCommonPrefix"
    )

    relative_contains = sgqlc.types.Field(
        AiDecisionsRelativeContainsInput, graphql_name="relativeContains"
    )

    relative_cosine_distance = sgqlc.types.Field(
        AiDecisionsRelativeCosineDistanceInput, graphql_name="relativeCosineDistance"
    )

    relative_ends_with = sgqlc.types.Field(
        AiDecisionsRelativeEndsWithInput, graphql_name="relativeEndsWith"
    )

    relative_equal = sgqlc.types.Field(
        AiDecisionsRelativeEqualInput, graphql_name="relativeEqual"
    )

    relative_fuzzy_score = sgqlc.types.Field(
        AiDecisionsRelativeFuzzyScoreInput, graphql_name="relativeFuzzyScore"
    )

    relative_fuzzy_wuzzy_adaptive_ratio = sgqlc.types.Field(
        AiDecisionsRelativeFuzzyWuzzyAdaptiveRatioInput,
        graphql_name="relativeFuzzyWuzzyAdaptiveRatio",
    )

    relative_fuzzy_wuzzy_partial_ratio = sgqlc.types.Field(
        AiDecisionsRelativeFuzzyWuzzyPartialRatioInput,
        graphql_name="relativeFuzzyWuzzyPartialRatio",
    )

    relative_fuzzy_wuzzy_ratio = sgqlc.types.Field(
        AiDecisionsRelativeFuzzyWuzzyRatioInput, graphql_name="relativeFuzzyWuzzyRatio"
    )

    relative_fuzzy_wuzzy_token_set_ratio = sgqlc.types.Field(
        AiDecisionsRelativeFuzzyWuzzyTokenSetRatioInput,
        graphql_name="relativeFuzzyWuzzyTokenSetRatio",
    )

    relative_greater_than = sgqlc.types.Field(
        AiDecisionsRelativeGreaterThanInput, graphql_name="relativeGreaterThan"
    )

    relative_greater_than_or_equal = sgqlc.types.Field(
        AiDecisionsRelativeGreaterThanOrEqualInput,
        graphql_name="relativeGreaterThanOrEqual",
    )

    relative_hamming_distance = sgqlc.types.Field(
        AiDecisionsRelativeHammingDistanceInput, graphql_name="relativeHammingDistance"
    )

    relative_jaccard_distance = sgqlc.types.Field(
        AiDecisionsRelativeJaccardDistanceInput, graphql_name="relativeJaccardDistance"
    )

    relative_jaro_winkler = sgqlc.types.Field(
        AiDecisionsRelativeJaroWinklerInput, graphql_name="relativeJaroWinkler"
    )

    relative_less_than = sgqlc.types.Field(
        AiDecisionsRelativeLessThanInput, graphql_name="relativeLessThan"
    )

    relative_less_than_or_equal = sgqlc.types.Field(
        AiDecisionsRelativeLessThanOrEqualInput, graphql_name="relativeLessThanOrEqual"
    )

    relative_levenshtein = sgqlc.types.Field(
        AiDecisionsRelativeLevenshteinInput, graphql_name="relativeLevenshtein"
    )

    relative_longest_common_subsequence_distance = sgqlc.types.Field(
        AiDecisionsRelativeLongestCommonSubsequenceDistanceInput,
        graphql_name="relativeLongestCommonSubsequenceDistance",
    )

    relative_numerical_equal = sgqlc.types.Field(
        AiDecisionsRelativeNumericalEqualInput, graphql_name="relativeNumericalEqual"
    )

    relative_regular_expression = sgqlc.types.Field(
        AiDecisionsRelativeRegularExpressionInput,
        graphql_name="relativeRegularExpression",
    )

    relative_sound_ex = sgqlc.types.Field(
        AiDecisionsRelativeSoundExInput, graphql_name="relativeSoundEx"
    )

    relative_starts_with = sgqlc.types.Field(
        AiDecisionsRelativeStartsWithInput, graphql_name="relativeStartsWith"
    )

    relative_topologically_dependent = sgqlc.types.Field(
        AiDecisionsRelativeTopologicallyDependentInput,
        graphql_name="relativeTopologicallyDependent",
    )

    whole_cosine_distance = sgqlc.types.Field(
        "AiDecisionsWholeCosineDistanceInput", graphql_name="wholeCosineDistance"
    )

    whole_jaccard_similarity = sgqlc.types.Field(
        "AiDecisionsWholeJaccardSimilarityInput", graphql_name="wholeJaccardSimilarity"
    )

# %% [markdown]
# #### 88. `AiDecisionsSearchBlueprint`

# %% [markdown]
# Blueprint for a search operation
#
#
# Available input fields:
#
#
#
# * `expression` : Expression to use to compare incidents.
# * `limit` : Maximum number of incidents to query for each available incident selector
# * `retentionWindowLength` : Duration to consider resources for.

# %%
# | export
class AiDecisionsSearchBlueprint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("expression", "limit", "retention_window_length")
    expression = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsRuleExpressionInput), graphql_name="expression"
    )

    limit = sgqlc.types.Field(Int, graphql_name="limit")

    retention_window_length = sgqlc.types.Field(
        Milliseconds, graphql_name="retentionWindowLength"
    )

# %% [markdown]
# #### 89. `AiDecisionsSimulationBlueprint`

# %% [markdown]
# Blueprint for simulation creation.
#
#
# Available input fields:
#
#
#
# * `correlationWindowLength` : Length of the window in which incidents are compared.
# * `expression` : Expression to use to compare incidents.
# * `minCorrelationThreshold` : Number of correlated incidents within window required to merge issues.
# * `retentionWindowLength` : Duration to consider resources for.

# %%
# | export
class AiDecisionsSimulationBlueprint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "correlation_window_length",
        "expression",
        "min_correlation_threshold",
        "retention_window_length",
    )
    correlation_window_length = sgqlc.types.Field(
        Milliseconds, graphql_name="correlationWindowLength"
    )

    expression = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsRuleExpressionInput), graphql_name="expression"
    )

    min_correlation_threshold = sgqlc.types.Field(
        Int, graphql_name="minCorrelationThreshold"
    )

    retention_window_length = sgqlc.types.Field(
        Milliseconds, graphql_name="retentionWindowLength"
    )

# %% [markdown]
# #### 90. `AiDecisionsSuggestionBlueprint`

# %% [markdown]
# Blueprint for suggestion creation.
#
#
# Available input fields:
#
#
#
# * `correlationWindowLength` : Length of the window in which incidents are compared.
# * `description` : Description of suggestion.
# * `hash` : Hash of suggestion.
# * `minCorrelationThreshold` : Number of correlations within a window required to merge issues.
# * `name` : Name of suggestion.
# * `overrideConfiguration` : Configuration to allow rule to override issue properties.
# * `ruleExpression` : Expression to use to compare incidents.
# * `suggester` : Service/user that created this suggestion.
# * `support` : Support for suggestion.

# %%
# | export
class AiDecisionsSuggestionBlueprint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "correlation_window_length",
        "description",
        "hash",
        "min_correlation_threshold",
        "name",
        "override_configuration",
        "rule_expression",
        "suggester",
        "support",
    )
    correlation_window_length = sgqlc.types.Field(
        Milliseconds, graphql_name="correlationWindowLength"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    hash = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="hash")

    min_correlation_threshold = sgqlc.types.Field(
        Int, graphql_name="minCorrelationThreshold"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    override_configuration = sgqlc.types.Field(
        AiDecisionsOverrideConfigurationInput, graphql_name="overrideConfiguration"
    )

    rule_expression = sgqlc.types.Field(
        sgqlc.types.non_null(AiDecisionsRuleExpressionInput),
        graphql_name="ruleExpression",
    )

    suggester = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="suggester"
    )

    support = sgqlc.types.Field(String, graphql_name="support")

# %% [markdown]
# #### 91. `AiDecisionsWholeCosineDistanceInput`

# %% [markdown]
# Input type for WholeCosineDistance expression
#
#
# Available input fields:
#
#
#
# * `maxDistance` : Maximum distance threshold.

# %%
# | export
class AiDecisionsWholeCosineDistanceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("max_distance",)
    max_distance = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="maxDistance"
    )

# %% [markdown]
# #### 92. `AiDecisionsWholeJaccardSimilarityInput`

# %% [markdown]
# Input type for WholeJaccardSimilarity expression
#
#
# Available input fields:
#
#
#
# * `threshold` : Threshold for comparison.

# %%
# | export
class AiDecisionsWholeJaccardSimilarityInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("threshold",)
    threshold = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="threshold")

# %% [markdown]
# #### 93. `AiIssuesFilterIncidents`

# %% [markdown]
# Filter incidents
#
#
# Available input fields:
#
#
#
# * `entityGuids` : entityGuids
# * `entityTypes` : entityTypes
# * `ids` : ids
# * `priority` : priority
# * `states` : states

# %%
# | export
class AiIssuesFilterIncidents(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_guids", "entity_types", "ids", "priority", "states")
    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="entityTypes"
    )

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    priority = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="priority"
    )

    states = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiIssuesIncidentState)),
        graphql_name="states",
    )

# %% [markdown]
# #### 94. `AiIssuesFilterIncidentsEvents`

# %% [markdown]
# Filter incidents events
#
#
# Available input fields:
#
#
#
# * `entityGuids` : entityGuids
# * `entityTypes` : entityTypes
# * `ids` : ids

# %%
# | export
class AiIssuesFilterIncidentsEvents(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_guids", "entity_types", "ids")
    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="entityTypes"
    )

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

# %% [markdown]
# #### 95. `AiIssuesFilterIssues`

# %% [markdown]
# Filter issues
#
#
# Available input fields:
#
#
#
# * `conditionIds` : A list of condition ids associated with an issue.
# * `contains` : A string to filter results that includes this string on key issue attributes (examples: condition, entity, ...). Case sensitive.
# * `entityGuids` : Entity guids associated with an issue.
# * `entityTypes` : Entity types associated with an issue.
# * `ids` : A list of unique issue identifiers.
# * `isAcknowledged` : For acknowledged issues
# * `isCorrelated` : For correlated issues
# * `mutingStates` : Filtering for muting states
# * `policyIds` : A list of policy ids associated with an issue.
# * `priority` : A list of priorities associated with an issue. Can be: 'CRITICAL', 'HIGH', 'MEDIUM' or 'LOW'
# * `sources` : A list of sources associated with an issue.
# Sources can be:
# - 'newrelic' (indicating data originating from the NewRelic platform)
# - 'rest' (indicating data originating from external sources via api)
# * `states` : A list of states associated with an issue.

# %%
# | export
class AiIssuesFilterIssues(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "condition_ids",
        "contains",
        "entity_guids",
        "entity_types",
        "ids",
        "is_acknowledged",
        "is_correlated",
        "muting_states",
        "policy_ids",
        "priority",
        "sources",
        "states",
    )
    condition_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="conditionIds"
    )

    contains = sgqlc.types.Field(String, graphql_name="contains")

    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="entityTypes"
    )

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    is_acknowledged = sgqlc.types.Field(Boolean, graphql_name="isAcknowledged")

    is_correlated = sgqlc.types.Field(Boolean, graphql_name="isCorrelated")

    muting_states = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiIssuesIssueMutingState)),
        graphql_name="mutingStates",
    )

    policy_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="policyIds"
    )

    priority = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="priority"
    )

    sources = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="sources"
    )

    states = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiIssuesIssueState)),
        graphql_name="states",
    )

# %% [markdown]
# #### 96. `AiIssuesFilterIssuesEvents`

# %% [markdown]
# Filter issues events
#
#
# Available input fields:
#
#
#
# * `entityGuids` : entityGuids
# * `entityTypes` : entityTypes
# * `ids` : ids
# * `states` : A list of states associated with an issue.

# %%
# | export
class AiIssuesFilterIssuesEvents(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_guids", "entity_types", "ids", "states")
    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="entityTypes"
    )

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    states = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiIssuesIssueState)),
        graphql_name="states",
    )

# %% [markdown]
# #### 97. `AiIssuesGracePeriodConfigurationInput`

# %% [markdown]
# Grace periods for issue to be activated per priority
#
#
# Available input fields:
#
#
#
# * `critical` : critical
# * `high` : high
# * `low` : low
# * `medium` : medium

# %%
# | export
class AiIssuesGracePeriodConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("critical", "high", "low", "medium")
    critical = sgqlc.types.Field(sgqlc.types.non_null(Seconds), graphql_name="critical")

    high = sgqlc.types.Field(sgqlc.types.non_null(Seconds), graphql_name="high")

    low = sgqlc.types.Field(sgqlc.types.non_null(Seconds), graphql_name="low")

    medium = sgqlc.types.Field(sgqlc.types.non_null(Seconds), graphql_name="medium")

# %% [markdown]
# #### 98. `AiNotificationsBasicAuthInput`

# %% [markdown]
# Basic auth input object
#
#
# Available input fields:
#
#
#
# * `password` : password
# * `user` : user

# %%
# | export
class AiNotificationsBasicAuthInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("password", "user")
    password = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="password"
    )

    user = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="user")

# %% [markdown]
# #### 99. `AiNotificationsChannelFilter`

# %% [markdown]
# Filter channel object
#
#
# Available input fields:
#
#
#
# * `active` : active
# * `destinationId` : destinationId
# * `id` : id
# * `ids` : ids
# * `name` : name
# * `product` : product
# * `property` : property
# * `statuses` : statuses
# * `type` : type

# %%
# | export
class AiNotificationsChannelFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "active",
        "destination_id",
        "id",
        "ids",
        "name",
        "product",
        "property",
        "statuses",
        "type",
    )
    active = sgqlc.types.Field(Boolean, graphql_name="active")

    destination_id = sgqlc.types.Field(ID, graphql_name="destinationId")

    id = sgqlc.types.Field(ID, graphql_name="id")

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    product = sgqlc.types.Field(AiNotificationsProduct, graphql_name="product")

    property = sgqlc.types.Field(
        "AiNotificationsPropertyFilter", graphql_name="property"
    )

    statuses = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiNotificationsChannelStatus)),
        graphql_name="statuses",
    )

    type = sgqlc.types.Field(AiNotificationsChannelType, graphql_name="type")

# %% [markdown]
# #### 100. `AiNotificationsChannelInput`

# %% [markdown]
# Channel input object
#
#
# Available input fields:
#
#
#
# * `destinationId` : destinationId
# * `name` : name
# * `product` : product
# * `properties` : properties
# * `type` : type

# %%
# | export
class AiNotificationsChannelInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("destination_id", "name", "product", "properties", "type")
    destination_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="destinationId"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    product = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsProduct), graphql_name="product"
    )

    properties = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AiNotificationsPropertyInput"))
        ),
        graphql_name="properties",
    )

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsChannelType), graphql_name="type"
    )

# %% [markdown]
# #### 101. `AiNotificationsChannelSorter`

# %% [markdown]
# Sort object
#
#
# Available input fields:
#
#
#
# * `direction` : direction
# * `field` : field

# %%
# | export
class AiNotificationsChannelSorter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "field")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsSortOrder), graphql_name="direction"
    )

    field = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsChannelFields), graphql_name="field"
    )

# %% [markdown]
# #### 102. `AiNotificationsChannelUpdate`

# %% [markdown]
# Channel update object
#
#
# Available input fields:
#
#
#
# * `active` : active
# * `name` : name
# * `properties` : properties

# %%
# | export
class AiNotificationsChannelUpdate(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("active", "name", "properties")
    active = sgqlc.types.Field(Boolean, graphql_name="active")

    name = sgqlc.types.Field(String, graphql_name="name")

    properties = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("AiNotificationsPropertyInput")),
        graphql_name="properties",
    )

# %% [markdown]
# #### 103. `AiNotificationsConstraint`

# %% [markdown]
# List of schema/suggestions constraints
#
#
# Available input fields:
#
#
#
# * `key` : key
# * `value` : value

# %%
# | export
class AiNotificationsConstraint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 104. `AiNotificationsCredentialsInput`

# %% [markdown]
# Credential input object
#
#
# Available input fields:
#
#
#
# * `basic` : basic
# * `customHeaders` : customHeaders
# * `oauth2` : oauth2
# * `token` : token
# * `type` : type

# %%
# | export
class AiNotificationsCredentialsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("basic", "custom_headers", "oauth2", "token", "type")
    basic = sgqlc.types.Field(AiNotificationsBasicAuthInput, graphql_name="basic")

    custom_headers = sgqlc.types.Field(
        "AiNotificationsCustomHeadersAuthInput", graphql_name="customHeaders"
    )

    oauth2 = sgqlc.types.Field("AiNotificationsOAuth2AuthInput", graphql_name="oauth2")

    token = sgqlc.types.Field("AiNotificationsTokenAuthInput", graphql_name="token")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsAuthType), graphql_name="type"
    )

# %% [markdown]
# #### 105. `AiNotificationsCustomHeaderInput`

# %% [markdown]
# Custom header input object
#
#
# Available input fields:
#
#
#
# * `key` : key
# * `value` : value

# %%
# | export
class AiNotificationsCustomHeaderInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(SecureValue, graphql_name="value")

# %% [markdown]
# #### 106. `AiNotificationsCustomHeadersAuthInput`

# %% [markdown]
# Custom headers auth input object
#
#
# Available input fields:
#
#
#
# * `customHeaders` : customHeaders

# %%
# | export
class AiNotificationsCustomHeadersAuthInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("custom_headers",)
    custom_headers = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(AiNotificationsCustomHeaderInput))
        ),
        graphql_name="customHeaders",
    )

# %% [markdown]
# #### 107. `AiNotificationsDestinationFilter`

# %% [markdown]
# Filter destination object
#
#
# Available input fields:
#
#
#
# * `active` : active
# * `authType` : authType
# * `exactName` : exactName
# * `id` : id
# * `ids` : ids
# * `name` : name
# * `property` : property
# * `scopeTypes` : scopeTypes
# * `type` : type
# * `updatedAt` : updatedAt

# %%
# | export
class AiNotificationsDestinationFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "active",
        "auth_type",
        "exact_name",
        "id",
        "ids",
        "name",
        "property",
        "scope_types",
        "type",
        "updated_at",
    )
    active = sgqlc.types.Field(Boolean, graphql_name="active")

    auth_type = sgqlc.types.Field(AiNotificationsAuthType, graphql_name="authType")

    exact_name = sgqlc.types.Field(String, graphql_name="exactName")

    id = sgqlc.types.Field(ID, graphql_name="id")

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    property = sgqlc.types.Field(
        "AiNotificationsPropertyFilter", graphql_name="property"
    )

    scope_types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiNotificationsEntityScopeTypeInput)),
        graphql_name="scopeTypes",
    )

    type = sgqlc.types.Field(AiNotificationsDestinationType, graphql_name="type")

    updated_at = sgqlc.types.Field(DateTime, graphql_name="updatedAt")

# %% [markdown]
# #### 108. `AiNotificationsDestinationInput`

# %% [markdown]
# Destination input object
#
#
# Available input fields:
#
#
#
# * `auth` : auth
# * `name` : name
# * `properties` : properties
# * `secureUrl` : secureUrl
# * `type` : type

# %%
# | export
class AiNotificationsDestinationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("auth", "name", "properties", "secure_url", "type")
    auth = sgqlc.types.Field(AiNotificationsCredentialsInput, graphql_name="auth")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    properties = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AiNotificationsPropertyInput"))
        ),
        graphql_name="properties",
    )

    secure_url = sgqlc.types.Field(
        "AiNotificationsSecureUrlInput", graphql_name="secureUrl"
    )

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsDestinationType), graphql_name="type"
    )

# %% [markdown]
# #### 109. `AiNotificationsDestinationSorter`

# %% [markdown]
# Sort object
#
#
# Available input fields:
#
#
#
# * `direction` : direction
# * `field` : field

# %%
# | export
class AiNotificationsDestinationSorter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "field")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsSortOrder), graphql_name="direction"
    )

    field = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsDestinationFields), graphql_name="field"
    )

# %% [markdown]
# #### 110. `AiNotificationsDestinationUpdate`

# %% [markdown]
# Destination update object
#
#
# Available input fields:
#
#
#
# * `active` : active
# * `auth` : auth
# * `disableAuth` : disableAuth
# * `name` : name
# * `properties` : properties
# * `secureUrl` : secureUrl

# %%
# | export
class AiNotificationsDestinationUpdate(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "active",
        "auth",
        "disable_auth",
        "name",
        "properties",
        "secure_url",
    )
    active = sgqlc.types.Field(Boolean, graphql_name="active")

    auth = sgqlc.types.Field(AiNotificationsCredentialsInput, graphql_name="auth")

    disable_auth = sgqlc.types.Field(Boolean, graphql_name="disableAuth")

    name = sgqlc.types.Field(String, graphql_name="name")

    properties = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("AiNotificationsPropertyInput")),
        graphql_name="properties",
    )

    secure_url = sgqlc.types.Field(
        "AiNotificationsSecureUrlUpdate", graphql_name="secureUrl"
    )

# %% [markdown]
# #### 111. `AiNotificationsDynamicVariable`

# %% [markdown]
# A list of dynamic variables used by the Channel
#
#
# Available input fields:
#
#
#
# * `exampleValue` : exampleValue
# * `name` : name

# %%
# | export
class AiNotificationsDynamicVariable(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("example_value", "name")
    example_value = sgqlc.types.Field(
        "AiNotificationsExampleValue", graphql_name="exampleValue"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 112. `AiNotificationsEntityScopeInput`

# %% [markdown]
# Entity Scope
#
#
# Available input fields:
#
#
#
# * `id` : id
# * `type` : type

# %%
# | export
class AiNotificationsEntityScopeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsEntityScopeTypeInput), graphql_name="type"
    )

# %% [markdown]
# #### 113. `AiNotificationsExampleValue`

# %% [markdown]
# Example properties to be added to the rendering context, for tests
#
#
# Available input fields:
#
#
#
# * `example` : example
# * `type` : type

# %%
# | export
class AiNotificationsExampleValue(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("example", "type")
    example = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="example")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsVariableType), graphql_name="type"
    )

# %% [markdown]
# #### 114. `AiNotificationsOAuth2AuthInput`

# %% [markdown]
# OAuth2 auth input object
#
#
# Available input fields:
#
#
#
# * `accessTokenUrl` : accessTokenUrl
# * `authorizationUrl` : authorizationUrl
# * `clientId` : clientId
# * `clientSecret` : clientSecret
# * `prefix` : prefix
# * `refreshInterval` : refreshInterval
# * `refreshToken` : refreshToken
# * `refreshable` : refreshable
# * `scope` : scope
# * `token` : token

# %%
# | export
class AiNotificationsOAuth2AuthInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "access_token_url",
        "authorization_url",
        "client_id",
        "client_secret",
        "prefix",
        "refresh_interval",
        "refresh_token",
        "refreshable",
        "scope",
        "token",
    )
    access_token_url = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="accessTokenUrl"
    )

    authorization_url = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="authorizationUrl"
    )

    client_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="clientId")

    client_secret = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="clientSecret"
    )

    prefix = sgqlc.types.Field(String, graphql_name="prefix")

    refresh_interval = sgqlc.types.Field(Int, graphql_name="refreshInterval")

    refresh_token = sgqlc.types.Field(SecureValue, graphql_name="refreshToken")

    refreshable = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="refreshable"
    )

    scope = sgqlc.types.Field(String, graphql_name="scope")

    token = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="token")

# %% [markdown]
# #### 115. `AiNotificationsPropertyFilter`

# %% [markdown]
# Filter object by property
#
#
# Available input fields:
#
#
#
# * `key` : key
# * `value` : value

# %%
# | export
class AiNotificationsPropertyFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 116. `AiNotificationsPropertyInput`

# %% [markdown]
# Property object
#
#
# Available input fields:
#
#
#
# * `displayValue` : displayValue
# * `key` : key
# * `label` : label
# * `value` : value

# %%
# | export
class AiNotificationsPropertyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("display_value", "key", "label", "value")
    display_value = sgqlc.types.Field(String, graphql_name="displayValue")

    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    label = sgqlc.types.Field(String, graphql_name="label")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 117. `AiNotificationsSecureUrlInput`

# %% [markdown]
# Destination SecureUrlInput object
#
#
# Available input fields:
#
#
#
# * `prefix` : prefix
# * `secureSuffix` : secureSuffix

# %%
# | export
class AiNotificationsSecureUrlInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("prefix", "secure_suffix")
    prefix = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="prefix")

    secure_suffix = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="secureSuffix"
    )

# %% [markdown]
# #### 118. `AiNotificationsSecureUrlUpdate`

# %% [markdown]
# Destination SecureUrlUpdate object
#
#
# Available input fields:
#
#
#
# * `prefix` : prefix
# * `secureSuffix` : secureSuffix

# %%
# | export
class AiNotificationsSecureUrlUpdate(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("prefix", "secure_suffix")
    prefix = sgqlc.types.Field(String, graphql_name="prefix")

    secure_suffix = sgqlc.types.Field(SecureValue, graphql_name="secureSuffix")

# %% [markdown]
# #### 119. `AiNotificationsSuggestionFilter`

# %% [markdown]
# Suggestion filter object
#
#
# Available input fields:
#
#
#
# * `type` : type
# * `value` : value

# %%
# | export
class AiNotificationsSuggestionFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("type", "value")
    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsSuggestionFilterType), graphql_name="type"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 120. `AiNotificationsTokenAuthInput`

# %% [markdown]
# Token auth input object
#
#
# Available input fields:
#
#
#
# * `prefix` : prefix
# * `token` : token

# %%
# | export
class AiNotificationsTokenAuthInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("prefix", "token")
    prefix = sgqlc.types.Field(String, graphql_name="prefix")

    token = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="token")

# %% [markdown]
# #### 121. `AiNotificationsUnverifiedEmailsFilters`

# %% [markdown]
# Filters for unverified emails query
#
#
# Available input fields:
#
#
#
# * `emails` : emails
# * `statuses` : statuses
# * `updatedAt` : updatedAt

# %%
# | export
class AiNotificationsUnverifiedEmailsFilters(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("emails", "statuses", "updated_at")
    emails = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="emails"
    )

    statuses = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AiNotificationsEmailVerificationStatus)
        ),
        graphql_name="statuses",
    )

    updated_at = sgqlc.types.Field(DateTime, graphql_name="updatedAt")

# %% [markdown]
# #### 122. `AiNotificationsUnverifiedEmailsSorter`

# %% [markdown]
# Sorting configuration for unverified emails query
#
#
# Available input fields:
#
#
#
# * `direction` : direction
# * `field` : field

# %%
# | export
class AiNotificationsUnverifiedEmailsSorter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "field")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsSortOrder), graphql_name="direction"
    )

    field = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsUnverifiedEmailsFields),
        graphql_name="field",
    )

# %% [markdown]
# #### 123. `AiNotificationsVariableFilter`

# %% [markdown]
# Filter variable object
#
#
# Available input fields:
#
#
#
# * `active` : active
# * `key` : key
# * `label` : label
# * `name` : name
# * `product` : product

# %%
# | export
class AiNotificationsVariableFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("active", "key", "label", "name", "product")
    active = sgqlc.types.Field(Boolean, graphql_name="active")

    key = sgqlc.types.Field(String, graphql_name="key")

    label = sgqlc.types.Field(String, graphql_name="label")

    name = sgqlc.types.Field(String, graphql_name="name")

    product = sgqlc.types.Field(AiNotificationsProduct, graphql_name="product")

# %% [markdown]
# #### 124. `AiNotificationsVariableSorter`

# %% [markdown]
# Sort object
#
#
# Available input fields:
#
#
#
# * `direction` : direction
# * `field` : field

# %%
# | export
class AiNotificationsVariableSorter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "field")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsSortOrder), graphql_name="direction"
    )

    field = sgqlc.types.Field(
        sgqlc.types.non_null(AiNotificationsVariableFields), graphql_name="field"
    )

# %% [markdown]
# #### 125. `AiTopologyCollectorAttributeInput`

# %% [markdown]
# A key-value entry.
#
#
# Available input fields:
#
#
#
# * `key` : Key of entry.
# * `value` : Value of entry.

# %%
# | export
class AiTopologyCollectorAttributeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 126. `AiTopologyCollectorEdgeBlueprint`

# %% [markdown]
# Blueprint for edge creation.
#
#
# Available input fields:
#
#
#
# * `directed` : Whether or not from and to have any semantic meaning.
# * `fromVertexName` : The source vertex name.
# * `toVertexName` : The destination vertex name.

# %%
# | export
class AiTopologyCollectorEdgeBlueprint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("directed", "from_vertex_name", "to_vertex_name")
    directed = sgqlc.types.Field(Boolean, graphql_name="directed")

    from_vertex_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="fromVertexName"
    )

    to_vertex_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="toVertexName"
    )

# %% [markdown]
# #### 127. `AiTopologyCollectorVertexBlueprint`

# %% [markdown]
# Blueprint for vertex creation.
#
#
# Available input fields:
#
#
#
# * `definingAttributes` : Attributes to define the vertex.
# * `name` : The name of the vertex.
# * `vertexClass` : The class of the vertex.

# %%
# | export
class AiTopologyCollectorVertexBlueprint(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("defining_attributes", "name", "vertex_class")
    defining_attributes = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(AiTopologyCollectorAttributeInput))
        ),
        graphql_name="definingAttributes",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    vertex_class = sgqlc.types.Field(
        sgqlc.types.non_null(AiTopologyCollectorVertexClass), graphql_name="vertexClass"
    )

# %% [markdown]
# #### 128. `AiWorkflowsCreateWorkflowInput`

# %% [markdown]
# Workflow input object
#
#
# Available input fields:
#
#
#
# * `destinationConfigurations` : destinationConfigurations
# * `destinationsEnabled` : destinationsEnabled
# * `enrichments` : enrichments
# * `enrichmentsEnabled` : enrichmentsEnabled
# * `issuesFilter` : issuesFilter
# * `mutingRulesHandling` : mutingRulesHandling
# * `name` : name
# * `workflowEnabled` : workflowEnabled

# %%
# | export
class AiWorkflowsCreateWorkflowInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "destination_configurations",
        "destinations_enabled",
        "enrichments",
        "enrichments_enabled",
        "issues_filter",
        "muting_rules_handling",
        "name",
        "workflow_enabled",
    )
    destination_configurations = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null("AiWorkflowsDestinationConfigurationInput")
            )
        ),
        graphql_name="destinationConfigurations",
    )

    destinations_enabled = sgqlc.types.Field(
        Boolean, graphql_name="destinationsEnabled"
    )

    enrichments = sgqlc.types.Field(
        "AiWorkflowsEnrichmentsInput", graphql_name="enrichments"
    )

    enrichments_enabled = sgqlc.types.Field(Boolean, graphql_name="enrichmentsEnabled")

    issues_filter = sgqlc.types.Field(
        "AiWorkflowsFilterInput", graphql_name="issuesFilter"
    )

    muting_rules_handling = sgqlc.types.Field(
        sgqlc.types.non_null(AiWorkflowsMutingRulesHandling),
        graphql_name="mutingRulesHandling",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    workflow_enabled = sgqlc.types.Field(Boolean, graphql_name="workflowEnabled")

# %% [markdown]
# #### 129. `AiWorkflowsDestinationConfigurationInput`

# %% [markdown]
# Destination Configuration input object
#
#
# Available input fields:
#
#
#
# * `channelId` : channelId
# * `notificationTriggers` : notificationTriggers
# * `updateOriginalMessage` : updateOriginalMessage

# %%
# | export
class AiWorkflowsDestinationConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("channel_id", "notification_triggers", "update_original_message")
    channel_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="channelId")

    notification_triggers = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AiWorkflowsNotificationTrigger)),
        graphql_name="notificationTriggers",
    )

    update_original_message = sgqlc.types.Field(
        Boolean, graphql_name="updateOriginalMessage"
    )

# %% [markdown]
# #### 130. `AiWorkflowsEnrichmentsInput`

# %% [markdown]
# Enrichment input object
#
#
# Available input fields:
#
#
#
# * `nrql` : nrql

# %%
# | export
class AiWorkflowsEnrichmentsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql",)
    nrql = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AiWorkflowsNrqlEnrichmentInput"))
        ),
        graphql_name="nrql",
    )

# %% [markdown]
# #### 131. `AiWorkflowsFilterInput`

# %% [markdown]
# Filter input object
#
#
# Available input fields:
#
#
#
# * `name` : name
# * `predicates` : predicates
# * `type` : type

# %%
# | export
class AiWorkflowsFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "predicates", "type")
    name = sgqlc.types.Field(String, graphql_name="name")

    predicates = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AiWorkflowsPredicateInput"))
        ),
        graphql_name="predicates",
    )

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AiWorkflowsFilterType), graphql_name="type"
    )

# %% [markdown]
# #### 132. `AiWorkflowsFilters`

# %% [markdown]
# Filter on the workflow objects
#
#
# Available input fields:
#
#
#
# * `channelId` : channelId
# * `destinationType` : destinationType
# * `enrichmentId` : enrichmentId
# * `filterId` : filterId
# * `guid` : guid
# * `id` : id
# * `name` : name
# * `nameLike` : nameLike
# * `workflowEnabled` : workflowEnabled

# %%
# | export
class AiWorkflowsFilters(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "channel_id",
        "destination_type",
        "enrichment_id",
        "filter_id",
        "guid",
        "id",
        "name",
        "name_like",
        "workflow_enabled",
    )
    channel_id = sgqlc.types.Field(ID, graphql_name="channelId")

    destination_type = sgqlc.types.Field(
        AiWorkflowsDestinationType, graphql_name="destinationType"
    )

    enrichment_id = sgqlc.types.Field(ID, graphql_name="enrichmentId")

    filter_id = sgqlc.types.Field(ID, graphql_name="filterId")

    guid = sgqlc.types.Field(EntityGuid, graphql_name="guid")

    id = sgqlc.types.Field(ID, graphql_name="id")

    name = sgqlc.types.Field(String, graphql_name="name")

    name_like = sgqlc.types.Field(String, graphql_name="nameLike")

    workflow_enabled = sgqlc.types.Field(Boolean, graphql_name="workflowEnabled")

# %% [markdown]
# #### 133. `AiWorkflowsNrqlConfigurationInput`

# %% [markdown]
# NRQL type configuration input object
#
#
# Available input fields:
#
#
#
# * `query` : query

# %%
# | export
class AiWorkflowsNrqlConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("query",)
    query = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="query")

# %% [markdown]
# #### 134. `AiWorkflowsNrqlEnrichmentInput`

# %% [markdown]
# NRQL type enrichment input object
#
#
# Available input fields:
#
#
#
# * `configuration` : configuration
# * `name` : name

# %%
# | export
class AiWorkflowsNrqlEnrichmentInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("configuration", "name")
    configuration = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(AiWorkflowsNrqlConfigurationInput))
        ),
        graphql_name="configuration",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 135. `AiWorkflowsNrqlTestEnrichmentInput`

# %% [markdown]
# NRQL type test enrichment input object
#
#
# Available input fields:
#
#
#
# * `configuration` : configuration
# * `id` : id
# * `name` : name

# %%
# | export
class AiWorkflowsNrqlTestEnrichmentInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("configuration", "id", "name")
    configuration = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(AiWorkflowsNrqlConfigurationInput))
        ),
        graphql_name="configuration",
    )

    id = sgqlc.types.Field(ID, graphql_name="id")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 136. `AiWorkflowsNrqlUpdateEnrichmentInput`

# %% [markdown]
# NRQL type update enrichment input object
#
#
# Available input fields:
#
#
#
# * `configuration` : configuration
# * `id` : id
# * `name` : name

# %%
# | export
class AiWorkflowsNrqlUpdateEnrichmentInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("configuration", "id", "name")
    configuration = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(AiWorkflowsNrqlConfigurationInput))
        ),
        graphql_name="configuration",
    )

    id = sgqlc.types.Field(ID, graphql_name="id")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 137. `AiWorkflowsPredicateInput`

# %% [markdown]
# PredicateInput input object
#
#
# Available input fields:
#
#
#
# * `attribute` : attribute
# * `operator` : operator
# * `values` : values

# %%
# | export
class AiWorkflowsPredicateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute", "operator", "values")
    attribute = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="attribute"
    )

    operator = sgqlc.types.Field(
        sgqlc.types.non_null(AiWorkflowsOperator), graphql_name="operator"
    )

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="values",
    )

# %% [markdown]
# #### 138. `AiWorkflowsTestEnrichmentsInput`

# %% [markdown]
# Test Enrichment input object
#
#
# Available input fields:
#
#
#
# * `nrql` : nrql

# %%
# | export
class AiWorkflowsTestEnrichmentsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql",)
    nrql = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(AiWorkflowsNrqlTestEnrichmentInput)
            )
        ),
        graphql_name="nrql",
    )

# %% [markdown]
# #### 139. `AiWorkflowsTestWorkflowInput`

# %% [markdown]
# Test Workflow input object
#
#
# Available input fields:
#
#
#
# * `destinationConfigurations` : destinationConfigurations
# * `enrichments` : enrichments
# * `issuesFilter` : issuesFilter

# %%
# | export
class AiWorkflowsTestWorkflowInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("destination_configurations", "enrichments", "issues_filter")
    destination_configurations = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(AiWorkflowsDestinationConfigurationInput)
            )
        ),
        graphql_name="destinationConfigurations",
    )

    enrichments = sgqlc.types.Field(
        AiWorkflowsTestEnrichmentsInput, graphql_name="enrichments"
    )

    issues_filter = sgqlc.types.Field(
        AiWorkflowsFilterInput, graphql_name="issuesFilter"
    )

# %% [markdown]
# #### 140. `AiWorkflowsUpdateEnrichmentsInput`

# %% [markdown]
# Update Enrichment input object
#
#
# Available input fields:
#
#
#
# * `nrql` : nrql

# %%
# | export
class AiWorkflowsUpdateEnrichmentsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql",)
    nrql = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(AiWorkflowsNrqlUpdateEnrichmentInput)
            )
        ),
        graphql_name="nrql",
    )

# %% [markdown]
# #### 141. `AiWorkflowsUpdateWorkflowInput`

# %% [markdown]
# Update Workflow input object
#
#
# Available input fields:
#
#
#
# * `destinationConfigurations` : destinationConfigurations
# * `destinationsEnabled` : destinationsEnabled
# * `enrichments` : enrichments
# * `enrichmentsEnabled` : enrichmentsEnabled
# * `id` : id
# * `issuesFilter` : issuesFilter
# * `mutingRulesHandling` : mutingRulesHandling
# * `name` : name
# * `workflowEnabled` : workflowEnabled

# %%
# | export
class AiWorkflowsUpdateWorkflowInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "destination_configurations",
        "destinations_enabled",
        "enrichments",
        "enrichments_enabled",
        "id",
        "issues_filter",
        "muting_rules_handling",
        "name",
        "workflow_enabled",
    )
    destination_configurations = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AiWorkflowsDestinationConfigurationInput)
        ),
        graphql_name="destinationConfigurations",
    )

    destinations_enabled = sgqlc.types.Field(
        Boolean, graphql_name="destinationsEnabled"
    )

    enrichments = sgqlc.types.Field(
        AiWorkflowsUpdateEnrichmentsInput, graphql_name="enrichments"
    )

    enrichments_enabled = sgqlc.types.Field(Boolean, graphql_name="enrichmentsEnabled")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    issues_filter = sgqlc.types.Field(
        "AiWorkflowsUpdatedFilterInput", graphql_name="issuesFilter"
    )

    muting_rules_handling = sgqlc.types.Field(
        AiWorkflowsMutingRulesHandling, graphql_name="mutingRulesHandling"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    workflow_enabled = sgqlc.types.Field(Boolean, graphql_name="workflowEnabled")

# %% [markdown]
# #### 142. `AiWorkflowsUpdatedFilterInput`

# %% [markdown]
# Update Filter input object
#
#
# Available input fields:
#
#
#
# * `filterInput` : filterInput
# * `id` : id

# %%
# | export
class AiWorkflowsUpdatedFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("filter_input", "id")
    filter_input = sgqlc.types.Field(
        sgqlc.types.non_null(AiWorkflowsFilterInput), graphql_name="filterInput"
    )

    id = sgqlc.types.Field(ID, graphql_name="id")

# %% [markdown]
# #### 143. `AlertsAsNrqlConditionsSearchCriteriaInput`

# %% [markdown]
# Search criteria for returning specific NRQL-converted conditions.
#
#
# Available input fields:
#
#
#
# * `name` : Exact name of the NRQL condition.
# * `nameLike` : String to partially match a NRQL condition name.
# * `policyId` : Policy ID associated with the NRQL condition.
# * `sourceProduct` : List of source products that the asNrql condition was converted from.
# Can accept an array of enum values, e.g. [MOBILE, APM, BROWSER].
# * `termsOperator` : Terms operator to match while searching for NRQL conditions.

# %%
# | export
class AlertsAsNrqlConditionsSearchCriteriaInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "name",
        "name_like",
        "policy_id",
        "source_product",
        "terms_operator",
    )
    name = sgqlc.types.Field(String, graphql_name="name")

    name_like = sgqlc.types.Field(String, graphql_name="nameLike")

    policy_id = sgqlc.types.Field(ID, graphql_name="policyId")

    source_product = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AlertsAsNrqlSourceProduct)),
        graphql_name="sourceProduct",
    )

    terms_operator = sgqlc.types.Field(
        AlertsNrqlConditionTermsOperator, graphql_name="termsOperator"
    )

# %% [markdown]
# #### 144. `AlertsCompoundConditionFilterInput`

# %% [markdown]
# Filter criteria for returning specific compound alert conditions.
#
#
# Available input fields:
#
#
#
# * `id` : Compound alert condition id filter object for filtering search results.

# %%
# | export
class AlertsCompoundConditionFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field("AlertsCompoundConditionIdInput", graphql_name="id")

# %% [markdown]
# #### 145. `AlertsCompoundConditionIdInput`

# %% [markdown]
# Compound alert condition id filter object for filtering search results.
#
#
# Available input fields:
#
#
#
# * `eq` : A compound alert condition id.
# * `in` : A list of compound alert condition ids.

# %%
# | export
class AlertsCompoundConditionIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 146. `AlertsCompoundConditionSortInput`

# %% [markdown]
# Sorting preferences for compound alert conditions' search results.
#
#
# Available input fields:
#
#
#
# * `direction` : Sorting direction for sort key of compound alert conditions' search results.
# * `key` : Sorting key preference for compound alert conditions' search results.

# %%
# | export
class AlertsCompoundConditionSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        AlertsCompoundConditionSortDirection, graphql_name="direction"
    )

    key = sgqlc.types.Field(AlertsCompoundConditionSortKey, graphql_name="key")

# %% [markdown]
# #### 147. `AlertsEmailNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new Email notification channel.
#
#
# Available input fields:
#
#
#
# * `emails` : List of email recipients.
# * `includeJson` : Include details about the violation as a JSON attachment.
# * `name` : Notification channel name.

# %%
# | export
class AlertsEmailNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("emails", "include_json", "name")
    emails = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="emails",
    )

    include_json = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="includeJson"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 148. `AlertsEmailNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing Email notification channel.
#
#
# Available input fields:
#
#
#
# * `emails` : List of email recipients.
# * `includeJson` : Include details about the violation as a JSON attachment.
# * `name` : Notification channel name.

# %%
# | export
class AlertsEmailNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("emails", "include_json", "name")
    emails = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="emails"
    )

    include_json = sgqlc.types.Field(Boolean, graphql_name="includeJson")

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 149. `AlertsMutingRuleConditionGroupInput`

# %% [markdown]
# A group of MutingRuleConditions combined by an operator.
#
#
# Available input fields:
#
#
#
# * `conditions` : The individual MutingRuleConditions within the group.
# * `operator` : The operator used to combine all the MutingRuleConditions within the group.

# %%
# | export
class AlertsMutingRuleConditionGroupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("conditions", "operator")
    conditions = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("AlertsMutingRuleConditionInput"))
        ),
        graphql_name="conditions",
    )

    operator = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsMutingRuleConditionGroupOperator),
        graphql_name="operator",
    )

# %% [markdown]
# #### 150. `AlertsMutingRuleConditionInput`

# %% [markdown]
# A condition which describes how to target a New Relic Alerts Violation.
#
#
# Available input fields:
#
#
#
# * `attribute` : The attribute on a violation. Expects one of:
#
# * **accountId** - The account id
# * **conditionId** - The alert condition id
# * **conditionName** - The alert condition name
# * **conditionRunbookUrl** - The alert condition's runbook url
# * **conditionType** - The alert condition type, such as `metric`
# * **entity.guid** - The entity GUID
# * **nrqlEventType** - The NRQL event type
# * **nrqlQuery** - The NRQL query string
# * **policyId** - The alert policy id
# * **policyName** - The alert policy name
# * **product** - The target product (e.g., `SYNTHETICS`)
# * **tags.<NAME>** - Arbitrary tags associated with some entity (e.g., FACET from a NRQL query, for example `tags.appName` or `tags.host`)
# * **targetId** - The ID of the alerts target
# * **targetName** - The name of the alerts target
# * `operator` : The operator used to compare the attribute's value with the supplied value(s).
# * `values` : The value(s) to compare against the attribute's value.

# %%
# | export
class AlertsMutingRuleConditionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute", "operator", "values")
    attribute = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="attribute"
    )

    operator = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsMutingRuleConditionOperator), graphql_name="operator"
    )

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)), graphql_name="values"
    )

# %% [markdown]
# #### 151. `AlertsMutingRuleInput`

# %% [markdown]
# Input for creating MutingRules for New Relic Alerts Violations.
#
#
# Available input fields:
#
#
#
# * `actionOnMutingRuleWindowEnded` : The action when the muting rule window is ended or disabled.
# * `condition` : The condition that defines which violations to target.
# * `description` : The description of the MutingRule.
# * `enabled` : Whether the MutingRule is enabled
# * `name` : The name of the MutingRule.
# * `schedule` : The time window when the MutingRule should actively mute violations.

# %%
# | export
class AlertsMutingRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "action_on_muting_rule_window_ended",
        "condition",
        "description",
        "enabled",
        "name",
        "schedule",
    )
    action_on_muting_rule_window_ended = sgqlc.types.Field(
        AlertsActionOnMutingRuleWindowEnded,
        graphql_name="actionOnMutingRuleWindowEnded",
    )

    condition = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsMutingRuleConditionGroupInput),
        graphql_name="condition",
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    schedule = sgqlc.types.Field(
        "AlertsMutingRuleScheduleInput", graphql_name="schedule"
    )

# %% [markdown]
# #### 152. `AlertsMutingRuleScheduleInput`

# %% [markdown]
# The time window when the MutingRule should actively mute violations.
#
#
# Available input fields:
#
#
#
# * `endRepeat` : The datetime stamp when the MutingRule schedule should stop repeating.
# This is in local ISO 8601 format without an offset.
#
# Example: `'2020-07-10T15:00:00'`
#
# Note: Either `endRepeat` or `repeatCount` should be used to end a MutingRule schedule.
# Both fields should not be provided together.
# * `endTime` : The datetime stamp representing when the MutingRule should end.
# This is in local ISO 8601 format without an offset.
#
# Example: `'2020-07-10T15:00:00'`
# * `repeat` : The frequency the MutingRule schedule repeats.
# If the MutingRule repeats `WEEKLY`, be sure to set `weeklyRepeatDays`.
# If the MutingRule does not repeat, use `null`.
#
# Example: `DAILY`
# * `repeatCount` : The number of times the MutingRule schedule should repeat.
#
# Note: Either `repeatCount` or `endRepeat` should be used to end a MutingRule schedule.
# Both fields should not be provided together.
# * `startTime` : The datetime stamp representing when the MutingRule should start.
# This is in local ISO 8601 format without an offset.
#
# Example: `'2020-07-08T14:30:00'`
# * `timeZone` : The time zone that applies to the MutingRule schedule.
#
# Example: `'America/Los_Angeles'`
#
# See https://en.wikipedia.org/wiki/List_of_tz_database_time_zones.
# * `weeklyRepeatDays` : The day(s) of the week that a MutingRule should repeat when the repeat field is set to `WEEKLY`.
#
# Example: `[MONDAY, WEDNESDAY]`

# %%
# | export
class AlertsMutingRuleScheduleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "end_repeat",
        "end_time",
        "repeat",
        "repeat_count",
        "start_time",
        "time_zone",
        "weekly_repeat_days",
    )
    end_repeat = sgqlc.types.Field(NaiveDateTime, graphql_name="endRepeat")

    end_time = sgqlc.types.Field(NaiveDateTime, graphql_name="endTime")

    repeat = sgqlc.types.Field(AlertsMutingRuleScheduleRepeat, graphql_name="repeat")

    repeat_count = sgqlc.types.Field(Int, graphql_name="repeatCount")

    start_time = sgqlc.types.Field(NaiveDateTime, graphql_name="startTime")

    time_zone = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="timeZone")

    weekly_repeat_days = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AlertsDayOfWeek)),
        graphql_name="weeklyRepeatDays",
    )

# %% [markdown]
# #### 153. `AlertsMutingRuleScheduleUpdateInput`

# %% [markdown]
# The time window when the MutingRule should actively mute violations.
#
#
# Available input fields:
#
#
#
# * `endRepeat` : The datetime stamp when the MutingRule schedule should stop repeating.
# This is in local ISO 8601 format without an offset.
#
# Example: `'2020-07-10T15:00:00'`
#
# Note: Either `endRepeat` or `repeatCount` should be used to end a MutingRule schedule.
# Both fields should not be provided together.
# * `endTime` : The datetime stamp representing when the MutingRule should end.
# This is in local ISO 8601 format without an offset.
#
# Example: `'2020-07-10T15:00:00'`
# * `repeat` : The frequency the MutingRule schedule repeats.
# If the MutingRule repeats `WEEKLY`, be sure to set `weeklyRepeatDays`.
# If the MutingRule does not repeat, use `null`.
#
# Example: `DAILY`
# * `repeatCount` : The number of times the MutingRule schedule should repeat.
#
# Note: Either `repeatCount` or `endRepeat` should be used to end a MutingRule schedule.
# Both fields should not be provided together.
# * `startTime` : The datetime stamp representing when the MutingRule should start.
# This is in local ISO 8601 format without an offset.
#
# Example: `'2020-07-08T14:30:00'`
# * `timeZone` : The time zone that applies to the MutingRule schedule.
#
# Example: `'America/Los_Angeles'`
#
# See https://en.wikipedia.org/wiki/List_of_tz_database_time_zones.
# * `weeklyRepeatDays` : The day(s) of the week that a MutingRule should repeat when the repeat field is set to `WEEKLY`.
#
# Example: `[MONDAY, WEDNESDAY]`

# %%
# | export
class AlertsMutingRuleScheduleUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "end_repeat",
        "end_time",
        "repeat",
        "repeat_count",
        "start_time",
        "time_zone",
        "weekly_repeat_days",
    )
    end_repeat = sgqlc.types.Field(NaiveDateTime, graphql_name="endRepeat")

    end_time = sgqlc.types.Field(NaiveDateTime, graphql_name="endTime")

    repeat = sgqlc.types.Field(AlertsMutingRuleScheduleRepeat, graphql_name="repeat")

    repeat_count = sgqlc.types.Field(Int, graphql_name="repeatCount")

    start_time = sgqlc.types.Field(NaiveDateTime, graphql_name="startTime")

    time_zone = sgqlc.types.Field(String, graphql_name="timeZone")

    weekly_repeat_days = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AlertsDayOfWeek)),
        graphql_name="weeklyRepeatDays",
    )

# %% [markdown]
# #### 154. `AlertsMutingRuleUpdateInput`

# %% [markdown]
# Input for updating MutingRules for New Relic Alerts Violations.
#
#
# Available input fields:
#
#
#
# * `actionOnMutingRuleWindowEnded` : The action when the muting rule window is ended or disabled.
# * `condition` : The condition that defines which violations to target.
# * `description` : The description of the MutingRule.
# * `enabled` : Whether the MutingRule is enabled
# * `name` : The name of the MutingRule.
# * `schedule` : The time window when the MutingRule should actively mute violations.

# %%
# | export
class AlertsMutingRuleUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "action_on_muting_rule_window_ended",
        "condition",
        "description",
        "enabled",
        "name",
        "schedule",
    )
    action_on_muting_rule_window_ended = sgqlc.types.Field(
        AlertsActionOnMutingRuleWindowEnded,
        graphql_name="actionOnMutingRuleWindowEnded",
    )

    condition = sgqlc.types.Field(
        AlertsMutingRuleConditionGroupInput, graphql_name="condition"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    name = sgqlc.types.Field(String, graphql_name="name")

    schedule = sgqlc.types.Field(
        AlertsMutingRuleScheduleUpdateInput, graphql_name="schedule"
    )

# %% [markdown]
# #### 155. `AlertsMutingRulesFilterCriteriaInput`

# %% [markdown]
# An input to filter muting rules for a certain criteria
#
#
# Available input fields:
#
#
#
# * `enabled` : Whether the MutingRule is enabled

# %%
# | export
class AlertsMutingRulesFilterCriteriaInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled",)
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

# %% [markdown]
# #### 156. `AlertsNotificationChannelCreateConfiguration`

# %% [markdown]
# The input configuration for creating a notification channel.
#
#
# Available input fields:
#
#
#
# * `email` : The input configuration for creating an Email notification channel.
# * `opsGenie` : The input configuration for creating an OpsGenie notification channel.
# * `pagerDuty` : The input configuration for creating a PagerDuty notification channel.
# * `slack` : The input configuration for creating a Slack notification channel.
# * `victorOps` : The input configuration for creating a VictorOps notification channel.
# * `webhook` : The input configuration for creating a Webhook notification channel.
# * `xMatters` : The input configuration for creating an xMatters notification channel.

# %%
# | export
class AlertsNotificationChannelCreateConfiguration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "email",
        "ops_genie",
        "pager_duty",
        "slack",
        "victor_ops",
        "webhook",
        "x_matters",
    )
    email = sgqlc.types.Field(
        AlertsEmailNotificationChannelCreateInput, graphql_name="email"
    )

    ops_genie = sgqlc.types.Field(
        "AlertsOpsGenieNotificationChannelCreateInput", graphql_name="opsGenie"
    )

    pager_duty = sgqlc.types.Field(
        "AlertsPagerDutyNotificationChannelCreateInput", graphql_name="pagerDuty"
    )

    slack = sgqlc.types.Field(
        "AlertsSlackNotificationChannelCreateInput", graphql_name="slack"
    )

    victor_ops = sgqlc.types.Field(
        "AlertsVictorOpsNotificationChannelCreateInput", graphql_name="victorOps"
    )

    webhook = sgqlc.types.Field(
        "AlertsWebhookNotificationChannelCreateInput", graphql_name="webhook"
    )

    x_matters = sgqlc.types.Field(
        "AlertsXMattersNotificationChannelCreateInput", graphql_name="xMatters"
    )

# %% [markdown]
# #### 157. `AlertsNotificationChannelUpdateConfiguration`

# %% [markdown]
# The input configuration for updating a notification channel.
#
#
# Available input fields:
#
#
#
# * `email` : The input configuration for updating an Email notification channel.
# * `opsGenie` : The input configuration for updating an OpsGenie notification channel.
# * `pagerDuty` : The input configuration for updating a PagerDuty notification channel.
# * `slack` : The input configuration for updating a Slack notification channel.
# * `victorOps` : The input configuration for updating a VictorOps notification channel.
# * `webhook` : The input configuration for updating a Webhook notification channel.
# * `xMatters` : The input configuration for updating an xMatters notification channel.

# %%
# | export
class AlertsNotificationChannelUpdateConfiguration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "email",
        "ops_genie",
        "pager_duty",
        "slack",
        "victor_ops",
        "webhook",
        "x_matters",
    )
    email = sgqlc.types.Field(
        AlertsEmailNotificationChannelUpdateInput, graphql_name="email"
    )

    ops_genie = sgqlc.types.Field(
        "AlertsOpsGenieNotificationChannelUpdateInput", graphql_name="opsGenie"
    )

    pager_duty = sgqlc.types.Field(
        "AlertsPagerDutyNotificationChannelUpdateInput", graphql_name="pagerDuty"
    )

    slack = sgqlc.types.Field(
        "AlertsSlackNotificationChannelUpdateInput", graphql_name="slack"
    )

    victor_ops = sgqlc.types.Field(
        "AlertsVictorOpsNotificationChannelUpdateInput", graphql_name="victorOps"
    )

    webhook = sgqlc.types.Field(
        "AlertsWebhookNotificationChannelUpdateInput", graphql_name="webhook"
    )

    x_matters = sgqlc.types.Field(
        "AlertsXMattersNotificationChannelUpdateInput", graphql_name="xMatters"
    )

# %% [markdown]
# #### 158. `AlertsNrqlConditionBaselineInput`

# %% [markdown]
# Input for creating a baseline NRQL condition.
#
#
# Available input fields:
#
#
#
# * `baselineDirection` : Direction in which the baseline is set on condition.
# * `description` : The custom violation description.
# * `enabled` : Whether the NRQL condition is enabled.
# * `expiration` : Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
# * `name` : The name of the NRQL condition.
# * `nrql` : The NRQL query that defines the signal for the condition.
# * `runbookUrl` : Runbook URL.
# * `signal` : Configuration that defines the signal that the NRQL condition will use to evaluate.
# * `signalSeasonality` : Seasonality under which the condition's signal(s) are evaluated. To have New Relic calculate seasonality automatically, set to `NEW_RELIC_CALCULATION` (default). To turn off seasonality completely, set to `NONE`.
# * `targetEntity` : BETA PREVIEW: The `targetEntity` field is in limited preview. The entity explicitly targeted by the condition.
# * `terms` : "List of critical and warning terms for the condition.
#
# Terms are required in most cases. For conditions with a loss of signal threshold only, terms can be blank.
# * `titleTemplate` : This field allows you to create a custom title to be used when incidents are opened by the condition. Setting this field will override the default title. Must be [Handlebars format](https://handlebarsjs.com/guide/).
# * `violationTimeLimit` : Deprecated - use violationTimeLimitSeconds for full range of values.
#
# Duration after which a violation automatically closes. Default is THIRTY_DAYS.
# * `violationTimeLimitSeconds` : Duration after which a violation automatically closes in seconds.
# Accepts values between 300 seconds (5 minutes) and 2592000 seconds (30 days).
#
# Default is 3 days (259200 seconds).

# %%
# | export
class AlertsNrqlConditionBaselineInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "baseline_direction",
        "description",
        "enabled",
        "expiration",
        "name",
        "nrql",
        "runbook_url",
        "signal",
        "signal_seasonality",
        "target_entity",
        "terms",
        "title_template",
        "violation_time_limit",
        "violation_time_limit_seconds",
    )
    baseline_direction = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlBaselineDirection),
        graphql_name="baselineDirection",
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    expiration = sgqlc.types.Field(
        "AlertsNrqlConditionExpirationInput", graphql_name="expiration"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql = sgqlc.types.Field(
        sgqlc.types.non_null("AlertsNrqlConditionQueryInput"), graphql_name="nrql"
    )

    runbook_url = sgqlc.types.Field(String, graphql_name="runbookUrl")

    signal = sgqlc.types.Field("AlertsNrqlConditionSignalInput", graphql_name="signal")

    signal_seasonality = sgqlc.types.Field(
        AlertsNrqlSignalSeasonality, graphql_name="signalSeasonality"
    )

    target_entity = sgqlc.types.Field(EntityGuid, graphql_name="targetEntity")

    terms = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("AlertsNrqlDynamicConditionTermsInput")
        ),
        graphql_name="terms",
    )

    title_template = sgqlc.types.Field(String, graphql_name="titleTemplate")

    violation_time_limit = sgqlc.types.Field(
        AlertsViolationTimeLimit, graphql_name="violationTimeLimit"
    )

    violation_time_limit_seconds = sgqlc.types.Field(
        Seconds, graphql_name="violationTimeLimitSeconds"
    )

# %% [markdown]
# #### 159. `AlertsNrqlConditionExpirationInput`

# %% [markdown]
# Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
#
#
# Available input fields:
#
#
#
# * `closeViolationsOnExpiration` : Whether to close all open violations when the signal expires. Defaults to true.
# * `expirationDuration` : The amount of time (in seconds) to wait before considering if the signal has been lost. Max value of 172800 (48 hours).
# * `ignoreOnExpectedTermination` : Indicates whether an alert condition should ignore expected termination of a signal when considering whether to create a loss of signal incident. Defaults to false.
# * `openViolationOnExpiration` : Whether to create a new "lost signal" violation to capture that the signal expired. Defaults to false.

# %%
# | export
class AlertsNrqlConditionExpirationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "close_violations_on_expiration",
        "expiration_duration",
        "ignore_on_expected_termination",
        "open_violation_on_expiration",
    )
    close_violations_on_expiration = sgqlc.types.Field(
        Boolean, graphql_name="closeViolationsOnExpiration"
    )

    expiration_duration = sgqlc.types.Field(Seconds, graphql_name="expirationDuration")

    ignore_on_expected_termination = sgqlc.types.Field(
        Boolean, graphql_name="ignoreOnExpectedTermination"
    )

    open_violation_on_expiration = sgqlc.types.Field(
        Boolean, graphql_name="openViolationOnExpiration"
    )

# %% [markdown]
# #### 160. `AlertsNrqlConditionOutlierInput`

# %% [markdown]
# Input for creating an outlier NRQL condition.
#
#
# Available input fields:
#
#
#
# * `description` : The custom violation description.
# * `enabled` : Whether the NRQL condition is enabled.
# * `expiration` : Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
# * `name` : Name of the NRQL condition.
# * `nrql` : The NRQL query that defines the signal for the condition.
# * `outlierConfiguration` : Configuration that defines the outlier detection settings for the NRQL condition.
# * `runbookUrl` : Runbook URL.
# * `signal` : Configuration that defines the signal that the NRQL condition will use to evaluate.
# * `targetEntity` : BETA PREVIEW: The `targetEntity` field is in limited preview. The entity explicitly targeted by the condition.
# * `terms` : List of critical and warning terms for the condition.
# * `titleTemplate` : This field allows you to create a custom title to be used when incidents are opened by the condition. Setting this field will override the default title. Must be [Handlebars format](https://handlebarsjs.com/guide/).
# * `violationTimeLimit` : Deprecated - use violationTimeLimitSeconds for full range of values.
#
# Duration after which a violation automatically closes. Default is THIRTY_DAYS.
# * `violationTimeLimitSeconds` : Duration after which a violation automatically closes in seconds.
# Accepts values between 300 seconds (5 minutes) and 2592000 seconds (30 days).
#
# Default is 3 days (259200 seconds).

# %%
# | export
class AlertsNrqlConditionOutlierInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "expiration",
        "name",
        "nrql",
        "outlier_configuration",
        "runbook_url",
        "signal",
        "target_entity",
        "terms",
        "title_template",
        "violation_time_limit",
        "violation_time_limit_seconds",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    expiration = sgqlc.types.Field(
        AlertsNrqlConditionExpirationInput, graphql_name="expiration"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql = sgqlc.types.Field(
        sgqlc.types.non_null("AlertsNrqlConditionQueryInput"), graphql_name="nrql"
    )

    outlier_configuration = sgqlc.types.Field(
        "AlertsOutlierConfigurationInput", graphql_name="outlierConfiguration"
    )

    runbook_url = sgqlc.types.Field(String, graphql_name="runbookUrl")

    signal = sgqlc.types.Field("AlertsNrqlConditionSignalInput", graphql_name="signal")

    target_entity = sgqlc.types.Field(EntityGuid, graphql_name="targetEntity")

    terms = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null("AlertsNrqlDynamicConditionTermsInput")
            )
        ),
        graphql_name="terms",
    )

    title_template = sgqlc.types.Field(String, graphql_name="titleTemplate")

    violation_time_limit = sgqlc.types.Field(
        AlertsViolationTimeLimit, graphql_name="violationTimeLimit"
    )

    violation_time_limit_seconds = sgqlc.types.Field(
        Seconds, graphql_name="violationTimeLimitSeconds"
    )

# %% [markdown]
# #### 161. `AlertsNrqlConditionPredictionInput`

# %% [markdown]
# Information for generating the prediction to be used in predictive alerting.
#
#
# Available input fields:
#
#
#
# * `predictBy` : The duration, in seconds, that the prediction should look into the future.
# * `preferPredictionViolation` : If a prediction incident is open when a term's static threshold is breached by the actual signal, default behavior is to close the prediction incident and open a static incident. Setting `preferPredictionViolation` to `true` overrides this behavior leaving the prediction incident open and preventing a static incident from opening.

# %%
# | export
class AlertsNrqlConditionPredictionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("predict_by", "prefer_prediction_violation")
    predict_by = sgqlc.types.Field(Seconds, graphql_name="predictBy")

    prefer_prediction_violation = sgqlc.types.Field(
        Boolean, graphql_name="preferPredictionViolation"
    )

# %% [markdown]
# #### 162. `AlertsNrqlConditionQueryInput`

# %% [markdown]
# Information for generating the condition NRQL query.
# The output of data from this NRQL query will be compared to the condition terms to detect violations.
#
#
# Available input fields:
#
#
#
# * `dataAccountId` : The New Relic account ID to use as the basis for the NRQL alert condition's `query`; will default to the condition's account ID if unspecified.
# * `evaluationOffset` : Deprecated; superseded by `signal.aggregationMethod` with `signal.aggregationDelay` or `signal.aggregationTimer`.
#
# By default, we evaluate the NRQL query in one-minute time windows. Start time depends on the value you select in the NRQL condition's `evaluationOffset`. Evaluation offset cannot be greater than 60 minutes.
#
# This value is the number of time windows we look back at the aggregated.
#
# Example: With an `evaluationOffset` of 3, the NRQL time window applied to your query will be:
#
# `SINCE 3 minutes ago UNTIL 2 minutes ago`
# * `query` : NRQL syntax that defines the query.

# %%
# | export
class AlertsNrqlConditionQueryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("data_account_id", "evaluation_offset", "query")
    data_account_id = sgqlc.types.Field(Int, graphql_name="dataAccountId")

    evaluation_offset = sgqlc.types.Field(Int, graphql_name="evaluationOffset")

    query = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="query")

# %% [markdown]
# #### 163. `AlertsNrqlConditionSignalInput`

# %% [markdown]
# Configuration that defines the signal that the NRQL condition will use to evaluate.
#
#
# Available input fields:
#
#
#
# * `aggregationDelay` : How long we wait for data that belongs in each aggregation window. Depending
# on your data, a longer delay may increase accuracy but delay notifications.
#
# Use `aggregationDelay` with the `EVENT_FLOW` and `CADENCE` methods. The maximum
# delay is **1200 seconds** (20 minutes) when using `EVENT_FLOW` and **3600 seconds**
# (60 minutes) when using `CADENCE`. In both cases, the minimum delay is **0 seconds**
# and the default is **120 seconds**.
#
# When using `aggregationDelay`, do **not** use `evaluationOffset`.
# * `aggregationMethod` : The method that determines when we consider an aggregation window to be complete
# so that we can evaluate the signal for violations. Default is `EVENT_FLOW`.
#
# When using any `aggregationMethod`, do **not** use `evaluationOffset`.
#
# When using the `aggregationMethod` with `EVENT_TIMER`, use `aggregationTimer`.
# For `EVENT_FLOW` and `CADENCE`, use `aggregationDelay`.
# * `aggregationTimer` : How long we wait after each data point arrives to make sure we've processed
# the whole batch.
#
# Use `aggregationTimer` with the `EVENT_TIMER` method. The timer value can range
# from **5 seconds** to **1200 seconds** (20 minutes); the default is **60 seconds**.
#
# When using `aggregationTimer`, do **not** use `evaluationOffset`.
# * `aggregationWindow` : Aggregation window controls the duration of the time window used to evaluate the NRQL query, in seconds.
# The value must be at least 30 seconds, and no more than 6 hours (21600 seconds). Default is 60 seconds.
# * `evaluationDelay` : How long we wait until the signal starts evaluating. The maximum delay is **7200 seconds** (120 minutes).
# * `evaluationOffset` : Deprecated; superseded by `signal.aggregationMethod` with `signal.aggregationDelay` or `signal.aggregationTimer`.
#
# By default, we evaluate the NRQL query in one-minute time windows. The start time depends on the value you select in the NRQL condition's `evaluationOffset`. Evaluation offset cannot be greater than 60 minutes.
#
# This value is the number of time windows we look back at the aggregated data.
#
# Example: With an `evaluationOffset` of 3 and a 1 minute aggregation window, the NRQL time window applied to your query will be:
#
# `SINCE 3 minutes ago UNTIL 2 minutes ago`
# * `fillOption` : Option that determines the type of value that should be used to fill gaps (empty windows). Defaults to STATIC.
#
# Outlier NRQL conditions may only use NONE.
# * `fillValue` : If using the static fill option, this the value used for filling. Defaults to 0.
# * `pollingFrequency` : The frequency at which the NRQL will be executed and the results will be evaluated, in seconds.
#
# Polling cannot happen more frequently than 3600 seconds (1 hour), and must be specified in whole hour increments.
# Example: Frequency may be 3600 seconds (1 hour), but not 5400 seconds (1.5 hours).
#
# Polling cannot happen less frequently than the duration of the warning term, critical term, or 24 hours, whichever is shortest.
# Example: If the warning term duration is 2 days and the critical term duration is 3 days, the polling must be no less frequent than once every 86400 seconds (24 hours).
# Example: If the warning term duration is 6 hours and the critical term duration is 12 hours, the polling must be no less frequent than once every 21600 seconds (6 hours).
#
# Default polling frequency will be 3600 seconds (1 hour).
#
# Only valid for NRQL conditions with CloudCost, KubernetesCost, or CloudCostEstimate event types. Conditions for these event types are evaluated in a polling fashion.
# * `slideBy` : This setting gathers data in overlapping time windows to smooth the chart line, making it easier to spot trends.
#
# The `slideBy` value is specified in seconds and must be **smaller than** and **a factor of** the `aggregationWindow`.
#
# Cannot be used with:
# - Outlier NRQL conditions

# %%
# | export
class AlertsNrqlConditionSignalInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aggregation_delay",
        "aggregation_method",
        "aggregation_timer",
        "aggregation_window",
        "evaluation_delay",
        "evaluation_offset",
        "fill_option",
        "fill_value",
        "polling_frequency",
        "slide_by",
    )
    aggregation_delay = sgqlc.types.Field(Seconds, graphql_name="aggregationDelay")

    aggregation_method = sgqlc.types.Field(
        AlertsSignalAggregationMethod, graphql_name="aggregationMethod"
    )

    aggregation_timer = sgqlc.types.Field(Seconds, graphql_name="aggregationTimer")

    aggregation_window = sgqlc.types.Field(Seconds, graphql_name="aggregationWindow")

    evaluation_delay = sgqlc.types.Field(Seconds, graphql_name="evaluationDelay")

    evaluation_offset = sgqlc.types.Field(Int, graphql_name="evaluationOffset")

    fill_option = sgqlc.types.Field(AlertsFillOption, graphql_name="fillOption")

    fill_value = sgqlc.types.Field(Float, graphql_name="fillValue")

    polling_frequency = sgqlc.types.Field(Seconds, graphql_name="pollingFrequency")

    slide_by = sgqlc.types.Field(Seconds, graphql_name="slideBy")

# %% [markdown]
# #### 164. `AlertsNrqlConditionStaticInput`

# %% [markdown]
# Input for creating a static NRQL condition.
#
#
# Available input fields:
#
#
#
# * `description` : The custom violation description.
# * `enabled` : Whether the NRQL condition is enabled.
# * `expiration` : Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
# * `name` : Name of the NRQL condition.
# * `nrql` : The NRQL query that defines the signal for the condition.
# * `runbookUrl` : Runbook URL.
# * `signal` : Configuration that defines the signal that the NRQL condition will use to evaluate.
# * `targetEntity` : BETA PREVIEW: The `targetEntity` field is in limited preview. The entity explicitly targeted by the condition.
# * `terms` : List of critical and warning terms for the condition.
#
# Terms are required in most cases. For conditions with a loss of signal threshold only, terms can be blank.
# * `titleTemplate` : This field allows you to create a custom title to be used when incidents are opened by the condition. Setting this field will override the default title. Must be [Handlebars format](https://handlebarsjs.com/guide/).
# * `valueFunction` : Deprecated - use `signal.slideBy` instead.
#
# Function used to aggregate the NRQL query value(s) for comparison to the `terms.threshold`. When the result of this aggregate surpasses the `terms.threshold`, a violation is opened.
# * `violationTimeLimit` : Deprecated - use violationTimeLimitSeconds for full range of values.
#
# Duration after which a violation automatically closes. Default is THIRTY_DAYS.
# * `violationTimeLimitSeconds` : Duration after which a violation automatically closes in seconds.
# Accepts values between 300 seconds (5 minutes) and 2592000 seconds (30 days).
#
# Default is 3 days (259200 seconds).

# %%
# | export
class AlertsNrqlConditionStaticInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "expiration",
        "name",
        "nrql",
        "runbook_url",
        "signal",
        "target_entity",
        "terms",
        "title_template",
        "value_function",
        "violation_time_limit",
        "violation_time_limit_seconds",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    expiration = sgqlc.types.Field(
        AlertsNrqlConditionExpirationInput, graphql_name="expiration"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlConditionQueryInput), graphql_name="nrql"
    )

    runbook_url = sgqlc.types.Field(String, graphql_name="runbookUrl")

    signal = sgqlc.types.Field(AlertsNrqlConditionSignalInput, graphql_name="signal")

    target_entity = sgqlc.types.Field(EntityGuid, graphql_name="targetEntity")

    terms = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("AlertsNrqlConditionTermsInput")),
        graphql_name="terms",
    )

    title_template = sgqlc.types.Field(String, graphql_name="titleTemplate")

    value_function = sgqlc.types.Field(
        AlertsNrqlStaticConditionValueFunction, graphql_name="valueFunction"
    )

    violation_time_limit = sgqlc.types.Field(
        AlertsViolationTimeLimit, graphql_name="violationTimeLimit"
    )

    violation_time_limit_seconds = sgqlc.types.Field(
        Seconds, graphql_name="violationTimeLimitSeconds"
    )

# %% [markdown]
# #### 165. `AlertsNrqlConditionTermsInput`

# %% [markdown]
# NRQL condition terms determine when a violation will be opened.
#
#
# Available input fields:
#
#
#
# * `disableHealthStatusReporting` : Violations will not change system health status for this term.
# * `operator` : Operator used to compare against the threshold.
# * `prediction` : Use `prediction` to open alerts when your static threshold is predicted to be reached in the future.
#
# Note that the predictive alerts feature are available only to [Advanced Compute](https://newrelic.com/pricing/compute#pricing_plan-compute) customers.
# * `priority` : Priority determines how much attention your incidents need. Your workflow settings then tell us when and where to send notifications for different priorities.
# * `threshold` : Value that triggers a violation.
# * `thresholdDuration` : The duration, in seconds, that the threshold must violate for in order to create a violation.
# This value must be within 60-86400 seconds and must be a multiple of the aggregation window.
# (Default aggregation window duration is 60 seconds.)
# * `thresholdOccurrences` : How many data points must be in violation for the specified thresholdDuration.

# %%
# | export
class AlertsNrqlConditionTermsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "disable_health_status_reporting",
        "operator",
        "prediction",
        "priority",
        "threshold",
        "threshold_duration",
        "threshold_occurrences",
    )
    disable_health_status_reporting = sgqlc.types.Field(
        Boolean, graphql_name="disableHealthStatusReporting"
    )

    operator = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlConditionTermsOperator), graphql_name="operator"
    )

    prediction = sgqlc.types.Field(
        AlertsNrqlConditionPredictionInput, graphql_name="prediction"
    )

    priority = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlConditionPriority), graphql_name="priority"
    )

    threshold = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="threshold")

    threshold_duration = sgqlc.types.Field(
        sgqlc.types.non_null(Seconds), graphql_name="thresholdDuration"
    )

    threshold_occurrences = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlConditionThresholdOccurrences),
        graphql_name="thresholdOccurrences",
    )

# %% [markdown]
# #### 166. `AlertsNrqlConditionUpdateBaselineInput`

# %% [markdown]
# Input for updating a baseline NRQL condition.
#
#
# Available input fields:
#
#
#
# * `baselineDirection` : Direction in which the baseline is set on condition.
# * `description` : The custom violation description.
# * `enabled` : Whether the NRQL condition is enabled.
# * `expiration` : Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
# * `name` : Name of the NRQL condition.
# * `nrql` : The NRQL query that defines the signal for the condition.
# * `runbookUrl` : Runbook URL.
# * `signal` : Configuration that defines the signal that the NRQL condition will use to evaluate.
# * `signalSeasonality` : Seasonality under which the condition's signal(s) are evaluated. To have New Relic calculate seasonality automatically, set to `NEW_RELIC_CALCULATION` (default). To turn off seasonality completely, set to `NONE`.
# * `targetEntity` : BETA PREVIEW: The `targetEntity` field is in limited preview. The entity explicitly targeted by the condition.
# * `terms` : List of critical and warning terms for the condition.
#
# Terms are required in most cases. For conditions with a loss of signal threshold only, terms can be blank.
# * `titleTemplate` : This field allows you to create a custom title to be used when incidents are opened by the condition. Setting this field will override the default title. Must be [Handlebars format](https://handlebarsjs.com/guide/).
# * `violationTimeLimit` : Deprecated - use violationTimeLimitSeconds for full range of values.
#
# Duration after which a violation automatically closes. Default is THIRTY_DAYS.
# * `violationTimeLimitSeconds` : Duration after which a violation automatically closes in seconds.
# Accepts values between 300 seconds (5 minutes) and 2592000 seconds (30 days).
#
# Default is 3 days (259200 seconds).

# %%
# | export
class AlertsNrqlConditionUpdateBaselineInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "baseline_direction",
        "description",
        "enabled",
        "expiration",
        "name",
        "nrql",
        "runbook_url",
        "signal",
        "signal_seasonality",
        "target_entity",
        "terms",
        "title_template",
        "violation_time_limit",
        "violation_time_limit_seconds",
    )
    baseline_direction = sgqlc.types.Field(
        AlertsNrqlBaselineDirection, graphql_name="baselineDirection"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    expiration = sgqlc.types.Field(
        AlertsNrqlConditionExpirationInput, graphql_name="expiration"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    nrql = sgqlc.types.Field("AlertsNrqlConditionUpdateQueryInput", graphql_name="nrql")

    runbook_url = sgqlc.types.Field(String, graphql_name="runbookUrl")

    signal = sgqlc.types.Field(AlertsNrqlConditionSignalInput, graphql_name="signal")

    signal_seasonality = sgqlc.types.Field(
        AlertsNrqlSignalSeasonality, graphql_name="signalSeasonality"
    )

    target_entity = sgqlc.types.Field(EntityGuid, graphql_name="targetEntity")

    terms = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("AlertsNrqlDynamicConditionTermsInput")
        ),
        graphql_name="terms",
    )

    title_template = sgqlc.types.Field(String, graphql_name="titleTemplate")

    violation_time_limit = sgqlc.types.Field(
        AlertsViolationTimeLimit, graphql_name="violationTimeLimit"
    )

    violation_time_limit_seconds = sgqlc.types.Field(
        Seconds, graphql_name="violationTimeLimitSeconds"
    )

# %% [markdown]
# #### 167. `AlertsNrqlConditionUpdateOutlierInput`

# %% [markdown]
# Input for updating an outlier NRQL condition.
#
#
# Available input fields:
#
#
#
# * `description` : The custom violation description.
# * `enabled` : Whether the NRQL condition is enabled.
# * `expiration` : Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
# * `name` : Name of the NRQL condition.
# * `nrql` : The NRQL query that defines the signal for the condition.
# * `outlierConfiguration` : Configuration that defines the outlier detection settings for the NRQL condition.
# * `runbookUrl` : Runbook URL.
# * `signal` : Configuration that defines the signal that the NRQL condition will use to evaluate.
# * `targetEntity` : BETA PREVIEW: The `targetEntity` field is in limited preview. The entity explicitly targeted by the condition.
# * `terms` : List of critical and warning terms for the condition.
# * `titleTemplate` : This field allows you to create a custom title to be used when incidents are opened by the condition. Setting this field will override the default title. Must be [Handlebars format](https://handlebarsjs.com/guide/).
# * `violationTimeLimit` : Deprecated - use violationTimeLimitSeconds for full range of values.
#
# Duration after which a violation automatically closes. Default is THIRTY_DAYS.
# * `violationTimeLimitSeconds` : Duration after which a violation automatically closes in seconds.
# Accepts values between 300 seconds (5 minutes) and 2592000 seconds (30 days).
#
# Default is 3 days (259200 seconds).

# %%
# | export
class AlertsNrqlConditionUpdateOutlierInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "expiration",
        "name",
        "nrql",
        "outlier_configuration",
        "runbook_url",
        "signal",
        "target_entity",
        "terms",
        "title_template",
        "violation_time_limit",
        "violation_time_limit_seconds",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    expiration = sgqlc.types.Field(
        AlertsNrqlConditionExpirationInput, graphql_name="expiration"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    nrql = sgqlc.types.Field("AlertsNrqlConditionUpdateQueryInput", graphql_name="nrql")

    outlier_configuration = sgqlc.types.Field(
        "AlertsOutlierConfigurationInput", graphql_name="outlierConfiguration"
    )

    runbook_url = sgqlc.types.Field(String, graphql_name="runbookUrl")

    signal = sgqlc.types.Field(AlertsNrqlConditionSignalInput, graphql_name="signal")

    target_entity = sgqlc.types.Field(EntityGuid, graphql_name="targetEntity")

    terms = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("AlertsNrqlDynamicConditionTermsInput")
        ),
        graphql_name="terms",
    )

    title_template = sgqlc.types.Field(String, graphql_name="titleTemplate")

    violation_time_limit = sgqlc.types.Field(
        AlertsViolationTimeLimit, graphql_name="violationTimeLimit"
    )

    violation_time_limit_seconds = sgqlc.types.Field(
        Seconds, graphql_name="violationTimeLimitSeconds"
    )

# %% [markdown]
# #### 168. `AlertsNrqlConditionUpdateQueryInput`

# %% [markdown]
# Information for generating the condition NRQL query.
# Output from this NRQL query will be compared to the condition terms to detect violations.
#
#
# Available input fields:
#
#
#
# * `dataAccountId` : The New Relic account ID to use as the basis for the NRQL alert condition's `query`; will default to the condition's account ID if unspecified.
# * `evaluationOffset` : Deprecated; superseded by `signal.aggregationMethod` with `signal.aggregationDelay` or `signal.aggregationTimer`.
#
# By default, we evaluate the NRQL query in one-minute time windows. Start time depends on the value you select in the NRQL condition's `evaluationOffset`. Evaluation offset cannot be greater than 60 minutes.
#
# This value is the number of time windows we look back at the aggregated data.
#
# Example: With an `evaluationOffset` of 3, the NRQL time window applied to your query will be:
#
# `SINCE 3 minutes ago UNTIL 2 minutes ago`
# * `query` : NRQL syntax that defines the query.

# %%
# | export
class AlertsNrqlConditionUpdateQueryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("data_account_id", "evaluation_offset", "query")
    data_account_id = sgqlc.types.Field(Int, graphql_name="dataAccountId")

    evaluation_offset = sgqlc.types.Field(Int, graphql_name="evaluationOffset")

    query = sgqlc.types.Field(String, graphql_name="query")

# %% [markdown]
# #### 169. `AlertsNrqlConditionUpdateStaticInput`

# %% [markdown]
# Input for updating a static NRQL condition.
#
#
# Available input fields:
#
#
#
# * `description` : The custom violation description.
# * `enabled` : Whether the NRQL condition is enabled.
# * `expiration` : Also known as **loss of signal**, these are settings for how violations are opened or closed when a signal expires.
# * `name` : Name of the NRQL condition.
# * `nrql` : The NRQL query that defines the signal for the condition.
# * `runbookUrl` : Runbook URL.
# * `signal` : Configuration that defines the signal that the NRQL condition will use to evaluate.
# * `targetEntity` : BETA PREVIEW: The `targetEntity` field is in limited preview. The entity explicitly targeted by the condition.
# * `terms` : List of critical and warning terms for the condition.
#
# Terms are required in most cases. For conditions with a loss of signal threshold only, terms can be blank.
# * `titleTemplate` : This field allows you to create a custom title to be used when incidents are opened by the condition. Setting this field will override the default title. Must be [Handlebars format](https://handlebarsjs.com/guide/).
# * `valueFunction` : Deprecated - use `signal.slideBy` instead.
#
# Function used to aggregate the NRQL query value(s) for comparison to the `terms.threshold`. When the result of this aggregate surpasses the `terms.threshold`, a violation is opened.
# * `violationTimeLimit` : Deprecated - use violationTimeLimitSeconds for full range of values.
#
# Duration after which a violation automatically closes. Default is THIRTY_DAYS.
# * `violationTimeLimitSeconds` : Duration after which a violation automatically closes in seconds.
# Accepts values between 300 seconds (5 minutes) and 2592000 seconds (30 days).
#
# Default is 3 days (259200 seconds).

# %%
# | export
class AlertsNrqlConditionUpdateStaticInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "expiration",
        "name",
        "nrql",
        "runbook_url",
        "signal",
        "target_entity",
        "terms",
        "title_template",
        "value_function",
        "violation_time_limit",
        "violation_time_limit_seconds",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    expiration = sgqlc.types.Field(
        AlertsNrqlConditionExpirationInput, graphql_name="expiration"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    nrql = sgqlc.types.Field(AlertsNrqlConditionUpdateQueryInput, graphql_name="nrql")

    runbook_url = sgqlc.types.Field(String, graphql_name="runbookUrl")

    signal = sgqlc.types.Field(AlertsNrqlConditionSignalInput, graphql_name="signal")

    target_entity = sgqlc.types.Field(EntityGuid, graphql_name="targetEntity")

    terms = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(AlertsNrqlConditionTermsInput)),
        graphql_name="terms",
    )

    title_template = sgqlc.types.Field(String, graphql_name="titleTemplate")

    value_function = sgqlc.types.Field(
        AlertsNrqlStaticConditionValueFunction, graphql_name="valueFunction"
    )

    violation_time_limit = sgqlc.types.Field(
        AlertsViolationTimeLimit, graphql_name="violationTimeLimit"
    )

    violation_time_limit_seconds = sgqlc.types.Field(
        Seconds, graphql_name="violationTimeLimitSeconds"
    )

# %% [markdown]
# #### 170. `AlertsNrqlConditionsSearchCriteriaInput`

# %% [markdown]
# Search criteria for returning specific NRQL conditions.
#
#
# Available input fields:
#
#
#
# * `name` : Exact name of the NRQL condition.
# * `nameLike` : String to partially match a NRQL condition name.
# * `policyId` : Policy ID associated with the NRQL condition.
# * `query` : Exact NRQL query used in the NRQL condition.
# * `queryLike` : String to partially match the NRQL query used in the NRQL condition.
# * `termsOperator` : Terms operator to match while searching for NRQL conditions.

# %%
# | export
class AlertsNrqlConditionsSearchCriteriaInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "name",
        "name_like",
        "policy_id",
        "query",
        "query_like",
        "terms_operator",
    )
    name = sgqlc.types.Field(String, graphql_name="name")

    name_like = sgqlc.types.Field(String, graphql_name="nameLike")

    policy_id = sgqlc.types.Field(ID, graphql_name="policyId")

    query = sgqlc.types.Field(String, graphql_name="query")

    query_like = sgqlc.types.Field(String, graphql_name="queryLike")

    terms_operator = sgqlc.types.Field(
        AlertsNrqlConditionTermsOperator, graphql_name="termsOperator"
    )

# %% [markdown]
# #### 171. `AlertsNrqlDynamicConditionTermsInput`

# %% [markdown]
# NRQL condition terms determine when a violation will be opened.
#
#
# Available input fields:
#
#
#
# * `disableHealthStatusReporting` : Violations will not change system health status for this term.
# * `operator` : Operator used to compare against the threshold.
# * `priority` : Priority determines how much attention your incidents need. Your workflow settings then tell us when and where to send notifications for different priorities.
# * `threshold` : Value that triggers a violation.
# * `thresholdDuration` : The duration, in seconds, that the threshold must violate in order to create a violation.
# Value must be within 120-86400 seconds and a multiple of the aggregation window for baseline conditions.
# (Default aggregation window duration is 60 seconds.)
# * `thresholdOccurrences` : How many data points must be in violation for the specified threshold duration.

# %%
# | export
class AlertsNrqlDynamicConditionTermsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "disable_health_status_reporting",
        "operator",
        "priority",
        "threshold",
        "threshold_duration",
        "threshold_occurrences",
    )
    disable_health_status_reporting = sgqlc.types.Field(
        Boolean, graphql_name="disableHealthStatusReporting"
    )

    operator = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlDynamicConditionTermsOperator),
        graphql_name="operator",
    )

    priority = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlConditionPriority), graphql_name="priority"
    )

    threshold = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="threshold")

    threshold_duration = sgqlc.types.Field(
        sgqlc.types.non_null(Seconds), graphql_name="thresholdDuration"
    )

    threshold_occurrences = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsNrqlConditionThresholdOccurrences),
        graphql_name="thresholdOccurrences",
    )

# %% [markdown]
# #### 172. `AlertsOpsGenieNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new OpsGenie notification channel.
#
#
# Available input fields:
#
#
#
# * `apiKey` : API key.
# * `dataCenterRegion` : OpsGenie data center region.
# * `name` : Notification channel name.
# * `recipients` : List of email recipients.
# * `tags` : Tags.
# * `teams` : Teams.

# %%
# | export
class AlertsOpsGenieNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "api_key",
        "data_center_region",
        "name",
        "recipients",
        "tags",
        "teams",
    )
    api_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiKey"
    )

    data_center_region = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsOpsGenieDataCenterRegion),
        graphql_name="dataCenterRegion",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    recipients = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="recipients"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="tags"
    )

    teams = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="teams"
    )

# %% [markdown]
# #### 173. `AlertsOpsGenieNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing OpsGenie notification channel.
#
#
# Available input fields:
#
#
#
# * `apiKey` : API key.
# * `dataCenterRegion` : OpsGenie data center region.
# * `name` : Notification channel name.
# * `recipients` : List of email recipients.
# * `tags` : Tags.
# * `teams` : Teams.

# %%
# | export
class AlertsOpsGenieNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "api_key",
        "data_center_region",
        "name",
        "recipients",
        "tags",
        "teams",
    )
    api_key = sgqlc.types.Field(SecureValue, graphql_name="apiKey")

    data_center_region = sgqlc.types.Field(
        AlertsOpsGenieDataCenterRegion, graphql_name="dataCenterRegion"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    recipients = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="recipients"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="tags"
    )

    teams = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="teams"
    )

# %% [markdown]
# #### 174. `AlertsOutlierAlgorithmDbScanConfigurationInput`

# %% [markdown]
# Input representing the outlier detection configuration settings for the DBSCAN algorithm.
#
#
# Available input fields:
#
#
#
# * `epsilon` : The maximum distance between two samples for one to be considered as in the neighborhood of the other. A lower value creates more distinct clusters.
# * `evaluationGroupFacet` : The facet name to pre-group data by before applying the outlier detection algorithm. If not specified, the algorithm is applied to all returned data.
# * `minimumPoints` : The number of samples in a neighborhood for a point to be considered as a core point.

# %%
# | export
class AlertsOutlierAlgorithmDbScanConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("epsilon", "evaluation_group_facet", "minimum_points")
    epsilon = sgqlc.types.Field(Float, graphql_name="epsilon")

    evaluation_group_facet = sgqlc.types.Field(
        String, graphql_name="evaluationGroupFacet"
    )

    minimum_points = sgqlc.types.Field(Int, graphql_name="minimumPoints")

# %% [markdown]
# #### 175. `AlertsOutlierConfigurationInput`

# %% [markdown]
# Input representing the outlier detection configuration settings for the various algorithms.
#
#
# Available input fields:
#
#
#
# * `dbscan` : Configuration for the DBSCAN outlier detection algorithm.

# %%
# | export
class AlertsOutlierConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("dbscan",)
    dbscan = sgqlc.types.Field(
        AlertsOutlierAlgorithmDbScanConfigurationInput, graphql_name="dbscan"
    )

# %% [markdown]
# #### 176. `AlertsPagerDutyNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new PagerDuty notification channel.
#
#
# Available input fields:
#
#
#
# * `apiKey` : API key.
# * `name` : Notification channel name.

# %%
# | export
class AlertsPagerDutyNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("api_key", "name")
    api_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiKey"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 177. `AlertsPagerDutyNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing PagerDuty notification channel.
#
#
# Available input fields:
#
#
#
# * `apiKey` : API key.
# * `name` : Notification channel name.

# %%
# | export
class AlertsPagerDutyNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("api_key", "name")
    api_key = sgqlc.types.Field(SecureValue, graphql_name="apiKey")

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 178. `AlertsPoliciesSearchCriteriaInput`

# %% [markdown]
# Search criteria for returning specific policies.
#
#
# Available input fields:
#
#
#
# * `ids` : The list of policy ids to return.
# * `name` : Exact name of the policy.
# * `nameLike` : String to partially match a policy name.

# %%
# | export
class AlertsPoliciesSearchCriteriaInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ids", "name", "name_like")
    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    name_like = sgqlc.types.Field(String, graphql_name="nameLike")

# %% [markdown]
# #### 179. `AlertsPolicyInput`

# %% [markdown]
# Container for conditions with associated notifications channels.
#
#
# Available input fields:
#
#
#
# * `incidentPreference` : Determines how incidents are created for critical violations of the conditions contained in the policy.
# * `name` : Description of the policy.

# %%
# | export
class AlertsPolicyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident_preference", "name")
    incident_preference = sgqlc.types.Field(
        sgqlc.types.non_null(AlertsIncidentPreference),
        graphql_name="incidentPreference",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 180. `AlertsPolicyUpdateInput`

# %% [markdown]
# Policy fields to be updated.
#
#
# Available input fields:
#
#
#
# * `incidentPreference` : Determines how incidents are created for critical violations of the conditions contained in the policy.
# * `name` : Description of the policy.

# %%
# | export
class AlertsPolicyUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("incident_preference", "name")
    incident_preference = sgqlc.types.Field(
        AlertsIncidentPreference, graphql_name="incidentPreference"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 181. `AlertsSlackNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new Slack notification channel.
#
#
# Available input fields:
#
#
#
# * `name` : Notification channel name.
# * `teamChannel` : Slack channel name.
# * `url` : Slack channel URL.

# %%
# | export
class AlertsSlackNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "team_channel", "url")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    team_channel = sgqlc.types.Field(String, graphql_name="teamChannel")

    url = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="url")

# %% [markdown]
# #### 182. `AlertsSlackNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing Slack notification channel.
#
#
# Available input fields:
#
#
#
# * `name` : Notification channel name.
# * `teamChannel` : Slack channel name.
# * `url` : Slack channel URL.

# %%
# | export
class AlertsSlackNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "team_channel", "url")
    name = sgqlc.types.Field(String, graphql_name="name")

    team_channel = sgqlc.types.Field(String, graphql_name="teamChannel")

    url = sgqlc.types.Field(SecureValue, graphql_name="url")

# %% [markdown]
# #### 183. `AlertsVictorOpsNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new VictorOps notification channel.
#
#
# Available input fields:
#
#
#
# * `key` : Key.
# * `name` : Notification channel name.
# * `routeKey` : Route key.

# %%
# | export
class AlertsVictorOpsNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "name", "route_key")
    key = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="key")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    route_key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="routeKey")

# %% [markdown]
# #### 184. `AlertsVictorOpsNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing VictorOps notification channel.
#
#
# Available input fields:
#
#
#
# * `key` : Key.
# * `name` : Notification channel name.
# * `routeKey` : Route key.

# %%
# | export
class AlertsVictorOpsNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "name", "route_key")
    key = sgqlc.types.Field(SecureValue, graphql_name="key")

    name = sgqlc.types.Field(String, graphql_name="name")

    route_key = sgqlc.types.Field(String, graphql_name="routeKey")

# %% [markdown]
# #### 185. `AlertsWebhookBasicAuthMutationInput`

# %% [markdown]
# Webhook basic auth
#
#
# Available input fields:
#
#
#
# * `password` : Password
# * `username` : Username

# %%
# | export
class AlertsWebhookBasicAuthMutationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("password", "username")
    password = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="password"
    )

    username = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="username")

# %% [markdown]
# #### 186. `AlertsWebhookCustomHeaderMutationInput`

# %% [markdown]
# Webhook header
#
#
# Available input fields:
#
#
#
# * `name` : Header name
# * `value` : Header value

# %%
# | export
class AlertsWebhookCustomHeaderMutationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "value")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    value = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="value")

# %% [markdown]
# #### 187. `AlertsWebhookNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new Webhook notification channel.
#
#
# Available input fields:
#
#
#
# * `baseUrl` : Base URL.
# * `basicAuth` : Basic auth.
# * `customHttpHeaders` : Custom HTTP headers.
# * `customPayloadBody` : Custom payload body.
# * `customPayloadType` : Custom payload type.
# * `name` : Notification channel name.

# %%
# | export
class AlertsWebhookNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "base_url",
        "basic_auth",
        "custom_http_headers",
        "custom_payload_body",
        "custom_payload_type",
        "name",
    )
    base_url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="baseUrl")

    basic_auth = sgqlc.types.Field(
        AlertsWebhookBasicAuthMutationInput, graphql_name="basicAuth"
    )

    custom_http_headers = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AlertsWebhookCustomHeaderMutationInput)
        ),
        graphql_name="customHttpHeaders",
    )

    custom_payload_body = sgqlc.types.Field(String, graphql_name="customPayloadBody")

    custom_payload_type = sgqlc.types.Field(
        AlertsWebhookCustomPayloadType, graphql_name="customPayloadType"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 188. `AlertsWebhookNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing Webhook notification channel.
#
#
# Available input fields:
#
#
#
# * `baseUrl` : Base URL.
# * `basicAuth` : Basic auth.
# * `customHttpHeaders` : Custom HTTP headers.
# * `customPayloadBody` : Custom payload body.
# * `customPayloadType` : Custom payload type.
# * `name` : Notification channel name.

# %%
# | export
class AlertsWebhookNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "base_url",
        "basic_auth",
        "custom_http_headers",
        "custom_payload_body",
        "custom_payload_type",
        "name",
    )
    base_url = sgqlc.types.Field(String, graphql_name="baseUrl")

    basic_auth = sgqlc.types.Field(
        AlertsWebhookBasicAuthMutationInput, graphql_name="basicAuth"
    )

    custom_http_headers = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AlertsWebhookCustomHeaderMutationInput)
        ),
        graphql_name="customHttpHeaders",
    )

    custom_payload_body = sgqlc.types.Field(String, graphql_name="customPayloadBody")

    custom_payload_type = sgqlc.types.Field(
        AlertsWebhookCustomPayloadType, graphql_name="customPayloadType"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 189. `AlertsXMattersNotificationChannelCreateInput`

# %% [markdown]
# The input for creating a new xMatters notification channel.
#
#
# Available input fields:
#
#
#
# * `integrationUrl` : Integration URL.
# * `name` : Notification channel name.

# %%
# | export
class AlertsXMattersNotificationChannelCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("integration_url", "name")
    integration_url = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="integrationUrl"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 190. `AlertsXMattersNotificationChannelUpdateInput`

# %% [markdown]
# The input for updating an existing xMatters notification channel.
#
#
# Available input fields:
#
#
#
# * `integrationUrl` : Integration URL.
# * `name` : Notification channel name.

# %%
# | export
class AlertsXMattersNotificationChannelUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("integration_url", "name")
    integration_url = sgqlc.types.Field(SecureValue, graphql_name="integrationUrl")

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 191. `ApiAccessCreateIngestKeyInput`

# %% [markdown]
# The input for any ingest keys you want to create. Each ingest key must have a type that communicates what kind of data it is for. You can optionally add a name or notes to your key, which can be updated later.
#
#
# Available input fields:
#
#
#
# * `accountId` : The account ID indicating which account you want to make the key for. This cannot be updated once created.
# * `ingestType` : The type of ingest key you want to create. This cannot be updated once created.
# * `name` : The name of the key. This can be updated later.
# * `notes` : Any notes about this ingest key. This can be updated later.

# %%
# | export
class ApiAccessCreateIngestKeyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "ingest_type", "name", "notes")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    ingest_type = sgqlc.types.Field(
        sgqlc.types.non_null(ApiAccessIngestKeyType), graphql_name="ingestType"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    notes = sgqlc.types.Field(String, graphql_name="notes")

# %% [markdown]
# #### 192. `ApiAccessCreateInput`

# %% [markdown]
# The input object to create one or more keys.
#
#
# Available input fields:
#
#
#
# * `ingest` : Ingest keys are used by agents to report data about your applications to New Relic. Each ingest key input entered here must have a type that communicates what kind of data it is for. You can optionally add a name or notes to your key, which can be updated later.
# * `user` : Create user keys. You can optionally add a name or notes to your key, which can be updated later.

# %%
# | export
class ApiAccessCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ingest", "user")
    ingest = sgqlc.types.Field(
        sgqlc.types.list_of(ApiAccessCreateIngestKeyInput), graphql_name="ingest"
    )

    user = sgqlc.types.Field(
        sgqlc.types.list_of("ApiAccessCreateUserKeyInput"), graphql_name="user"
    )

# %% [markdown]
# #### 193. `ApiAccessCreateUserKeyInput`

# %% [markdown]
# The input for any ingest keys you want to create. Each ingest key must have a type that communicates what kind of data it is for. You can optionally add a name or notes to your key, which can be updated later.
#
#
# Available input fields:
#
#
#
# * `accountId` : The account ID indicating which account you want to make the key for. This cannot be updated once created.
# * `name` : The name of the key. This can be updated later.
# * `notes` : Any notes about this ingest key. This can be updated later.
# * `userId` : The user ID indicating which user you want to make the key for. This cannot be updated once created.

# %%
# | export
class ApiAccessCreateUserKeyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "name", "notes", "user_id")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    name = sgqlc.types.Field(String, graphql_name="name")

    notes = sgqlc.types.Field(String, graphql_name="notes")

    user_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="userId")

# %% [markdown]
# #### 194. `ApiAccessDeleteInput`

# %% [markdown]
# The input to delete keys.
#
#
# Available input fields:
#
#
#
# * `ingestKeyIds` : A list of the ingest key `id`s that you want to delete.
# * `userKeyIds` : A list of the user key `id`s that you want to delete.

# %%
# | export
class ApiAccessDeleteInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ingest_key_ids", "user_key_ids")
    ingest_key_ids = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="ingestKeyIds"
    )

    user_key_ids = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="userKeyIds"
    )

# %% [markdown]
# #### 195. `ApiAccessKeySearchQuery`

# %% [markdown]
# Parameters by which to filter the search.
#
#
# Available input fields:
#
#
#
# * `scope` : Criteria by which to narrow the scope of keys to be returned.
# * `types` : A list of key types to be included in the search. If no types are provided, all types will be returned by default.

# %%
# | export
class ApiAccessKeySearchQuery(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("scope", "types")
    scope = sgqlc.types.Field("ApiAccessKeySearchScope", graphql_name="scope")

    types = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(ApiAccessKeyType)),
        graphql_name="types",
    )

# %% [markdown]
# #### 196. `ApiAccessKeySearchScope`

# %% [markdown]
# The scope of keys to be returned. Note that some filters only apply to certain key types.
#
#
# Available input fields:
#
#
#
# * `accountIds` : A list of key account IDs.
# * `ingestTypes` : The ingest type of the key. Only applies to ingest keys, and does not affect user key filtering.
# * `userIds` : A list of key user ids. Only applies to user keys, and does not affect ingest key filtering.

# %%
# | export
class ApiAccessKeySearchScope(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids", "ingest_types", "user_ids")
    account_ids = sgqlc.types.Field(sgqlc.types.list_of(Int), graphql_name="accountIds")

    ingest_types = sgqlc.types.Field(
        sgqlc.types.list_of(ApiAccessIngestKeyType), graphql_name="ingestTypes"
    )

    user_ids = sgqlc.types.Field(sgqlc.types.list_of(Int), graphql_name="userIds")

# %% [markdown]
# #### 197. `ApiAccessUpdateIngestKeyInput`

# %% [markdown]
# The `id` and data to update one or more keys.
#
#
# Available input fields:
#
#
#
# * `keyId` : The `id` of the key you want to update.
# * `name` : The name you want to assign to the key.
# * `notes` : The notes you want to assign to the key.

# %%
# | export
class ApiAccessUpdateIngestKeyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key_id", "name", "notes")
    key_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="keyId")

    name = sgqlc.types.Field(String, graphql_name="name")

    notes = sgqlc.types.Field(String, graphql_name="notes")

# %% [markdown]
# #### 198. `ApiAccessUpdateInput`

# %% [markdown]
# The `id` and data to update one or more keys.
#
#
# Available input fields:
#
#
#
# * `ingest` : A list of the configurations of each ingest key you want to update.
# * `user` : A list of the configurations of each user key you want to update.

# %%
# | export
class ApiAccessUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ingest", "user")
    ingest = sgqlc.types.Field(
        sgqlc.types.list_of(ApiAccessUpdateIngestKeyInput), graphql_name="ingest"
    )

    user = sgqlc.types.Field(
        sgqlc.types.list_of("ApiAccessUpdateUserKeyInput"), graphql_name="user"
    )

# %% [markdown]
# #### 199. `ApiAccessUpdateUserKeyInput`

# %% [markdown]
# The `id` and data to update one or more keys.
#
#
# Available input fields:
#
#
#
# * `keyId` : The `id` of the key you want to update.
# * `name` : The name you want to assign to the key.
# * `notes` : The notes you want to assign to the key.

# %%
# | export
class ApiAccessUpdateUserKeyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key_id", "name", "notes")
    key_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="keyId")

    name = sgqlc.types.Field(String, graphql_name="name")

    notes = sgqlc.types.Field(String, graphql_name="notes")

# %% [markdown]
# #### 200. `ApmApplicationEntitySettings`

# %% [markdown]
# The ApmApplicationEntity's settings to update.
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The ApmApplicationEntity's apdex target. For documentation on using apdex effectively, visit [our docs about apdex](https://docs.newrelic.com/docs/apm/new-relic-apm/apdex/apdex-measure-user-satisfaction).

# %%
# | export
class ApmApplicationEntitySettings(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("apdex_target",)
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

# %% [markdown]
# #### 201. `AuthorizationManagementAccountAccessGrant`

# %% [markdown]
# The Account and Role a Group should have access to
#
#
# Available input fields:
#
#
#
# * `accountId` : The Account ID the Role will grant access to
# * `dataAccessPolicyId` : The Data Access Policy ID will define what data in an account is allowed
# * `roleId` : The Role ID that will define the access

# %%
# | export
class AuthorizationManagementAccountAccessGrant(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "data_access_policy_id", "role_id")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    data_access_policy_id = sgqlc.types.Field(ID, graphql_name="dataAccessPolicyId")

    role_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="roleId")

# %% [markdown]
# #### 202. `AuthorizationManagementAccountAccessGrantUpdate`

# %% [markdown]
# The Data Access Policy a Grant should have
#
#
# Available input fields:
#
#
#
# * `dataAccessPolicyId` : defines what data is allowed. Grants without a data access policy id allow
#   access to all data by default. Use `null`  to remove a data access policy id from access grants.

# %%
# | export
class AuthorizationManagementAccountAccessGrantUpdate(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("data_access_policy_id",)
    data_access_policy_id = sgqlc.types.Field(ID, graphql_name="dataAccessPolicyId")

# %% [markdown]
# #### 203. `AuthorizationManagementEntity`

# %% [markdown]
# The Entity a Group should have access to
#
#
# Available input fields:
#
#
#
# * `id` : The Entity id that will define the Entity's access
# * `type` : The Entity type that defines the scope (organization, account, or group)

# %%
# | export
class AuthorizationManagementEntity(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    type = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="type")

# %% [markdown]
# #### 204. `AuthorizationManagementEntityAccessGrants`

# %% [markdown]
# The Entity and Role a Group should have access to
#
#
# Available input fields:
#
#
#
# * `entity` : The Entity type that defines the scope (organization, account, or group)
# * `iamParent` : The IAM Parent entity with the given scope and entity id (organization or account)
# * `roleId` : The Role ID that will define the Entity's access

# %%
# | export
class AuthorizationManagementEntityAccessGrants(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity", "iam_parent", "role_id")
    entity = sgqlc.types.Field(
        sgqlc.types.non_null(AuthorizationManagementEntity), graphql_name="entity"
    )

    iam_parent = sgqlc.types.Field(
        "AuthorizationManagementIamParent", graphql_name="iamParent"
    )

    role_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="roleId")

# %% [markdown]
# #### 205. `AuthorizationManagementGrantAccess`

# %% [markdown]
# The input object representing the access to grant for the group
#
#
# Available input fields:
#
#
#
# * `accountAccessGrants` : The Role, Data Access Policy, and the Account that the Target Group should have access to
# * `entityAccessGrants` : The Entity and Role a Group should have access to
# * `grantee` : The Grantee to which the access will be granted
# * `groupAccessGrants` : The Role and the Group the Target Group should have access to
# * `groupId` : The Group ID that will have access granted
# * `organizationAccessGrants` : The Role and the Organization the Target Group should have access to

# %%
# | export
class AuthorizationManagementGrantAccess(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "account_access_grants",
        "entity_access_grants",
        "grantee",
        "group_access_grants",
        "group_id",
        "organization_access_grants",
    )
    account_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AuthorizationManagementAccountAccessGrant)
        ),
        graphql_name="accountAccessGrants",
    )

    entity_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AuthorizationManagementEntityAccessGrants)
        ),
        graphql_name="entityAccessGrants",
    )

    grantee = sgqlc.types.Field(
        "AuthorizationManagementGrantee", graphql_name="grantee"
    )

    group_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("AuthorizationManagementGroupAccessGrant")
        ),
        graphql_name="groupAccessGrants",
    )

    group_id = sgqlc.types.Field(ID, graphql_name="groupId")

    organization_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("AuthorizationManagementOrganizationAccessGrant")
        ),
        graphql_name="organizationAccessGrants",
    )

# %% [markdown]
# #### 206. `AuthorizationManagementGrantee`

# %% [markdown]
# The actor or group that are the recipient of the access grant
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the object that is having access modified
# * `type` : The type of the object that is having access modified. Valid values are: group, user, system_identity, system_identity_group, organization

# %%
# | export
class AuthorizationManagementGrantee(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(AuthorizationManagementGranteeTypeEnum),
        graphql_name="type",
    )

# %% [markdown]
# #### 207. `AuthorizationManagementGroupAccessGrant`

# %% [markdown]
# The Group and Role another Group should have access to
#
#
# Available input fields:
#
#
#
# * `groupId` : The Group ID the Role will grant access to
# * `roleId` : The Role ID that will define the access

# %%
# | export
class AuthorizationManagementGroupAccessGrant(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("group_id", "role_id")
    group_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="groupId")

    role_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="roleId")

# %% [markdown]
# #### 208. `AuthorizationManagementIamParent`

# %% [markdown]
# The IAM Parent entity with the given scope and entity id (organization or account)
#
#
# Available input fields:
#
#
#
# * `id` : The id of the entity at parent scope
# * `scope` : The parent IAM scope (account or organization)

# %%
# | export
class AuthorizationManagementIamParent(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "scope")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null(AuthorizationManagementIamParentScopeTypeEnum),
        graphql_name="scope",
    )

# %% [markdown]
# #### 209. `AuthorizationManagementOrganizationAccessGrant`

# %% [markdown]
# The Organization Role a Group should have access to
#
#
# Available input fields:
#
#
#
# * `roleId` : The Role ID that will define the Organization access

# %%
# | export
class AuthorizationManagementOrganizationAccessGrant(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("role_id",)
    role_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="roleId")

# %% [markdown]
# #### 210. `AuthorizationManagementRevokeAccess`

# %% [markdown]
# The input object representing the access to revoke for the group
#
#
# Available input fields:
#
#
#
# * `accountAccessGrants` : The Role, Data Access Policy, and the Account that the Target Group should no longer have access to
# * `entityAccessGrants` : The Entity and Role a Group should no longer have access to
# * `grantee` : The Grantee to which the access will be granted
# * `groupAccessGrants` : The Role and the Group the Target Group should no longer have access to
# * `groupId` : The Group ID that will have access revoked
# * `organizationAccessGrants` : The Role and the Organization the Target Group should no longer have access to

# %%
# | export
class AuthorizationManagementRevokeAccess(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "account_access_grants",
        "entity_access_grants",
        "grantee",
        "group_access_grants",
        "group_id",
        "organization_access_grants",
    )
    account_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AuthorizationManagementAccountAccessGrant)
        ),
        graphql_name="accountAccessGrants",
    )

    entity_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AuthorizationManagementEntityAccessGrants)
        ),
        graphql_name="entityAccessGrants",
    )

    grantee = sgqlc.types.Field(AuthorizationManagementGrantee, graphql_name="grantee")

    group_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AuthorizationManagementGroupAccessGrant)
        ),
        graphql_name="groupAccessGrants",
    )

    group_id = sgqlc.types.Field(ID, graphql_name="groupId")

    organization_access_grants = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(AuthorizationManagementOrganizationAccessGrant)
        ),
        graphql_name="organizationAccessGrants",
    )

# %% [markdown]
# #### 211. `AuthorizationManagementUpdateAccess`

# %% [markdown]
# The input objects needed to update access for a group
#
#
# Available input fields:
#
#
#
# * `accountAccessGrant` : The grant properties for update - data access policy id
# * `ids` : The Grant Ids to update

# %%
# | export
class AuthorizationManagementUpdateAccess(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_access_grant", "ids")
    account_access_grant = sgqlc.types.Field(
        sgqlc.types.non_null(AuthorizationManagementAccountAccessGrantUpdate),
        graphql_name="accountAccessGrant",
    )

    ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(ID))),
        graphql_name="ids",
    )

# %% [markdown]
# #### 212. `ChangeTrackingCategoryAndTypeInput`

# %% [markdown]
# The category and type of the change event. These should match the prefix and suffix of the CategoryType enum.
#
#
# Available input fields:
#
#
#
# * `category` : The category of the change event.
#
# For a list of supported categories, [view our docs](https://docs.newrelic.com/docs/change-tracking/change-tracking-events/#supported-types).
# * `type` : The type of the change event.
#
# For a list of supported types, [view our docs](https://docs.newrelic.com/docs/change-tracking/change-tracking-events/#supported-types).

# %%
# | export
class ChangeTrackingCategoryAndTypeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("category", "type")
    category = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="category")

    type = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="type")

# %% [markdown]
# #### 213. `ChangeTrackingCategoryFieldsInput`

# %% [markdown]
# "
# This is a container for the various category related input fields.
#
#
# Available input fields:
#
#
#
# * `deployment` : This container is mandatory for a category of `DEPLOYMENT`.
# * `featureFlag` : This container is mandatory for a category of `FEATURE_FLAG`.

# %%
# | export
class ChangeTrackingCategoryFieldsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("deployment", "feature_flag")
    deployment = sgqlc.types.Field(
        "ChangeTrackingDeploymentFieldsInput", graphql_name="deployment"
    )

    feature_flag = sgqlc.types.Field(
        "ChangeTrackingFeatureFlagFieldsInput", graphql_name="featureFlag"
    )

# %% [markdown]
# #### 214. `ChangeTrackingCategoryRelatedInput`

# %% [markdown]
# The data that defines the category and type of change event as well as the category-specific fields.
#
#
# Available input fields:
#
#
#
# * `categoryFields` : This is a container for the various category related input fields.
# * `kind` : The category and type of the change event. If you'd like to use your own, please add `ALLOW_CUSTOM_CATEGORY_OR_TYPE` to your validation flags.
#
# For a list of supported categories and types, [view our docs](https://docs.newrelic.com/docs/change-tracking/change-tracking-events/#supported-types).

# %%
# | export
class ChangeTrackingCategoryRelatedInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("category_fields", "kind")
    category_fields = sgqlc.types.Field(
        ChangeTrackingCategoryFieldsInput, graphql_name="categoryFields"
    )

    kind = sgqlc.types.Field(
        sgqlc.types.non_null(ChangeTrackingCategoryAndTypeInput), graphql_name="kind"
    )

# %% [markdown]
# #### 215. `ChangeTrackingChangeTrackingSearchFilter`

# %% [markdown]
# The object contains the filters to be applied to the search.
#
#
# Available input fields:
#
#
#
# * `accountIds` : A list of account ids to search. If none provided, all authorized accounts will be searched.
# * `limit` : Maximum number of deployments to be returned. Default value is 100 deployments.
# There is a maximum limit value of 2,000. If you set the limit greater than 2,000, the service will only return the latest 2,000 deployments."
# * `query` : Change tracking search query string. The query string can search for a match on users and change tracking IDs, and any other change tracking event attributes.
#
# Operators available: Any valid NRQL operators, other than subqueries. For example, =, OR, AND, IN, LIKE, RLIKE, NOT.
#
# For the full list of operators, see the where clause documentation [here](https://docs.newrelic.com/docs/query-your-data/nrql-new-relic-query-language/get-started/nrql-syntax-clauses-functions/#sel-where)
#
# Note: Do not include keywords like SELECT, WHERE, SINCE, FACET, and TIMESERIES.
#
# Examples:
#
# • "user = 'Test User'"
# • "user RLIKE r'Test.*|test.*'"
# • "version = '1.0' OR categoryType IN ('DEPLOYMENT__BLUE_GREEN', 'DEPLOYMENT__ROLLING')"
# • "changeTrackingId IN ('1234', '4567')"
# * `timeWindow` : Search time window. If not specified, defaults to the past hour.

# %%
# | export
class ChangeTrackingChangeTrackingSearchFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids", "limit", "query", "time_window")
    account_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="accountIds"
    )

    limit = sgqlc.types.Field(Int, graphql_name="limit")

    query = sgqlc.types.Field(String, graphql_name="query")

    time_window = sgqlc.types.Field(
        "ChangeTrackingTimeWindowInputWithDefaults", graphql_name="timeWindow"
    )

# %% [markdown]
# #### 216. `ChangeTrackingCreateEventInput`

# %% [markdown]
# The data necessary to create a change tracking event.
#
#
# Available input fields:
#
#
#
# * `categoryAndTypeData` : The data that defines the category and type of change event as well as the category-specific fields.
# * `customAttributes` : Represents key-value pairs of custom attributes in JavaScript object format. Attribute values can be of type `string`, `boolean`, or `number`. We store JavaScript `number` values to either Java `long` or `double` values. The main difference between JavaScript object format vs. JSON is that keys are not enclosed in quotes.
#
# For more information on limitations, see [our docs](https://docs.newrelic.com/docs/change-tracking/change-tracking-graphql/)
#
# **Examples:**
#
# • {cloud_vendor : "vendor_name", region : "us-east-1", environment : "staging"}
# • {isProd : true, region : "us-east-1", instances: 2, deploy_time : 10.5}
# * `description` : A description of the event.
# * `entitySearch` : Specify the entity to associate with the change tracking event via query.
# * `groupId` : An identifier used to correlate account-wide changes across entities. These changes are shown together in the `Changes in group` section of the change event details UI.
# * `shortDescription` : This field allows you to add your own context to help you quickly identify the change events sent to our system. This field should contain a concise description of the change suitable for showing in various parts of New Relic One:
#
# 1. In the marker flag, shown when hovering over the pinhead of a "Changes" marker on a chart.
# 2. In the "Activity stream" panels.
#
# If this field is left blank sensible defaults will be shown instead.
#
# To see an example of how the `shortDescription` appears in change markers, see the optional attributes section of [our docs](https://docs.newrelic.com/docs/change-tracking/change-tracking-events/#optional-fields).
# * `timestamp` : The start time of the change tracking event as the number of milliseconds since the Unix epoch.  Defaults to now.
# * `user` : The name or identifier of the person responsible for the change.

# %%
# | export
class ChangeTrackingCreateEventInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "category_and_type_data",
        "custom_attributes",
        "description",
        "entity_search",
        "group_id",
        "short_description",
        "timestamp",
        "user",
    )
    category_and_type_data = sgqlc.types.Field(
        sgqlc.types.non_null(ChangeTrackingCategoryRelatedInput),
        graphql_name="categoryAndTypeData",
    )

    custom_attributes = sgqlc.types.Field(
        ChangeTrackingRawCustomAttributesMap, graphql_name="customAttributes"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    entity_search = sgqlc.types.Field(
        sgqlc.types.non_null("ChangeTrackingEntitySearchInput"),
        graphql_name="entitySearch",
    )

    group_id = sgqlc.types.Field(String, graphql_name="groupId")

    short_description = sgqlc.types.Field(String, graphql_name="shortDescription")

    timestamp = sgqlc.types.Field(EpochMilliseconds, graphql_name="timestamp")

    user = sgqlc.types.Field(String, graphql_name="user")

# %% [markdown]
# #### 217. `ChangeTrackingDataHandlingRules`

# %% [markdown]
# Validation and data handling rules to be applied to deployment input data.
#
#
# Available input fields:
#
#
#
# * `validationFlags` : Flags for validation, for example, ‘FAIL_ON_FIELD_LENGTH’.

# %%
# | export
class ChangeTrackingDataHandlingRules(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("validation_flags",)
    validation_flags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ChangeTrackingValidationFlag)),
        graphql_name="validationFlags",
    )

# %% [markdown]
# #### 218. `ChangeTrackingDeploymentFieldsInput`

# %% [markdown]
# Deployment-related fields.
#
#
# Available input fields:
#
#
#
# * `changelog` : A URL to the changelog or, if not linkable, a list of changes.
# * `commit` : The commit identifier, for example, a Git commit SHA.
# * `deepLink` : A link to the system that generated the deployment.
# * `version` : The version of the deployed software, for example, something like v1.1.

# %%
# | export
class ChangeTrackingDeploymentFieldsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("changelog", "commit", "deep_link", "version")
    changelog = sgqlc.types.Field(String, graphql_name="changelog")

    commit = sgqlc.types.Field(String, graphql_name="commit")

    deep_link = sgqlc.types.Field(String, graphql_name="deepLink")

    version = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="version")

# %% [markdown]
# #### 219. `ChangeTrackingDeploymentInput`

# %% [markdown]
# A deployment.
#
#
# Available input fields:
#
#
#
# * `changelog` : A URL for the changelog or, if not linkable, a list of changes.
# * `commit` : The commit identifier, for example, a Git commit SHA.
# * `deepLink` : A URL to the system that generated the deployment.
# * `deploymentType` : The type of deployment, for example, ‘Blue green’ or ‘Rolling’.
# * `description` : A description of the deployment.
# * `entityGuid` : The NR entity that was deployed.
# * `groupId` : An identifier used to correlate account-wide changes across entities. These changes are shown together in the `Changes in group` section of the change event details UI.
# * `timestamp` : The start time of the deployment as the number of milliseconds since the Unix epoch. Should be within the boundary of the past or future 24 hours. Defaults to now.
# * `user` : The username of the deployer or bot.
# * `version` : The version of the deployed software, for example, something like v1.1

# %%
# | export
class ChangeTrackingDeploymentInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "changelog",
        "commit",
        "deep_link",
        "deployment_type",
        "description",
        "entity_guid",
        "group_id",
        "timestamp",
        "user",
        "version",
    )
    changelog = sgqlc.types.Field(String, graphql_name="changelog")

    commit = sgqlc.types.Field(String, graphql_name="commit")

    deep_link = sgqlc.types.Field(String, graphql_name="deepLink")

    deployment_type = sgqlc.types.Field(
        ChangeTrackingDeploymentType, graphql_name="deploymentType"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    entity_guid = sgqlc.types.Field(
        sgqlc.types.non_null(EntityGuid), graphql_name="entityGuid"
    )

    group_id = sgqlc.types.Field(String, graphql_name="groupId")

    timestamp = sgqlc.types.Field(EpochMilliseconds, graphql_name="timestamp")

    user = sgqlc.types.Field(String, graphql_name="user")

    version = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="version")

# %% [markdown]
# #### 220. `ChangeTrackingEntitySearchInput`

# %% [markdown]
# This field is how you specify the entity to associate with the change tracking event.
#
#
# Available input fields:
#
#
#
# * `query` : Entity search query string that matches exactly one entity.
# The query string can search for an exact or fuzzy match on id, name, as well as searching several other attributes.
#
# Operators available: `=`, `AND`, `IN`, `LIKE`
#
# Special characters (`.,;:*-_`) are treated as whitespace. For example, `"name LIKE ':aws:'"` will match `-aws.` or `foo aws.`
#
# You can filter by default properties and tags.
#
# Default entity properties:
#
# - id
# - accountId
# - name
# - domainId
# - alertSeverity
# - reporting
# - indexedAt
# - firstIndexedAt
# - lastReportingChangeAt
#
# Tags:
#
# Tags are metadata usually linked to a more specific domainType or group of domainTypes. For example:
# - language - the agent language for APM applications.
# - clusterAgentId - in a Browser application, clusterAgentId denotes a link to an APM application with a specific cluster agent.
# - aws.accountId - the AWS account id for INFRA entities from AWS.
#
# Tags can be referenced with or without backticks.
#
# Examples:
# 1. I know the entity guid:
# - `"id = '<entity guid>'"`
#
# 1. I know the app id (REST v2 API):
# - `"domainId = '<app id>' AND domain = 'APM'"`
#
# 1. I have an OpenTelemetry entity:
# - `"name = '<service name>' AND domain = 'EXT' AND type = 'SERVICE' AND accountId = '<account id>'"`

# %%
# | export
class ChangeTrackingEntitySearchInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("query",)
    query = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="query")

# %% [markdown]
# #### 221. `ChangeTrackingFeatureFlagFieldsInput`

# %% [markdown]
# Feature flag-related fields.
#
#
# Available input fields:
#
#
#
# * `featureFlagId` : The identifier of the feature flag.

# %%
# | export
class ChangeTrackingFeatureFlagFieldsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("feature_flag_id",)
    feature_flag_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="featureFlagId"
    )

# %% [markdown]
# #### 222. `ChangeTrackingSearchFilter`

# %% [markdown]
# The object contains the filters to be applied to the search.
#
#
# Available input fields:
#
#
#
# * `limit` : Maximum number of deployments to be returned. Default value is 100 deployments.
# There is a maximum limit value of 2,000. If you set the limit greater than 2,000, the service will only return the latest 2,000 deployments."
# * `query` : Deployment search query string. The query string can search for a match on users and deployment IDs, and any other deployment event attributes.
#
# Operators available: Any valid NRQL operators, other than subqueries. For example, =, OR, AND, IN, LIKE, RLIKE, NOT.
#
# For the full list of operators, see the where clause documentation [here](https://docs.newrelic.com/docs/query-your-data/nrql-new-relic-query-language/get-started/nrql-syntax-clauses-functions/#sel-where)
#
# Note: Do not include keywords like SELECT, WHERE, SINCE, FACET, and TIMESERIES.
#
# Examples:
#
#     • "user = 'Test User'"
#     • "user LIKE '%Test User%' AND deploymentType IN ('BLUE_GREEN', 'CANARY')"
#     • "user RLIKE r'Test.*|test.*'"
#     • "version = '1.0' OR deploymentType IN ('BASIC')"
#     • "deploymentId IN ('1234', '4567')"
#     • "((user = 'Test User' AND version = '1.0') OR deploymentType in ('BLUE_GREEN', 'CANARY'))"
# * `timeWindow` : Search time window. If not specified, defaults to the past hour.

# %%
# | export
class ChangeTrackingSearchFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("limit", "query", "time_window")
    limit = sgqlc.types.Field(Int, graphql_name="limit")

    query = sgqlc.types.Field(String, graphql_name="query")

    time_window = sgqlc.types.Field(
        "ChangeTrackingTimeWindowInputWithDefaults", graphql_name="timeWindow"
    )

# %% [markdown]
# #### 223. `ChangeTrackingTimeWindowInputWithDefaults`

# %% [markdown]
# A time window input with default values.
#
#
# Available input fields:
#
#
#
# * `endTime` : The end time of the time window. If not specified, it defaults to the current time.
# * `startTime` : The start time of the time window. If not specified, it defaults to 60 minutes before the endTime.

# %%
# | export
class ChangeTrackingTimeWindowInputWithDefaults(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("end_time", "start_time")
    end_time = sgqlc.types.Field(EpochMilliseconds, graphql_name="endTime")

    start_time = sgqlc.types.Field(EpochMilliseconds, graphql_name="startTime")

# %% [markdown]
# #### 224. `CloudAlbIntegrationInput`

# %% [markdown]
# Elastic Load Balancing - Application Load Balancer (ALB)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `loadBalancerPrefixes` : Specify each name or prefix for the LBs that you want to monitor. Filter values are case-sensitive.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAlbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "load_balancer_prefixes",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    load_balancer_prefixes = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="loadBalancerPrefixes"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 225. `CloudApigatewayIntegrationInput`

# %% [markdown]
# Amazon API Gateway
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `stagePrefixes` : Specify each name or prefix for the Stages that you want to monitor. Filter values are case-sensitive.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudApigatewayIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "stage_prefixes",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    stage_prefixes = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="stagePrefixes"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 226. `CloudAutoscalingIntegrationInput`

# %% [markdown]
# AWS Auto Scaling
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAutoscalingIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 227. `CloudAwsAppsyncIntegrationInput`

# %% [markdown]
# AppSync
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsAppsyncIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 228. `CloudAwsAthenaIntegrationInput`

# %% [markdown]
# Athena
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsAthenaIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 229. `CloudAwsAutoDiscoveryIntegrationInput`

# %% [markdown]
# AWS Auto Discovery
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsAutoDiscoveryIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 230. `CloudAwsCognitoIntegrationInput`

# %% [markdown]
# Cognito
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsCognitoIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 231. `CloudAwsConnectIntegrationInput`

# %% [markdown]
# Connect
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsConnectIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 232. `CloudAwsDirectconnectIntegrationInput`

# %% [markdown]
# Direct Connect
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsDirectconnectIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 233. `CloudAwsDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `alb` : ALB/NLB integration
# * `apigateway` : API Gateway integration
# * `autoscaling` : AutoScaling integration
# * `awsAppsync` : AppSync integration
# * `awsAthena` : Athena integration
# * `awsAutoDiscovery` : AutoDiscovery integration
# * `awsCognito` : Cognito integration
# * `awsConnect` : Connect integration
# * `awsDirectconnect` : Direct Connect integration
# * `awsDocdb` : DocumentDB integration
# * `awsFsx` : FSx integration
# * `awsGlue` : Glue integration
# * `awsKinesisanalytics` : Kinesis Data Analytics integration
# * `awsMediaconvert` : Elemental MediaConvert integration
# * `awsMediapackagevod` : MediaPackage VOD integration
# * `awsMetadata` : Fetch Metadata for AWS integrations integration
# * `awsMq` : MQ integration
# * `awsMsElasticache` : Fetch ElastiCache entities integration
# * `awsMsk` : Managed Kafka integration
# * `awsNeptune` : Neptune integration
# * `awsQldb` : QLDB integration
# * `awsRoute53resolver` : Route53 Resolver integration
# * `awsStates` : Step Functions integration
# * `awsTagsGlobal` : Fetch tags for all integrations integration
# * `awsTransitgateway` : Transit Gateway integration
# * `awsWaf` : WAF integration
# * `awsWafv2` : WAFV2 integration
# * `awsXray` : X-Ray integration
# * `billing` : Billing integration
# * `cloudfront` : CloudFront integration
# * `cloudtrail` : CloudTrail integration
# * `dynamodb` : DynamoDB integration
# * `ebs` : EBS integration
# * `ec2` : EC2 integration
# * `ecs` : ECS integration
# * `efs` : EFS integration
# * `elasticache` : ElastiCache integration
# * `elasticbeanstalk` : Elastic Beanstalk integration
# * `elasticsearch` : Elasticsearch Service integration
# * `elb` : ELB (Classic) integration
# * `emr` : EMR integration
# * `health` : Health integration
# * `iam` : IAM integration
# * `iot` : IoT integration
# * `kinesis` : Kinesis Streams integration
# * `kinesisFirehose` : Kinesis Firehose integration
# * `lambda` : Lambda integration
# * `rds` : RDS integration
# * `redshift` : Redshift integration
# * `route53` : Route 53 integration
# * `s3` : S3 integration
# * `securityHub` : SecurityHub integration
# * `ses` : SES integration
# * `sns` : SNS integration
# * `sqs` : SQS integration
# * `trustedadvisor` : Trusted Advisor integration
# * `vpc` : VPC integration

# %%
# | export
class CloudAwsDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "alb",
        "apigateway",
        "autoscaling",
        "aws_appsync",
        "aws_athena",
        "aws_auto_discovery",
        "aws_cognito",
        "aws_connect",
        "aws_directconnect",
        "aws_docdb",
        "aws_fsx",
        "aws_glue",
        "aws_kinesisanalytics",
        "aws_mediaconvert",
        "aws_mediapackagevod",
        "aws_metadata",
        "aws_mq",
        "aws_ms_elasticache",
        "aws_msk",
        "aws_neptune",
        "aws_qldb",
        "aws_route53resolver",
        "aws_states",
        "aws_tags_global",
        "aws_transitgateway",
        "aws_waf",
        "aws_wafv2",
        "aws_xray",
        "billing",
        "cloudfront",
        "cloudtrail",
        "dynamodb",
        "ebs",
        "ec2",
        "ecs",
        "efs",
        "elasticache",
        "elasticbeanstalk",
        "elasticsearch",
        "elb",
        "emr",
        "health",
        "iam",
        "iot",
        "kinesis",
        "kinesis_firehose",
        "lambda_",
        "rds",
        "redshift",
        "route53",
        "s3",
        "security_hub",
        "ses",
        "sns",
        "sqs",
        "trustedadvisor",
        "vpc",
    )
    alb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="alb"
    )

    apigateway = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="apigateway",
    )

    autoscaling = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="autoscaling",
    )

    aws_appsync = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsAppsync",
    )

    aws_athena = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsAthena",
    )

    aws_auto_discovery = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsAutoDiscovery",
    )

    aws_cognito = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsCognito",
    )

    aws_connect = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsConnect",
    )

    aws_directconnect = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsDirectconnect",
    )

    aws_docdb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsDocdb",
    )

    aws_fsx = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsFsx",
    )

    aws_glue = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsGlue",
    )

    aws_kinesisanalytics = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsKinesisanalytics",
    )

    aws_mediaconvert = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMediaconvert",
    )

    aws_mediapackagevod = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMediapackagevod",
    )

    aws_metadata = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMetadata",
    )

    aws_mq = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="awsMq"
    )

    aws_ms_elasticache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMsElasticache",
    )

    aws_msk = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMsk",
    )

    aws_neptune = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsNeptune",
    )

    aws_qldb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsQldb",
    )

    aws_route53resolver = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsRoute53resolver",
    )

    aws_states = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsStates",
    )

    aws_tags_global = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsTagsGlobal",
    )

    aws_transitgateway = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsTransitgateway",
    )

    aws_waf = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsWaf",
    )

    aws_wafv2 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsWafv2",
    )

    aws_xray = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsXray",
    )

    billing = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="billing",
    )

    cloudfront = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="cloudfront",
    )

    cloudtrail = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="cloudtrail",
    )

    dynamodb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="dynamodb",
    )

    ebs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="ebs"
    )

    ec2 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="ec2"
    )

    ecs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="ecs"
    )

    efs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="efs"
    )

    elasticache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="elasticache",
    )

    elasticbeanstalk = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="elasticbeanstalk",
    )

    elasticsearch = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="elasticsearch",
    )

    elb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="elb"
    )

    emr = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="emr"
    )

    health = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="health",
    )

    iam = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="iam"
    )

    iot = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="iot"
    )

    kinesis = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="kinesis",
    )

    kinesis_firehose = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="kinesisFirehose",
    )

    lambda_ = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="lambda",
    )

    rds = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="rds"
    )

    redshift = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="redshift",
    )

    route53 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="route53",
    )

    s3 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="s3"
    )

    security_hub = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="securityHub",
    )

    ses = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="ses"
    )

    sns = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="sns"
    )

    sqs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="sqs"
    )

    trustedadvisor = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="trustedadvisor",
    )

    vpc = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="vpc"
    )

# %% [markdown]
# #### 234. `CloudAwsDocdbIntegrationInput`

# %% [markdown]
# DocumentDB
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsDocdbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 235. `CloudAwsEuSovereignDisableIntegrationsInput`

# %% [markdown]
# Disable integrations for AWS EU Sovereign Cloud
#
#
# Available input fields:
#
#
#
# * `awsMetadataEuSovereign` : AWS Metadata EU Sovereign integration
# * `awsMsElasticacheEuSovereign` : ElastiCache EU Sovereign integration
# * `awsTagsGlobalEuSovereign` : AWS Tags Global EU Sovereign integration
# * `awsXray` : X-Ray integration
# * `billing` : Billing integration
# * `cloudtrail` : CloudTrail integration

# %%
# | export
class CloudAwsEuSovereignDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_metadata_eu_sovereign",
        "aws_ms_elasticache_eu_sovereign",
        "aws_tags_global_eu_sovereign",
        "aws_xray",
        "billing",
        "cloudtrail",
    )
    aws_metadata_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMetadataEuSovereign",
    )

    aws_ms_elasticache_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMsElasticacheEuSovereign",
    )

    aws_tags_global_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsTagsGlobalEuSovereign",
    )

    aws_xray = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsXray",
    )

    billing = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="billing",
    )

    cloudtrail = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="cloudtrail",
    )

# %% [markdown]
# #### 236. `CloudAwsEuSovereignIntegrationsInput`

# %% [markdown]
# List of integrations for AWS EU Sovereign Cloud
#
#
# Available input fields:
#
#
#
# * `awsMetadataEuSovereign` : Fetch Metadata for AWS EU Sovereign integrations integration
# * `awsMsElasticacheEuSovereign` : ElastiCache EU Sovereign integration
# * `awsTagsGlobalEuSovereign` : Tags EU Sovereign integration
# * `awsXray` : X-Ray integration
# * `billing` : Billing integration
# * `cloudtrail` : CloudTrail integration

# %%
# | export
class CloudAwsEuSovereignIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_metadata_eu_sovereign",
        "aws_ms_elasticache_eu_sovereign",
        "aws_tags_global_eu_sovereign",
        "aws_xray",
        "billing",
        "cloudtrail",
    )
    aws_metadata_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMetadataEuSovereignIntegrationInput"),
        graphql_name="awsMetadataEuSovereign",
    )

    aws_ms_elasticache_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMsElasticacheEuSovereignIntegrationInput"),
        graphql_name="awsMsElasticacheEuSovereign",
    )

    aws_tags_global_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsTagsGlobalEuSovereignIntegrationInput"),
        graphql_name="awsTagsGlobalEuSovereign",
    )

    aws_xray = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsXrayIntegrationInput"), graphql_name="awsXray"
    )

    billing = sgqlc.types.Field(
        sgqlc.types.list_of("CloudBillingIntegrationInput"), graphql_name="billing"
    )

    cloudtrail = sgqlc.types.Field(
        sgqlc.types.list_of("CloudCloudtrailIntegrationInput"),
        graphql_name="cloudtrail",
    )

# %% [markdown]
# #### 237. `CloudAwsEuSovereignLinkAccountInput`

# %% [markdown]
# Information required to link an AWS EU Sovereign Cloud account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `arn` : The AWS role ARN (used to fetch data).
# * `metricCollectionMode` : How metrics will be collected.
# * `name` : The linked account name.

# %%
# | export
class CloudAwsEuSovereignLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("arn", "metric_collection_mode", "name")
    arn = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="arn")

    metric_collection_mode = sgqlc.types.Field(
        CloudMetricCollectionMode, graphql_name="metricCollectionMode"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 238. `CloudAwsEuSovereignUpdateAccountInput`

# %% [markdown]
# Information required to update an AWS EU Sovereign Cloud account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `arn` : The AWS role ARN (used to fetch data).
# * `disabled` : Disable the linked account.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.

# %%
# | export
class CloudAwsEuSovereignUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("arn", "disabled", "linked_account_id", "name")
    arn = sgqlc.types.Field(String, graphql_name="arn")

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 239. `CloudAwsFsxIntegrationInput`

# %% [markdown]
# FSx
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsFsxIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 240. `CloudAwsGlueIntegrationInput`

# %% [markdown]
# Glue
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsGlueIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 241. `CloudAwsGovCloudLinkAccountInput`

# %% [markdown]
# Information required to link an AWS GovCloud account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `accessKeyId` : The key used to make requests to AWS service APIs
# * `awsAccountId` : The AWS account id
# * `metricCollectionMode` : How metrics will be collected.
# * `name` : The linked account name.
# * `secretAccessKey` : The secret key used to make requests to AWS service APIs

# %%
# | export
class CloudAwsGovCloudLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "access_key_id",
        "aws_account_id",
        "metric_collection_mode",
        "name",
        "secret_access_key",
    )
    access_key_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="accessKeyId"
    )

    aws_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="awsAccountId"
    )

    metric_collection_mode = sgqlc.types.Field(
        CloudMetricCollectionMode, graphql_name="metricCollectionMode"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    secret_access_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="secretAccessKey"
    )

# %% [markdown]
# #### 242. `CloudAwsGovCloudMigrateToAssumeroleInput`

# %% [markdown]
# Information required to migrate an existing AWS GovCloud account to use AssumeRole Authentication.
#
#
# Available input fields:
#
#
#
# * `arn` : The AWS role ARN (used to fetch data).
# * `linkedAccountId` : The linked account identifier.

# %%
# | export
class CloudAwsGovCloudMigrateToAssumeroleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("arn", "linked_account_id")
    arn = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="arn")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

# %% [markdown]
# #### 243. `CloudAwsGovCloudUpdateAccountInput`

# %% [markdown]
# Information required to update an AWS GovCloud account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `accessKeyId` : The key used to make requests to AWS service APIs
# * `awsAccountId` : The AWS account id
# * `disabled` : Disable the linked account.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.
# * `secretAccessKey` : The secret key used to make requests to AWS service APIs

# %%
# | export
class CloudAwsGovCloudUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "access_key_id",
        "aws_account_id",
        "disabled",
        "linked_account_id",
        "name",
        "secret_access_key",
    )
    access_key_id = sgqlc.types.Field(String, graphql_name="accessKeyId")

    aws_account_id = sgqlc.types.Field(String, graphql_name="awsAccountId")

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    secret_access_key = sgqlc.types.Field(SecureValue, graphql_name="secretAccessKey")

# %% [markdown]
# #### 244. `CloudAwsGovcloudDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `alb` : ALB/NLB integration
# * `apigateway` : API Gateway integration
# * `autoscaling` : AutoScaling integration
# * `awsDirectconnect` : Direct Connect integration
# * `awsMetaDataGov` : Metdata Gov integration
# * `awsMsElasticacheGov` : ElasticCache Gov integration
# * `awsStates` : Step Functions integration
# * `awsTagsGlobalGov` : Tags Gov integration
# * `cloudtrail` : CloudTrail integration
# * `dynamodb` : DynamoDB integration
# * `ebs` : EBS integration
# * `ec2` : EC2 integration
# * `elasticsearch` : Elasticsearch Service integration
# * `elb` : ELB (Classic) integration
# * `emr` : EMR integration
# * `iam` : IAM integration
# * `lambda` : Lambda integration
# * `rds` : RDS integration
# * `redshift` : Redshift integration
# * `route53` : Route 53 integration
# * `s3` : S3 integration
# * `sns` : SNS integration
# * `sqs` : SQS integration

# %%
# | export
class CloudAwsGovcloudDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "alb",
        "apigateway",
        "autoscaling",
        "aws_directconnect",
        "aws_meta_data_gov",
        "aws_ms_elasticache_gov",
        "aws_states",
        "aws_tags_global_gov",
        "cloudtrail",
        "dynamodb",
        "ebs",
        "ec2",
        "elasticsearch",
        "elb",
        "emr",
        "iam",
        "lambda_",
        "rds",
        "redshift",
        "route53",
        "s3",
        "sns",
        "sqs",
    )
    alb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="alb"
    )

    apigateway = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="apigateway",
    )

    autoscaling = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="autoscaling",
    )

    aws_directconnect = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsDirectconnect",
    )

    aws_meta_data_gov = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMetaDataGov",
    )

    aws_ms_elasticache_gov = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsMsElasticacheGov",
    )

    aws_states = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsStates",
    )

    aws_tags_global_gov = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="awsTagsGlobalGov",
    )

    cloudtrail = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="cloudtrail",
    )

    dynamodb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="dynamodb",
    )

    ebs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="ebs"
    )

    ec2 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="ec2"
    )

    elasticsearch = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="elasticsearch",
    )

    elb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="elb"
    )

    emr = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="emr"
    )

    iam = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="iam"
    )

    lambda_ = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="lambda",
    )

    rds = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="rds"
    )

    redshift = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="redshift",
    )

    route53 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="route53",
    )

    s3 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="s3"
    )

    sns = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="sns"
    )

    sqs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"), graphql_name="sqs"
    )

# %% [markdown]
# #### 245. `CloudAwsGovcloudIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `alb` : ALB/NLB integration
# * `apigateway` : API Gateway integration
# * `autoscaling` : AutoScaling integration
# * `awsDirectconnect` : Direct Connect integration
# * `awsMetadataGov` : Fetch Metadata for AWS Gov integrations integration
# * `awsMsElasticacheGov` : ElasticCache Gov integration
# * `awsStates` : Step Functions integration
# * `awsTagsGlobalGov` : Tags Gov integration
# * `cloudtrail` : CloudTrail integration
# * `dynamodb` : DynamoDB integration
# * `ebs` : EBS integration
# * `ec2` : EC2 integration
# * `elasticsearch` : Elasticsearch Service integration
# * `elb` : ELB (Classic) integration
# * `emr` : EMR integration
# * `iam` : IAM integration
# * `lambda` : Lambda integration
# * `rds` : RDS integration
# * `redshift` : Redshift integration
# * `route53` : Route 53 integration
# * `s3` : S3 integration
# * `sns` : SNS integration
# * `sqs` : SQS integration

# %%
# | export
class CloudAwsGovcloudIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "alb",
        "apigateway",
        "autoscaling",
        "aws_directconnect",
        "aws_metadata_gov",
        "aws_ms_elasticache_gov",
        "aws_states",
        "aws_tags_global_gov",
        "cloudtrail",
        "dynamodb",
        "ebs",
        "ec2",
        "elasticsearch",
        "elb",
        "emr",
        "iam",
        "lambda_",
        "rds",
        "redshift",
        "route53",
        "s3",
        "sns",
        "sqs",
    )
    alb = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAlbIntegrationInput), graphql_name="alb"
    )

    apigateway = sgqlc.types.Field(
        sgqlc.types.list_of(CloudApigatewayIntegrationInput), graphql_name="apigateway"
    )

    autoscaling = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAutoscalingIntegrationInput),
        graphql_name="autoscaling",
    )

    aws_directconnect = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsDirectconnectIntegrationInput),
        graphql_name="awsDirectconnect",
    )

    aws_metadata_gov = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMetadataGovIntegrationInput"),
        graphql_name="awsMetadataGov",
    )

    aws_ms_elasticache_gov = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMsElasticacheGovIntegrationInput"),
        graphql_name="awsMsElasticacheGov",
    )

    aws_states = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsStatesIntegrationInput"), graphql_name="awsStates"
    )

    aws_tags_global_gov = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsTagsGlobalGovIntegrationInput"),
        graphql_name="awsTagsGlobalGov",
    )

    cloudtrail = sgqlc.types.Field(
        sgqlc.types.list_of("CloudCloudtrailIntegrationInput"),
        graphql_name="cloudtrail",
    )

    dynamodb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDynamodbIntegrationInput"), graphql_name="dynamodb"
    )

    ebs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEbsIntegrationInput"), graphql_name="ebs"
    )

    ec2 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEc2IntegrationInput"), graphql_name="ec2"
    )

    elasticsearch = sgqlc.types.Field(
        sgqlc.types.list_of("CloudElasticsearchIntegrationInput"),
        graphql_name="elasticsearch",
    )

    elb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudElbIntegrationInput"), graphql_name="elb"
    )

    emr = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEmrIntegrationInput"), graphql_name="emr"
    )

    iam = sgqlc.types.Field(
        sgqlc.types.list_of("CloudIamIntegrationInput"), graphql_name="iam"
    )

    lambda_ = sgqlc.types.Field(
        sgqlc.types.list_of("CloudLambdaIntegrationInput"), graphql_name="lambda"
    )

    rds = sgqlc.types.Field(
        sgqlc.types.list_of("CloudRdsIntegrationInput"), graphql_name="rds"
    )

    redshift = sgqlc.types.Field(
        sgqlc.types.list_of("CloudRedshiftIntegrationInput"), graphql_name="redshift"
    )

    route53 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudRoute53IntegrationInput"), graphql_name="route53"
    )

    s3 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudS3IntegrationInput"), graphql_name="s3"
    )

    sns = sgqlc.types.Field(
        sgqlc.types.list_of("CloudSnsIntegrationInput"), graphql_name="sns"
    )

    sqs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudSqsIntegrationInput"), graphql_name="sqs"
    )

# %% [markdown]
# #### 246. `CloudAwsIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `alb` : ALB/NLB integration
# * `apigateway` : API Gateway integration
# * `autoscaling` : AutoScaling integration
# * `awsAppsync` : AppSync integration
# * `awsAthena` : Athena integration
# * `awsAutoDiscovery` : AutoDiscovery integration
# * `awsCognito` : Cognito integration
# * `awsConnect` : Connect integration
# * `awsDirectconnect` : Direct Connect integration
# * `awsDocdb` : DocumentDB integration
# * `awsFsx` : FSx integration
# * `awsGlue` : Glue integration
# * `awsKinesisanalytics` : Kinesis Data Analytics integration
# * `awsMediaconvert` : Elemental MediaConvert integration
# * `awsMediapackagevod` : MediaPackage VOD integration
# * `awsMetadata` : Fetch Metadata for AWS integrations integration
# * `awsMq` : MQ integration
# * `awsMsElasticache` : Fetch ElastiCache entities integration
# * `awsMsk` : Managed Kafka integration
# * `awsNeptune` : Neptune integration
# * `awsQldb` : QLDB integration
# * `awsRoute53resolver` : Route53 Resolver integration
# * `awsStates` : Step Functions integration
# * `awsTagsGlobal` : Fetch tags for all integrations integration
# * `awsTransitgateway` : Transit Gateway integration
# * `awsWaf` : WAF integration
# * `awsWafv2` : WAFV2 integration
# * `awsXray` : X-Ray integration
# * `billing` : Billing integration
# * `cloudfront` : CloudFront integration
# * `cloudtrail` : CloudTrail integration
# * `dynamodb` : DynamoDB integration
# * `ebs` : EBS integration
# * `ec2` : EC2 integration
# * `ecs` : ECS integration
# * `efs` : EFS integration
# * `elasticache` : ElastiCache integration
# * `elasticbeanstalk` : Elastic Beanstalk integration
# * `elasticsearch` : Elasticsearch Service integration
# * `elb` : ELB (Classic) integration
# * `emr` : EMR integration
# * `health` : Health integration
# * `iam` : IAM integration
# * `iot` : IoT integration
# * `kinesis` : Kinesis Streams integration
# * `kinesisFirehose` : Kinesis Firehose integration
# * `lambda` : Lambda integration
# * `rds` : RDS integration
# * `redshift` : Redshift integration
# * `route53` : Route 53 integration
# * `s3` : S3 integration
# * `securityHub` : SecurityHub integration
# * `ses` : SES integration
# * `sns` : SNS integration
# * `sqs` : SQS integration
# * `trustedadvisor` : Trusted Advisor integration
# * `vpc` : VPC integration

# %%
# | export
class CloudAwsIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "alb",
        "apigateway",
        "autoscaling",
        "aws_appsync",
        "aws_athena",
        "aws_auto_discovery",
        "aws_cognito",
        "aws_connect",
        "aws_directconnect",
        "aws_docdb",
        "aws_fsx",
        "aws_glue",
        "aws_kinesisanalytics",
        "aws_mediaconvert",
        "aws_mediapackagevod",
        "aws_metadata",
        "aws_mq",
        "aws_ms_elasticache",
        "aws_msk",
        "aws_neptune",
        "aws_qldb",
        "aws_route53resolver",
        "aws_states",
        "aws_tags_global",
        "aws_transitgateway",
        "aws_waf",
        "aws_wafv2",
        "aws_xray",
        "billing",
        "cloudfront",
        "cloudtrail",
        "dynamodb",
        "ebs",
        "ec2",
        "ecs",
        "efs",
        "elasticache",
        "elasticbeanstalk",
        "elasticsearch",
        "elb",
        "emr",
        "health",
        "iam",
        "iot",
        "kinesis",
        "kinesis_firehose",
        "lambda_",
        "rds",
        "redshift",
        "route53",
        "s3",
        "security_hub",
        "ses",
        "sns",
        "sqs",
        "trustedadvisor",
        "vpc",
    )
    alb = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAlbIntegrationInput), graphql_name="alb"
    )

    apigateway = sgqlc.types.Field(
        sgqlc.types.list_of(CloudApigatewayIntegrationInput), graphql_name="apigateway"
    )

    autoscaling = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAutoscalingIntegrationInput),
        graphql_name="autoscaling",
    )

    aws_appsync = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsAppsyncIntegrationInput), graphql_name="awsAppsync"
    )

    aws_athena = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsAthenaIntegrationInput), graphql_name="awsAthena"
    )

    aws_auto_discovery = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsAutoDiscoveryIntegrationInput),
        graphql_name="awsAutoDiscovery",
    )

    aws_cognito = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsCognitoIntegrationInput), graphql_name="awsCognito"
    )

    aws_connect = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsConnectIntegrationInput), graphql_name="awsConnect"
    )

    aws_directconnect = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsDirectconnectIntegrationInput),
        graphql_name="awsDirectconnect",
    )

    aws_docdb = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsDocdbIntegrationInput), graphql_name="awsDocdb"
    )

    aws_fsx = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsFsxIntegrationInput), graphql_name="awsFsx"
    )

    aws_glue = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAwsGlueIntegrationInput), graphql_name="awsGlue"
    )

    aws_kinesisanalytics = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsKinesisanalyticsIntegrationInput"),
        graphql_name="awsKinesisanalytics",
    )

    aws_mediaconvert = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMediaconvertIntegrationInput"),
        graphql_name="awsMediaconvert",
    )

    aws_mediapackagevod = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMediapackagevodIntegrationInput"),
        graphql_name="awsMediapackagevod",
    )

    aws_metadata = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMetadataIntegrationInput"),
        graphql_name="awsMetadata",
    )

    aws_mq = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMqIntegrationInput"), graphql_name="awsMq"
    )

    aws_ms_elasticache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMsElasticacheIntegrationInput"),
        graphql_name="awsMsElasticache",
    )

    aws_msk = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsMskIntegrationInput"), graphql_name="awsMsk"
    )

    aws_neptune = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsNeptuneIntegrationInput"),
        graphql_name="awsNeptune",
    )

    aws_qldb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsQldbIntegrationInput"), graphql_name="awsQldb"
    )

    aws_route53resolver = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsRoute53resolverIntegrationInput"),
        graphql_name="awsRoute53resolver",
    )

    aws_states = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsStatesIntegrationInput"), graphql_name="awsStates"
    )

    aws_tags_global = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsTagsGlobalIntegrationInput"),
        graphql_name="awsTagsGlobal",
    )

    aws_transitgateway = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsTransitgatewayIntegrationInput"),
        graphql_name="awsTransitgateway",
    )

    aws_waf = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsWafIntegrationInput"), graphql_name="awsWaf"
    )

    aws_wafv2 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsWafv2IntegrationInput"), graphql_name="awsWafv2"
    )

    aws_xray = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAwsXrayIntegrationInput"), graphql_name="awsXray"
    )

    billing = sgqlc.types.Field(
        sgqlc.types.list_of("CloudBillingIntegrationInput"), graphql_name="billing"
    )

    cloudfront = sgqlc.types.Field(
        sgqlc.types.list_of("CloudCloudfrontIntegrationInput"),
        graphql_name="cloudfront",
    )

    cloudtrail = sgqlc.types.Field(
        sgqlc.types.list_of("CloudCloudtrailIntegrationInput"),
        graphql_name="cloudtrail",
    )

    dynamodb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDynamodbIntegrationInput"), graphql_name="dynamodb"
    )

    ebs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEbsIntegrationInput"), graphql_name="ebs"
    )

    ec2 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEc2IntegrationInput"), graphql_name="ec2"
    )

    ecs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEcsIntegrationInput"), graphql_name="ecs"
    )

    efs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEfsIntegrationInput"), graphql_name="efs"
    )

    elasticache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudElasticacheIntegrationInput"),
        graphql_name="elasticache",
    )

    elasticbeanstalk = sgqlc.types.Field(
        sgqlc.types.list_of("CloudElasticbeanstalkIntegrationInput"),
        graphql_name="elasticbeanstalk",
    )

    elasticsearch = sgqlc.types.Field(
        sgqlc.types.list_of("CloudElasticsearchIntegrationInput"),
        graphql_name="elasticsearch",
    )

    elb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudElbIntegrationInput"), graphql_name="elb"
    )

    emr = sgqlc.types.Field(
        sgqlc.types.list_of("CloudEmrIntegrationInput"), graphql_name="emr"
    )

    health = sgqlc.types.Field(
        sgqlc.types.list_of("CloudHealthIntegrationInput"), graphql_name="health"
    )

    iam = sgqlc.types.Field(
        sgqlc.types.list_of("CloudIamIntegrationInput"), graphql_name="iam"
    )

    iot = sgqlc.types.Field(
        sgqlc.types.list_of("CloudIotIntegrationInput"), graphql_name="iot"
    )

    kinesis = sgqlc.types.Field(
        sgqlc.types.list_of("CloudKinesisIntegrationInput"), graphql_name="kinesis"
    )

    kinesis_firehose = sgqlc.types.Field(
        sgqlc.types.list_of("CloudKinesisFirehoseIntegrationInput"),
        graphql_name="kinesisFirehose",
    )

    lambda_ = sgqlc.types.Field(
        sgqlc.types.list_of("CloudLambdaIntegrationInput"), graphql_name="lambda"
    )

    rds = sgqlc.types.Field(
        sgqlc.types.list_of("CloudRdsIntegrationInput"), graphql_name="rds"
    )

    redshift = sgqlc.types.Field(
        sgqlc.types.list_of("CloudRedshiftIntegrationInput"), graphql_name="redshift"
    )

    route53 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudRoute53IntegrationInput"), graphql_name="route53"
    )

    s3 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudS3IntegrationInput"), graphql_name="s3"
    )

    security_hub = sgqlc.types.Field(
        sgqlc.types.list_of("CloudSecurityHubIntegrationInput"),
        graphql_name="securityHub",
    )

    ses = sgqlc.types.Field(
        sgqlc.types.list_of("CloudSesIntegrationInput"), graphql_name="ses"
    )

    sns = sgqlc.types.Field(
        sgqlc.types.list_of("CloudSnsIntegrationInput"), graphql_name="sns"
    )

    sqs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudSqsIntegrationInput"), graphql_name="sqs"
    )

    trustedadvisor = sgqlc.types.Field(
        sgqlc.types.list_of("CloudTrustedadvisorIntegrationInput"),
        graphql_name="trustedadvisor",
    )

    vpc = sgqlc.types.Field(
        sgqlc.types.list_of("CloudVpcIntegrationInput"), graphql_name="vpc"
    )

# %% [markdown]
# #### 247. `CloudAwsKinesisanalyticsIntegrationInput`

# %% [markdown]
# Kinesis Data Analytics
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsKinesisanalyticsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 248. `CloudAwsLinkAccountInput`

# %% [markdown]
# Information required to link a AWS account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `arn` : The AWS role ARN (used to fetch data).
# * `metricCollectionMode` : How metrics will be collected.
# * `name` : The linked account name.

# %%
# | export
class CloudAwsLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("arn", "metric_collection_mode", "name")
    arn = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="arn")

    metric_collection_mode = sgqlc.types.Field(
        CloudMetricCollectionMode, graphql_name="metricCollectionMode"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 249. `CloudAwsMediaconvertIntegrationInput`

# %% [markdown]
# Elemental MediaConvert
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMediaconvertIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 250. `CloudAwsMediapackagevodIntegrationInput`

# %% [markdown]
# MediaPackage VOD
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMediapackagevodIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 251. `CloudAwsMetadataEuSovereignIntegrationInput`

# %% [markdown]
# Fetch Metadata for AWS EU Sovereign integrations
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMetadataEuSovereignIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 252. `CloudAwsMetadataGovIntegrationInput`

# %% [markdown]
# Fetch Metadata for AWS Gov integrations
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMetadataGovIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 253. `CloudAwsMetadataIntegrationInput`

# %% [markdown]
# Fetch Metadata for AWS integrations
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMetadataIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 254. `CloudAwsMqIntegrationInput`

# %% [markdown]
# MQ
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMqIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 255. `CloudAwsMsElasticacheEuSovereignIntegrationInput`

# %% [markdown]
# Fetch ElastiCache EU Sovereign entities
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMsElasticacheEuSovereignIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 256. `CloudAwsMsElasticacheGovIntegrationInput`

# %% [markdown]
# Fetch ElastiCache entities
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMsElasticacheGovIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 257. `CloudAwsMsElasticacheIntegrationInput`

# %% [markdown]
# Fetch ElastiCache entities
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMsElasticacheIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 258. `CloudAwsMskIntegrationInput`

# %% [markdown]
# Managed Kafka
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsMskIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 259. `CloudAwsNeptuneIntegrationInput`

# %% [markdown]
# Neptune
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsNeptuneIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 260. `CloudAwsQldbIntegrationInput`

# %% [markdown]
# QLDB
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsQldbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 261. `CloudAwsRoute53resolverIntegrationInput`

# %% [markdown]
# Route53 Resolver
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsRoute53resolverIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 262. `CloudAwsStatesIntegrationInput`

# %% [markdown]
# Step Functions
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsStatesIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 263. `CloudAwsTagsGlobalEuSovereignIntegrationInput`

# %% [markdown]
# Fetch tags for all AWS EU Sovereign integrations
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsTagsGlobalEuSovereignIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 264. `CloudAwsTagsGlobalGovIntegrationInput`

# %% [markdown]
# Fetch tags for Gov for all integrations
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsTagsGlobalGovIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 265. `CloudAwsTagsGlobalIntegrationInput`

# %% [markdown]
# Fetch tags for all integrations
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsTagsGlobalIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 266. `CloudAwsTransitgatewayIntegrationInput`

# %% [markdown]
# Transit Gateway
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsTransitgatewayIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 267. `CloudAwsUpdateAccountInput`

# %% [markdown]
# Information required to update a AWS account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `arn` : The AWS role ARN (used to fetch data).
# * `disabled` : Disable the linked account.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.

# %%
# | export
class CloudAwsUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("arn", "disabled", "linked_account_id", "name")
    arn = sgqlc.types.Field(String, graphql_name="arn")

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 268. `CloudAwsWafIntegrationInput`

# %% [markdown]
# WAF
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsWafIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 269. `CloudAwsWafv2IntegrationInput`

# %% [markdown]
# WAFV2
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsWafv2IntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 270. `CloudAwsXrayIntegrationInput`

# %% [markdown]
# X-Ray
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAwsXrayIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 271. `CloudAzureApimanagementIntegrationInput`

# %% [markdown]
# Api Management
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureApimanagementIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 272. `CloudAzureAppgatewayIntegrationInput`

# %% [markdown]
# App Gateway
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureAppgatewayIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 273. `CloudAzureAppserviceIntegrationInput`

# %% [markdown]
# Azure App Service
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureAppserviceIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 274. `CloudAzureAutoDiscoveryIntegrationInput`

# %% [markdown]
# Azure Auto Discovery
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudAzureAutoDiscoveryIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 275. `CloudAzureContainersIntegrationInput`

# %% [markdown]
# Containers
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureContainersIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 276. `CloudAzureCosmosdbIntegrationInput`

# %% [markdown]
# Azure Cosmos DB
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureCosmosdbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 277. `CloudAzureCostmanagementIntegrationInput`

# %% [markdown]
# Cost Management
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKeys` : Specify if additional cost data per tag should be collected. This field is case sensitive.

# %%
# | export
class CloudAzureCostmanagementIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_keys",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_keys = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="tagKeys")

# %% [markdown]
# #### 278. `CloudAzureDatafactoryIntegrationInput`

# %% [markdown]
# Data Factory
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureDatafactoryIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 279. `CloudAzureDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `azureApimanagement` : Api Management integration
# * `azureAppgateway` : App Gateway integration
# * `azureAppservice` : App Service integration
# * `azureAutoDiscovery` : Azure Auto Discovery integration
# * `azureContainers` : Containers integration
# * `azureCosmosdb` : Cosmos DB integration
# * `azureCostmanagement` : Cost Management integration
# * `azureDatafactory` : Data Factory integration
# * `azureEventhub` : Event Hub integration
# * `azureExpressroute` : Express Route integration
# * `azureFirewalls` : Firewalls integration
# * `azureFrontdoor` : Front Door integration
# * `azureFunctions` : Functions integration
# * `azureKeyvault` : Key Vault integration
# * `azureLoadbalancer` : Load Balancer integration
# * `azureLogicapps` : Logic Apps integration
# * `azureMachinelearning` : Machine Learning integration
# * `azureMariadb` : Database for MariaDB integration
# * `azureMonitor` : Azure Monitor metrics integration
# * `azureMysql` : Database for MySQL integration
# * `azureMysqlflexible` : MySQL Flexible Server integration
# * `azurePostgresql` : Database for PostgreSQL integration
# * `azurePostgresqlflexible` : PostgreSQL Flexible Server integration
# * `azurePowerbidedicated` : Power BI Dedicated integration
# * `azureRediscache` : Redis Cache integration
# * `azureServicebus` : Service Bus integration
# * `azureSql` : SQL Database integration
# * `azureSqlmanaged` : SQL Managed Instances integration
# * `azureStorage` : Storage integration
# * `azureVirtualmachine` : Virtual machine scale sets integration
# * `azureVirtualnetworks` : Virtual Network integration
# * `azureVms` : Virtual Machines integration
# * `azureVpngateways` : VPN Gateways integration

# %%
# | export
class CloudAzureDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "azure_apimanagement",
        "azure_appgateway",
        "azure_appservice",
        "azure_auto_discovery",
        "azure_containers",
        "azure_cosmosdb",
        "azure_costmanagement",
        "azure_datafactory",
        "azure_eventhub",
        "azure_expressroute",
        "azure_firewalls",
        "azure_frontdoor",
        "azure_functions",
        "azure_keyvault",
        "azure_loadbalancer",
        "azure_logicapps",
        "azure_machinelearning",
        "azure_mariadb",
        "azure_monitor",
        "azure_mysql",
        "azure_mysqlflexible",
        "azure_postgresql",
        "azure_postgresqlflexible",
        "azure_powerbidedicated",
        "azure_rediscache",
        "azure_servicebus",
        "azure_sql",
        "azure_sqlmanaged",
        "azure_storage",
        "azure_virtualmachine",
        "azure_virtualnetworks",
        "azure_vms",
        "azure_vpngateways",
    )
    azure_apimanagement = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureApimanagement",
    )

    azure_appgateway = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureAppgateway",
    )

    azure_appservice = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureAppservice",
    )

    azure_auto_discovery = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureAutoDiscovery",
    )

    azure_containers = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureContainers",
    )

    azure_cosmosdb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureCosmosdb",
    )

    azure_costmanagement = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureCostmanagement",
    )

    azure_datafactory = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureDatafactory",
    )

    azure_eventhub = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureEventhub",
    )

    azure_expressroute = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureExpressroute",
    )

    azure_firewalls = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureFirewalls",
    )

    azure_frontdoor = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureFrontdoor",
    )

    azure_functions = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureFunctions",
    )

    azure_keyvault = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureKeyvault",
    )

    azure_loadbalancer = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureLoadbalancer",
    )

    azure_logicapps = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureLogicapps",
    )

    azure_machinelearning = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureMachinelearning",
    )

    azure_mariadb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureMariadb",
    )

    azure_monitor = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureMonitor",
    )

    azure_mysql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureMysql",
    )

    azure_mysqlflexible = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureMysqlflexible",
    )

    azure_postgresql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azurePostgresql",
    )

    azure_postgresqlflexible = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azurePostgresqlflexible",
    )

    azure_powerbidedicated = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azurePowerbidedicated",
    )

    azure_rediscache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureRediscache",
    )

    azure_servicebus = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureServicebus",
    )

    azure_sql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureSql",
    )

    azure_sqlmanaged = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureSqlmanaged",
    )

    azure_storage = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureStorage",
    )

    azure_virtualmachine = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureVirtualmachine",
    )

    azure_virtualnetworks = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureVirtualnetworks",
    )

    azure_vms = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureVms",
    )

    azure_vpngateways = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="azureVpngateways",
    )

# %% [markdown]
# #### 280. `CloudAzureEventhubIntegrationInput`

# %% [markdown]
# Event Hub
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureEventhubIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 281. `CloudAzureExpressrouteIntegrationInput`

# %% [markdown]
# Express Route
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureExpressrouteIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 282. `CloudAzureFirewallsIntegrationInput`

# %% [markdown]
# Firewalls
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureFirewallsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 283. `CloudAzureFrontdoorIntegrationInput`

# %% [markdown]
# Front Door
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureFrontdoorIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 284. `CloudAzureFunctionsIntegrationInput`

# %% [markdown]
# Azure Functions
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureFunctionsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 285. `CloudAzureIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `azureApimanagement` : Api Management integration
# * `azureAppgateway` : App Gateway integration
# * `azureAppservice` : App Service integration
# * `azureAutoDiscovery` : Azure Auto Discovery integration
# * `azureContainers` : Containers integration
# * `azureCosmosdb` : Cosmos DB integration
# * `azureCostmanagement` : Cost Management integration
# * `azureDatafactory` : Data Factory integration
# * `azureEventhub` : Event Hub integration
# * `azureExpressroute` : Express Route integration
# * `azureFirewalls` : Firewalls integration
# * `azureFrontdoor` : Front Door integration
# * `azureFunctions` : Functions integration
# * `azureKeyvault` : Key Vault integration
# * `azureLoadbalancer` : Load Balancer integration
# * `azureLogicapps` : Logic Apps integration
# * `azureMachinelearning` : Machine Learning integration
# * `azureMariadb` : Database for MariaDB integration
# * `azureMonitor` : Azure Monitor metrics integration
# * `azureMysql` : Database for MySQL integration
# * `azureMysqlflexible` : MySQL Flexible Server integration
# * `azurePostgresql` : Database for PostgreSQL integration
# * `azurePostgresqlflexible` : PostgreSQL Flexible Server integration
# * `azurePowerbidedicated` : Power BI Dedicated integration
# * `azureRediscache` : Redis Cache integration
# * `azureServicebus` : Service Bus integration
# * `azureSql` : SQL Database integration
# * `azureSqlmanaged` : SQL Managed Instances integration
# * `azureStorage` : Storage integration
# * `azureVirtualmachine` : Virtual machine scale sets integration
# * `azureVirtualnetworks` : Virtual Network integration
# * `azureVms` : Virtual Machines integration
# * `azureVpngateways` : VPN Gateways integration

# %%
# | export
class CloudAzureIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "azure_apimanagement",
        "azure_appgateway",
        "azure_appservice",
        "azure_auto_discovery",
        "azure_containers",
        "azure_cosmosdb",
        "azure_costmanagement",
        "azure_datafactory",
        "azure_eventhub",
        "azure_expressroute",
        "azure_firewalls",
        "azure_frontdoor",
        "azure_functions",
        "azure_keyvault",
        "azure_loadbalancer",
        "azure_logicapps",
        "azure_machinelearning",
        "azure_mariadb",
        "azure_monitor",
        "azure_mysql",
        "azure_mysqlflexible",
        "azure_postgresql",
        "azure_postgresqlflexible",
        "azure_powerbidedicated",
        "azure_rediscache",
        "azure_servicebus",
        "azure_sql",
        "azure_sqlmanaged",
        "azure_storage",
        "azure_virtualmachine",
        "azure_virtualnetworks",
        "azure_vms",
        "azure_vpngateways",
    )
    azure_apimanagement = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureApimanagementIntegrationInput),
        graphql_name="azureApimanagement",
    )

    azure_appgateway = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureAppgatewayIntegrationInput),
        graphql_name="azureAppgateway",
    )

    azure_appservice = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureAppserviceIntegrationInput),
        graphql_name="azureAppservice",
    )

    azure_auto_discovery = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureAutoDiscoveryIntegrationInput),
        graphql_name="azureAutoDiscovery",
    )

    azure_containers = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureContainersIntegrationInput),
        graphql_name="azureContainers",
    )

    azure_cosmosdb = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureCosmosdbIntegrationInput),
        graphql_name="azureCosmosdb",
    )

    azure_costmanagement = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureCostmanagementIntegrationInput),
        graphql_name="azureCostmanagement",
    )

    azure_datafactory = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureDatafactoryIntegrationInput),
        graphql_name="azureDatafactory",
    )

    azure_eventhub = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureEventhubIntegrationInput),
        graphql_name="azureEventhub",
    )

    azure_expressroute = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureExpressrouteIntegrationInput),
        graphql_name="azureExpressroute",
    )

    azure_firewalls = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureFirewallsIntegrationInput),
        graphql_name="azureFirewalls",
    )

    azure_frontdoor = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureFrontdoorIntegrationInput),
        graphql_name="azureFrontdoor",
    )

    azure_functions = sgqlc.types.Field(
        sgqlc.types.list_of(CloudAzureFunctionsIntegrationInput),
        graphql_name="azureFunctions",
    )

    azure_keyvault = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureKeyvaultIntegrationInput"),
        graphql_name="azureKeyvault",
    )

    azure_loadbalancer = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureLoadbalancerIntegrationInput"),
        graphql_name="azureLoadbalancer",
    )

    azure_logicapps = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureLogicappsIntegrationInput"),
        graphql_name="azureLogicapps",
    )

    azure_machinelearning = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureMachinelearningIntegrationInput"),
        graphql_name="azureMachinelearning",
    )

    azure_mariadb = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureMariadbIntegrationInput"),
        graphql_name="azureMariadb",
    )

    azure_monitor = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureMonitorIntegrationInput"),
        graphql_name="azureMonitor",
    )

    azure_mysql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureMysqlIntegrationInput"),
        graphql_name="azureMysql",
    )

    azure_mysqlflexible = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureMysqlflexibleIntegrationInput"),
        graphql_name="azureMysqlflexible",
    )

    azure_postgresql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzurePostgresqlIntegrationInput"),
        graphql_name="azurePostgresql",
    )

    azure_postgresqlflexible = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzurePostgresqlflexibleIntegrationInput"),
        graphql_name="azurePostgresqlflexible",
    )

    azure_powerbidedicated = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzurePowerbidedicatedIntegrationInput"),
        graphql_name="azurePowerbidedicated",
    )

    azure_rediscache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureRediscacheIntegrationInput"),
        graphql_name="azureRediscache",
    )

    azure_servicebus = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureServicebusIntegrationInput"),
        graphql_name="azureServicebus",
    )

    azure_sql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureSqlIntegrationInput"), graphql_name="azureSql"
    )

    azure_sqlmanaged = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureSqlmanagedIntegrationInput"),
        graphql_name="azureSqlmanaged",
    )

    azure_storage = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureStorageIntegrationInput"),
        graphql_name="azureStorage",
    )

    azure_virtualmachine = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureVirtualmachineIntegrationInput"),
        graphql_name="azureVirtualmachine",
    )

    azure_virtualnetworks = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureVirtualnetworksIntegrationInput"),
        graphql_name="azureVirtualnetworks",
    )

    azure_vms = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureVmsIntegrationInput"), graphql_name="azureVms"
    )

    azure_vpngateways = sgqlc.types.Field(
        sgqlc.types.list_of("CloudAzureVpngatewaysIntegrationInput"),
        graphql_name="azureVpngateways",
    )

# %% [markdown]
# #### 286. `CloudAzureKeyvaultIntegrationInput`

# %% [markdown]
# Key Vault
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureKeyvaultIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 287. `CloudAzureLinkAccountInput`

# %% [markdown]
# Information required to link a Azure account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `applicationId` : The Azure account application identifier (used to fetch data).
# * `clientSecret` : The Azure account application secret key.
# * `name` : The linked account name.
# * `subscriptionId` : The Azure account subscription identifier.
# * `tenantId` : The Azure account tenant identifier.

# %%
# | export
class CloudAzureLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "application_id",
        "client_secret",
        "name",
        "subscription_id",
        "tenant_id",
    )
    application_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="applicationId"
    )

    client_secret = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="clientSecret"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    subscription_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="subscriptionId"
    )

    tenant_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="tenantId")

# %% [markdown]
# #### 288. `CloudAzureLoadbalancerIntegrationInput`

# %% [markdown]
# Azure Load Balancer
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureLoadbalancerIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 289. `CloudAzureLogicappsIntegrationInput`

# %% [markdown]
# Logic Apps
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureLogicappsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 290. `CloudAzureMachinelearningIntegrationInput`

# %% [markdown]
# Machine Learning
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureMachinelearningIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 291. `CloudAzureMariadbIntegrationInput`

# %% [markdown]
# Database for MariaDB
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureMariadbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 292. `CloudAzureMonitorIntegrationInput`

# %% [markdown]
# Azure Monitor metrics
#
#
# Available input fields:
#
#
#
# * `enabled` : Specify if integration is active
# * `excludeResourceTypes` : Specify each Azure resource type that you don't want to monitor.
# * `excludeTags` : Specify resource tags (in 'key:value' form) associated with the resources that you want to exclude from monitoring. Exclusion takes precedence over inclusion.
# * `includeTags` : Specify resource tags (in 'key:value' form) associated with the resources that you want to monitor. If empty, all resources will be monitored.
# * `inventoryPollingInterval` : The polling interval for metadata and tags, in seconds.
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The polling interval for metrics, in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `resourceTypes` : Specify each Azure resource type that you want to monitor.

# %%
# | export
class CloudAzureMonitorIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "enabled",
        "exclude_resource_types",
        "exclude_tags",
        "include_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
        "resource_types",
    )
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    exclude_resource_types = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="excludeResourceTypes"
    )

    exclude_tags = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="excludeTags"
    )

    include_tags = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="includeTags"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

    resource_types = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceTypes"
    )

# %% [markdown]
# #### 293. `CloudAzureMysqlIntegrationInput`

# %% [markdown]
# Database for MySQL
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureMysqlIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 294. `CloudAzureMysqlflexibleIntegrationInput`

# %% [markdown]
# MySQL Flexible Server
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureMysqlflexibleIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 295. `CloudAzurePostgresqlIntegrationInput`

# %% [markdown]
# Database for PostgreSQL
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzurePostgresqlIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 296. `CloudAzurePostgresqlflexibleIntegrationInput`

# %% [markdown]
# PostgreSQL Flexible Server
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzurePostgresqlflexibleIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 297. `CloudAzurePowerbidedicatedIntegrationInput`

# %% [markdown]
# Power BI Dedicated
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzurePowerbidedicatedIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 298. `CloudAzureRediscacheIntegrationInput`

# %% [markdown]
# Azure Redis Cache
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureRediscacheIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 299. `CloudAzureServicebusIntegrationInput`

# %% [markdown]
# Azure Service Bus
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureServicebusIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 300. `CloudAzureSqlIntegrationInput`

# %% [markdown]
# Azure SQL Database
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureSqlIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 301. `CloudAzureSqlmanagedIntegrationInput`

# %% [markdown]
# SQL Managed Instances
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureSqlmanagedIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 302. `CloudAzureStorageIntegrationInput`

# %% [markdown]
# Azure Storage
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureStorageIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 303. `CloudAzureUpdateAccountInput`

# %% [markdown]
# Information required to update a Azure account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `applicationId` : The Azure account application identifier (used to fetch data).
# * `clientSecret` : The Azure account application secret key.
# * `disabled` : Disable the linked account.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.
# * `subscriptionId` : The Azure account subscription identifier.
# * `tenantId` : The Azure account tenant identifier.

# %%
# | export
class CloudAzureUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "application_id",
        "client_secret",
        "disabled",
        "linked_account_id",
        "name",
        "subscription_id",
        "tenant_id",
    )
    application_id = sgqlc.types.Field(String, graphql_name="applicationId")

    client_secret = sgqlc.types.Field(SecureValue, graphql_name="clientSecret")

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    subscription_id = sgqlc.types.Field(String, graphql_name="subscriptionId")

    tenant_id = sgqlc.types.Field(String, graphql_name="tenantId")

# %% [markdown]
# #### 304. `CloudAzureVirtualmachineIntegrationInput`

# %% [markdown]
# Virtual machine scale sets
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureVirtualmachineIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 305. `CloudAzureVirtualnetworksIntegrationInput`

# %% [markdown]
# Azure Virtual Network
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureVirtualnetworksIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 306. `CloudAzureVmsIntegrationInput`

# %% [markdown]
# Azure Virtual Machines
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureVmsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 307. `CloudAzureVpngatewaysIntegrationInput`

# %% [markdown]
# VPN Gateways
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `resourceGroups` : Specify each Resource group associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudAzureVpngatewaysIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "resource_groups",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    resource_groups = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="resourceGroups"
    )

# %% [markdown]
# #### 308. `CloudBillingIntegrationInput`

# %% [markdown]
# AWS Billing
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudBillingIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 309. `CloudCciAwsDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `cciAwsS3` : CCI AWS S3 integration

# %%
# | export
class CloudCciAwsDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cci_aws_s3",)
    cci_aws_s3 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="cciAwsS3",
    )

# %% [markdown]
# #### 310. `CloudCciAwsIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `cciAwsS3` : CCI AWS S3 Integration integration

# %%
# | export
class CloudCciAwsIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cci_aws_s3",)
    cci_aws_s3 = sgqlc.types.Field(
        sgqlc.types.list_of("CloudCciAwsS3IntegrationInput"), graphql_name="cciAwsS3"
    )

# %% [markdown]
# #### 311. `CloudCciAwsLinkAccountInput`

# %% [markdown]
# Information required to link a CCI AWS account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `arn` : The arn of the AWS Payer Account
# * `externalId` : External ID to assume the role
# * `metricCollectionMode` : How metrics will be collected.
# * `name` : The name of the CCI AWS Connection

# %%
# | export
class CloudCciAwsLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("arn", "external_id", "metric_collection_mode", "name")
    arn = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="arn")

    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    metric_collection_mode = sgqlc.types.Field(
        CloudMetricCollectionMode, graphql_name="metricCollectionMode"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 312. `CloudCciAwsS3IntegrationInput`

# %% [markdown]
# Cci AWS S3
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `s3BucketName` : The name of the S3 bucket to collect data from.
# * `s3BucketPath` : The path within the S3 bucket to collect data from.
# * `s3BucketRegion` : The region of the S3 bucket to collect data from.

# %%
# | export
class CloudCciAwsS3IntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "s3_bucket_name",
        "s3_bucket_path",
        "s3_bucket_region",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    s3_bucket_name = sgqlc.types.Field(String, graphql_name="s3BucketName")

    s3_bucket_path = sgqlc.types.Field(String, graphql_name="s3BucketPath")

    s3_bucket_region = sgqlc.types.Field(String, graphql_name="s3BucketRegion")

# %% [markdown]
# #### 313. `CloudCloudfrontIntegrationInput`

# %% [markdown]
# Amazon CloudFront
#
#
# Available input fields:
#
#
#
# * `fetchLambdasAtEdge` : Specify if Lambdas@Edge should be monitored. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudCloudfrontIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_lambdas_at_edge",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    fetch_lambdas_at_edge = sgqlc.types.Field(
        Boolean, graphql_name="fetchLambdasAtEdge"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 314. `CloudCloudtrailIntegrationInput`

# %% [markdown]
# AWS CloudTrail
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudCloudtrailIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 315. `CloudConfluentDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `confluentKafkaConnectorResource` : Confluent Kafka Connector integration
# * `confluentKafkaFlinkResource` : Confluent Kafka Flink integration
# * `confluentKafkaKsqlResource` : Confluent Kafka Ksql integration
# * `confluentKafkaResource` : Confluent Kafka Resource integration

# %%
# | export
class CloudConfluentDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "confluent_kafka_connector_resource",
        "confluent_kafka_flink_resource",
        "confluent_kafka_ksql_resource",
        "confluent_kafka_resource",
    )
    confluent_kafka_connector_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="confluentKafkaConnectorResource",
    )

    confluent_kafka_flink_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="confluentKafkaFlinkResource",
    )

    confluent_kafka_ksql_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="confluentKafkaKsqlResource",
    )

    confluent_kafka_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudDisableAccountIntegrationInput"),
        graphql_name="confluentKafkaResource",
    )

# %% [markdown]
# #### 316. `CloudConfluentIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `confluentKafkaConnectorResource` : Confluent Kafka Connector integration
# * `confluentKafkaFlinkResource` : Confluent Kafka Flink integration
# * `confluentKafkaKsqlResource` : Confluent Kafka Ksql integration
# * `confluentKafkaResource` : Confluent Kafka Resource integration

# %%
# | export
class CloudConfluentIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "confluent_kafka_connector_resource",
        "confluent_kafka_flink_resource",
        "confluent_kafka_ksql_resource",
        "confluent_kafka_resource",
    )
    confluent_kafka_connector_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudConfluentKafkaConnectorResourceIntegrationInput"),
        graphql_name="confluentKafkaConnectorResource",
    )

    confluent_kafka_flink_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudConfluentKafkaFlinkResourceIntegrationInput"),
        graphql_name="confluentKafkaFlinkResource",
    )

    confluent_kafka_ksql_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudConfluentKafkaKsqlResourceIntegrationInput"),
        graphql_name="confluentKafkaKsqlResource",
    )

    confluent_kafka_resource = sgqlc.types.Field(
        sgqlc.types.list_of("CloudConfluentKafkaResourceIntegrationInput"),
        graphql_name="confluentKafkaResource",
    )

# %% [markdown]
# #### 317. `CloudConfluentKafkaConnectorResourceIntegrationInput`

# %% [markdown]
# Confluent Kafka Connector Resource
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudConfluentKafkaConnectorResourceIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 318. `CloudConfluentKafkaFlinkResourceIntegrationInput`

# %% [markdown]
# Confluent Kafka Flink Resource
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudConfluentKafkaFlinkResourceIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 319. `CloudConfluentKafkaKsqlResourceIntegrationInput`

# %% [markdown]
# Confluent Kafka Ksql Resource
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudConfluentKafkaKsqlResourceIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 320. `CloudConfluentKafkaResourceIntegrationInput`

# %% [markdown]
# Confluent Kafka Resource
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudConfluentKafkaResourceIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 321. `CloudConfluentLinkAccountInput`

# %% [markdown]
# Information required to link a Confluent Cloud account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `apiKey` : The Confluent Cloud account API key.
# * `apiSecret` : The Confluent Cloud account API Secret key.
# * `externalId` : The Confluent Cloud account identifier.
# * `name` : The linked account name.

# %%
# | export
class CloudConfluentLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("api_key", "api_secret", "external_id", "name")
    api_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiKey"
    )

    api_secret = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiSecret"
    )

    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 322. `CloudConfluentUpdateAccountInput`

# %% [markdown]
# Information required to update a Confluent Cloud account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `apiKey` : The Confluent account API key.
# * `apiSecret` : The Confluent Cloud account API Secret key.
# * `disabled` : Disable the linked account.
# * `externalId` : The Confluent Cloud account identifier.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.

# %%
# | export
class CloudConfluentUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "api_key",
        "api_secret",
        "disabled",
        "external_id",
        "linked_account_id",
        "name",
    )
    api_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiKey"
    )

    api_secret = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiSecret"
    )

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 323. `CloudCostIntelligenceAwsIntegration`

# %% [markdown]
# Input for creating AWS connection.
#
#
# Available input fields:
#
#
#
# * `connectionName` : Name for this connection
# * `externalId` : External ID for additional security
# * `roleArn` : IAM role ARN for AWS authentication
# * `s3BucketName` : Name of the S3 bucket containing cost data
# * `s3BucketPathPrefix` : Path prefix within the S3 bucket

# %%
# | export
class CloudCostIntelligenceAwsIntegration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "connection_name",
        "external_id",
        "role_arn",
        "s3_bucket_name",
        "s3_bucket_path_prefix",
    )
    connection_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="connectionName"
    )

    external_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="externalId"
    )

    role_arn = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="roleArn")

    s3_bucket_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="s3BucketName"
    )

    s3_bucket_path_prefix = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="s3BucketPathPrefix"
    )

# %% [markdown]
# #### 324. `CloudCostIntelligenceAzureIntegration`

# %% [markdown]
# Input for creating Azure connection.
#
#
# Available input fields:
#
#
#
# * `agreementType` : Agreement type
# * `baseDropPath` : Base drop path
# * `billingAccountId` : Billing account id for Azure authentication
# * `connectionName` : Connection name for Azure authentication
# * `containerName` : Name of the container within the storage account
# * `storageAccountName` : Name of the storage account containing cost data
# * `tenantId` : Tenant Id for Azure authentication

# %%
# | export
class CloudCostIntelligenceAzureIntegration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "agreement_type",
        "base_drop_path",
        "billing_account_id",
        "connection_name",
        "container_name",
        "storage_account_name",
        "tenant_id",
    )
    agreement_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="agreementType"
    )

    base_drop_path = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="baseDropPath"
    )

    billing_account_id = sgqlc.types.Field(String, graphql_name="billingAccountId")

    connection_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="connectionName"
    )

    container_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="containerName"
    )

    storage_account_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="storageAccountName"
    )

    tenant_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="tenantId")

# %% [markdown]
# #### 325. `CloudCostIntelligenceGcpIntegration`

# %% [markdown]
# Input for creating GCP connection.
#
#
# Available input fields:
#
#
#
# * `billingTableName` : BigQuery billing table name
# * `connectionName` : Connection name for GCP authentication
# * `datasetName` : BigQuery dataset name
# * `pricingTableName` : BigQuery pricing table name
# * `projectId` : GCP project ID

# %%
# | export
class CloudCostIntelligenceGcpIntegration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "billing_table_name",
        "connection_name",
        "dataset_name",
        "pricing_table_name",
        "project_id",
    )
    billing_table_name = sgqlc.types.Field(String, graphql_name="billingTableName")

    connection_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="connectionName"
    )

    dataset_name = sgqlc.types.Field(String, graphql_name="datasetName")

    pricing_table_name = sgqlc.types.Field(String, graphql_name="pricingTableName")

    project_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="projectId"
    )

# %% [markdown]
# #### 326. `CloudCostIntelligenceIntegrationFilter`

# %% [markdown]
# Filter input for integrations filtering.
#
#
# Available input fields:
#
#
#
# * `operator` : Operator for the filter
# * `term` : The term to filter by
# * `value` : Values to filter on

# %%
# | export
class CloudCostIntelligenceIntegrationFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("operator", "term", "value")
    operator = sgqlc.types.Field(
        sgqlc.types.non_null(CloudCostIntelligenceIntegrationFilterOperator),
        graphql_name="operator",
    )

    term = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="term")

    value = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)), graphql_name="value"
    )

# %% [markdown]
# #### 327. `CloudDisableAccountIntegrationInput`

# %% [markdown]
# Information required to disable a cloud service integration from a linked account.
#
#
# Available input fields:
#
#
#
# * `linkedAccountId` : The linked account identifier

# %%
# | export
class CloudDisableAccountIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("linked_account_id",)
    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

# %% [markdown]
# #### 328. `CloudDisableIntegrationsInput`

# %% [markdown]
# List of providers
#
#
# Available input fields:
#
#
#
# * `aws` : Aws provider
# * `awsEuSovereign` : AWS EU Sovereign Cloud provider
# * `awsGovcloud` : AwsGovcloud provider
# * `azure` : Azure provider
# * `cciAws` : CciAws provider
# * `confluent` : Confluent provider
# * `fossa` : Fossa provider
# * `gcp` : Gcp provider
# * `oci` : OCI Provider

# %%
# | export
class CloudDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws",
        "aws_eu_sovereign",
        "aws_govcloud",
        "azure",
        "cci_aws",
        "confluent",
        "fossa",
        "gcp",
        "oci",
    )
    aws = sgqlc.types.Field(CloudAwsDisableIntegrationsInput, graphql_name="aws")

    aws_eu_sovereign = sgqlc.types.Field(
        CloudAwsEuSovereignDisableIntegrationsInput, graphql_name="awsEuSovereign"
    )

    aws_govcloud = sgqlc.types.Field(
        CloudAwsGovcloudDisableIntegrationsInput, graphql_name="awsGovcloud"
    )

    azure = sgqlc.types.Field(CloudAzureDisableIntegrationsInput, graphql_name="azure")

    cci_aws = sgqlc.types.Field(
        CloudCciAwsDisableIntegrationsInput, graphql_name="cciAws"
    )

    confluent = sgqlc.types.Field(
        CloudConfluentDisableIntegrationsInput, graphql_name="confluent"
    )

    fossa = sgqlc.types.Field(
        "CloudFossaDisableIntegrationsInput", graphql_name="fossa"
    )

    gcp = sgqlc.types.Field("CloudGcpDisableIntegrationsInput", graphql_name="gcp")

    oci = sgqlc.types.Field("CloudOciDisableIntegrationsInput", graphql_name="oci")

# %% [markdown]
# #### 329. `CloudDynamodbIntegrationInput`

# %% [markdown]
# Amazon DynamoDB
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudDynamodbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 330. `CloudEbsIntegrationInput`

# %% [markdown]
# Amazon Elastic Block Store (EBS)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudEbsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 331. `CloudEc2IntegrationInput`

# %% [markdown]
# Amazon Elastic Compute Cloud (EC2)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `duplicateEc2Tags` : Specify if the old legacy metadata and tag names have to be kept, it will consume more ingest data size
# * `fetchIpAddresses` : Specify if IP addresses of ec2 instance should be collected
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudEc2IntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "duplicate_ec2_tags",
        "fetch_ip_addresses",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    duplicate_ec2_tags = sgqlc.types.Field(Boolean, graphql_name="duplicateEc2Tags")

    fetch_ip_addresses = sgqlc.types.Field(Boolean, graphql_name="fetchIpAddresses")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 332. `CloudEcsIntegrationInput`

# %% [markdown]
# Amazon Elastic Container Service (ECS)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudEcsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 333. `CloudEfsIntegrationInput`

# %% [markdown]
# Amazon Elastic File System (EFS)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudEfsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 334. `CloudElasticacheIntegrationInput`

# %% [markdown]
# Amazon ElastiCache
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudElasticacheIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 335. `CloudElasticbeanstalkIntegrationInput`

# %% [markdown]
# AWS Elastic Beanstalk
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudElasticbeanstalkIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 336. `CloudElasticsearchIntegrationInput`

# %% [markdown]
# Amazon Elasticsearch Service
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchNodes` : Specify if metrics should be collected for nodes. Turning it on will increase the number of API calls made to CloudWatch.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudElasticsearchIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_nodes",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_nodes = sgqlc.types.Field(Boolean, graphql_name="fetchNodes")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 337. `CloudElbIntegrationInput`

# %% [markdown]
# Elastic Load Balancing - Classic Load Balancer (ELB)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudElbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 338. `CloudEmrIntegrationInput`

# %% [markdown]
# Amazon Elastic MapReduce (EMR)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchTags` : Specify if tags and the extended inventory should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudEmrIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 339. `CloudFossaDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `fossaIssues` : FOSSA Issues integration

# %%
# | export
class CloudFossaDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("fossa_issues",)
    fossa_issues = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="fossaIssues",
    )

# %% [markdown]
# #### 340. `CloudFossaIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `fossaIssues` : FOSSA Issues integration

# %%
# | export
class CloudFossaIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("fossa_issues",)
    fossa_issues = sgqlc.types.Field(
        sgqlc.types.list_of("CloudFossaIssuesIntegrationInput"),
        graphql_name="fossaIssues",
    )

# %% [markdown]
# #### 341. `CloudFossaIssuesIntegrationInput`

# %% [markdown]
# FOSSA Issues
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudFossaIssuesIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 342. `CloudFossaLinkAccountInput`

# %% [markdown]
# Information required to link a Fossa account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `apiKey` : The Fossa account application api key(bearer token).
# * `externalId` : The Fossa account identifier.
# * `name` : The linked account name.

# %%
# | export
class CloudFossaLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("api_key", "external_id", "name")
    api_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiKey"
    )

    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 343. `CloudFossaUpdateAccountInput`

# %% [markdown]
# Information required to update a Fossa account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `apiKey` : The Fossa account application api key(bearer token).
# * `disabled` : Disable the linked account.
# * `externalId` : The Fossa account identifier.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.

# %%
# | export
class CloudFossaUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "api_key",
        "disabled",
        "external_id",
        "linked_account_id",
        "name",
    )
    api_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="apiKey"
    )

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 344. `CloudGcpAiplatformIntegrationInput`

# %% [markdown]
# Vertex AI
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpAiplatformIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 345. `CloudGcpAlloydbIntegrationInput`

# %% [markdown]
# AlloyDB
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpAlloydbIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 346. `CloudGcpAppengineIntegrationInput`

# %% [markdown]
# Google App Engine
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpAppengineIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 347. `CloudGcpBigqueryIntegrationInput`

# %% [markdown]
# BigQuery
#
#
# Available input fields:
#
#
#
# * `fetchTableMetrics` : Fetch BigQuery Table metrics, disabled by default
# * `fetchTags` : Specify if labels and the extended inventory should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpBigqueryIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_table_metrics",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    fetch_table_metrics = sgqlc.types.Field(Boolean, graphql_name="fetchTableMetrics")

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 348. `CloudGcpBigtableIntegrationInput`

# %% [markdown]
# Bigtable
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpBigtableIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 349. `CloudGcpComposerIntegrationInput`

# %% [markdown]
# Composer
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpComposerIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 350. `CloudGcpDataflowIntegrationInput`

# %% [markdown]
# Dataflow
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpDataflowIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 351. `CloudGcpDataprocIntegrationInput`

# %% [markdown]
# Dataproc
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpDataprocIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 352. `CloudGcpDatastoreIntegrationInput`

# %% [markdown]
# Datastore
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpDatastoreIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 353. `CloudGcpDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `gcpAiplatform` : Vertex AI integration
# * `gcpAlloydb` : AlloyDB integration
# * `gcpAppengine` : App Engine integration
# * `gcpBigquery` : BigQuery integration
# * `gcpBigtable` : Bigtable integration
# * `gcpComposer` : Composer integration
# * `gcpDataflow` : Dataflow integration
# * `gcpDataproc` : Dataproc integration
# * `gcpDatastore` : Datastore integration
# * `gcpFirebasedatabase` : Firebase Database integration
# * `gcpFirebasehosting` : Firebase Hosting integration
# * `gcpFirebasestorage` : Firebase Storage integration
# * `gcpFirestore` : Firestore integration
# * `gcpFunctions` : Cloud Functions integration
# * `gcpInterconnect` : Interconnect integration
# * `gcpKubernetes` : Kubernetes Engine integration
# * `gcpLoadbalancing` : Cloud Load Balancing integration
# * `gcpMemcache` : Memcache integration
# * `gcpPubsub` : Cloud Pub/Sub integration
# * `gcpRedis` : Redis integration
# * `gcpRouter` : Router integration
# * `gcpRun` : Run integration
# * `gcpSpanner` : Cloud Spanner integration
# * `gcpSql` : Cloud SQL integration
# * `gcpStorage` : Cloud Storage integration
# * `gcpVms` : Compute Engine integration
# * `gcpVpcaccess` : VPC Access integration

# %%
# | export
class CloudGcpDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "gcp_aiplatform",
        "gcp_alloydb",
        "gcp_appengine",
        "gcp_bigquery",
        "gcp_bigtable",
        "gcp_composer",
        "gcp_dataflow",
        "gcp_dataproc",
        "gcp_datastore",
        "gcp_firebasedatabase",
        "gcp_firebasehosting",
        "gcp_firebasestorage",
        "gcp_firestore",
        "gcp_functions",
        "gcp_interconnect",
        "gcp_kubernetes",
        "gcp_loadbalancing",
        "gcp_memcache",
        "gcp_pubsub",
        "gcp_redis",
        "gcp_router",
        "gcp_run",
        "gcp_spanner",
        "gcp_sql",
        "gcp_storage",
        "gcp_vms",
        "gcp_vpcaccess",
    )
    gcp_aiplatform = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpAiplatform",
    )

    gcp_alloydb = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpAlloydb",
    )

    gcp_appengine = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpAppengine",
    )

    gcp_bigquery = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpBigquery",
    )

    gcp_bigtable = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpBigtable",
    )

    gcp_composer = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpComposer",
    )

    gcp_dataflow = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpDataflow",
    )

    gcp_dataproc = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpDataproc",
    )

    gcp_datastore = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpDatastore",
    )

    gcp_firebasedatabase = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpFirebasedatabase",
    )

    gcp_firebasehosting = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpFirebasehosting",
    )

    gcp_firebasestorage = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpFirebasestorage",
    )

    gcp_firestore = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpFirestore",
    )

    gcp_functions = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpFunctions",
    )

    gcp_interconnect = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpInterconnect",
    )

    gcp_kubernetes = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpKubernetes",
    )

    gcp_loadbalancing = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpLoadbalancing",
    )

    gcp_memcache = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpMemcache",
    )

    gcp_pubsub = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpPubsub",
    )

    gcp_redis = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpRedis",
    )

    gcp_router = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpRouter",
    )

    gcp_run = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput), graphql_name="gcpRun"
    )

    gcp_spanner = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpSpanner",
    )

    gcp_sql = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput), graphql_name="gcpSql"
    )

    gcp_storage = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpStorage",
    )

    gcp_vms = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput), graphql_name="gcpVms"
    )

    gcp_vpcaccess = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="gcpVpcaccess",
    )

# %% [markdown]
# #### 354. `CloudGcpFirebasedatabaseIntegrationInput`

# %% [markdown]
# Firebase Database
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpFirebasedatabaseIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 355. `CloudGcpFirebasehostingIntegrationInput`

# %% [markdown]
# Firebase Hosting
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpFirebasehostingIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 356. `CloudGcpFirebasestorageIntegrationInput`

# %% [markdown]
# Firebase Storage
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpFirebasestorageIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 357. `CloudGcpFirestoreIntegrationInput`

# %% [markdown]
# Firestore
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpFirestoreIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 358. `CloudGcpFunctionsIntegrationInput`

# %% [markdown]
# Google Cloud Functions
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpFunctionsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 359. `CloudGcpIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `gcpAiplatform` : Vertex AI integration
# * `gcpAlloydb` : AlloyDB integration
# * `gcpAppengine` : App Engine integration
# * `gcpBigquery` : BigQuery integration
# * `gcpBigtable` : Bigtable integration
# * `gcpComposer` : Composer integration
# * `gcpDataflow` : Dataflow integration
# * `gcpDataproc` : Dataproc integration
# * `gcpDatastore` : Datastore integration
# * `gcpFirebasedatabase` : Firebase Database integration
# * `gcpFirebasehosting` : Firebase Hosting integration
# * `gcpFirebasestorage` : Firebase Storage integration
# * `gcpFirestore` : Firestore integration
# * `gcpFunctions` : Cloud Functions integration
# * `gcpInterconnect` : Interconnect integration
# * `gcpKubernetes` : Kubernetes Engine integration
# * `gcpLoadbalancing` : Cloud Load Balancing integration
# * `gcpMemcache` : Memcache integration
# * `gcpPubsub` : Cloud Pub/Sub integration
# * `gcpRedis` : Redis integration
# * `gcpRouter` : Router integration
# * `gcpRun` : Run integration
# * `gcpSpanner` : Cloud Spanner integration
# * `gcpSql` : Cloud SQL integration
# * `gcpStorage` : Cloud Storage integration
# * `gcpVms` : Compute Engine integration
# * `gcpVpcaccess` : VPC Access integration

# %%
# | export
class CloudGcpIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "gcp_aiplatform",
        "gcp_alloydb",
        "gcp_appengine",
        "gcp_bigquery",
        "gcp_bigtable",
        "gcp_composer",
        "gcp_dataflow",
        "gcp_dataproc",
        "gcp_datastore",
        "gcp_firebasedatabase",
        "gcp_firebasehosting",
        "gcp_firebasestorage",
        "gcp_firestore",
        "gcp_functions",
        "gcp_interconnect",
        "gcp_kubernetes",
        "gcp_loadbalancing",
        "gcp_memcache",
        "gcp_pubsub",
        "gcp_redis",
        "gcp_router",
        "gcp_run",
        "gcp_spanner",
        "gcp_sql",
        "gcp_storage",
        "gcp_vms",
        "gcp_vpcaccess",
    )
    gcp_aiplatform = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpAiplatformIntegrationInput),
        graphql_name="gcpAiplatform",
    )

    gcp_alloydb = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpAlloydbIntegrationInput), graphql_name="gcpAlloydb"
    )

    gcp_appengine = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpAppengineIntegrationInput),
        graphql_name="gcpAppengine",
    )

    gcp_bigquery = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpBigqueryIntegrationInput),
        graphql_name="gcpBigquery",
    )

    gcp_bigtable = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpBigtableIntegrationInput),
        graphql_name="gcpBigtable",
    )

    gcp_composer = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpComposerIntegrationInput),
        graphql_name="gcpComposer",
    )

    gcp_dataflow = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpDataflowIntegrationInput),
        graphql_name="gcpDataflow",
    )

    gcp_dataproc = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpDataprocIntegrationInput),
        graphql_name="gcpDataproc",
    )

    gcp_datastore = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpDatastoreIntegrationInput),
        graphql_name="gcpDatastore",
    )

    gcp_firebasedatabase = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpFirebasedatabaseIntegrationInput),
        graphql_name="gcpFirebasedatabase",
    )

    gcp_firebasehosting = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpFirebasehostingIntegrationInput),
        graphql_name="gcpFirebasehosting",
    )

    gcp_firebasestorage = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpFirebasestorageIntegrationInput),
        graphql_name="gcpFirebasestorage",
    )

    gcp_firestore = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpFirestoreIntegrationInput),
        graphql_name="gcpFirestore",
    )

    gcp_functions = sgqlc.types.Field(
        sgqlc.types.list_of(CloudGcpFunctionsIntegrationInput),
        graphql_name="gcpFunctions",
    )

    gcp_interconnect = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpInterconnectIntegrationInput"),
        graphql_name="gcpInterconnect",
    )

    gcp_kubernetes = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpKubernetesIntegrationInput"),
        graphql_name="gcpKubernetes",
    )

    gcp_loadbalancing = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpLoadbalancingIntegrationInput"),
        graphql_name="gcpLoadbalancing",
    )

    gcp_memcache = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpMemcacheIntegrationInput"),
        graphql_name="gcpMemcache",
    )

    gcp_pubsub = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpPubsubIntegrationInput"), graphql_name="gcpPubsub"
    )

    gcp_redis = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpRedisIntegrationInput"), graphql_name="gcpRedis"
    )

    gcp_router = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpRouterIntegrationInput"), graphql_name="gcpRouter"
    )

    gcp_run = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpRunIntegrationInput"), graphql_name="gcpRun"
    )

    gcp_spanner = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpSpannerIntegrationInput"),
        graphql_name="gcpSpanner",
    )

    gcp_sql = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpSqlIntegrationInput"), graphql_name="gcpSql"
    )

    gcp_storage = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpStorageIntegrationInput"),
        graphql_name="gcpStorage",
    )

    gcp_vms = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpVmsIntegrationInput"), graphql_name="gcpVms"
    )

    gcp_vpcaccess = sgqlc.types.Field(
        sgqlc.types.list_of("CloudGcpVpcaccessIntegrationInput"),
        graphql_name="gcpVpcaccess",
    )

# %% [markdown]
# #### 360. `CloudGcpInterconnectIntegrationInput`

# %% [markdown]
# Interconnect
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpInterconnectIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 361. `CloudGcpKubernetesIntegrationInput`

# %% [markdown]
# Google Kubernetes Engine
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpKubernetesIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 362. `CloudGcpLinkAccountInput`

# %% [markdown]
# Information required to link a GCP account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `name` : The linked account name.
# * `projectId` : The GCP project identifier.

# %%
# | export
class CloudGcpLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "project_id")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    project_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="projectId"
    )

# %% [markdown]
# #### 363. `CloudGcpLoadbalancingIntegrationInput`

# %% [markdown]
# Google Cloud Load Balancing
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpLoadbalancingIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 364. `CloudGcpMemcacheIntegrationInput`

# %% [markdown]
# Memcache
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpMemcacheIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 365. `CloudGcpPubsubIntegrationInput`

# %% [markdown]
# Cloud Pub/Sub
#
#
# Available input fields:
#
#
#
# * `fetchTags` : Specify if labels and the extended inventory should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpPubsubIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 366. `CloudGcpRedisIntegrationInput`

# %% [markdown]
# Redis
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpRedisIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 367. `CloudGcpRouterIntegrationInput`

# %% [markdown]
# Router
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpRouterIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 368. `CloudGcpRunIntegrationInput`

# %% [markdown]
# Run
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpRunIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 369. `CloudGcpSpannerIntegrationInput`

# %% [markdown]
# Cloud Spanner
#
#
# Available input fields:
#
#
#
# * `fetchTags` : Specify if labels and the extended inventory should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpSpannerIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 370. `CloudGcpSqlIntegrationInput`

# %% [markdown]
# Google Cloud SQL
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpSqlIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 371. `CloudGcpStorageIntegrationInput`

# %% [markdown]
# Google Cloud Storage
#
#
# Available input fields:
#
#
#
# * `fetchTags` : Specify if labels and the extended inventory should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpStorageIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 372. `CloudGcpUpdateAccountInput`

# %% [markdown]
# Information required to update a GCP account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `disabled` : Disable the linked account.
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.
# * `projectId` : The GCP project identifier.

# %%
# | export
class CloudGcpUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("disabled", "linked_account_id", "name", "project_id")
    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    project_id = sgqlc.types.Field(String, graphql_name="projectId")

# %% [markdown]
# #### 373. `CloudGcpVmsIntegrationInput`

# %% [markdown]
# Google Compute Engine
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpVmsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 374. `CloudGcpVpcaccessIntegrationInput`

# %% [markdown]
# VPC Access
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudGcpVpcaccessIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 375. `CloudHealthIntegrationInput`

# %% [markdown]
# AWS Health
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudHealthIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 376. `CloudIamIntegrationInput`

# %% [markdown]
# AWS Identity and Access Management (IAM)
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudIamIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 377. `CloudIntegrationsInput`

# %% [markdown]
# List of providers
#
#
# Available input fields:
#
#
#
# * `aws` : Aws provider
# * `awsEuSovereign` : AWS EU Sovereign Cloud provider
# * `awsGovcloud` : AwsGovcloud provider
# * `azure` : Azure provider
# * `cciAws` : CciAws provider
# * `confluent` : Confluent provider
# * `fossa` : Fossa provider
# * `gcp` : Gcp provider
# * `oci` : OCI Provider

# %%
# | export
class CloudIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws",
        "aws_eu_sovereign",
        "aws_govcloud",
        "azure",
        "cci_aws",
        "confluent",
        "fossa",
        "gcp",
        "oci",
    )
    aws = sgqlc.types.Field(CloudAwsIntegrationsInput, graphql_name="aws")

    aws_eu_sovereign = sgqlc.types.Field(
        CloudAwsEuSovereignIntegrationsInput, graphql_name="awsEuSovereign"
    )

    aws_govcloud = sgqlc.types.Field(
        CloudAwsGovcloudIntegrationsInput, graphql_name="awsGovcloud"
    )

    azure = sgqlc.types.Field(CloudAzureIntegrationsInput, graphql_name="azure")

    cci_aws = sgqlc.types.Field(CloudCciAwsIntegrationsInput, graphql_name="cciAws")

    confluent = sgqlc.types.Field(
        CloudConfluentIntegrationsInput, graphql_name="confluent"
    )

    fossa = sgqlc.types.Field(CloudFossaIntegrationsInput, graphql_name="fossa")

    gcp = sgqlc.types.Field(CloudGcpIntegrationsInput, graphql_name="gcp")

    oci = sgqlc.types.Field("CloudOciIntegrationsInput", graphql_name="oci")

# %% [markdown]
# #### 378. `CloudIotIntegrationInput`

# %% [markdown]
# AWS IoT
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudIotIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 379. `CloudKinesisFirehoseIntegrationInput`

# %% [markdown]
# Amazon Kinesis Data Firehose
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudKinesisFirehoseIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 380. `CloudKinesisIntegrationInput`

# %% [markdown]
# Amazon Kinesis Data Streams
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchShards` : Specify if Shards should be monitored. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudKinesisIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_shards",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_shards = sgqlc.types.Field(Boolean, graphql_name="fetchShards")

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 381. `CloudLambdaIntegrationInput`

# %% [markdown]
# AWS Lambda
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudLambdaIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 382. `CloudLinkCloudAccountsInput`

# %% [markdown]
# Specific Cloud provider information required to link the Cloud provider account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `aws` : Aws provider
# * `awsEuSovereign` : AWS EU Sovereign Cloud provider
# * `awsGovcloud` : AwsGovCloud provider
# * `azure` : Azure provider
# * `cciAws` : CCI AWS provider
# * `confluent` : Confluent Cloud provider
# * `fossa` : Fossa provider
# * `gcp` : Gcp provider
# * `oci` : OCI Provider

# %%
# | export
class CloudLinkCloudAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws",
        "aws_eu_sovereign",
        "aws_govcloud",
        "azure",
        "cci_aws",
        "confluent",
        "fossa",
        "gcp",
        "oci",
    )
    aws = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAwsLinkAccountInput)),
        graphql_name="aws",
    )

    aws_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAwsEuSovereignLinkAccountInput)),
        graphql_name="awsEuSovereign",
    )

    aws_govcloud = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAwsGovCloudLinkAccountInput)),
        graphql_name="awsGovcloud",
    )

    azure = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAzureLinkAccountInput)),
        graphql_name="azure",
    )

    cci_aws = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudCciAwsLinkAccountInput)),
        graphql_name="cciAws",
    )

    confluent = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudConfluentLinkAccountInput)),
        graphql_name="confluent",
    )

    fossa = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudFossaLinkAccountInput)),
        graphql_name="fossa",
    )

    gcp = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudGcpLinkAccountInput)),
        graphql_name="gcp",
    )

    oci = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("CloudOciLinkAccountInput")),
        graphql_name="oci",
    )

# %% [markdown]
# #### 383. `CloudOciDisableIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `ociLogs` : Fetch Metadata for OCI Logs integrations integration
# * `ociMetadataAndTags` : Fetch Metadata for OCI integrations integration

# %%
# | export
class CloudOciDisableIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("oci_logs", "oci_metadata_and_tags")
    oci_logs = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput), graphql_name="ociLogs"
    )

    oci_metadata_and_tags = sgqlc.types.Field(
        sgqlc.types.list_of(CloudDisableAccountIntegrationInput),
        graphql_name="ociMetadataAndTags",
    )

# %% [markdown]
# #### 384. `CloudOciInstrumentedPayloadInput`

# %% [markdown]
# Input for OCI instrumented payload generation.
#
#
# Available input fields:
#
#
#
# * `changed` : Flag to indicate if the compartment is changed.
# * `id` : The identifier for a compartment in a region.
# * `namespaceInstrumentationStatuses` : The list of namespaces to be instrumented.

# %%
# | export
class CloudOciInstrumentedPayloadInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("changed", "id", "namespace_instrumentation_statuses")
    changed = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="changed")

    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    namespace_instrumentation_statuses = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null("CloudOciNamespaceInstrumentationStatus")
            )
        ),
        graphql_name="namespaceInstrumentationStatuses",
    )

# %% [markdown]
# #### 385. `CloudOciIntegrationsInput`

# %% [markdown]
# List of integrations
#
#
# Available input fields:
#
#
#
# * `ociLogs` : Metadata and Tags for OCI Logs integrations
# * `ociMetadataAndTags` : Metadata and Tags for OCI integrations

# %%
# | export
class CloudOciIntegrationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("oci_logs", "oci_metadata_and_tags")
    oci_logs = sgqlc.types.Field(
        sgqlc.types.list_of("CloudOciLogsIntegrationInput"), graphql_name="ociLogs"
    )

    oci_metadata_and_tags = sgqlc.types.Field(
        sgqlc.types.list_of("CloudOciMetadataAndTagsIntegrationInput"),
        graphql_name="ociMetadataAndTags",
    )

# %% [markdown]
# #### 386. `CloudOciLinkAccountInput`

# %% [markdown]
# Information required to link a OCI tenancy to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `compartmentOcid` : The New Relic compartment OCID in OCI.
# * `ingestVaultOcid` : The OCI ingest secret OCID.
# * `instrumentationType` : Specifies the type of integration, such as metrics, logs, or a combination of logs and metrics.
# * `name` : The linked account name.
# * `ociClientId` : The client ID for OCI WIF.
# * `ociClientSecret` : The client secret for OCI WIF.
# * `ociDomainUrl` : The OCI domain URL for WIF.
# * `ociHomeRegion` : The home region of the tenancy.
# * `tenantId` : The OCI tenant identifier.
# * `userVaultOcid` : The user secret OCID.

# %%
# | export
class CloudOciLinkAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "compartment_ocid",
        "ingest_vault_ocid",
        "instrumentation_type",
        "name",
        "oci_client_id",
        "oci_client_secret",
        "oci_domain_url",
        "oci_home_region",
        "tenant_id",
        "user_vault_ocid",
    )
    compartment_ocid = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="compartmentOcid"
    )

    ingest_vault_ocid = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="ingestVaultOcid"
    )

    instrumentation_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="instrumentationType"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    oci_client_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="ociClientId"
    )

    oci_client_secret = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="ociClientSecret"
    )

    oci_domain_url = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="ociDomainUrl"
    )

    oci_home_region = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="ociHomeRegion"
    )

    tenant_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="tenantId")

    user_vault_ocid = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="userVaultOcid"
    )

# %% [markdown]
# #### 387. `CloudOciLogGroupInstrumentationStatus`

# %% [markdown]
# Instrumentation status for a Log Group.
#
#
# Available input fields:
#
#
#
# * `changed` : Whether the instrumentation is changed or not.
# * `id` : The log group Id.
# * `instrumented` : Whether the log Group is instrumented.
# * `logGroup` : The log Group name.

# %%
# | export
class CloudOciLogGroupInstrumentationStatus(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("changed", "id", "instrumented", "log_group")
    changed = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="changed")

    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    instrumented = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="instrumented"
    )

    log_group = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="logGroup")

# %% [markdown]
# #### 388. `CloudOciLogGroupInstrumentedPayloadInput`

# %% [markdown]
# Input for OCI Log Group instrumented payload generation.
#
#
# Available input fields:
#
#
#
# * `changed` : Flag to indicate if the compartment is changed.
# * `id` : The identifier for a compartment in a region.
# * `logGroupInstrumentationStatuses` : The list of log group to be instrumented.

# %%
# | export
class CloudOciLogGroupInstrumentedPayloadInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("changed", "id", "log_group_instrumentation_statuses")
    changed = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="changed")

    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    log_group_instrumentation_statuses = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(CloudOciLogGroupInstrumentationStatus)
            )
        ),
        graphql_name="logGroupInstrumentationStatuses",
    )

# %% [markdown]
# #### 389. `CloudOciLogsIntegrationInput`

# %% [markdown]
# Fetch Metadata and Tags for OCI Logs integrations
#
#
# Available input fields:
#
#
#
# * `linkedAccountId` : The linked account identifier.

# %%
# | export
class CloudOciLogsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("linked_account_id",)
    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

# %% [markdown]
# #### 390. `CloudOciMetadataAndTagsIntegrationInput`

# %% [markdown]
# Fetch Metadata and Tags for OCI integrations
#
#
# Available input fields:
#
#
#
# * `linkedAccountId` : The linked account identifier.

# %%
# | export
class CloudOciMetadataAndTagsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("linked_account_id",)
    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

# %% [markdown]
# #### 391. `CloudOciNamespaceInstrumentationStatus`

# %% [markdown]
# Instrumentation status for a namespace.
#
#
# Available input fields:
#
#
#
# * `changed` : Whether the instrumentation is changed or not.
# * `instrumented` : Whether the namespace is instrumented.
# * `namespace` : The namespace name.

# %%
# | export
class CloudOciNamespaceInstrumentationStatus(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("changed", "instrumented", "namespace")
    changed = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="changed")

    instrumented = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="instrumented"
    )

    namespace = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="namespace"
    )

# %% [markdown]
# #### 392. `CloudOciUpdateAccountInput`

# %% [markdown]
# Information required to update a AWS account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `compartmentOcid` : The New Relic compartment OCID in OCI.
# * `disabled` : Disable the linked account.
# * `ingestVaultOcid` : The OCI ingest secret OCID.
# * `instrumentationType` : Specifies the type of integration, such as metrics, logs, or a combination of logs and metrics.
# * `linkedAccountId` : The linked account identifier.
# * `loggingStackOcid` : The Logging stack identifier for the OCI account.
# * `metricStackOcid` : The metric stack identifier for the OCI account.
# * `name` : The linked account new name.
# * `ociClientId` : The client ID for OCI WIF.
# * `ociClientSecret` : The client secret for OCI WIF.
# * `ociDomainUrl` : The domain URL for OCI WIF.
# * `ociHomeRegion` : The home region of the tenancy.
# * `ociRegion` : The OCI region for the account.
# * `tenantId` : The OCI tenant (used to fetch data).
# * `userVaultOcid` : The OCI user secret OCID.

# %%
# | export
class CloudOciUpdateAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "compartment_ocid",
        "disabled",
        "ingest_vault_ocid",
        "instrumentation_type",
        "linked_account_id",
        "logging_stack_ocid",
        "metric_stack_ocid",
        "name",
        "oci_client_id",
        "oci_client_secret",
        "oci_domain_url",
        "oci_home_region",
        "oci_region",
        "tenant_id",
        "user_vault_ocid",
    )
    compartment_ocid = sgqlc.types.Field(String, graphql_name="compartmentOcid")

    disabled = sgqlc.types.Field(Boolean, graphql_name="disabled")

    ingest_vault_ocid = sgqlc.types.Field(String, graphql_name="ingestVaultOcid")

    instrumentation_type = sgqlc.types.Field(String, graphql_name="instrumentationType")

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    logging_stack_ocid = sgqlc.types.Field(String, graphql_name="loggingStackOcid")

    metric_stack_ocid = sgqlc.types.Field(String, graphql_name="metricStackOcid")

    name = sgqlc.types.Field(String, graphql_name="name")

    oci_client_id = sgqlc.types.Field(String, graphql_name="ociClientId")

    oci_client_secret = sgqlc.types.Field(SecureValue, graphql_name="ociClientSecret")

    oci_domain_url = sgqlc.types.Field(String, graphql_name="ociDomainUrl")

    oci_home_region = sgqlc.types.Field(String, graphql_name="ociHomeRegion")

    oci_region = sgqlc.types.Field(String, graphql_name="ociRegion")

    tenant_id = sgqlc.types.Field(String, graphql_name="tenantId")

    user_vault_ocid = sgqlc.types.Field(String, graphql_name="userVaultOcid")

# %% [markdown]
# #### 393. `CloudRdsIntegrationInput`

# %% [markdown]
# Amazon Relation Database Service (RDS)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudRdsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 394. `CloudRedshiftIntegrationInput`

# %% [markdown]
# Amazon Redshift
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudRedshiftIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 395. `CloudRenameAccountsInput`

# %% [markdown]
# Information required when operating on a Linked Account.
#
#
# Available input fields:
#
#
#
# * `linkedAccountId` : The linked account identifier.
# * `name` : The linked account new name.

# %%
# | export
class CloudRenameAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("linked_account_id", "name")
    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 396. `CloudRoute53IntegrationInput`

# %% [markdown]
# Amazon Route 53
#
#
# Available input fields:
#
#
#
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudRoute53IntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_extended_inventory",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 397. `CloudS3IntegrationInput`

# %% [markdown]
# Amazon Simple Storage Service (S3)
#
#
# Available input fields:
#
#
#
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudS3IntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "fetch_extended_inventory",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 398. `CloudSecurityHubIntegrationInput`

# %% [markdown]
# AWS SecurityHub
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudSecurityHubIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 399. `CloudSesIntegrationInput`

# %% [markdown]
# Amazon Simple Email Service (SES)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudSesIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 400. `CloudSnsIntegrationInput`

# %% [markdown]
# Amazon Simple Notification Service (SNS)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudSnsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 401. `CloudSqsIntegrationInput`

# %% [markdown]
# Amazon Simple Queue Service (SQS)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchExtendedInventory` : Determine if extra inventory data be collected or not. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchTags` : Specify if tags should be collected. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `queuePrefixes` : Specify each name or prefix for the Queues that you want to monitor. Filter values are case-sensitive.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudSqsIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_extended_inventory",
        "fetch_tags",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "queue_prefixes",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_extended_inventory = sgqlc.types.Field(
        Boolean, graphql_name="fetchExtendedInventory"
    )

    fetch_tags = sgqlc.types.Field(Boolean, graphql_name="fetchTags")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    queue_prefixes = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="queuePrefixes"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 402. `CloudTrustedadvisorIntegrationInput`

# %% [markdown]
# Trusted Advisor
#
#
# Available input fields:
#
#
#
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.

# %%
# | export
class CloudTrustedadvisorIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
    )
    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

# %% [markdown]
# #### 403. `CloudUnlinkAccountsInput`

# %% [markdown]
# Information required to unlink (remove) a linked account.
#
#
# Available input fields:
#
#
#
# * `linkedAccountId` : The linked account identifier.

# %%
# | export
class CloudUnlinkAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("linked_account_id",)
    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

# %% [markdown]
# #### 404. `CloudUpdateCloudAccountsInput`

# %% [markdown]
# Specific Cloud provider information required to update the Cloud provider account to a NewRelic account.
#
#
# Available input fields:
#
#
#
# * `aws` : Aws provider
# * `awsEuSovereign` : AWS EU Sovereign Cloud provider
# * `awsGovcloud` : AwsGovCloud provider
# * `azure` : Azure provider
# * `confluent` : Confluent Cloud provider
# * `fossa` : Fossa provider
# * `gcp` : Gcp provider
# * `oci` : OCI Provider

# %%
# | export
class CloudUpdateCloudAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws",
        "aws_eu_sovereign",
        "aws_govcloud",
        "azure",
        "confluent",
        "fossa",
        "gcp",
        "oci",
    )
    aws = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAwsUpdateAccountInput)),
        graphql_name="aws",
    )

    aws_eu_sovereign = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(CloudAwsEuSovereignUpdateAccountInput)
        ),
        graphql_name="awsEuSovereign",
    )

    aws_govcloud = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAwsGovCloudUpdateAccountInput)),
        graphql_name="awsGovcloud",
    )

    azure = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudAzureUpdateAccountInput)),
        graphql_name="azure",
    )

    confluent = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudConfluentUpdateAccountInput)),
        graphql_name="confluent",
    )

    fossa = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudFossaUpdateAccountInput)),
        graphql_name="fossa",
    )

    gcp = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudGcpUpdateAccountInput)),
        graphql_name="gcp",
    )

    oci = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(CloudOciUpdateAccountInput)),
        graphql_name="oci",
    )

# %% [markdown]
# #### 405. `CloudVpcIntegrationInput`

# %% [markdown]
# Amazon Virtual Private Cloud (VPC)
#
#
# Available input fields:
#
#
#
# * `awsRegions` : Specify each AWS region that includes the resources that you want to monitor.
# * `fetchNatGateway` : Specify if NAT gateway should be monitored. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `fetchVpn` : Specify if VPN should be monitored. May affect total data collection time and contribute to the Cloud provider API rate limit.
# * `inventoryPollingInterval` : [DEPRECATED] Multiple polling interval is no longer supported, use only metrics_polling_interval
# * `linkedAccountId` : The linked account identifier.
# * `metricsPollingInterval` : The data polling interval in seconds.
# * `tagKey` : Specify a Tag key associated with the resources that you want to monitor. Filter values are case-sensitive.
# * `tagValue` : Specify a Tag value associated with the resources that you want to monitor. Filter values are case-sensitive.

# %%
# | export
class CloudVpcIntegrationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aws_regions",
        "fetch_nat_gateway",
        "fetch_vpn",
        "inventory_polling_interval",
        "linked_account_id",
        "metrics_polling_interval",
        "tag_key",
        "tag_value",
    )
    aws_regions = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="awsRegions"
    )

    fetch_nat_gateway = sgqlc.types.Field(Boolean, graphql_name="fetchNatGateway")

    fetch_vpn = sgqlc.types.Field(Boolean, graphql_name="fetchVpn")

    inventory_polling_interval = sgqlc.types.Field(
        Int, graphql_name="inventoryPollingInterval"
    )

    linked_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="linkedAccountId"
    )

    metrics_polling_interval = sgqlc.types.Field(
        Int, graphql_name="metricsPollingInterval"
    )

    tag_key = sgqlc.types.Field(String, graphql_name="tagKey")

    tag_value = sgqlc.types.Field(String, graphql_name="tagValue")

# %% [markdown]
# #### 406. `CollaborationAssistantConfigInput`

# %% [markdown]
# Assistant configuration options
#
#
# Available input fields:
#
#
#
# * `name` : Name of the configuration
# * `value` : Configuration value

# %%
# | export
class CollaborationAssistantConfigInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "value")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 407. `CustomRoleContainerInput`

# %% [markdown]
# The container in which a custom role is created
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the container
# * `type` : The type of the container (organization)

# %%
# | export
class CustomRoleContainerInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    type = sgqlc.types.Field(String, graphql_name="type")

# %% [markdown]
# #### 408. `DashboardAreaWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.area'
#
#
# Available input fields:
#
#
#
# * `nrqlQueries` : NRQL queries.

# %%
# | export
class DashboardAreaWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql_queries",)
    nrql_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetNrqlQueryInput")),
        graphql_name="nrqlQueries",
    )

# %% [markdown]
# #### 409. `DashboardBarWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.bar'. Learn more about [bar](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#bar) widget.
#
#
# Available input fields:
#
#
#
# * `nrqlQueries` : NRQL queries.

# %%
# | export
class DashboardBarWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql_queries",)
    nrql_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetNrqlQueryInput")),
        graphql_name="nrqlQueries",
    )

# %% [markdown]
# #### 410. `DashboardBillboardWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.billboard'. Learn more about [billboard](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#billboard) widget.
#
#
# Available input fields:
#
#
#
# * `nrqlQueries` : NRQL queries.
# * `thresholds` : Array of thresholds to categorize the results of the query in different groups.

# %%
# | export
class DashboardBillboardWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql_queries", "thresholds")
    nrql_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetNrqlQueryInput")),
        graphql_name="nrqlQueries",
    )

    thresholds = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("DashboardBillboardWidgetThresholdInput")
        ),
        graphql_name="thresholds",
    )

# %% [markdown]
# #### 411. `DashboardBillboardWidgetThresholdInput`

# %% [markdown]
# Billboard widget threshold input.
#
#
# Available input fields:
#
#
#
# * `alertSeverity` : Severity of the alert.
# * `value` : Value of the alert.

# %%
# | export
class DashboardBillboardWidgetThresholdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("alert_severity", "value")
    alert_severity = sgqlc.types.Field(
        DashboardAlertSeverity, graphql_name="alertSeverity"
    )

    value = sgqlc.types.Field(Float, graphql_name="value")

# %% [markdown]
# #### 412. `DashboardInput`

# %% [markdown]
# Dashboard input.
#
#
# Available input fields:
#
#
#
# * `description` : Brief text describing the dashboard.
# * `name` : The name of the dashboard.
# * `pages` : A nested block of all pages belonging to the dashboard.
# * `permissions` : Permissions to set level of visibility & editing.
# * `variables` : Dashboard-local variable definitions.

# %%
# | export
class DashboardInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "pages", "permissions", "variables")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    pages = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("DashboardPageInput"))
        ),
        graphql_name="pages",
    )

    permissions = sgqlc.types.Field(
        sgqlc.types.non_null(DashboardPermissions), graphql_name="permissions"
    )

    variables = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardVariableInput")),
        graphql_name="variables",
    )

# %% [markdown]
# #### 413. `DashboardLineWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.line'. Learn more about [line](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#line) widget.
#
#
# Available input fields:
#
#
#
# * `nrqlQueries` : NRQL queries.

# %%
# | export
class DashboardLineWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql_queries",)
    nrql_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetNrqlQueryInput")),
        graphql_name="nrqlQueries",
    )

# %% [markdown]
# #### 414. `DashboardLiveUrlAuthCreationInput`

# %% [markdown]
# Input type used to setup the Live URL auth policies in creation time
#
#
# Available input fields:
#
#
#
# * `factors` : The auth factors that will be used to protect the Live URL

# %%
# | export
class DashboardLiveUrlAuthCreationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("factors",)
    factors = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("DashboardLiveUrlAuthFactorInput"))
        ),
        graphql_name="factors",
    )

# %% [markdown]
# #### 415. `DashboardLiveUrlAuthFactorInput`

# %% [markdown]
# Input type use to define each Live URL auth factor
#
#
# Available input fields:
#
#
#
# * `type` : Type of authentication factor.

# %%
# | export
class DashboardLiveUrlAuthFactorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("type",)
    type = sgqlc.types.Field(
        sgqlc.types.non_null(DashboardLiveUrlAuthType), graphql_name="type"
    )

# %% [markdown]
# #### 416. `DashboardLiveUrlAuthUpdateInput`

# %% [markdown]
# Input type used to update the Live URL auth policies
#
#
# Available input fields:
#
#
#
# * `factors` : The auth factors that will be used to protect the Live URL

# %%
# | export
class DashboardLiveUrlAuthUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("factors",)
    factors = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null(DashboardLiveUrlAuthFactorInput))
        ),
        graphql_name="factors",
    )

# %% [markdown]
# #### 417. `DashboardLiveUrlCreationPoliciesFilterInput`

# %% [markdown]
# Filter to apply when fetching list of live URL creation policies.
#
#
# Available input fields:
#
#
#
# * `accountIds` : List of account ids by which to filter the list of live URL creation policies.

# %%
# | export
class DashboardLiveUrlCreationPoliciesFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids",)
    account_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="accountIds"
    )

# %% [markdown]
# #### 418. `DashboardLiveUrlOptionsInput`

# %% [markdown]
# Options to configure the Live URL
#
#
# Available input fields:
#
#
#
# * `ttl` : The amount of time (in seconds) until the Live Url becomes unavailable from the date on which the operation is executed. Min value of 300 (5 minutes). Max value of 631,152,000 (20 year). When it is not set, by default 2,592,000 (30 days) will be used.

# %%
# | export
class DashboardLiveUrlOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ttl",)
    ttl = sgqlc.types.Field(Seconds, graphql_name="ttl")

# %% [markdown]
# #### 419. `DashboardLiveUrlsFilterInput`

# %% [markdown]
# Live URLs input.
#
#
# Available input fields:
#
#
#
# * `cursor` : The cursor to fetch additional live url results.
# * `entityGuid` : Filter by the associated Entity GUID of a public live URL.
# * `type` : Live URL type.
# * `uuid` : The unique identifier of a public live URL.

# %%
# | export
class DashboardLiveUrlsFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cursor", "entity_guid", "type", "uuid")
    cursor = sgqlc.types.Field(String, graphql_name="cursor")

    entity_guid = sgqlc.types.Field(EntityGuid, graphql_name="entityGuid")

    type = sgqlc.types.Field(DashboardLiveUrlType, graphql_name="type")

    uuid = sgqlc.types.Field(ID, graphql_name="uuid")

# %% [markdown]
# #### 420. `DashboardMarkdownWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.markdown'. Learn more about [markdown](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#markdown) widget.
#
#
# Available input fields:
#
#
#
# * `text` : Markdown content of the widget.

# %%
# | export
class DashboardMarkdownWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("text",)
    text = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="text")

# %% [markdown]
# #### 421. `DashboardPageInput`

# %% [markdown]
# Page input.
#
#
# Available input fields:
#
#
#
# * `description` : Brief text describing the page.
# * `guid` : Unique entity identifier of the Page to be updated. When null, it means a new Page will be created.
# * `name` : The name of the page.
# * `widgets` : A nested block of all widgets belonging to the page.

# %%
# | export
class DashboardPageInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "guid", "name", "widgets")
    description = sgqlc.types.Field(String, graphql_name="description")

    guid = sgqlc.types.Field(EntityGuid, graphql_name="guid")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    widgets = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetInput"))
        ),
        graphql_name="widgets",
    )

# %% [markdown]
# #### 422. `DashboardPieWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.pie'.  Learn more about [pie](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#pie) widget.
#
#
# Available input fields:
#
#
#
# * `nrqlQueries` : NRQL queries.

# %%
# | export
class DashboardPieWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql_queries",)
    nrql_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetNrqlQueryInput")),
        graphql_name="nrqlQueries",
    )

# %% [markdown]
# #### 423. `DashboardSnapshotUrlInput`

# %% [markdown]
# Parameters that affect the data and the rendering of the dashboards returned by the snapshot url mutation.
#
#
# Available input fields:
#
#
#
# * `timeWindow` : Period of time from which the data to be displayed on the dashboard will be obtained.

# %%
# | export
class DashboardSnapshotUrlInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("time_window",)
    time_window = sgqlc.types.Field(
        "DashboardSnapshotUrlTimeWindowInput", graphql_name="timeWindow"
    )

# %% [markdown]
# #### 424. `DashboardSnapshotUrlTimeWindowInput`

# %% [markdown]
# Period of time from which the data to be displayed on the dashboard will be obtained.
#
#
# Available input fields:
#
#
#
# * `beginTime` : The starting time of the time window. If specified, an endTime or a duration must also be specified.
# * `duration` : The duration of the time window.
# * `endTime` : The end time of the time window. If specified, a beginTime or a duration must also be specified.

# %%
# | export
class DashboardSnapshotUrlTimeWindowInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("begin_time", "duration", "end_time")
    begin_time = sgqlc.types.Field(EpochMilliseconds, graphql_name="beginTime")

    duration = sgqlc.types.Field(Milliseconds, graphql_name="duration")

    end_time = sgqlc.types.Field(EpochMilliseconds, graphql_name="endTime")

# %% [markdown]
# #### 425. `DashboardTableWidgetConfigurationInput`

# %% [markdown]
# Configuration for visualization type 'viz.table'.  Learn more about [table](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#table) widget.
#
#
# Available input fields:
#
#
#
# * `nrqlQueries` : NRQL queries.

# %%
# | export
class DashboardTableWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nrql_queries",)
    nrql_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetNrqlQueryInput")),
        graphql_name="nrqlQueries",
    )

# %% [markdown]
# #### 426. `DashboardUpdateLiveUrlCreationPoliciesInput`

# %% [markdown]
# Parameters for setting the Live URL creation policies.
#
#
# Available input fields:
#
#
#
# * `accountIds` : The account ids for which the policy applies.
# * `liveUrlCreationAllowed` : Whether or not live URL creation is allowed for the accounts.

# %%
# | export
class DashboardUpdateLiveUrlCreationPoliciesInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids", "live_url_creation_allowed")
    account_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accountIds",
    )

    live_url_creation_allowed = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="liveUrlCreationAllowed"
    )

# %% [markdown]
# #### 427. `DashboardUpdatePageInput`

# %% [markdown]
# Page input used when updating an individual page.
#
#
# Available input fields:
#
#
#
# * `description` : Page description.
# * `name` : Page name.
# * `widgets` : Page widgets.

# %%
# | export
class DashboardUpdatePageInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "widgets")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    widgets = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("DashboardWidgetInput"))
        ),
        graphql_name="widgets",
    )

# %% [markdown]
# #### 428. `DashboardUpdateWidgetInput`

# %% [markdown]
# Input type used when updating widgets.
#
#
# Available input fields:
#
#
#
# * `configuration` : Typed widgets are area, bar, billboard, line, markdown, pie, and table. Check our [docs](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#widget-typed) for more info.
# * `description` : A description of the widget, will be displayed in a tooltip.
# * `id` : ID of the widget to be updated.
# * `layout` : The widget's position and size in the dashboard.
# * `link` : Input for configuring a link to be displayed in the widget. The URL will be rendered as a clickable link.
# * `linkedEntityGuids` : Entities related to the widget. Currently only supports one Dashboard entity guid, but may allow other cases in the future.
# * `rawConfiguration` : Untyped widgets are all other widgets, such as bullet, histogram, inventory, etc. Check our [docs](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#widget-untyped) for more info.
# * `title` : A title for the widget.
# * `visualization` : Specifies how this widget will be visualized. If null, the WidgetConfigurationInput will be used to determine the visualization.

# %%
# | export
class DashboardUpdateWidgetInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "configuration",
        "description",
        "id",
        "layout",
        "link",
        "linked_entity_guids",
        "raw_configuration",
        "title",
        "visualization",
    )
    configuration = sgqlc.types.Field(
        "DashboardWidgetConfigurationInput", graphql_name="configuration"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    layout = sgqlc.types.Field("DashboardWidgetLayoutInput", graphql_name="layout")

    link = sgqlc.types.Field("DashboardWidgetLinkInput", graphql_name="link")

    linked_entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="linkedEntityGuids",
    )

    raw_configuration = sgqlc.types.Field(
        DashboardWidgetRawConfiguration, graphql_name="rawConfiguration"
    )

    title = sgqlc.types.Field(String, graphql_name="title")

    visualization = sgqlc.types.Field(
        "DashboardWidgetVisualizationInput", graphql_name="visualization"
    )

# %% [markdown]
# #### 429. `DashboardVariableDefaultItemInput`

# %% [markdown]
# Represents a possible default value item.
#
#
# Available input fields:
#
#
#
# * `value` : The value of this default item.

# %%
# | export
class DashboardVariableDefaultItemInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("value",)
    value = sgqlc.types.Field(
        sgqlc.types.non_null("DashboardVariableDefaultValueInput"), graphql_name="value"
    )

# %% [markdown]
# #### 430. `DashboardVariableDefaultValueInput`

# %% [markdown]
# Specifies a default value for variables.
#
#
# Available input fields:
#
#
#
# * `string` : Default string value.

# %%
# | export
class DashboardVariableDefaultValueInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("string",)
    string = sgqlc.types.Field(String, graphql_name="string")

# %% [markdown]
# #### 431. `DashboardVariableEnumItemInput`

# %% [markdown]
# Input type that represents a possible value for a variable of type ENUM.
#
#
# Available input fields:
#
#
#
# * `title` : A human-friendly display string for this value.
# * `value` : A possible variable value

# %%
# | export
class DashboardVariableEnumItemInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("title", "value")
    title = sgqlc.types.Field(String, graphql_name="title")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 432. `DashboardVariableInput`

# %% [markdown]
# Definition of a variable that is local to this dashboard. Variables are placeholders for dynamic values in widget NRQLs.
#
#
# Available input fields:
#
#
#
# * `defaultValue` : [DEPRECATED] Default value for this variable. The actual value to be used will depend on the type.
# * `defaultValues` : Default values for this variable. The actual value to be used will depend on the type.
# * `isMultiSelection` : Indicates whether this variable supports multiple selection or not. Only applies to variables of type NRQL or ENUM.
# * `items` : List of possible values for variables of type ENUM
# * `name` : Variable identifier.
# * `nrqlQuery` : Configuration for variables of type NRQL.
# * `options` : Options applied to the variable
# * `replacementStrategy` : Indicates the strategy to apply when replacing a variable in a NRQL query.
# * `title` : Human-friendly display string for this variable.
# * `type` : Specifies the data type of the variable and where its possible values may come from.

# %%
# | export
class DashboardVariableInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "default_value",
        "default_values",
        "is_multi_selection",
        "items",
        "name",
        "nrql_query",
        "options",
        "replacement_strategy",
        "title",
        "type",
    )
    default_value = sgqlc.types.Field(
        DashboardVariableDefaultValueInput, graphql_name="defaultValue"
    )

    default_values = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(DashboardVariableDefaultItemInput)),
        graphql_name="defaultValues",
    )

    is_multi_selection = sgqlc.types.Field(Boolean, graphql_name="isMultiSelection")

    items = sgqlc.types.Field(
        sgqlc.types.list_of(DashboardVariableEnumItemInput), graphql_name="items"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql_query = sgqlc.types.Field(
        "DashboardVariableNrqlQueryInput", graphql_name="nrqlQuery"
    )

    options = sgqlc.types.Field("DashboardVariableOptionsInput", graphql_name="options")

    replacement_strategy = sgqlc.types.Field(
        DashboardVariableReplacementStrategy, graphql_name="replacementStrategy"
    )

    title = sgqlc.types.Field(String, graphql_name="title")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(DashboardVariableType), graphql_name="type"
    )

# %% [markdown]
# #### 433. `DashboardVariableNrqlQueryInput`

# %% [markdown]
# Configuration for variables of type NRQL.
#
#
# Available input fields:
#
#
#
# * `accountIds` : New Relic account ID(s) to issue the query against.
# * `query` : NRQL formatted query.

# %%
# | export
class DashboardVariableNrqlQueryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids", "query")
    account_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accountIds",
    )

    query = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="query")

# %% [markdown]
# #### 434. `DashboardVariableOptionsInput`

# %% [markdown]
# Options applied to the variable
#
#
# Available input fields:
#
#
#
# * `excluded` : With this turned on, query condition defined with the variable will not be included in the query.
# * `hiddenOnVariablesBar` : Controls whether this variable is visible in the UI when not in edit mode.
# * `ignoreTimeRange` : Only applies to variables of type NRQL. With this turned on, the time range for the NRQL query will override the time picker on dashboards and other pages. Turn this off to use the time picker as normal.
# * `showApplyAction` : Determines whether or not an Apply action will be shown when selecting multiple values in ENUM and NRQL variables.

# %%
# | export
class DashboardVariableOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "excluded",
        "hidden_on_variables_bar",
        "ignore_time_range",
        "show_apply_action",
    )
    excluded = sgqlc.types.Field(Boolean, graphql_name="excluded")

    hidden_on_variables_bar = sgqlc.types.Field(
        Boolean, graphql_name="hiddenOnVariablesBar"
    )

    ignore_time_range = sgqlc.types.Field(Boolean, graphql_name="ignoreTimeRange")

    show_apply_action = sgqlc.types.Field(Boolean, graphql_name="showApplyAction")

# %% [markdown]
# #### 435. `DashboardWidgetConfigurationInput`

# %% [markdown]
# Typed configuration for known visualizations. At most one may be populated.
#
#
# Available input fields:
#
#
#
# * `area` : Configuration for visualization type 'viz.area'
# * `bar` : Configuration for visualization type 'viz.bar'
# * `billboard` : Configuration for visualization type 'viz.billboard'
# * `line` : Configuration for visualization type 'viz.line'
# * `markdown` : Configuration for visualization type 'viz.markdown'
# * `pie` : Configuration for visualization type 'viz.pie'
# * `table` : Configuration for visualization type 'viz.table'

# %%
# | export
class DashboardWidgetConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("area", "bar", "billboard", "line", "markdown", "pie", "table")
    area = sgqlc.types.Field(DashboardAreaWidgetConfigurationInput, graphql_name="area")

    bar = sgqlc.types.Field(DashboardBarWidgetConfigurationInput, graphql_name="bar")

    billboard = sgqlc.types.Field(
        DashboardBillboardWidgetConfigurationInput, graphql_name="billboard"
    )

    line = sgqlc.types.Field(DashboardLineWidgetConfigurationInput, graphql_name="line")

    markdown = sgqlc.types.Field(
        DashboardMarkdownWidgetConfigurationInput, graphql_name="markdown"
    )

    pie = sgqlc.types.Field(DashboardPieWidgetConfigurationInput, graphql_name="pie")

    table = sgqlc.types.Field(
        DashboardTableWidgetConfigurationInput, graphql_name="table"
    )

# %% [markdown]
# #### 436. `DashboardWidgetInput`

# %% [markdown]
# Widget input.
#
#
# Available input fields:
#
#
#
# * `configuration` : Typed widgets are area, bar, billboard, line, markdown, pie, and table. Check our [docs](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#widget-typed) for more info.
# * `description` : A description of the widget, will be displayed in a tooltip.
# * `id` : ID of the widget. If null, a new widget will be created and added to a dashboard.
# * `layout` : The widget's position and size in the dashboard.
# * `link` : Input for configuring a link to be displayed in the widget. The URL will be rendered as a clickable link.
# * `linkedEntityGuids` : Entities related to the widget. Currently only supports one Dashboard entity guid, but may allow other cases in the future.
# * `rawConfiguration` : Untyped widgets are all other widgets, such as bullet, histogram, inventory, etc. Check our [docs](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#widget-untyped) for more info.
# * `title` : A title for the widget.
# * `visualization` : Specifies how this widget will be visualized. If null, the WidgetConfigurationInput will be used to determine the visualization.

# %%
# | export
class DashboardWidgetInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "configuration",
        "description",
        "id",
        "layout",
        "link",
        "linked_entity_guids",
        "raw_configuration",
        "title",
        "visualization",
    )
    configuration = sgqlc.types.Field(
        DashboardWidgetConfigurationInput, graphql_name="configuration"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    id = sgqlc.types.Field(ID, graphql_name="id")

    layout = sgqlc.types.Field("DashboardWidgetLayoutInput", graphql_name="layout")

    link = sgqlc.types.Field("DashboardWidgetLinkInput", graphql_name="link")

    linked_entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="linkedEntityGuids",
    )

    raw_configuration = sgqlc.types.Field(
        DashboardWidgetRawConfiguration, graphql_name="rawConfiguration"
    )

    title = sgqlc.types.Field(String, graphql_name="title")

    visualization = sgqlc.types.Field(
        "DashboardWidgetVisualizationInput", graphql_name="visualization"
    )

# %% [markdown]
# #### 437. `DashboardWidgetLayoutInput`

# %% [markdown]
# Widget layout input.
#
#
# Available input fields:
#
#
#
# * `column` : Column position of widget from top left, starting at 1.
# * `height` : Height of the widget. Valid values are 1 to 12 inclusive. Defaults to 3.
# * `row` : Row position of widget from top left, starting at 1.
# * `width` : Width of the widget. Valid values are 1 to 12 inclusive. Defaults to 4.

# %%
# | export
class DashboardWidgetLayoutInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("column", "height", "row", "width")
    column = sgqlc.types.Field(Int, graphql_name="column")

    height = sgqlc.types.Field(Int, graphql_name="height")

    row = sgqlc.types.Field(Int, graphql_name="row")

    width = sgqlc.types.Field(Int, graphql_name="width")

# %% [markdown]
# #### 438. `DashboardWidgetLinkInput`

# %% [markdown]
# Input for configuring a link to be displayed in the widget. The URL will be rendered as a clickable link.
#
#
# Available input fields:
#
#
#
# * `url` : The target URL for the link.

# %%
# | export
class DashboardWidgetLinkInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("url",)
    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 439. `DashboardWidgetNrqlQueryInput`

# %% [markdown]
# NRQL query used by a widget.
#
#
# Available input fields:
#
#
#
# * `accountId` : New Relic account ID to issue the query against.
# * `query` : NRQL formatted query.

# %%
# | export
class DashboardWidgetNrqlQueryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "query")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    query = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="query")

# %% [markdown]
# #### 440. `DashboardWidgetVisualizationInput`

# %% [markdown]
# Visualization configuration.
#
#
# Available input fields:
#
#
#
# * `id` : This field can either have a known type like `viz.area` or `<nerdpack-id>.<visualization-id>` in the case of [custom visualizations](https://developer.newrelic.com/explore-docs/custom-viz/build-visualization/). Check out [docs](https://docs.newrelic.com/docs/apis/nerdgraph/examples/create-widgets-dashboards-api/#widget-schema) for more info.

# %%
# | export
class DashboardWidgetVisualizationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(String, graphql_name="id")

# %% [markdown]
# #### 441. `DataAccessPolicyAssignedFilter`

# %% [markdown]
# Input type for filtering by assigned status.
#
#
# Available input fields:
#
#
#
# * `eq` : Filter for an exact match.

# %%
# | export
class DataAccessPolicyAssignedFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(
        sgqlc.types.non_null(DataAccessPolicyAssignedStatus), graphql_name="eq"
    )

# %% [markdown]
# #### 442. `DataAccessPolicyFilterInput`

# %% [markdown]
# Input type for filtering data access policies.
#
#
# Available input fields:
#
#
#
# * `assigned` : Filter by assigned status.
# * `id` : Filter by policy ID.
# * `name` : Filter by policy name.
# * `organizationId` : Filter by organization ID (required).

# %%
# | export
class DataAccessPolicyFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("assigned", "id", "name", "organization_id")
    assigned = sgqlc.types.Field(
        DataAccessPolicyAssignedFilter, graphql_name="assigned"
    )

    id = sgqlc.types.Field("DataAccessPolicyIdFilter", graphql_name="id")

    name = sgqlc.types.Field("DataAccessPolicyNameFilter", graphql_name="name")

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("DataAccessPolicyIdFilter"), graphql_name="organizationId"
    )

# %% [markdown]
# #### 443. `DataAccessPolicyIdFilter`

# %% [markdown]
# Input type for UUID filtering operations.
#
#
# Available input fields:
#
#
#
# * `eq` : Filter for an exact match.
# * `in` : Filter for exact matches.

# %%
# | export
class DataAccessPolicyIdFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(String, graphql_name="eq")

    in_ = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="in")

# %% [markdown]
# #### 444. `DataAccessPolicyNameFilter`

# %% [markdown]
# Input type for string-based filtering operations.
#
#
# Available input fields:
#
#
#
# * `contains` : Filter for values containing the specified string.
# * `eq` : Filter for exact matches.

# %%
# | export
class DataAccessPolicyNameFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 445. `DataAccessPolicySortInput`

# %% [markdown]
# Input type for specifying sort order and field.
#
#
# Available input fields:
#
#
#
# * `direction` : The direction of sorting (e.g., ASCENDING or DESCENDING).
# * `key` : The key to sort by (e.g., NAME).

# %%
# | export
class DataAccessPolicySortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(DataAccessPolicySortOrder), graphql_name="direction"
    )

    key = sgqlc.types.Field(
        sgqlc.types.non_null(DataAccessPolicySortKey), graphql_name="key"
    )

# %% [markdown]
# #### 446. `DataManagementAccountFeatureSettingInput`

# %% [markdown]
# Input object to add and change a feature setting toggle for an account
#
#
# Available input fields:
#
#
#
# * `enabled` : Enabled state for the feature setting
# * `featureSetting` : Feature setting lookup
# * `locked` : When locked is true, children inherit parent's enabled state

# %%
# | export
class DataManagementAccountFeatureSettingInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled", "feature_setting", "locked")
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    feature_setting = sgqlc.types.Field(
        "DataManagementFeatureSettingLookup", graphql_name="featureSetting"
    )

    locked = sgqlc.types.Field(Boolean, graphql_name="locked")

# %% [markdown]
# #### 447. `DataManagementAccountLimitInput`

# %% [markdown]
# Input for an account Limit
#
#
# Available input fields:
#
#
#
# * `limit` : Unique limit identifier
# * `overrideReason` : The reason for the override
# * `overrideValue` : The value which should be applied to the account
# * `qualifier` : Optional qualifier for limit override

# %%
# | export
class DataManagementAccountLimitInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("limit", "override_reason", "override_value", "qualifier")
    limit = sgqlc.types.Field(
        sgqlc.types.non_null("DataManagementLimitLookupInput"), graphql_name="limit"
    )

    override_reason = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="overrideReason"
    )

    override_value = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="overrideValue"
    )

    qualifier = sgqlc.types.Field(String, graphql_name="qualifier")

# %% [markdown]
# #### 448. `DataManagementFeatureSettingLookup`

# %% [markdown]
# Input object to lookup a feature setting
#
#
# Available input fields:
#
#
#
# * `key` : Key of the feature setting

# %%
# | export
class DataManagementFeatureSettingLookup(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key",)
    key = sgqlc.types.Field(String, graphql_name="key")

# %% [markdown]
# #### 449. `DataManagementLimitLookupInput`

# %% [markdown]
# Input to look up a Limit
#
#
# Available input fields:
#
#
#
# * `name` : Limit name

# %%
# | export
class DataManagementLimitLookupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name",)
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 450. `DataManagementOrganizationLimitInput`

# %% [markdown]
# Input for an organization Limit
#
#
# Available input fields:
#
#
#
# * `enforceViolations` : Whether violations should be enforced for this override
# * `isDefaultOverride` : Whether this override should be the default for users in the organization
# * `limit` : Unique limit identifier
# * `overrideReason` : The reason for the override
# * `overrideValue` : The value which should be applied to the organization
# * `userId` : The id of the user making for this override

# %%
# | export
class DataManagementOrganizationLimitInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "enforce_violations",
        "is_default_override",
        "limit",
        "override_reason",
        "override_value",
        "user_id",
    )
    enforce_violations = sgqlc.types.Field(Boolean, graphql_name="enforceViolations")

    is_default_override = sgqlc.types.Field(Boolean, graphql_name="isDefaultOverride")

    limit = sgqlc.types.Field(
        sgqlc.types.non_null(DataManagementLimitLookupInput), graphql_name="limit"
    )

    override_reason = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="overrideReason"
    )

    override_value = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="overrideValue"
    )

    user_id = sgqlc.types.Field(Int, graphql_name="userId")

# %% [markdown]
# #### 451. `DataManagementOrganizationLimitLookupInput`

# %% [markdown]
# Input for an looking up an organization Limit
#
#
# Available input fields:
#
#
#
# * `isDefaultOverride` : Set to true, without user_id, to lookup the default user override for the organization
# * `limit` : Unique limit identifier
# * `userId` : The id of the user making for this override

# %%
# | export
class DataManagementOrganizationLimitLookupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("is_default_override", "limit", "user_id")
    is_default_override = sgqlc.types.Field(Boolean, graphql_name="isDefaultOverride")

    limit = sgqlc.types.Field(
        sgqlc.types.non_null(DataManagementLimitLookupInput), graphql_name="limit"
    )

    user_id = sgqlc.types.Field(Int, graphql_name="userId")

# %% [markdown]
# #### 452. `DataManagementRuleInput`

# %% [markdown]
# Input rule type for bulk rule creation
#
#
# Available input fields:
#
#
#
# * `namespace` : The namespace the event retention rule applies to
# * `retentionInDays` : Length of time for event data retention (in days)

# %%
# | export
class DataManagementRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("namespace", "retention_in_days")
    namespace = sgqlc.types.Field(String, graphql_name="namespace")

    retention_in_days = sgqlc.types.Field(Int, graphql_name="retentionInDays")

# %% [markdown]
# #### 453. `DataSourceGapsGapsQuery`

# %% [markdown]
# Query parameters used to filter data source gaps.
#
#
# Available input fields:
#
#
#
# * `accountIds` : A list of account IDs used to filter data source gaps.
# * `entityGuids` : A list of entity GUIDs used to filter data source gaps.
# * `gapTypeIds` : A list of gap type identifiers used to filter data source gaps.

# %%
# | export
class DataSourceGapsGapsQuery(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids", "entity_guids", "gap_type_ids")
    account_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="accountIds"
    )

    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    gap_type_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(DataSourceGapsGapTypeIdentifier)),
        graphql_name="gapTypeIds",
    )

# %% [markdown]
# #### 454. `DomainTypeInput`

# %% [markdown]
# Input for getting details about an entity type
#
#
# Available input fields:
#
#
#
# * `domain` : The domain of the entity.
#
# The domain must be a value matching /[A-Z][A-Z0-9_]{2,14}/.
# * `type` : The type of the entity.
#
# The type must be a value matching /[A-Z][A-Z0-9_]{2,49}/.
#
# Some examples are APPLICATION, HOST or CONTAINER.

# %%
# | export
class DomainTypeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("domain", "type")
    domain = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="domain")

    type = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="type")

# %% [markdown]
# #### 455. `EdgeCreateSpanAttributeRuleInput`

# %% [markdown]
# Data required to create a span attribute trace filter rule.
#
#
# Available input fields:
#
#
#
# * `action` : The action that this trace filter rule takes if it matches the provided attribute name and value
# * `key` : Name of the attribute to match on
# * `keyOperator` : Type of match to apply to the attribute name (EQUALS, LIKE). Key match type is required.
# * `value` : Value of the attribute to match on. Value is required unless the `SpanAttributeValueOperator` is set to `IS_NOT_NULL`
# * `valueOperator` : Type of match to apply to the attribute value (EQUALS, LIKE, IS_NOT_NULL).

# %%
# | export
class EdgeCreateSpanAttributeRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("action", "key", "key_operator", "value", "value_operator")
    action = sgqlc.types.Field(
        sgqlc.types.non_null(EdgeTraceFilterAction), graphql_name="action"
    )

    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    key_operator = sgqlc.types.Field(
        sgqlc.types.non_null(EdgeSpanAttributeKeyOperator), graphql_name="keyOperator"
    )

    value = sgqlc.types.Field(String, graphql_name="value")

    value_operator = sgqlc.types.Field(
        sgqlc.types.non_null(EdgeSpanAttributeValueOperator),
        graphql_name="valueOperator",
    )

# %% [markdown]
# #### 456. `EdgeCreateTraceFilterRulesInput`

# %% [markdown]
# Input for creating multiple trace filter rules
#
#
# Available input fields:
#
#
#
# * `spanAttributeRules` : One or more `CreateSpanAttributeRuleInput` that describe the span attribute trace filter rule(s) to be created.

# %%
# | export
class EdgeCreateTraceFilterRulesInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("span_attribute_rules",)
    span_attribute_rules = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EdgeCreateSpanAttributeRuleInput)),
        graphql_name="spanAttributeRules",
    )

# %% [markdown]
# #### 457. `EdgeCreateTraceObserverInput`

# %% [markdown]
# Data required to create a trace observer.
#
#
# Available input fields:
#
#
#
# * `complianceTypes` : Optional list of compliance types (e.g., FedRAMP) applied to this trace observer.
# * `monitoring` : When set to `true` a trace observer will write trace metrics to the current account.
# * `name` : Name of the trace observer.
# * `providerRegion` : Provider and region where the trace observer must run. Currently, only AWS regions are supported.

# %%
# | export
class EdgeCreateTraceObserverInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("compliance_types", "monitoring", "name", "provider_region")
    compliance_types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EdgeComplianceTypeCode)),
        graphql_name="complianceTypes",
    )

    monitoring = sgqlc.types.Field(Boolean, graphql_name="monitoring")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    provider_region = sgqlc.types.Field(
        sgqlc.types.non_null(EdgeProviderRegion), graphql_name="providerRegion"
    )

# %% [markdown]
# #### 458. `EdgeDataSourceGroupInput`

# %% [markdown]
# Data required to change the data source group.
#
#
# Available input fields:
#
#
#
# * `guids` : The entity guids representing the entities you would like to update.
# * `updateType` : The type of update that should be performed with the supplied entity guids.

# %%
# | export
class EdgeDataSourceGroupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("guids", "update_type")
    guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)), graphql_name="guids"
    )

    update_type = sgqlc.types.Field(
        sgqlc.types.non_null(EdgeDataSourceGroupUpdateType), graphql_name="updateType"
    )

# %% [markdown]
# #### 459. `EdgeDeleteTraceFilterRulesInput`

# %% [markdown]
# Input for deleting multiple trace filter rules by id
#
#
# Available input fields:
#
#
#
# * `spanAttributeRuleIds` : One or more SpanAttributeRule id(s) to be deleted.

# %%
# | export
class EdgeDeleteTraceFilterRulesInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("span_attribute_rule_ids",)
    span_attribute_rule_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)),
        graphql_name="spanAttributeRuleIds",
    )

# %% [markdown]
# #### 460. `EdgeDeleteTraceObserverInput`

# %% [markdown]
# Data required to delete a trace observer.
#
#
# Available input fields:
#
#
#
# * `id` : Globally unique identifier of the trace observer being deleted.

# %%
# | export
class EdgeDeleteTraceObserverInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="id")

# %% [markdown]
# #### 461. `EdgeRandomTraceFilterInput`

# %% [markdown]
# Data required to change the random trace filter configuration.
#
#
# Available input fields:
#
#
#
# * `percentKept` : The percentage of randomly selected traces to keep. Acceptable values are between 0.0001 and 100.

# %%
# | export
class EdgeRandomTraceFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("percent_kept",)
    percent_kept = sgqlc.types.Field(
        sgqlc.types.non_null(Float), graphql_name="percentKept"
    )

# %% [markdown]
# #### 462. `EdgeUpdateTraceObserverInput`

# %% [markdown]
# Data required to update a trace observer.
#
#
# Available input fields:
#
#
#
# * `dataSourceGroupConfig` : When set, allows updating the data source group.
# * `id` : Globally unique identifier of the trace observer being updated.
# * `monitoring` : When set to `true` a trace observer will write trace metrics to the current account.
# * `name` : Name of the trace observer.
# * `randomTraceFilterConfig` : When set, allows changing the random trace filter configuration.

# %%
# | export
class EdgeUpdateTraceObserverInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "data_source_group_config",
        "id",
        "monitoring",
        "name",
        "random_trace_filter_config",
    )
    data_source_group_config = sgqlc.types.Field(
        EdgeDataSourceGroupInput, graphql_name="dataSourceGroupConfig"
    )

    id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="id")

    monitoring = sgqlc.types.Field(Boolean, graphql_name="monitoring")

    name = sgqlc.types.Field(String, graphql_name="name")

    random_trace_filter_config = sgqlc.types.Field(
        EdgeRandomTraceFilterInput, graphql_name="randomTraceFilterConfig"
    )

# %% [markdown]
# #### 463. `EntityGoldenContextInput`

# %% [markdown]
# Input type used to define the context for the golden metrics.
#
#
# Available input fields:
#
#
#
# * `account` : Account context.
# * `guid` : Collection guid context.

# %%
# | export
class EntityGoldenContextInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account", "guid")
    account = sgqlc.types.Field(Int, graphql_name="account")

    guid = sgqlc.types.Field(EntityGuid, graphql_name="guid")

# %% [markdown]
# #### 464. `EntityGoldenMetricInput`

# %% [markdown]
# Input type for the metrics.
#
#
# Available input fields:
#
#
#
# * `eventId` : The field that is used identifies the entities. Default: entity.guid
# * `facet` : The field to FACET by. Default: entity.name
# * `from` : The FROM clause of the query. Default: Metric
# * `name` : The name of the metric
# * `select` : The SELECT clause of the query.
# * `title` : The title of the metric
# * `where` : If a complementary WHERE clause is given this field will contain it.

# %%
# | export
class EntityGoldenMetricInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("event_id", "facet", "from_", "name", "select", "title", "where")
    event_id = sgqlc.types.Field(String, graphql_name="eventId")

    facet = sgqlc.types.Field(String, graphql_name="facet")

    from_ = sgqlc.types.Field(String, graphql_name="from")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    select = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="select")

    title = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="title")

    where = sgqlc.types.Field(String, graphql_name="where")

# %% [markdown]
# #### 465. `EntityGoldenNrqlTimeWindowInput`

# %% [markdown]
# Time range to apply to the golden metric NRQL query
#
#
# Available input fields:
#
#
#
# * `since` : Start time.
# * `until` : End time.

# %%
# | export
class EntityGoldenNrqlTimeWindowInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("since", "until")
    since = sgqlc.types.Field(Nrql, graphql_name="since")

    until = sgqlc.types.Field(Nrql, graphql_name="until")

# %% [markdown]
# #### 466. `EntityGoldenTagInput`

# %% [markdown]
# An input that represents a golden tag
#
#
# Available input fields:
#
#
#
# * `key` : The golden tag key.

# %%
# | export
class EntityGoldenTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key",)
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

# %% [markdown]
# #### 467. `EntityManagementAiAgentEntityCreateInput`

# %% [markdown]
# Create input for AiAgentEntity entity type.
#
#
# Available input fields:
#
#
#
# * `agentsId` : See agentsId in AiAgentEntity.
# * `category` : See category in AiAgentEntity.
# * `description` : See description in AiAgentEntity.
# * `displayName` : See displayName in AiAgentEntity.
# * `llmConfig` : See llmConfig in AiAgentEntity.
# * `mcpServers` : See mcpServers in AiAgentEntity.
# * `name` : See name in AiAgentEntity.
# * `prompt` : See prompt in AiAgentEntity.
# * `scope` : See scope in AiAgentEntity.
# * `tags` : See tags in AiAgentEntity.
# * `test` : See test in AiAgentEntity.
# * `tools` : See tools in AiAgentEntity.

# %%
# | export
class EntityManagementAiAgentEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "agents_id",
        "category",
        "description",
        "display_name",
        "llm_config",
        "mcp_servers",
        "name",
        "prompt",
        "scope",
        "tags",
        "test",
        "tools",
    )
    agents_id = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="agentsId"
    )

    category = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="category")

    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    display_name = sgqlc.types.Field(String, graphql_name="displayName")

    llm_config = sgqlc.types.Field(
        "EntityManagementLlmConfigCreateInput", graphql_name="llmConfig"
    )

    mcp_servers = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementAiAgentMcpServerConfigCreateInput")
        ),
        graphql_name="mcpServers",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    prompt = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="prompt")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    test = sgqlc.types.Field(Boolean, graphql_name="test")

    tools = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementAiAgentToolConfigCreateInput")
        ),
        graphql_name="tools",
    )

# %% [markdown]
# #### 468. `EntityManagementAiAgentEntityUpdateInput`

# %% [markdown]
# Update input for AiAgentEntity entity type.
#
#
# Available input fields:
#
#
#
# * `agentsId` : See agentsId in AiAgentEntity.
# * `category` : See category in AiAgentEntity.
# * `description` : See description in AiAgentEntity.
# * `displayName` : See displayName in AiAgentEntity.
# * `llmConfig` : See llmConfig in AiAgentEntity.
# * `mcpServers` : See mcpServers in AiAgentEntity.
# * `name` : See name in AiAgentEntity.
# * `prompt` : See prompt in AiAgentEntity.
# * `tags` : See tags in AiAgentEntity.
# * `test` : See test in AiAgentEntity.
# * `tools` : See tools in AiAgentEntity.

# %%
# | export
class EntityManagementAiAgentEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "agents_id",
        "category",
        "description",
        "display_name",
        "llm_config",
        "mcp_servers",
        "name",
        "prompt",
        "tags",
        "test",
        "tools",
    )
    agents_id = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="agentsId"
    )

    category = sgqlc.types.Field(String, graphql_name="category")

    description = sgqlc.types.Field(String, graphql_name="description")

    display_name = sgqlc.types.Field(String, graphql_name="displayName")

    llm_config = sgqlc.types.Field(
        "EntityManagementLlmConfigUpdateInput", graphql_name="llmConfig"
    )

    mcp_servers = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementAiAgentMcpServerConfigUpdateInput")
        ),
        graphql_name="mcpServers",
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    prompt = sgqlc.types.Field(String, graphql_name="prompt")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    test = sgqlc.types.Field(Boolean, graphql_name="test")

    tools = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementAiAgentToolConfigUpdateInput")
        ),
        graphql_name="tools",
    )

# %% [markdown]
# #### 469. `EntityManagementAiAgentMcpServerConfigCreateInput`

# %% [markdown]
# Create input for AiAgentMcpServerConfig.
#
#
# Available input fields:
#
#
#
# * `excludeTools` : See excludeTools in AiAgentMcpServerConfig.
# * `includeTools` : See includeTools in AiAgentMcpServerConfig.
# * `serverId` : See serverId in AiAgentMcpServerConfig.

# %%
# | export
class EntityManagementAiAgentMcpServerConfigCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exclude_tools", "include_tools", "server_id")
    exclude_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="excludeTools"
    )

    include_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="includeTools"
    )

    server_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="serverId")

# %% [markdown]
# #### 470. `EntityManagementAiAgentMcpServerConfigUpdateInput`

# %% [markdown]
# Update input for AiAgentMcpServerConfig.
#
#
# Available input fields:
#
#
#
# * `excludeTools` : See excludeTools in AiAgentMcpServerConfig.
# * `includeTools` : See includeTools in AiAgentMcpServerConfig.
# * `serverId` : See serverId in AiAgentMcpServerConfig.

# %%
# | export
class EntityManagementAiAgentMcpServerConfigUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exclude_tools", "include_tools", "server_id")
    exclude_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="excludeTools"
    )

    include_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="includeTools"
    )

    server_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="serverId")

# %% [markdown]
# #### 471. `EntityManagementAiAgentToolConfigCreateInput`

# %% [markdown]
# Create input for AiAgentToolConfig.
#
#
# Available input fields:
#
#
#
# * `excludeTools` : See excludeTools in AiAgentToolConfig.
# * `includeTools` : See includeTools in AiAgentToolConfig.
# * `toolId` : See toolId in AiAgentToolConfig.

# %%
# | export
class EntityManagementAiAgentToolConfigCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exclude_tools", "include_tools", "tool_id")
    exclude_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="excludeTools"
    )

    include_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="includeTools"
    )

    tool_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="toolId")

# %% [markdown]
# #### 472. `EntityManagementAiAgentToolConfigUpdateInput`

# %% [markdown]
# Update input for AiAgentToolConfig.
#
#
# Available input fields:
#
#
#
# * `excludeTools` : See excludeTools in AiAgentToolConfig.
# * `includeTools` : See includeTools in AiAgentToolConfig.
# * `toolId` : See toolId in AiAgentToolConfig.

# %%
# | export
class EntityManagementAiAgentToolConfigUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exclude_tools", "include_tools", "tool_id")
    exclude_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="excludeTools"
    )

    include_tools = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="includeTools"
    )

    tool_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="toolId")

# %% [markdown]
# #### 473. `EntityManagementAiToolEntityCreateInput`

# %% [markdown]
# Create input for AiToolEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in AiToolEntity.
# * `name` : See name in AiToolEntity.
# * `parameters` : See parameters in AiToolEntity.
# * `scope` : See scope in AiToolEntity.
# * `tags` : See tags in AiToolEntity.
# * `test` : See test in AiToolEntity.
# * `toolType` : See toolType in AiToolEntity.
# * `url` : See url in AiToolEntity.

# %%
# | export
class EntityManagementAiToolEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "name",
        "parameters",
        "scope",
        "tags",
        "test",
        "tool_type",
        "url",
    )
    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    parameters = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementAiToolParameterCreateInput")
        ),
        graphql_name="parameters",
    )

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    test = sgqlc.types.Field(Boolean, graphql_name="test")

    tool_type = sgqlc.types.Field(EntityManagementAiToolType, graphql_name="toolType")

    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 474. `EntityManagementAiToolEntityUpdateInput`

# %% [markdown]
# Update input for AiToolEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in AiToolEntity.
# * `name` : See name in AiToolEntity.
# * `parameters` : See parameters in AiToolEntity.
# * `tags` : See tags in AiToolEntity.
# * `test` : See test in AiToolEntity.
# * `toolType` : See toolType in AiToolEntity.
# * `url` : See url in AiToolEntity.

# %%
# | export
class EntityManagementAiToolEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "name",
        "parameters",
        "tags",
        "test",
        "tool_type",
        "url",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    parameters = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementAiToolParameterUpdateInput")
        ),
        graphql_name="parameters",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    test = sgqlc.types.Field(Boolean, graphql_name="test")

    tool_type = sgqlc.types.Field(EntityManagementAiToolType, graphql_name="toolType")

    url = sgqlc.types.Field(String, graphql_name="url")

# %% [markdown]
# #### 475. `EntityManagementAiToolParameterCreateInput`

# %% [markdown]
# Create input for AiToolParameter.
#
#
# Available input fields:
#
#
#
# * `description` : See description in AiToolParameter.
# * `name` : See name in AiToolParameter.
# * `type` : See type in AiToolParameter.

# %%
# | export
class EntityManagementAiToolParameterCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "type")
    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementAiToolParameterType), graphql_name="type"
    )

# %% [markdown]
# #### 476. `EntityManagementAiToolParameterUpdateInput`

# %% [markdown]
# Update input for AiToolParameter.
#
#
# Available input fields:
#
#
#
# * `description` : See description in AiToolParameter.
# * `name` : See name in AiToolParameter.
# * `type` : See type in AiToolParameter.

# %%
# | export
class EntityManagementAiToolParameterUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "type")
    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementAiToolParameterType), graphql_name="type"
    )

# %% [markdown]
# #### 477. `EntityManagementCategoryScopeCreateInput`

# %% [markdown]
# Create input for CategoryScope.
#
#
# Available input fields:
#
#
#
# * `id` : See id in CategoryScope.
# * `type` : See type in CategoryScope.

# %%
# | export
class EntityManagementCategoryScopeCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementCategoryScopeType), graphql_name="type"
    )

# %% [markdown]
# #### 478. `EntityManagementCategoryScopeUpdateInput`

# %% [markdown]
# Update input for CategoryScope.
#
#
# Available input fields:
#
#
#
# * `id` : See id in CategoryScope.
# * `type` : See type in CategoryScope.

# %%
# | export
class EntityManagementCategoryScopeUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementCategoryScopeType), graphql_name="type"
    )

# %% [markdown]
# #### 479. `EntityManagementCharacterTextSplitterOptionsCreateInput`

# %% [markdown]
# Create input for CharacterTextSplitterOptions.
#
#
# Available input fields:
#
#
#
# * `isSeparatorRegex` : See isSeparatorRegex in CharacterTextSplitterOptions.
# * `separator` : See separator in CharacterTextSplitterOptions.

# %%
# | export
class EntityManagementCharacterTextSplitterOptionsCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("is_separator_regex", "separator")
    is_separator_regex = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="isSeparatorRegex"
    )

    separator = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="separator"
    )

# %% [markdown]
# #### 480. `EntityManagementCharacterTextSplitterOptionsUpdateInput`

# %% [markdown]
# Update input for CharacterTextSplitterOptions.
#
#
# Available input fields:
#
#
#
# * `isSeparatorRegex` : See isSeparatorRegex in CharacterTextSplitterOptions.
# * `separator` : See separator in CharacterTextSplitterOptions.

# %%
# | export
class EntityManagementCharacterTextSplitterOptionsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("is_separator_regex", "separator")
    is_separator_regex = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="isSeparatorRegex"
    )

    separator = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="separator"
    )

# %% [markdown]
# #### 481. `EntityManagementCollectionElementsFilter`

# %% [markdown]
# Input for filtering collection elements.
#
#
# Available input fields:
#
#
#
# * `collectionId` : The id of the group entity.

# %%
# | export
class EntityManagementCollectionElementsFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("collection_id",)
    collection_id = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementCollectionIdFilterArgument"),
        graphql_name="collectionId",
    )

# %% [markdown]
# #### 482. `EntityManagementCollectionEntityCreateInput`

# %% [markdown]
# Create input for CollectionEntity entity type.
#
#
# Available input fields:
#
#
#
# * `name` : See name in CollectionEntity.
# * `scope` : See scope in CollectionEntity.
# * `tags` : See tags in CollectionEntity.

# %%
# | export
class EntityManagementCollectionEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "scope", "tags")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 483. `EntityManagementCollectionEntityUpdateInput`

# %% [markdown]
# Update input for CollectionEntity entity type.
#
#
# Available input fields:
#
#
#
# * `name` : See name in CollectionEntity.
# * `tags` : See tags in CollectionEntity.

# %%
# | export
class EntityManagementCollectionEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "tags")
    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 484. `EntityManagementCollectionIdFilterArgument`

# %% [markdown]
# Input for filtering collection elements by id.
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equality check on the id.

# %%
# | export
class EntityManagementCollectionIdFilterArgument(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 485. `EntityManagementConfluenceIntegrationCreateInput`

# %% [markdown]
# Create input for ConfluenceIntegration entity type.
#
#
# Available input fields:
#
#
#
# * `confluenceUserId` : See confluenceUserId in ConfluenceIntegration.
# * `name` : See name in ConfluenceIntegration.
# * `scope` : See scope in ConfluenceIntegration.
# * `secretKey` : See secretKey in ConfluenceIntegration.
# * `tags` : See tags in ConfluenceIntegration.
# * `url` : See url in ConfluenceIntegration.

# %%
# | export
class EntityManagementConfluenceIntegrationCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "confluence_user_id",
        "name",
        "scope",
        "secret_key",
        "tags",
        "url",
    )
    confluence_user_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="confluenceUserId"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    secret_key = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="secretKey"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 486. `EntityManagementConfluenceIntegrationUpdateInput`

# %% [markdown]
# Update input for ConfluenceIntegration entity type.
#
#
# Available input fields:
#
#
#
# * `confluenceUserId` : See confluenceUserId in ConfluenceIntegration.
# * `name` : See name in ConfluenceIntegration.
# * `secretKey` : See secretKey in ConfluenceIntegration.
# * `tags` : See tags in ConfluenceIntegration.
# * `url` : See url in ConfluenceIntegration.

# %%
# | export
class EntityManagementConfluenceIntegrationUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("confluence_user_id", "name", "secret_key", "tags", "url")
    confluence_user_id = sgqlc.types.Field(String, graphql_name="confluenceUserId")

    name = sgqlc.types.Field(String, graphql_name="name")

    secret_key = sgqlc.types.Field(String, graphql_name="secretKey")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    url = sgqlc.types.Field(String, graphql_name="url")

# %% [markdown]
# #### 487. `EntityManagementConfluenceRagSettingsEntityCreateInput`

# %% [markdown]
# Create input for ConfluenceRagSettingsEntity entity type.
#
#
# Available input fields:
#
#
#
# * `characterTextSplitterOptions` : See characterTextSplitterOptions in ConfluenceRagSettingsEntity.
# * `chunkOverlap` : See chunkOverlap in ConfluenceRagSettingsEntity.
# * `chunkSize` : See chunkSize in ConfluenceRagSettingsEntity.
# * `confluenceIntegrationId` : See confluenceIntegrationId in ConfluenceRagSettingsEntity.
# * `confluenceQuery` : See confluenceQuery in ConfluenceRagSettingsEntity.
# * `intervalSeconds` : See intervalSeconds in ConfluenceRagSettingsEntity.
# * `markdownTextSplitterOptions` : See markdownTextSplitterOptions in ConfluenceRagSettingsEntity.
# * `name` : See name in ConfluenceRagSettingsEntity.
# * `scope` : See scope in ConfluenceRagSettingsEntity.
# * `tags` : See tags in ConfluenceRagSettingsEntity.
# * `textSplitterType` : See textSplitterType in ConfluenceRagSettingsEntity.
# * `tokenTextSplitterOptions` : See tokenTextSplitterOptions in ConfluenceRagSettingsEntity.

# %%
# | export
class EntityManagementConfluenceRagSettingsEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "character_text_splitter_options",
        "chunk_overlap",
        "chunk_size",
        "confluence_integration_id",
        "confluence_query",
        "interval_seconds",
        "markdown_text_splitter_options",
        "name",
        "scope",
        "tags",
        "text_splitter_type",
        "token_text_splitter_options",
    )
    character_text_splitter_options = sgqlc.types.Field(
        EntityManagementCharacterTextSplitterOptionsCreateInput,
        graphql_name="characterTextSplitterOptions",
    )

    chunk_overlap = sgqlc.types.Field(Int, graphql_name="chunkOverlap")

    chunk_size = sgqlc.types.Field(Int, graphql_name="chunkSize")

    confluence_integration_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="confluenceIntegrationId"
    )

    confluence_query = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="confluenceQuery"
    )

    interval_seconds = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="intervalSeconds"
    )

    markdown_text_splitter_options = sgqlc.types.Field(
        "EntityManagementMarkdownTextSplitterOptionsCreateInput",
        graphql_name="markdownTextSplitterOptions",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    text_splitter_type = sgqlc.types.Field(
        EntityManagementTextSplitterType, graphql_name="textSplitterType"
    )

    token_text_splitter_options = sgqlc.types.Field(
        "EntityManagementTokenTextSplitterOptionsCreateInput",
        graphql_name="tokenTextSplitterOptions",
    )

# %% [markdown]
# #### 488. `EntityManagementConfluenceRagSettingsEntityUpdateInput`

# %% [markdown]
# Update input for ConfluenceRagSettingsEntity entity type.
#
#
# Available input fields:
#
#
#
# * `characterTextSplitterOptions` : See characterTextSplitterOptions in ConfluenceRagSettingsEntity.
# * `chunkOverlap` : See chunkOverlap in ConfluenceRagSettingsEntity.
# * `chunkSize` : See chunkSize in ConfluenceRagSettingsEntity.
# * `confluenceIntegrationId` : See confluenceIntegrationId in ConfluenceRagSettingsEntity.
# * `confluenceQuery` : See confluenceQuery in ConfluenceRagSettingsEntity.
# * `intervalSeconds` : See intervalSeconds in ConfluenceRagSettingsEntity.
# * `markdownTextSplitterOptions` : See markdownTextSplitterOptions in ConfluenceRagSettingsEntity.
# * `name` : See name in ConfluenceRagSettingsEntity.
# * `tags` : See tags in ConfluenceRagSettingsEntity.
# * `textSplitterType` : See textSplitterType in ConfluenceRagSettingsEntity.
# * `tokenTextSplitterOptions` : See tokenTextSplitterOptions in ConfluenceRagSettingsEntity.

# %%
# | export
class EntityManagementConfluenceRagSettingsEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "character_text_splitter_options",
        "chunk_overlap",
        "chunk_size",
        "confluence_integration_id",
        "confluence_query",
        "interval_seconds",
        "markdown_text_splitter_options",
        "name",
        "tags",
        "text_splitter_type",
        "token_text_splitter_options",
    )
    character_text_splitter_options = sgqlc.types.Field(
        EntityManagementCharacterTextSplitterOptionsUpdateInput,
        graphql_name="characterTextSplitterOptions",
    )

    chunk_overlap = sgqlc.types.Field(Int, graphql_name="chunkOverlap")

    chunk_size = sgqlc.types.Field(Int, graphql_name="chunkSize")

    confluence_integration_id = sgqlc.types.Field(
        ID, graphql_name="confluenceIntegrationId"
    )

    confluence_query = sgqlc.types.Field(String, graphql_name="confluenceQuery")

    interval_seconds = sgqlc.types.Field(Int, graphql_name="intervalSeconds")

    markdown_text_splitter_options = sgqlc.types.Field(
        "EntityManagementMarkdownTextSplitterOptionsUpdateInput",
        graphql_name="markdownTextSplitterOptions",
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    text_splitter_type = sgqlc.types.Field(
        EntityManagementTextSplitterType, graphql_name="textSplitterType"
    )

    token_text_splitter_options = sgqlc.types.Field(
        "EntityManagementTokenTextSplitterOptionsUpdateInput",
        graphql_name="tokenTextSplitterOptions",
    )

# %% [markdown]
# #### 489. `EntityManagementDiscoverySettingsUpdateInput`

# %% [markdown]
# Update input for DiscoverySettings.
#
#
# Available input fields:
#
#
#
# * `enabled` : See enabled in DiscoverySettings.
# * `tagKeys` : See tagKeys in DiscoverySettings.

# %%
# | export
class EntityManagementDiscoverySettingsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled", "tag_keys")
    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    tag_keys = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="tagKeys",
    )

# %% [markdown]
# #### 490. `EntityManagementEntityReferenceInput`

# %% [markdown]
# Input for creating a new entity reference.
#
#
# Available input fields:
#
#
#
# * `id` : The id of the entity.
# * `scope` : The entity's scope.

# %%
# | export
class EntityManagementEntityReferenceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "scope")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementEntityScope), graphql_name="scope"
    )

# %% [markdown]
# #### 491. `EntityManagementExternalOwnerCreateInput`

# %% [markdown]
# Create input for ExternalOwner.
#
#
# Available input fields:
#
#
#
# * `id` : See id in ExternalOwner.
# * `type` : See type in ExternalOwner.

# %%
# | export
class EntityManagementExternalOwnerCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementExternalOwnerType), graphql_name="type"
    )

# %% [markdown]
# #### 492. `EntityManagementExternalOwnerUpdateInput`

# %% [markdown]
# Update input for ExternalOwner.
#
#
# Available input fields:
#
#
#
# * `id` : See id in ExternalOwner.
# * `type` : See type in ExternalOwner.

# %%
# | export
class EntityManagementExternalOwnerUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementExternalOwnerType), graphql_name="type"
    )

# %% [markdown]
# #### 493. `EntityManagementGenericEntityUpdateInput`

# %% [markdown]
# Update input for any entity type.
#
#
# Available input fields:
#
#
#
# * `name` : The name of this entity.
# * `tags` : The tags of the relationship.

# %%
# | export
class EntityManagementGenericEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "tags")
    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 494. `EntityManagementGitRepositoryEntityCreateInput`

# %% [markdown]
# Create input for GitRepositoryEntity entity type.
#
#
# Available input fields:
#
#
#
# * `closedPullRequestCount` : See closedPullRequestCount in GitRepositoryEntity.
# * `description` : See description in GitRepositoryEntity.
# * `externalCreatedAt` : See externalCreatedAt in GitRepositoryEntity.
# * `externalId` : See externalId in GitRepositoryEntity.
# * `externalLastDeployedAt` : See externalLastDeployedAt in GitRepositoryEntity.
# * `externalOwner` : See externalOwner in GitRepositoryEntity.
# * `externalUpdatedAt` : See externalUpdatedAt in GitRepositoryEntity.
# * `forkCount` : See forkCount in GitRepositoryEntity.
# * `hostingPlatform` : See hostingPlatform in GitRepositoryEntity.
# * `latestReleaseVersion` : See latestReleaseVersion in GitRepositoryEntity.
# * `license` : See license in GitRepositoryEntity.
# * `lockedPullRequestCount` : See lockedPullRequestCount in GitRepositoryEntity.
# * `name` : See name in GitRepositoryEntity.
# * `openPullRequestCount` : See openPullRequestCount in GitRepositoryEntity.
# * `primaryLanguage` : See primaryLanguage in GitRepositoryEntity.
# * `scope` : See scope in GitRepositoryEntity.
# * `tags` : See tags in GitRepositoryEntity.
# * `url` : See url in GitRepositoryEntity.

# %%
# | export
class EntityManagementGitRepositoryEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "closed_pull_request_count",
        "description",
        "external_created_at",
        "external_id",
        "external_last_deployed_at",
        "external_owner",
        "external_updated_at",
        "fork_count",
        "hosting_platform",
        "latest_release_version",
        "license",
        "locked_pull_request_count",
        "name",
        "open_pull_request_count",
        "primary_language",
        "scope",
        "tags",
        "url",
    )
    closed_pull_request_count = sgqlc.types.Field(
        Int, graphql_name="closedPullRequestCount"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    external_created_at = sgqlc.types.Field(
        EpochMilliseconds, graphql_name="externalCreatedAt"
    )

    external_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="externalId"
    )

    external_last_deployed_at = sgqlc.types.Field(
        EpochMilliseconds, graphql_name="externalLastDeployedAt"
    )

    external_owner = sgqlc.types.Field(
        EntityManagementExternalOwnerCreateInput, graphql_name="externalOwner"
    )

    external_updated_at = sgqlc.types.Field(
        EpochMilliseconds, graphql_name="externalUpdatedAt"
    )

    fork_count = sgqlc.types.Field(Int, graphql_name="forkCount")

    hosting_platform = sgqlc.types.Field(
        EntityManagementHostingPlatform, graphql_name="hostingPlatform"
    )

    latest_release_version = sgqlc.types.Field(
        String, graphql_name="latestReleaseVersion"
    )

    license = sgqlc.types.Field(
        "EntityManagementRepositoryLicenseCreateInput", graphql_name="license"
    )

    locked_pull_request_count = sgqlc.types.Field(
        Int, graphql_name="lockedPullRequestCount"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    open_pull_request_count = sgqlc.types.Field(
        Int, graphql_name="openPullRequestCount"
    )

    primary_language = sgqlc.types.Field(String, graphql_name="primaryLanguage")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 495. `EntityManagementGitRepositoryEntityUpdateInput`

# %% [markdown]
# Update input for GitRepositoryEntity entity type.
#
#
# Available input fields:
#
#
#
# * `closedPullRequestCount` : See closedPullRequestCount in GitRepositoryEntity.
# * `description` : See description in GitRepositoryEntity.
# * `externalCreatedAt` : See externalCreatedAt in GitRepositoryEntity.
# * `externalId` : See externalId in GitRepositoryEntity.
# * `externalLastDeployedAt` : See externalLastDeployedAt in GitRepositoryEntity.
# * `externalOwner` : See externalOwner in GitRepositoryEntity.
# * `externalUpdatedAt` : See externalUpdatedAt in GitRepositoryEntity.
# * `forkCount` : See forkCount in GitRepositoryEntity.
# * `hostingPlatform` : See hostingPlatform in GitRepositoryEntity.
# * `latestReleaseVersion` : See latestReleaseVersion in GitRepositoryEntity.
# * `license` : See license in GitRepositoryEntity.
# * `lockedPullRequestCount` : See lockedPullRequestCount in GitRepositoryEntity.
# * `name` : See name in GitRepositoryEntity.
# * `openPullRequestCount` : See openPullRequestCount in GitRepositoryEntity.
# * `primaryLanguage` : See primaryLanguage in GitRepositoryEntity.
# * `tags` : See tags in GitRepositoryEntity.
# * `url` : See url in GitRepositoryEntity.

# %%
# | export
class EntityManagementGitRepositoryEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "closed_pull_request_count",
        "description",
        "external_created_at",
        "external_id",
        "external_last_deployed_at",
        "external_owner",
        "external_updated_at",
        "fork_count",
        "hosting_platform",
        "latest_release_version",
        "license",
        "locked_pull_request_count",
        "name",
        "open_pull_request_count",
        "primary_language",
        "tags",
        "url",
    )
    closed_pull_request_count = sgqlc.types.Field(
        Int, graphql_name="closedPullRequestCount"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    external_created_at = sgqlc.types.Field(
        EpochMilliseconds, graphql_name="externalCreatedAt"
    )

    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    external_last_deployed_at = sgqlc.types.Field(
        EpochMilliseconds, graphql_name="externalLastDeployedAt"
    )

    external_owner = sgqlc.types.Field(
        EntityManagementExternalOwnerUpdateInput, graphql_name="externalOwner"
    )

    external_updated_at = sgqlc.types.Field(
        EpochMilliseconds, graphql_name="externalUpdatedAt"
    )

    fork_count = sgqlc.types.Field(Int, graphql_name="forkCount")

    hosting_platform = sgqlc.types.Field(
        EntityManagementHostingPlatform, graphql_name="hostingPlatform"
    )

    latest_release_version = sgqlc.types.Field(
        String, graphql_name="latestReleaseVersion"
    )

    license = sgqlc.types.Field(
        "EntityManagementRepositoryLicenseUpdateInput", graphql_name="license"
    )

    locked_pull_request_count = sgqlc.types.Field(
        Int, graphql_name="lockedPullRequestCount"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    open_pull_request_count = sgqlc.types.Field(
        Int, graphql_name="openPullRequestCount"
    )

    primary_language = sgqlc.types.Field(String, graphql_name="primaryLanguage")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    url = sgqlc.types.Field(String, graphql_name="url")

# %% [markdown]
# #### 496. `EntityManagementImpactProfileEntityCreateInput`

# %% [markdown]
# Create input for ImpactProfileEntity entity type.
#
#
# Available input fields:
#
#
#
# * `name` : See name in ImpactProfileEntity.
# * `scope` : See scope in ImpactProfileEntity.
# * `tags` : See tags in ImpactProfileEntity.

# %%
# | export
class EntityManagementImpactProfileEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "scope", "tags")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 497. `EntityManagementImpactProfileEntityUpdateInput`

# %% [markdown]
# Update input for ImpactProfileEntity entity type.
#
#
# Available input fields:
#
#
#
# * `name` : See name in ImpactProfileEntity.
# * `tags` : See tags in ImpactProfileEntity.

# %%
# | export
class EntityManagementImpactProfileEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "tags")
    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 498. `EntityManagementInboxIssueCategoryEntityCreateInput`

# %% [markdown]
# Create input for InboxIssueCategoryEntity entity type.
#
#
# Available input fields:
#
#
#
# * `categoryScope` : See categoryScope in InboxIssueCategoryEntity.
# * `categoryType` : See categoryType in InboxIssueCategoryEntity.
# * `issueType` : See issueType in InboxIssueCategoryEntity.
# * `messageAttributes` : See messageAttributes in InboxIssueCategoryEntity.
# * `name` : See name in InboxIssueCategoryEntity.
# * `nameAttributes` : See nameAttributes in InboxIssueCategoryEntity.
# * `scope` : See scope in InboxIssueCategoryEntity.
# * `tags` : See tags in InboxIssueCategoryEntity.

# %%
# | export
class EntityManagementInboxIssueCategoryEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "category_scope",
        "category_type",
        "issue_type",
        "message_attributes",
        "name",
        "name_attributes",
        "scope",
        "tags",
    )
    category_scope = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementCategoryScopeCreateInput),
        graphql_name="categoryScope",
    )

    category_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="categoryType"
    )

    issue_type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementIssueType), graphql_name="issueType"
    )

    message_attributes = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="messageAttributes"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    name_attributes = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)), graphql_name="nameAttributes"
    )

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 499. `EntityManagementInboxIssueCategoryEntityUpdateInput`

# %% [markdown]
# Update input for InboxIssueCategoryEntity entity type.
#
#
# Available input fields:
#
#
#
# * `categoryScope` : See categoryScope in InboxIssueCategoryEntity.
# * `categoryType` : See categoryType in InboxIssueCategoryEntity.
# * `issueType` : See issueType in InboxIssueCategoryEntity.
# * `messageAttributes` : See messageAttributes in InboxIssueCategoryEntity.
# * `name` : See name in InboxIssueCategoryEntity.
# * `nameAttributes` : See nameAttributes in InboxIssueCategoryEntity.
# * `tags` : See tags in InboxIssueCategoryEntity.

# %%
# | export
class EntityManagementInboxIssueCategoryEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "category_scope",
        "category_type",
        "issue_type",
        "message_attributes",
        "name",
        "name_attributes",
        "tags",
    )
    category_scope = sgqlc.types.Field(
        EntityManagementCategoryScopeUpdateInput, graphql_name="categoryScope"
    )

    category_type = sgqlc.types.Field(String, graphql_name="categoryType")

    issue_type = sgqlc.types.Field(EntityManagementIssueType, graphql_name="issueType")

    message_attributes = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="messageAttributes"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    name_attributes = sgqlc.types.Field(
        sgqlc.types.list_of(String), graphql_name="nameAttributes"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 500. `EntityManagementIncidentLinkEntityCreateInput`

# %% [markdown]
# Create input for IncidentLinkEntity entity type.
#
#
# Available input fields:
#
#
#
# * `externalId` : See externalId in IncidentLinkEntity.
# * `name` : See name in IncidentLinkEntity.
# * `scope` : See scope in IncidentLinkEntity.
# * `tags` : See tags in IncidentLinkEntity.
# * `url` : See url in IncidentLinkEntity.

# %%
# | export
class EntityManagementIncidentLinkEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("external_id", "name", "scope", "tags", "url")
    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 501. `EntityManagementIncidentLinkEntityUpdateInput`

# %% [markdown]
# Update input for IncidentLinkEntity entity type.
#
#
# Available input fields:
#
#
#
# * `externalId` : See externalId in IncidentLinkEntity.
# * `name` : See name in IncidentLinkEntity.
# * `tags` : See tags in IncidentLinkEntity.
# * `url` : See url in IncidentLinkEntity.

# %%
# | export
class EntityManagementIncidentLinkEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("external_id", "name", "tags", "url")
    external_id = sgqlc.types.Field(String, graphql_name="externalId")

    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    url = sgqlc.types.Field(String, graphql_name="url")

# %% [markdown]
# #### 502. `EntityManagementIncidentTimelineEntityCreateInput`

# %% [markdown]
# Create input for IncidentTimelineEntity entity type.
#
#
# Available input fields:
#
#
#
# * `content` : See content in IncidentTimelineEntity.
# * `entryType` : See entryType in IncidentTimelineEntity.
# * `name` : See name in IncidentTimelineEntity.
# * `scope` : See scope in IncidentTimelineEntity.
# * `source` : See source in IncidentTimelineEntity.
# * `tags` : See tags in IncidentTimelineEntity.

# %%
# | export
class EntityManagementIncidentTimelineEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("content", "entry_type", "name", "scope", "source", "tags")
    content = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="content")

    entry_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="entryType"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    source = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementIncidentTimelineSource),
        graphql_name="source",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 503. `EntityManagementIncidentTimelineEntityUpdateInput`

# %% [markdown]
# Update input for IncidentTimelineEntity entity type.
#
#
# Available input fields:
#
#
#
# * `content` : See content in IncidentTimelineEntity.
# * `entryType` : See entryType in IncidentTimelineEntity.
# * `name` : See name in IncidentTimelineEntity.
# * `source` : See source in IncidentTimelineEntity.
# * `tags` : See tags in IncidentTimelineEntity.

# %%
# | export
class EntityManagementIncidentTimelineEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("content", "entry_type", "name", "source", "tags")
    content = sgqlc.types.Field(String, graphql_name="content")

    entry_type = sgqlc.types.Field(String, graphql_name="entryType")

    name = sgqlc.types.Field(String, graphql_name="name")

    source = sgqlc.types.Field(
        EntityManagementIncidentTimelineSource, graphql_name="source"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 504. `EntityManagementLlmConfigCreateInput`

# %% [markdown]
# Create input for LlmConfig.
#
#
# Available input fields:
#
#
#
# * `cacheSeed` : See cacheSeed in LlmConfig.
# * `model` : See model in LlmConfig.
# * `temperature` : See temperature in LlmConfig.

# %%
# | export
class EntityManagementLlmConfigCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cache_seed", "model", "temperature")
    cache_seed = sgqlc.types.Field(String, graphql_name="cacheSeed")

    model = sgqlc.types.Field(String, graphql_name="model")

    temperature = sgqlc.types.Field(Float, graphql_name="temperature")

# %% [markdown]
# #### 505. `EntityManagementLlmConfigUpdateInput`

# %% [markdown]
# Update input for LlmConfig.
#
#
# Available input fields:
#
#
#
# * `cacheSeed` : See cacheSeed in LlmConfig.
# * `model` : See model in LlmConfig.
# * `temperature` : See temperature in LlmConfig.

# %%
# | export
class EntityManagementLlmConfigUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("cache_seed", "model", "temperature")
    cache_seed = sgqlc.types.Field(String, graphql_name="cacheSeed")

    model = sgqlc.types.Field(String, graphql_name="model")

    temperature = sgqlc.types.Field(Float, graphql_name="temperature")

# %% [markdown]
# #### 506. `EntityManagementMarkdownTextSplitterOptionsCreateInput`

# %% [markdown]
# Create input for MarkdownTextSplitterOptions.
#
#
# Available input fields:
#
#
#
# * `headersToSplitOn` : See headersToSplitOn in MarkdownTextSplitterOptions.
# * `returnEachLine` : See returnEachLine in MarkdownTextSplitterOptions.

# %%
# | export
class EntityManagementMarkdownTextSplitterOptionsCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("headers_to_split_on", "return_each_line")
    headers_to_split_on = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)),
        graphql_name="headersToSplitOn",
    )

    return_each_line = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="returnEachLine"
    )

# %% [markdown]
# #### 507. `EntityManagementMarkdownTextSplitterOptionsUpdateInput`

# %% [markdown]
# Update input for MarkdownTextSplitterOptions.
#
#
# Available input fields:
#
#
#
# * `headersToSplitOn` : See headersToSplitOn in MarkdownTextSplitterOptions.
# * `returnEachLine` : See returnEachLine in MarkdownTextSplitterOptions.

# %%
# | export
class EntityManagementMarkdownTextSplitterOptionsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("headers_to_split_on", "return_each_line")
    headers_to_split_on = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)),
        graphql_name="headersToSplitOn",
    )

    return_each_line = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="returnEachLine"
    )

# %% [markdown]
# #### 508. `EntityManagementMcpServerAuthCreateInput`

# %% [markdown]
# Create input for McpServerAuth.
#
#
# Available input fields:
#
#
#
# * `bearerToken` : See bearerToken in McpServerAuth.
# * `headerKey` : See headerKey in McpServerAuth.
# * `headerValue` : See headerValue in McpServerAuth.
# * `type` : See type in McpServerAuth.

# %%
# | export
class EntityManagementMcpServerAuthCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("bearer_token", "header_key", "header_value", "type")
    bearer_token = sgqlc.types.Field(
        "EntityManagementSecretReferenceCreateInput", graphql_name="bearerToken"
    )

    header_key = sgqlc.types.Field(String, graphql_name="headerKey")

    header_value = sgqlc.types.Field(
        "EntityManagementSecretReferenceCreateInput", graphql_name="headerValue"
    )

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementMcpAuthType), graphql_name="type"
    )

# %% [markdown]
# #### 509. `EntityManagementMcpServerAuthUpdateInput`

# %% [markdown]
# Update input for McpServerAuth.
#
#
# Available input fields:
#
#
#
# * `bearerToken` : See bearerToken in McpServerAuth.
# * `headerKey` : See headerKey in McpServerAuth.
# * `headerValue` : See headerValue in McpServerAuth.
# * `type` : See type in McpServerAuth.

# %%
# | export
class EntityManagementMcpServerAuthUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("bearer_token", "header_key", "header_value", "type")
    bearer_token = sgqlc.types.Field(
        "EntityManagementSecretReferenceUpdateInput", graphql_name="bearerToken"
    )

    header_key = sgqlc.types.Field(String, graphql_name="headerKey")

    header_value = sgqlc.types.Field(
        "EntityManagementSecretReferenceUpdateInput", graphql_name="headerValue"
    )

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementMcpAuthType), graphql_name="type"
    )

# %% [markdown]
# #### 510. `EntityManagementMcpServerEntityCreateInput`

# %% [markdown]
# Create input for McpServerEntity entity type.
#
#
# Available input fields:
#
#
#
# * `auth` : See auth in McpServerEntity.
# * `description` : See description in McpServerEntity.
# * `displayName` : See displayName in McpServerEntity.
# * `endpoint` : See endpoint in McpServerEntity.
# * `name` : See name in McpServerEntity.
# * `protocolVersion` : See protocolVersion in McpServerEntity.
# * `scope` : See scope in McpServerEntity.
# * `tags` : See tags in McpServerEntity.
# * `transport` : See transport in McpServerEntity.

# %%
# | export
class EntityManagementMcpServerEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "auth",
        "description",
        "display_name",
        "endpoint",
        "name",
        "protocol_version",
        "scope",
        "tags",
        "transport",
    )
    auth = sgqlc.types.Field(
        EntityManagementMcpServerAuthCreateInput, graphql_name="auth"
    )

    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    display_name = sgqlc.types.Field(String, graphql_name="displayName")

    endpoint = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="endpoint")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    protocol_version = sgqlc.types.Field(String, graphql_name="protocolVersion")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    transport = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementMcpTransport), graphql_name="transport"
    )

# %% [markdown]
# #### 511. `EntityManagementMcpServerEntityUpdateInput`

# %% [markdown]
# Update input for McpServerEntity entity type.
#
#
# Available input fields:
#
#
#
# * `auth` : See auth in McpServerEntity.
# * `description` : See description in McpServerEntity.
# * `displayName` : See displayName in McpServerEntity.
# * `endpoint` : See endpoint in McpServerEntity.
# * `name` : See name in McpServerEntity.
# * `protocolVersion` : See protocolVersion in McpServerEntity.
# * `tags` : See tags in McpServerEntity.
# * `transport` : See transport in McpServerEntity.

# %%
# | export
class EntityManagementMcpServerEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "auth",
        "description",
        "display_name",
        "endpoint",
        "name",
        "protocol_version",
        "tags",
        "transport",
    )
    auth = sgqlc.types.Field(
        EntityManagementMcpServerAuthUpdateInput, graphql_name="auth"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    display_name = sgqlc.types.Field(String, graphql_name="displayName")

    endpoint = sgqlc.types.Field(String, graphql_name="endpoint")

    name = sgqlc.types.Field(String, graphql_name="name")

    protocol_version = sgqlc.types.Field(String, graphql_name="protocolVersion")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    transport = sgqlc.types.Field(
        EntityManagementMcpTransport, graphql_name="transport"
    )

# %% [markdown]
# #### 512. `EntityManagementNrqlRuleEngineCreateInput`

# %% [markdown]
# Create input for NrqlRuleEngine.
#
#
# Available input fields:
#
#
#
# * `accounts` : See accounts in NrqlRuleEngine.
# * `joinAccounts` : See joinAccounts in NrqlRuleEngine.
# * `query` : See query in NrqlRuleEngine.

# %%
# | export
class EntityManagementNrqlRuleEngineCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("accounts", "join_accounts", "query")
    accounts = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accounts",
    )

    join_accounts = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="joinAccounts"
    )

    query = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="query")

# %% [markdown]
# #### 513. `EntityManagementNrqlRuleEngineUpdateInput`

# %% [markdown]
# Update input for NrqlRuleEngine.
#
#
# Available input fields:
#
#
#
# * `accounts` : See accounts in NrqlRuleEngine.
# * `joinAccounts` : See joinAccounts in NrqlRuleEngine.
# * `query` : See query in NrqlRuleEngine.

# %%
# | export
class EntityManagementNrqlRuleEngineUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("accounts", "join_accounts", "query")
    accounts = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accounts",
    )

    join_accounts = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="joinAccounts"
    )

    query = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="query")

# %% [markdown]
# #### 514. `EntityManagementPipelineCloudRuleEntityCreateInput`

# %% [markdown]
# Create input for PipelineCloudRuleEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in PipelineCloudRuleEntity.
# * `enabled` : See enabled in PipelineCloudRuleEntity.
# * `name` : See name in PipelineCloudRuleEntity.
# * `nrql` : See nrql in PipelineCloudRuleEntity.
# * `scope` : See scope in PipelineCloudRuleEntity.
# * `tags` : See tags in PipelineCloudRuleEntity.

# %%
# | export
class EntityManagementPipelineCloudRuleEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "enabled", "name", "nrql", "scope", "tags")
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="nrql")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 515. `EntityManagementPipelineCloudRuleEntityUpdateInput`

# %% [markdown]
# Update input for PipelineCloudRuleEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in PipelineCloudRuleEntity.
# * `enabled` : See enabled in PipelineCloudRuleEntity.
# * `name` : See name in PipelineCloudRuleEntity.
# * `nrql` : See nrql in PipelineCloudRuleEntity.
# * `tags` : See tags in PipelineCloudRuleEntity.

# %%
# | export
class EntityManagementPipelineCloudRuleEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "enabled", "name", "nrql", "tags")
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    name = sgqlc.types.Field(String, graphql_name="name")

    nrql = sgqlc.types.Field(Nrql, graphql_name="nrql")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 516. `EntityManagementProgressLevelDefinitionCreateInput`

# %% [markdown]
# Create input for ProgressLevelDefinition.
#
#
# Available input fields:
#
#
#
# * `description` : See description in ProgressLevelDefinition.
# * `hexColorCode` : See hexColorCode in ProgressLevelDefinition.
# * `id` : See id in ProgressLevelDefinition.
# * `name` : See name in ProgressLevelDefinition.

# %%
# | export
class EntityManagementProgressLevelDefinitionCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "hex_color_code", "id", "name")
    description = sgqlc.types.Field(String, graphql_name="description")

    hex_color_code = sgqlc.types.Field(String, graphql_name="hexColorCode")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 517. `EntityManagementProgressLevelDefinitionUpdateInput`

# %% [markdown]
# Update input for ProgressLevelDefinition.
#
#
# Available input fields:
#
#
#
# * `description` : See description in ProgressLevelDefinition.
# * `hexColorCode` : See hexColorCode in ProgressLevelDefinition.
# * `id` : See id in ProgressLevelDefinition.
# * `name` : See name in ProgressLevelDefinition.

# %%
# | export
class EntityManagementProgressLevelDefinitionUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "hex_color_code", "id", "name")
    description = sgqlc.types.Field(String, graphql_name="description")

    hex_color_code = sgqlc.types.Field(String, graphql_name="hexColorCode")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 518. `EntityManagementRagToolEntityCreateInput`

# %% [markdown]
# Create input for RagToolEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in RagToolEntity.
# * `name` : See name in RagToolEntity.
# * `scope` : See scope in RagToolEntity.
# * `tags` : See tags in RagToolEntity.

# %%
# | export
class EntityManagementRagToolEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "scope", "tags")
    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("EntityManagementScopedReferenceInput"),
        graphql_name="scope",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 519. `EntityManagementRagToolEntityUpdateInput`

# %% [markdown]
# Update input for RagToolEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in RagToolEntity.
# * `name` : See name in RagToolEntity.
# * `tags` : See tags in RagToolEntity.

# %%
# | export
class EntityManagementRagToolEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "tags")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 520. `EntityManagementRelationshipCreateInput`

# %% [markdown]
# Input for creating a new relationship.
#
#
# Available input fields:
#
#
#
# * `source` : The source entity of the relationship.
# * `tags` : The tags of the relationship.
# * `target` : The target entity of the relationship.
# * `type` : The type of the relationship.

# %%
# | export
class EntityManagementRelationshipCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("source", "tags", "target", "type")
    source = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementEntityReferenceInput),
        graphql_name="source",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

    target = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementEntityReferenceInput),
        graphql_name="target",
    )

    type = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="type")

# %% [markdown]
# #### 521. `EntityManagementRelationshipUpdateInput`

# %% [markdown]
# Input for updating a relationship.
#
#
# Available input fields:
#
#
#
# * `tags` : Tags to update

# %%
# | export
class EntityManagementRelationshipUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("tags",)
    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 522. `EntityManagementRepositoryLicenseCreateInput`

# %% [markdown]
# Create input for RepositoryLicense.
#
#
# Available input fields:
#
#
#
# * `name` : See name in RepositoryLicense.
# * `url` : See url in RepositoryLicense.

# %%
# | export
class EntityManagementRepositoryLicenseCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "url")
    name = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementLicenseName), graphql_name="name"
    )

    url = sgqlc.types.Field(String, graphql_name="url")

# %% [markdown]
# #### 523. `EntityManagementRepositoryLicenseUpdateInput`

# %% [markdown]
# Update input for RepositoryLicense.
#
#
# Available input fields:
#
#
#
# * `name` : See name in RepositoryLicense.
# * `url` : See url in RepositoryLicense.

# %%
# | export
class EntityManagementRepositoryLicenseUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "url")
    name = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementLicenseName), graphql_name="name"
    )

    url = sgqlc.types.Field(String, graphql_name="url")

# %% [markdown]
# #### 524. `EntityManagementScheduleCreateInput`

# %% [markdown]
# Create input for Schedule.
#
#
# Available input fields:
#
#
#
# * `enabled` : See enabled in Schedule.
# * `firstRunAt` : See firstRunAt in Schedule.
# * `period` : See period in Schedule.
# * `rrule` : See rrule in Schedule.
# * `scheduleAt` : See scheduleAt in Schedule.
# * `timezone` : See timezone in Schedule.

# %%
# | export
class EntityManagementScheduleCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "enabled",
        "first_run_at",
        "period",
        "rrule",
        "schedule_at",
        "timezone",
    )
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    first_run_at = sgqlc.types.Field(DateTime, graphql_name="firstRunAt")

    period = sgqlc.types.Field(Int, graphql_name="period")

    rrule = sgqlc.types.Field(String, graphql_name="rrule")

    schedule_at = sgqlc.types.Field(DateTime, graphql_name="scheduleAt")

    timezone = sgqlc.types.Field(String, graphql_name="timezone")

# %% [markdown]
# #### 525. `EntityManagementScheduleUpdateInput`

# %% [markdown]
# Update input for Schedule.
#
#
# Available input fields:
#
#
#
# * `enabled` : See enabled in Schedule.
# * `firstRunAt` : See firstRunAt in Schedule.
# * `period` : See period in Schedule.
# * `rrule` : See rrule in Schedule.
# * `scheduleAt` : See scheduleAt in Schedule.
# * `timezone` : See timezone in Schedule.

# %%
# | export
class EntityManagementScheduleUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "enabled",
        "first_run_at",
        "period",
        "rrule",
        "schedule_at",
        "timezone",
    )
    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    first_run_at = sgqlc.types.Field(DateTime, graphql_name="firstRunAt")

    period = sgqlc.types.Field(Int, graphql_name="period")

    rrule = sgqlc.types.Field(String, graphql_name="rrule")

    schedule_at = sgqlc.types.Field(DateTime, graphql_name="scheduleAt")

    timezone = sgqlc.types.Field(String, graphql_name="timezone")

# %% [markdown]
# #### 526. `EntityManagementScopedReferenceInput`

# %% [markdown]
# Input for ScopedReference.
#
#
# Available input fields:
#
#
#
# * `id` : See id in ScopedReference.
# * `type` : See type in ScopedReference.

# %%
# | export
class EntityManagementScopedReferenceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementEntityScope), graphql_name="type"
    )

# %% [markdown]
# #### 527. `EntityManagementScorecardEntityCreateInput`

# %% [markdown]
# Create input for ScorecardEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in ScorecardEntity.
# * `name` : See name in ScorecardEntity.
# * `progressLevels` : See progressLevels in ScorecardEntity.
# * `scope` : See scope in ScorecardEntity.
# * `tags` : See tags in ScorecardEntity.

# %%
# | export
class EntityManagementScorecardEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "progress_levels", "scope", "tags")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    progress_levels = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(EntityManagementProgressLevelDefinitionCreateInput)
        ),
        graphql_name="progressLevels",
    )

    scope = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementScopedReferenceInput), graphql_name="scope"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 528. `EntityManagementScorecardEntityUpdateInput`

# %% [markdown]
# Update input for ScorecardEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in ScorecardEntity.
# * `name` : See name in ScorecardEntity.
# * `progressLevels` : See progressLevels in ScorecardEntity.
# * `tags` : See tags in ScorecardEntity.

# %%
# | export
class EntityManagementScorecardEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "progress_levels", "tags")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    progress_levels = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(EntityManagementProgressLevelDefinitionUpdateInput)
        ),
        graphql_name="progressLevels",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 529. `EntityManagementScorecardRuleEntityCreateInput`

# %% [markdown]
# Create input for ScorecardRuleEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in ScorecardRuleEntity.
# * `enabled` : See enabled in ScorecardRuleEntity.
# * `impactWeight` : See impactWeight in ScorecardRuleEntity.
# * `name` : See name in ScorecardRuleEntity.
# * `nrqlEngine` : See nrqlEngine in ScorecardRuleEntity.
# * `progressLevel` : See progressLevel in ScorecardRuleEntity.
# * `runInterval` : See runInterval in ScorecardRuleEntity.
# * `schedule` : See schedule in ScorecardRuleEntity.
# * `scope` : See scope in ScorecardRuleEntity.
# * `tags` : See tags in ScorecardRuleEntity.

# %%
# | export
class EntityManagementScorecardRuleEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "impact_weight",
        "name",
        "nrql_engine",
        "progress_level",
        "run_interval",
        "schedule",
        "scope",
        "tags",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    impact_weight = sgqlc.types.Field(Int, graphql_name="impactWeight")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql_engine = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementNrqlRuleEngineCreateInput),
        graphql_name="nrqlEngine",
    )

    progress_level = sgqlc.types.Field(ID, graphql_name="progressLevel")

    run_interval = sgqlc.types.Field(Int, graphql_name="runInterval")

    schedule = sgqlc.types.Field(
        EntityManagementScheduleCreateInput, graphql_name="schedule"
    )

    scope = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementScopedReferenceInput), graphql_name="scope"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 530. `EntityManagementScorecardRuleEntityUpdateInput`

# %% [markdown]
# Update input for ScorecardRuleEntity entity type.
#
#
# Available input fields:
#
#
#
# * `description` : See description in ScorecardRuleEntity.
# * `enabled` : See enabled in ScorecardRuleEntity.
# * `impactWeight` : See impactWeight in ScorecardRuleEntity.
# * `name` : See name in ScorecardRuleEntity.
# * `nrqlEngine` : See nrqlEngine in ScorecardRuleEntity.
# * `progressLevel` : See progressLevel in ScorecardRuleEntity.
# * `runInterval` : See runInterval in ScorecardRuleEntity.
# * `schedule` : See schedule in ScorecardRuleEntity.
# * `tags` : See tags in ScorecardRuleEntity.

# %%
# | export
class EntityManagementScorecardRuleEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "impact_weight",
        "name",
        "nrql_engine",
        "progress_level",
        "run_interval",
        "schedule",
        "tags",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    impact_weight = sgqlc.types.Field(Int, graphql_name="impactWeight")

    name = sgqlc.types.Field(String, graphql_name="name")

    nrql_engine = sgqlc.types.Field(
        EntityManagementNrqlRuleEngineUpdateInput, graphql_name="nrqlEngine"
    )

    progress_level = sgqlc.types.Field(ID, graphql_name="progressLevel")

    run_interval = sgqlc.types.Field(Int, graphql_name="runInterval")

    schedule = sgqlc.types.Field(
        EntityManagementScheduleUpdateInput, graphql_name="schedule"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntityManagementTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 531. `EntityManagementSecretReferenceCreateInput`

# %% [markdown]
# Create input for SecretReference.
#
#
# Available input fields:
#
#
#
# * `keyName` : See keyName in SecretReference.
# * `namespace` : See namespace in SecretReference.

# %%
# | export
class EntityManagementSecretReferenceCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key_name", "namespace")
    key_name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="keyName")

    namespace = sgqlc.types.Field(String, graphql_name="namespace")

# %% [markdown]
# #### 532. `EntityManagementSecretReferenceUpdateInput`

# %% [markdown]
# Update input for SecretReference.
#
#
# Available input fields:
#
#
#
# * `keyName` : See keyName in SecretReference.
# * `namespace` : See namespace in SecretReference.

# %%
# | export
class EntityManagementSecretReferenceUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key_name", "namespace")
    key_name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="keyName")

    namespace = sgqlc.types.Field(String, graphql_name="namespace")

# %% [markdown]
# #### 533. `EntityManagementSyncGroupRuleConditionUpdateInput`

# %% [markdown]
# Update input for SyncGroupRuleCondition.
#
#
# Available input fields:
#
#
#
# * `type` : See type in SyncGroupRuleCondition.
# * `value` : See value in SyncGroupRuleCondition.

# %%
# | export
class EntityManagementSyncGroupRuleConditionUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("type", "value")
    type = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementSyncGroupRuleConditionType),
        graphql_name="type",
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 534. `EntityManagementSyncGroupRuleUpdateInput`

# %% [markdown]
# Update input for SyncGroupRule.
#
#
# Available input fields:
#
#
#
# * `conditions` : See conditions in SyncGroupRule.

# %%
# | export
class EntityManagementSyncGroupRuleUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("conditions",)
    conditions = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(EntityManagementSyncGroupRuleConditionUpdateInput)
            )
        ),
        graphql_name="conditions",
    )

# %% [markdown]
# #### 535. `EntityManagementSyncGroupsSettingsUpdateInput`

# %% [markdown]
# Update input for SyncGroupsSettings.
#
#
# Available input fields:
#
#
#
# * `enabled` : See enabled in SyncGroupsSettings.
# * `rules` : See rules in SyncGroupsSettings.

# %%
# | export
class EntityManagementSyncGroupsSettingsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled", "rules")
    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    rules = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(EntityManagementSyncGroupRuleUpdateInput)
        ),
        graphql_name="rules",
    )

# %% [markdown]
# #### 536. `EntityManagementTagInput`

# %% [markdown]
# Input for tags.
#
#
# Available input fields:
#
#
#
# * `key` : The key or name of the tag.
# * `values` : The list of values of the tag.

# %%
# | export
class EntityManagementTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "values")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="values",
    )

# %% [markdown]
# #### 537. `EntityManagementTeamEntityCreateInput`

# %% [markdown]
# Create input for TeamEntity entity type.
#
#
# Available input fields:
#
#
#
# * `aliases` : See aliases in TeamEntity.
# * `description` : See description in TeamEntity.
# * `externalIntegration` : See externalIntegration in TeamEntity.
# * `managers` : See managers in TeamEntity.
# * `name` : See name in TeamEntity.
# * `parentId` : See parentId in TeamEntity.
# * `resources` : See resources in TeamEntity.
# * `scope` : See scope in TeamEntity.
# * `tags` : See tags in TeamEntity.

# %%
# | export
class EntityManagementTeamEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aliases",
        "description",
        "external_integration",
        "managers",
        "name",
        "parent_id",
        "resources",
        "scope",
        "tags",
    )
    aliases = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="aliases"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    external_integration = sgqlc.types.Field(
        "EntityManagementTeamExternalIntegrationCreateInput",
        graphql_name="externalIntegration",
    )

    managers = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="managers"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    parent_id = sgqlc.types.Field(ID, graphql_name="parentId")

    resources = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementTeamResourceCreateInput")
        ),
        graphql_name="resources",
    )

    scope = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementScopedReferenceInput), graphql_name="scope"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityManagementTagInput)),
        graphql_name="tags",
    )

# %% [markdown]
# #### 538. `EntityManagementTeamEntityUpdateInput`

# %% [markdown]
# Update input for TeamEntity entity type.
#
#
# Available input fields:
#
#
#
# * `aliases` : See aliases in TeamEntity.
# * `description` : See description in TeamEntity.
# * `externalIntegration` : See externalIntegration in TeamEntity.
# * `managers` : See managers in TeamEntity.
# * `name` : See name in TeamEntity.
# * `parentId` : See parentId in TeamEntity.
# * `resources` : See resources in TeamEntity.
# * `tags` : See tags in TeamEntity.

# %%
# | export
class EntityManagementTeamEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "aliases",
        "description",
        "external_integration",
        "managers",
        "name",
        "parent_id",
        "resources",
        "tags",
    )
    aliases = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="aliases"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    external_integration = sgqlc.types.Field(
        "EntityManagementTeamExternalIntegrationUpdateInput",
        graphql_name="externalIntegration",
    )

    managers = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="managers"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    parent_id = sgqlc.types.Field(ID, graphql_name="parentId")

    resources = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("EntityManagementTeamResourceUpdateInput")
        ),
        graphql_name="resources",
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityManagementTagInput)),
        graphql_name="tags",
    )

# %% [markdown]
# #### 539. `EntityManagementTeamExternalIntegrationCreateInput`

# %% [markdown]
# Create input for TeamExternalIntegration.
#
#
# Available input fields:
#
#
#
# * `externalId` : See externalId in TeamExternalIntegration.
# * `type` : See type in TeamExternalIntegration.

# %%
# | export
class EntityManagementTeamExternalIntegrationCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("external_id", "type")
    external_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="externalId")

    type = sgqlc.types.Field(
        EntityManagementTeamExternalIntegrationType, graphql_name="type"
    )

# %% [markdown]
# #### 540. `EntityManagementTeamExternalIntegrationUpdateInput`

# %% [markdown]
# Update input for TeamExternalIntegration.
#
#
# Available input fields:
#
#
#
# * `externalId` : See externalId in TeamExternalIntegration.
# * `type` : See type in TeamExternalIntegration.

# %%
# | export
class EntityManagementTeamExternalIntegrationUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("external_id", "type")
    external_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="externalId")

    type = sgqlc.types.Field(
        EntityManagementTeamExternalIntegrationType, graphql_name="type"
    )

# %% [markdown]
# #### 541. `EntityManagementTeamResourceCreateInput`

# %% [markdown]
# Create input for TeamResource.
#
#
# Available input fields:
#
#
#
# * `content` : See content in TeamResource.
# * `title` : See title in TeamResource.
# * `type` : See type in TeamResource.

# %%
# | export
class EntityManagementTeamResourceCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("content", "title", "type")
    content = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="content")

    title = sgqlc.types.Field(String, graphql_name="title")

    type = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="type")

# %% [markdown]
# #### 542. `EntityManagementTeamResourceUpdateInput`

# %% [markdown]
# Update input for TeamResource.
#
#
# Available input fields:
#
#
#
# * `content` : See content in TeamResource.
# * `title` : See title in TeamResource.
# * `type` : See type in TeamResource.

# %%
# | export
class EntityManagementTeamResourceUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("content", "title", "type")
    content = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="content")

    title = sgqlc.types.Field(String, graphql_name="title")

    type = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="type")

# %% [markdown]
# #### 543. `EntityManagementTeamsHierarchyLevelEntityUpdateInput`

# %% [markdown]
# Update input for TeamsHierarchyLevelEntity entity type.
#
#
# Available input fields:
#
#
#
# * `name` : See name in TeamsHierarchyLevelEntity.
# * `tags` : See tags in TeamsHierarchyLevelEntity.

# %%
# | export
class EntityManagementTeamsHierarchyLevelEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "tags")
    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityManagementTagInput)),
        graphql_name="tags",
    )

# %% [markdown]
# #### 544. `EntityManagementTeamsOrganizationSettingsEntityUpdateInput`

# %% [markdown]
# Update input for TeamsOrganizationSettingsEntity entity type.
#
#
# Available input fields:
#
#
#
# * `discovery` : See discovery in TeamsOrganizationSettingsEntity.
# * `name` : See name in TeamsOrganizationSettingsEntity.
# * `syncGroups` : See syncGroups in TeamsOrganizationSettingsEntity.
# * `tags` : See tags in TeamsOrganizationSettingsEntity.

# %%
# | export
class EntityManagementTeamsOrganizationSettingsEntityUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("discovery", "name", "sync_groups", "tags")
    discovery = sgqlc.types.Field(
        EntityManagementDiscoverySettingsUpdateInput, graphql_name="discovery"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    sync_groups = sgqlc.types.Field(
        EntityManagementSyncGroupsSettingsUpdateInput, graphql_name="syncGroups"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityManagementTagInput)),
        graphql_name="tags",
    )

# %% [markdown]
# #### 545. `EntityManagementTokenTextSplitterOptionsCreateInput`

# %% [markdown]
# Create input for TokenTextSplitterOptions.
#
#
# Available input fields:
#
#
#
# * `encodingName` : See encodingName in TokenTextSplitterOptions.

# %%
# | export
class EntityManagementTokenTextSplitterOptionsCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("encoding_name",)
    encoding_name = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementEncodingName), graphql_name="encodingName"
    )

# %% [markdown]
# #### 546. `EntityManagementTokenTextSplitterOptionsUpdateInput`

# %% [markdown]
# Update input for TokenTextSplitterOptions.
#
#
# Available input fields:
#
#
#
# * `encodingName` : See encodingName in TokenTextSplitterOptions.

# %%
# | export
class EntityManagementTokenTextSplitterOptionsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("encoding_name",)
    encoding_name = sgqlc.types.Field(
        sgqlc.types.non_null(EntityManagementEncodingName), graphql_name="encodingName"
    )

# %% [markdown]
# #### 547. `EntityRelationshipEdgeFilter`

# %% [markdown]
# EntityRelationship edge filter.
#
#
# Available input fields:
#
#
#
# * `direction` : Filter by direction of relationship.
# * `entityDomainTypes` : Filter on entity domain-types.
# * `relationshipTypes` : Filter on relationship types.

# %%
# | export
class EntityRelationshipEdgeFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "entity_domain_types", "relationship_types")
    direction = sgqlc.types.Field(
        EntityRelationshipEdgeDirection, graphql_name="direction"
    )

    entity_domain_types = sgqlc.types.Field(
        "EntityRelationshipEntityDomainTypeFilter", graphql_name="entityDomainTypes"
    )

    relationship_types = sgqlc.types.Field(
        "EntityRelationshipEdgeTypeFilter", graphql_name="relationshipTypes"
    )

# %% [markdown]
# #### 548. `EntityRelationshipEdgeTypeFilter`

# %% [markdown]
# Filter on relationship types.
#
#
# Available input fields:
#
#
#
# * `exclude` : Filter the relationships to those that are not of specific relationship types.
# * `include` : Filter the relationships to those of specific relationship types.

# %%
# | export
class EntityRelationshipEdgeTypeFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exclude", "include")
    exclude = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityRelationshipEdgeType)),
        graphql_name="exclude",
    )

    include = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityRelationshipEdgeType)),
        graphql_name="include",
    )

# %% [markdown]
# #### 549. `EntityRelationshipEntityDomainTypeFilter`

# %% [markdown]
# Filter on entity domain-types.
#
#
# Available input fields:
#
#
#
# * `exclude` : Filter the relationships to those between entities that are not of specific domain-types.
# * `include` : Filter the relationships to those between entities of specific domain-types.

# %%
# | export
class EntityRelationshipEntityDomainTypeFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exclude", "include")
    exclude = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(DomainTypeInput)),
        graphql_name="exclude",
    )

    include = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(DomainTypeInput)),
        graphql_name="include",
    )

# %% [markdown]
# #### 550. `EntityRelationshipFilter`

# %% [markdown]
# Relationship filter
#
#
# Available input fields:
#
#
#
# * `entityType` : Filter the relationships to those that contain a specific entity type.
# * `infrastructureIntegrationType` : Filter the relationships to those that contain a specific Infrastructure integration entity type

# %%
# | export
class EntityRelationshipFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_type", "infrastructure_integration_type")
    entity_type = sgqlc.types.Field(
        sgqlc.types.list_of(EntityType), graphql_name="entityType"
    )

    infrastructure_integration_type = sgqlc.types.Field(
        sgqlc.types.list_of(EntityInfrastructureIntegrationType),
        graphql_name="infrastructureIntegrationType",
    )

# %% [markdown]
# #### 551. `EntitySearchOptions`

# %% [markdown]
# Additional entity search options.
#
#
# Available input fields:
#
#
#
# * `caseSensitiveTagMatching` : Whether or not matching on tag keys and values should be case-sensitive.
# * `limit` : A limit to apply to the number of entities returned. Note: this option can only _lower_ the default limits.
# * `tagFilter` : Specify which tags to include with search results. Does not affect which entities are returned.

# %%
# | export
class EntitySearchOptions(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("case_sensitive_tag_matching", "limit", "tag_filter")
    case_sensitive_tag_matching = sgqlc.types.Field(
        Boolean, graphql_name="caseSensitiveTagMatching"
    )

    limit = sgqlc.types.Field(Int, graphql_name="limit")

    tag_filter = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="tagFilter"
    )

# %% [markdown]
# #### 552. `EntitySearchQueryBuilder`

# %% [markdown]
# An object that can be used to discover and create the entity search query argument.
#
#
# Available input fields:
#
#
#
# * `alertSeverity` : The alerting severity of the entity.
# * `alertable` : The alertable status of the entity
# * `domain` : The entity domain. This is not a complete list of entity domains available; it is a way to explore the most popular domains.
# * `infrastructureIntegrationType` : **WARNING! This argument is deprecated and will not be updated with new infrastructure integration types.** If you want to query for a type not in this list, use the `query` argument instead of `queryBuilder`. To see the query string that is generated by your `queryBuilder` search, ask for the `query` field in the result object. You can then use this to build a query supplied to the `query` argument and remove your `queryBuilder`.
#
# The Infrastructure integration type. This should be used in place of the `type` field to search for Infrastructure integration specific types.
# * `name` : The entity name.
# * `reporting` : The reporting status of the entity.
# * `tags` : A list of tags applied to the entity.
# * `type` : The entity type.
#
# This is not a complete list of entity types available; it is a way to explore the most popular types.
#
# If you are querying for Infrastructure integration types, use the `infrastructureIntegrationType` field instead of `type`.

# %%
# | export
class EntitySearchQueryBuilder(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "alert_severity",
        "alertable",
        "domain",
        "infrastructure_integration_type",
        "name",
        "reporting",
        "tags",
        "type",
    )
    alert_severity = sgqlc.types.Field(
        EntityAlertSeverity, graphql_name="alertSeverity"
    )

    alertable = sgqlc.types.Field(Boolean, graphql_name="alertable")

    domain = sgqlc.types.Field(EntitySearchQueryBuilderDomain, graphql_name="domain")

    infrastructure_integration_type = sgqlc.types.Field(
        EntityInfrastructureIntegrationType,
        graphql_name="infrastructureIntegrationType",
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    reporting = sgqlc.types.Field(Boolean, graphql_name="reporting")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("EntitySearchQueryBuilderTag")),
        graphql_name="tags",
    )

    type = sgqlc.types.Field(EntitySearchQueryBuilderType, graphql_name="type")

# %% [markdown]
# #### 553. `EntitySearchQueryBuilderTag`

# %% [markdown]
# An entity tag.
#
#
# Available input fields:
#
#
#
# * `key` : The tag key. You can search using a `tags.` prefix or omit it and receive the same results.
#
# Examples: `tags.environment`, `environment`.
# * `value` : The tag value.

# %%
# | export
class EntitySearchQueryBuilderTag(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 554. `ErrorsInboxAssignErrorGroupInput`

# %% [markdown]
# Input for assignment mutation.
#
#
# Available input fields:
#
#
#
# * `userEmail` : Email address of the user that will be assigned.
# * `userId` : Id of the user that will be assigned.

# %%
# | export
class ErrorsInboxAssignErrorGroupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("user_email", "user_id")
    user_email = sgqlc.types.Field(String, graphql_name="userEmail")

    user_id = sgqlc.types.Field(Int, graphql_name="userId")

# %% [markdown]
# #### 555. `ErrorsInboxAssignmentSearchFilterInput`

# %% [markdown]
# Input type for assignment search filter
#
#
# Available input fields:
#
#
#
# * `userEmail` : Filter by assigned user email.
# * `userId` : Filter by assigned user id

# %%
# | export
class ErrorsInboxAssignmentSearchFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("user_email", "user_id")
    user_email = sgqlc.types.Field(String, graphql_name="userEmail")

    user_id = sgqlc.types.Field(Int, graphql_name="userId")

# %% [markdown]
# #### 556. `ErrorsInboxErrorEventInput`

# %% [markdown]
# Input for error events.
#
#
# Available input fields:
#
#
#
# * `entityGuid` : Guid of entity that generated the event.
# * `event` : A set of attributes representing an event associated with an error
# * `message` : Error event message.
# * `name` : Error event name.
# * `source` : Source of error event (ex: TransactionError, Span)

# %%
# | export
class ErrorsInboxErrorEventInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_guid", "event", "message", "name", "source")
    entity_guid = sgqlc.types.Field(
        sgqlc.types.non_null(EntityGuid), graphql_name="entityGuid"
    )

    event = sgqlc.types.Field(ErrorsInboxRawEvent, graphql_name="event")

    message = sgqlc.types.Field(String, graphql_name="message")

    name = sgqlc.types.Field(String, graphql_name="name")

    source = sgqlc.types.Field(ErrorsInboxEventSource, graphql_name="source")

# %% [markdown]
# #### 557. `ErrorsInboxErrorGroupSearchFilterInput`

# %% [markdown]
# Set of filters for scoping error group searches
#
#
# Available input fields:
#
#
#
# * `accountIds` : Filter error groups by account ID
# * `applicationVersions` : Filter error groups by the version of the application
# * `assignment` : Filter error groups by assignment
# * `ids` : Filter error groups by id
# * `isAssigned` : Filter error groups by assignment status
# * `states` : Filter error groups by error group states

# %%
# | export
class ErrorsInboxErrorGroupSearchFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "account_ids",
        "application_versions",
        "assignment",
        "ids",
        "is_assigned",
        "states",
    )
    account_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="accountIds"
    )

    application_versions = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)),
        graphql_name="applicationVersions",
    )

    assignment = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(ErrorsInboxAssignmentSearchFilterInput)
        ),
        graphql_name="assignment",
    )

    ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="ids"
    )

    is_assigned = sgqlc.types.Field(Boolean, graphql_name="isAssigned")

    states = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ErrorsInboxErrorGroupState)),
        graphql_name="states",
    )

# %% [markdown]
# #### 558. `ErrorsInboxErrorGroupSortOrderInput`

# %% [markdown]
# Sort object.
#
#
# Available input fields:
#
#
#
# * `direction` : Sort object order.
# * `field` : Sort object field.

# %%
# | export
class ErrorsInboxErrorGroupSortOrderInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "field")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(ErrorsInboxDirection), graphql_name="direction"
    )

    field = sgqlc.types.Field(
        sgqlc.types.non_null(ErrorsInboxErrorGroupSortOrderField), graphql_name="field"
    )

# %% [markdown]
# #### 559. `ErrorsInboxResourceFilterInput`

# %% [markdown]
# Criteria for the resource filter
#
#
# Available input fields:
#
#
#
# * `types` : Types of resources to include in the query

# %%
# | export
class ErrorsInboxResourceFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("types",)
    types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ErrorsInboxResourceType)),
        graphql_name="types",
    )

# %% [markdown]
# #### 560. `ErrorsInboxStateVersionInput`

# %% [markdown]
# Input for the version related to an applied state (e.g., Resolved in version <stateVersion>).
#
#
# Available input fields:
#
#
#
# * `values` : Version strings

# %%
# | export
class ErrorsInboxStateVersionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("values",)
    values = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="values"
    )

# %% [markdown]
# #### 561. `EventsToMetricsCreateRuleInput`

# %% [markdown]
# Details needed to create an events to metrics conversion rule.
#
#
# Available input fields:
#
#
#
# * `accountId` : The account where the events exist and the metrics will be put.
# * `description` : Provides additional information about the rule.
# * `name` : The name of the rule. This must be unique within a given account.
# * `nrql` : Explains how to create one or more metrics from events.

# %%
# | export
class EventsToMetricsCreateRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "description", "name", "nrql")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="nrql")

# %% [markdown]
# #### 562. `EventsToMetricsDeleteRuleInput`

# %% [markdown]
# Identifying information about the events to metrics rule you want to delete.
#
#
# Available input fields:
#
#
#
# * `accountId` : A submitted account id.
# * `ruleId` : A submitted rule id.

# %%
# | export
class EventsToMetricsDeleteRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "rule_id")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    rule_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="ruleId")

# %% [markdown]
# #### 563. `EventsToMetricsUpdateRuleInput`

# %% [markdown]
# Identifying information about the events to metrics rule you want to update.
#
#
# Available input fields:
#
#
#
# * `accountId` : A submitted account id.
# * `enabled` : Changes the state of the rule as being enabled or disabled.
# * `ruleId` : A submitted rule id.

# %%
# | export
class EventsToMetricsUpdateRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "enabled", "rule_id")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    rule_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="ruleId")

# %% [markdown]
# #### 564. `FleetControlAgentInput`

# %% [markdown]
# Agent input
#
#
# Available input fields:
#
#
#
# * `agentType` : Agent type
# * `configurationVersionList` : Configuration version list for this agent
# * `version` : Agent version

# %%
# | export
class FleetControlAgentInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("agent_type", "configuration_version_list", "version")
    agent_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="agentType"
    )

    configuration_version_list = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null("FleetControlConfigurationVersionListInput")
            )
        ),
        graphql_name="configurationVersionList",
    )

    version = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="version")

# %% [markdown]
# #### 565. `FleetControlConfigurationVersionListInput`

# %% [markdown]
# Configuration version list input
#
#
# Available input fields:
#
#
#
# * `id` : Configuration version id

# %%
# | export
class FleetControlConfigurationVersionListInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

# %% [markdown]
# #### 566. `FleetControlFleetDeploymentCreateInput`

# %% [markdown]
# Fleet deployment create input
#
#
# Available input fields:
#
#
#
# * `agents` : Agents configurations
# * `configurationVersionList` : Fleet deployment configuration version list - DEPRECATED
# * `description` : Fleet deployment description
# * `fleetId` : Fleet entity id
# * `name` : Fleet deployment name
# * `scope` : Entity scope
# * `tags` : Fleet deployment tags

# %%
# | export
class FleetControlFleetDeploymentCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "agents",
        "configuration_version_list",
        "description",
        "fleet_id",
        "name",
        "scope",
        "tags",
    )
    agents = sgqlc.types.Field(
        sgqlc.types.list_of(FleetControlAgentInput), graphql_name="agents"
    )

    configuration_version_list = sgqlc.types.Field(
        sgqlc.types.list_of(FleetControlConfigurationVersionListInput),
        graphql_name="configurationVersionList",
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    fleet_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="fleetId")

    name = sgqlc.types.Field(String, graphql_name="name")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("FleetControlScopedReferenceInput"), graphql_name="scope"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("FleetControlTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 567. `FleetControlFleetDeploymentPolicyInput`

# %% [markdown]
# Fleet deployment policy input
#
#
# Available input fields:
#
#
#
# * `ringDeploymentPolicy` : Rings to deploy

# %%
# | export
class FleetControlFleetDeploymentPolicyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ring_deployment_policy",)
    ring_deployment_policy = sgqlc.types.Field(
        "FleetControlRingDeploymentPolicyInput", graphql_name="ringDeploymentPolicy"
    )

# %% [markdown]
# #### 568. `FleetControlFleetDeploymentUpdateInput`

# %% [markdown]
# Fleet deployment update input
#
#
# Available input fields:
#
#
#
# * `agents` : Agents configurations
# * `configurationVersionList` : Fleet deployment configuration version list - DEPRECATED
# * `description` : Fleet deployment description
# * `name` : Fleet deployment name
# * `tags` : Fleet deployment tags

# %%
# | export
class FleetControlFleetDeploymentUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "agents",
        "configuration_version_list",
        "description",
        "name",
        "tags",
    )
    agents = sgqlc.types.Field(
        sgqlc.types.list_of(FleetControlAgentInput), graphql_name="agents"
    )

    configuration_version_list = sgqlc.types.Field(
        sgqlc.types.list_of(FleetControlConfigurationVersionListInput),
        graphql_name="configurationVersionList",
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("FleetControlTagInput")),
        graphql_name="tags",
    )

# %% [markdown]
# #### 569. `FleetControlFleetEntityCreateInput`

# %% [markdown]
# Fleet entity create input
#
#
# Available input fields:
#
#
#
# * `description` : The fleet entity description
# * `managedEntityType` : The type of entity the fleet will manage
# * `name` : The fleet entity name
# * `operatingSystem` : The operating system type of the managed entities in this fleet
# * `product` : The fleet specific product type
# * `scope` : The entity scope
# * `tags` : The fleet entity tags

# %%
# | export
class FleetControlFleetEntityCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "managed_entity_type",
        "name",
        "operating_system",
        "product",
        "scope",
        "tags",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    managed_entity_type = sgqlc.types.Field(
        sgqlc.types.non_null(FleetControlManagedEntityType),
        graphql_name="managedEntityType",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    operating_system = sgqlc.types.Field(
        "FleetControlOperatingSystemCreateInput", graphql_name="operatingSystem"
    )

    product = sgqlc.types.Field(String, graphql_name="product")

    scope = sgqlc.types.Field(
        sgqlc.types.non_null("FleetControlScopedReferenceInput"), graphql_name="scope"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of("FleetControlTagInput"), graphql_name="tags"
    )

# %% [markdown]
# #### 570. `FleetControlFleetMemberRingInput`

# %% [markdown]
# The ring to modify entities
#
#
# Available input fields:
#
#
#
# * `entityIds` : The list of entityIds to modify on the fleet
# * `ring` : The ring name to modify entities

# %%
# | export
class FleetControlFleetMemberRingInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_ids", "ring")
    entity_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="entityIds"
    )

    ring = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="ring")

# %% [markdown]
# #### 571. `FleetControlFleetMembersFilterInput`

# %% [markdown]
# Filter input for listing managed entities in a fleet
#
#
# Available input fields:
#
#
#
# * `fleetId` : Filter by fleet id
# * `ring` : Filter by ring name

# %%
# | export
class FleetControlFleetMembersFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("fleet_id", "ring")
    fleet_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="fleetId")

    ring = sgqlc.types.Field(String, graphql_name="ring")

# %% [markdown]
# #### 572. `FleetControlOperatingSystemCreateInput`

# %% [markdown]
# Operating System input for the host operating systems in a fleet
#
#
# Available input fields:
#
#
#
# * `type` : The operating system type enum

# %%
# | export
class FleetControlOperatingSystemCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("type",)
    type = sgqlc.types.Field(
        sgqlc.types.non_null(FleetControlOperatingSystemType), graphql_name="type"
    )

# %% [markdown]
# #### 573. `FleetControlRingDeploymentPolicyInput`

# %% [markdown]
# Ring deployment policy input
#
#
# Available input fields:
#
#
#
# * `ringsToDeploy` : Rings to deploy

# %%
# | export
class FleetControlRingDeploymentPolicyInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("rings_to_deploy",)
    rings_to_deploy = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="ringsToDeploy"
    )

# %% [markdown]
# #### 574. `FleetControlScopedReferenceInput`

# %% [markdown]
# Scoped reference input
#
#
# Available input fields:
#
#
#
# * `id` : Scope id of the entity
# * `type` : Scope type of the entity

# %%
# | export
class FleetControlScopedReferenceInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(FleetControlEntityScope), graphql_name="type"
    )

# %% [markdown]
# #### 575. `FleetControlTagInput`

# %% [markdown]
# Collection of tags
#
#
# Available input fields:
#
#
#
# * `key` : The tag key
# * `values` : List of tag values

# %%
# | export
class FleetControlTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "values")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="values",
    )

# %% [markdown]
# #### 576. `FleetControlUpdateFleetEntityInput`

# %% [markdown]
# Fleet entity update input
#
#
# Available input fields:
#
#
#
# * `description` : Fleet entity description
# * `name` : Fleet entity name
# * `tags` : Fleet entity tags

# %%
# | export
class FleetControlUpdateFleetEntityInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "tags")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(FleetControlTagInput)),
        graphql_name="tags",
    )

# %% [markdown]
# #### 577. `InstallationInstallStatusInput`

# %% [markdown]
# An object that contains the overall installation status to be created.
#
#
# Available input fields:
#
#
#
# * `cliVersion` : The version of the newrelic-cli that was used for a given installation attempt.
# * `deployedBy` : Refers to the source of the installation.
# * `enabledProxy` : Whether or not the installation is using a proxy.
# * `error` : The error for a given installation attempt.
# * `hostName` : The host name of the customer's machine.
# * `installId` : The unique ID that corresponds to an install status.
# * `installLibraryVersion` : The version of the open-install-library that is being used.
# * `isUnsupported` : Whether or not the installation is supported on the host machine.
# * `kernelArch` : The kernel architecture of the customer's machine.
# * `kernelVersion` : The kernel version of the customer's machine.
# * `logFilePath` : The path to the log file on the customer's host.
# * `os` : The OS of the customer's machine.
# * `platform` : The platform name provided by the open-install-library.
# * `platformFamily` : The platform family name provided by the open-install-library.
# * `platformVersion` : The platform version provided by the open-install-library.
# * `redirectUrl` : A URL generated by the newrelic-cli that redirects to the appropriate entity once an installation is complete.
# * `state` : The state of the installation.
# * `targetedInstall` : Whether or not the installation is a targeted install.
# * `timestamp` : The timestamp for when the install event occurred.

# %%
# | export
class InstallationInstallStatusInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "cli_version",
        "deployed_by",
        "enabled_proxy",
        "error",
        "host_name",
        "install_id",
        "install_library_version",
        "is_unsupported",
        "kernel_arch",
        "kernel_version",
        "log_file_path",
        "os",
        "platform",
        "platform_family",
        "platform_version",
        "redirect_url",
        "state",
        "targeted_install",
        "timestamp",
    )
    cli_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="cliVersion"
    )

    deployed_by = sgqlc.types.Field(String, graphql_name="deployedBy")

    enabled_proxy = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="enabledProxy"
    )

    error = sgqlc.types.Field(
        sgqlc.types.non_null("InstallationStatusErrorInput"), graphql_name="error"
    )

    host_name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="hostName")

    install_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="installId")

    install_library_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="installLibraryVersion"
    )

    is_unsupported = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="isUnsupported"
    )

    kernel_arch = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="kernelArch"
    )

    kernel_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="kernelVersion"
    )

    log_file_path = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="logFilePath"
    )

    os = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="os")

    platform = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="platform")

    platform_family = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="platformFamily"
    )

    platform_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="platformVersion"
    )

    redirect_url = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="redirectUrl"
    )

    state = sgqlc.types.Field(
        sgqlc.types.non_null(InstallationInstallStateType), graphql_name="state"
    )

    targeted_install = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="targetedInstall"
    )

    timestamp = sgqlc.types.Field(EpochSeconds, graphql_name="timestamp")

# %% [markdown]
# #### 578. `InstallationRecipeStatus`

# %% [markdown]
# An object that represents a recipe status.
#
#
# Available input fields:
#
#
#
# * `cliVersion` : The version of the newrelic-cli that was used for a given recipe.
# * `complete` : Whether or not the recipe has been installed and all steps have been completed.
# * `displayName` : The display name for a given recipe.
# * `entityGuid` : The entity Guid for a given recipe.
# * `error` : The error returned for a given recipe.
# * `hostName` : The host name of the customer's machine.
# * `installId` : The unique ID that corresponds to an install event.
# * `installLibraryVersion` : The version of the open-install-library that is being used.
# * `kernelArch` : The kernel architecture of the customer's machine.
# * `kernelVersion` : The kernel version of the customer's machine.
# * `logFilePath` : The path to the log file on the customer's host.
# * `metadata` : Additional key:value data related to an error or related to the environment where the installation occurred.
# * `name` : The unique name for a given recipe.
# * `os` : The OS of the customer's machine.
# * `platform` : The platform name provided by the open-install-library.
# * `platformFamily` : The platform family name provided by the open-install-library.
# * `platformVersion` : The platform version provided by the open-install-library.
# * `redirectUrl` : The redirect URL created by the CLI used for redirecting to a particular entity.
# * `status` : The status for a given recipe.
# * `targetedInstall` : Whether or not the recipe being installed is a targeted install.
# * `taskPath` : The path to the installation task as defined in the open-install-library.
# * `validationDurationMilliseconds` : The number of milliseconds it took to validate the recipe.

# %%
# | export
class InstallationRecipeStatus(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "cli_version",
        "complete",
        "display_name",
        "entity_guid",
        "error",
        "host_name",
        "install_id",
        "install_library_version",
        "kernel_arch",
        "kernel_version",
        "log_file_path",
        "metadata",
        "name",
        "os",
        "platform",
        "platform_family",
        "platform_version",
        "redirect_url",
        "status",
        "targeted_install",
        "task_path",
        "validation_duration_milliseconds",
    )
    cli_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="cliVersion"
    )

    complete = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="complete")

    display_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="displayName"
    )

    entity_guid = sgqlc.types.Field(
        sgqlc.types.non_null(EntityGuid), graphql_name="entityGuid"
    )

    error = sgqlc.types.Field(
        sgqlc.types.non_null("InstallationStatusErrorInput"), graphql_name="error"
    )

    host_name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="hostName")

    install_id = sgqlc.types.Field(ID, graphql_name="installId")

    install_library_version = sgqlc.types.Field(
        SemVer, graphql_name="installLibraryVersion"
    )

    kernel_arch = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="kernelArch"
    )

    kernel_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="kernelVersion"
    )

    log_file_path = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="logFilePath"
    )

    metadata = sgqlc.types.Field(InstallationRawMetadata, graphql_name="metadata")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    os = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="os")

    platform = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="platform")

    platform_family = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="platformFamily"
    )

    platform_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="platformVersion"
    )

    redirect_url = sgqlc.types.Field(String, graphql_name="redirectUrl")

    status = sgqlc.types.Field(
        sgqlc.types.non_null(InstallationRecipeStatusType), graphql_name="status"
    )

    targeted_install = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="targetedInstall"
    )

    task_path = sgqlc.types.Field(String, graphql_name="taskPath")

    validation_duration_milliseconds = sgqlc.types.Field(
        sgqlc.types.non_null(EpochMilliseconds),
        graphql_name="validationDurationMilliseconds",
    )

# %% [markdown]
# #### 579. `InstallationStatusErrorInput`

# %% [markdown]
# An object that represents a status error whenever an recipe has failed to install.
#
#
# Available input fields:
#
#
#
# * `details` : Error details, if any.
# * `message` : The actual error message.
# * `optimizedMessage` : An optimised message for the error.

# %%
# | export
class InstallationStatusErrorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("details", "message", "optimized_message")
    details = sgqlc.types.Field(String, graphql_name="details")

    message = sgqlc.types.Field(String, graphql_name="message")

    optimized_message = sgqlc.types.Field(String, graphql_name="optimizedMessage")

# %% [markdown]
# #### 580. `IntegrationServicesCapabilitySettingsInput`

# %% [markdown]
# Defines the input for capability setting of a ServiceNow entity.
#
#
# Available input fields:
#
#
#
# * `capability` : Name of the capability to update.

# %%
# | export
class IntegrationServicesCapabilitySettingsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("capability",)
    capability = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="capability"
    )

# %% [markdown]
# #### 581. `IntegrationServicesCapabilitySettingsUpdateInput`

# %% [markdown]
# Defines the input for updating a capability setting of a ServiceNow entity.
#
#
# Available input fields:
#
#
#
# * `capability` : Name of the capability to update.

# %%
# | export
class IntegrationServicesCapabilitySettingsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("capability",)
    capability = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="capability"
    )

# %% [markdown]
# #### 582. `IntegrationServicesInstallationInput`

# %% [markdown]
# Defines the input required for ServiceNow installation mutation.
#
#
# Available input fields:
#
#
#
# * `capabilitySettings` : List of capability settings for the ServiceNow entity.
# * `clientId` : Client ID for ServiceNow integration.
# * `clientSecret` : Client secret for ServiceNow integration.
# * `instanceName` : Instance name for ServiceNow integration.
# * `signingKey` : Signing key for ServiceNow integration.

# %%
# | export
class IntegrationServicesInstallationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "capability_settings",
        "client_id",
        "client_secret",
        "instance_name",
        "signing_key",
    )
    capability_settings = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(IntegrationServicesCapabilitySettingsInput)
            )
        ),
        graphql_name="capabilitySettings",
    )

    client_id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="clientId")

    client_secret = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="clientSecret"
    )

    instance_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="instanceName"
    )

    signing_key = sgqlc.types.Field(
        sgqlc.types.non_null(SecureValue), graphql_name="signingKey"
    )

# %% [markdown]
# #### 583. `IntegrationServicesTagInput`

# %% [markdown]
# Defines the input for a tag associated with a ServiceNow entity.
#
#
# Available input fields:
#
#
#
# * `key` : Key of the tag.
# * `values` : List of values for the tag.

# %%
# | export
class IntegrationServicesTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "values")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="values",
    )

# %% [markdown]
# #### 584. `IntegrationServicesUpdateInput`

# %% [markdown]
# Defines the input required for updating a ServiceNow entity.
#
#
# Available input fields:
#
#
#
# * `capabilitySettings` : List of capability settings to update for the ServiceNow entity.
# * `enabled` : Flag indicating if the ServiceNow entity is enabled.
# * `instanceName` : Instance name of the ServiceNow entity.
# * `lastSyncAt` : Timestamp of the last sync in epoch milliseconds.
# * `serviceNowConnectionId` : Connection ID for the ServiceNow entity.
# * `tags` : List of tags to associate with the ServiceNow entity.

# %%
# | export
class IntegrationServicesUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "capability_settings",
        "enabled",
        "instance_name",
        "last_sync_at",
        "service_now_connection_id",
        "tags",
    )
    capability_settings = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(IntegrationServicesCapabilitySettingsUpdateInput)
        ),
        graphql_name="capabilitySettings",
    )

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    instance_name = sgqlc.types.Field(String, graphql_name="instanceName")

    last_sync_at = sgqlc.types.Field(EpochMilliseconds, graphql_name="lastSyncAt")

    service_now_connection_id = sgqlc.types.Field(
        String, graphql_name="serviceNowConnectionId"
    )

    tags = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(IntegrationServicesTagInput)),
        graphql_name="tags",
    )

# %% [markdown]
# #### 585. `LogConfigurationsCreateDataPartitionRuleInput`

# %% [markdown]
# A new data partition rule.
#
#
# Available input fields:
#
#
#
# * `description` : The description of the data partition rule.
# * `enabled` : Whether or not this data partition rule is enabled.
# * `matchingCriteria` : The matching criteria of the data partition rule.
# * `nrql` : The NRQL to match events for this data partition rule. Logs matching this criteria will be routed to the specified data partition.
# * `retentionPolicy` : The retention policy of the data partition data.
# * `targetDataPartition` : The name of the data partition where logs will be allocated once the rule is enabled.

# %%
# | export
class LogConfigurationsCreateDataPartitionRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "enabled",
        "matching_criteria",
        "nrql",
        "retention_policy",
        "target_data_partition",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    matching_criteria = sgqlc.types.Field(
        "LogConfigurationsDataPartitionRuleMatchingCriteriaInput",
        graphql_name="matchingCriteria",
    )

    nrql = sgqlc.types.Field(Nrql, graphql_name="nrql")

    retention_policy = sgqlc.types.Field(
        sgqlc.types.non_null(LogConfigurationsDataPartitionRuleRetentionPolicyType),
        graphql_name="retentionPolicy",
    )

    target_data_partition = sgqlc.types.Field(
        sgqlc.types.non_null(LogConfigurationsLogDataPartitionName),
        graphql_name="targetDataPartition",
    )

# %% [markdown]
# #### 586. `LogConfigurationsCreateObfuscationActionInput`

# %% [markdown]
# Input for creating an obfuscation action on a rule being created.
#
#
# Available input fields:
#
#
#
# * `attributes` : Attribute names for action. An empty list applies the action to all the attributes.
# * `expressionId` : Expression Id for action.
# * `method` : Obfuscation method to use.

# %%
# | export
class LogConfigurationsCreateObfuscationActionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attributes", "expression_id", "method")
    attributes = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="attributes",
    )

    expression_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="expressionId"
    )

    method = sgqlc.types.Field(
        sgqlc.types.non_null(LogConfigurationsObfuscationMethod), graphql_name="method"
    )

# %% [markdown]
# #### 587. `LogConfigurationsCreateObfuscationExpressionInput`

# %% [markdown]
# Input for creating an obfuscation expression.
#
#
# Available input fields:
#
#
#
# * `description` : Description of expression.
# * `name` : Name of expression.
# * `regex` : Regex of expression.

# %%
# | export
class LogConfigurationsCreateObfuscationExpressionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "regex")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    regex = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="regex")

# %% [markdown]
# #### 588. `LogConfigurationsCreateObfuscationRuleInput`

# %% [markdown]
# Input for creating an obfuscation rule.
#
#
# Available input fields:
#
#
#
# * `actions` : Actions for the rule. The actions will be applied in the order specified by this list.
# * `description` : Description of rule.
# * `enabled` : Whether the rule should be applied or not to incoming data.
# * `filter` : NRQL for determining whether a given log record should have obfuscation actions applied.
# * `name` : Name of rule.

# %%
# | export
class LogConfigurationsCreateObfuscationRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("actions", "description", "enabled", "filter", "name")
    actions = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(LogConfigurationsCreateObfuscationActionInput)
            )
        ),
        graphql_name="actions",
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    filter = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="filter")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 589. `LogConfigurationsDataPartitionRuleMatchingCriteriaInput`

# %% [markdown]
# The data partition rule matching criteria.
#
#
# Available input fields:
#
#
#
# * `attributeName` : The attribute name against which this matching condition will be evaluated.
# * `matchingExpression` : The matching expression of the data partition rule definition.
# * `matchingMethod` : The matching method of the data partition rule definition.

# %%
# | export
class LogConfigurationsDataPartitionRuleMatchingCriteriaInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute_name", "matching_expression", "matching_method")
    attribute_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="attributeName"
    )

    matching_expression = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="matchingExpression"
    )

    matching_method = sgqlc.types.Field(
        sgqlc.types.non_null(LogConfigurationsDataPartitionRuleMatchingOperator),
        graphql_name="matchingMethod",
    )

# %% [markdown]
# #### 590. `LogConfigurationsParsingRuleConfiguration`

# %% [markdown]
# A new parsing rule.
#
#
# Available input fields:
#
#
#
# * `attribute` : The parsing rule will apply to value of this attribute. If field is not provided, value will default to message.
# * `description` : A description of what this parsing rule represents.
# * `enabled` : Whether or not this rule is enabled.
# * `grok` : The Grok of what to parse.
# * `lucene` : The Lucene to match events to the parsing rule.
# * `nrql` : The NRQL to match events to the parsing rule.
# * `source` : Source of the parsing rule. Defaults to WRITE_YOUR_OWN.

# %%
# | export
class LogConfigurationsParsingRuleConfiguration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "attribute",
        "description",
        "enabled",
        "grok",
        "lucene",
        "nrql",
        "source",
    )
    attribute = sgqlc.types.Field(String, graphql_name="attribute")

    description = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="description"
    )

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    grok = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="grok")

    lucene = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="lucene")

    nrql = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="nrql")

    source = sgqlc.types.Field(
        LogConfigurationsParsingRuleSource, graphql_name="source"
    )

# %% [markdown]
# #### 591. `LogConfigurationsPipelineConfigurationInput`

# %% [markdown]
# The pipeline configuration for an account.
#
#
# Available input fields:
#
#
#
# * `accountLevelNativeJsonEnabled` : Whether or not account-level native JSON is enabled."
# * `enrichmentDisabled` : Whether or not enrichment is disabled.
# * `jsonParsingDisabled` : Whether or not JSON parsing is disabled.
# * `obfuscationDisabled` : Whether or not obfuscation is disabled.
# * `parsingDisabled` : Whether or not parsing is disabled.
# * `patternsEnabled` : Whether or not patterns are enabled.
# * `pluginAttributesCleanupEnabled` : Whether or not plugin.* attributes should be dropped.
# * `recursiveJsonParsingDisabled` : Whether or not recursive JSON parsing is disabled.
# * `transformationDisabled` : Whether or not transformation is disabled.

# %%
# | export
class LogConfigurationsPipelineConfigurationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "account_level_native_json_enabled",
        "enrichment_disabled",
        "json_parsing_disabled",
        "obfuscation_disabled",
        "parsing_disabled",
        "patterns_enabled",
        "plugin_attributes_cleanup_enabled",
        "recursive_json_parsing_disabled",
        "transformation_disabled",
    )
    account_level_native_json_enabled = sgqlc.types.Field(
        Boolean, graphql_name="accountLevelNativeJsonEnabled"
    )

    enrichment_disabled = sgqlc.types.Field(Boolean, graphql_name="enrichmentDisabled")

    json_parsing_disabled = sgqlc.types.Field(
        Boolean, graphql_name="jsonParsingDisabled"
    )

    obfuscation_disabled = sgqlc.types.Field(
        Boolean, graphql_name="obfuscationDisabled"
    )

    parsing_disabled = sgqlc.types.Field(Boolean, graphql_name="parsingDisabled")

    patterns_enabled = sgqlc.types.Field(Boolean, graphql_name="patternsEnabled")

    plugin_attributes_cleanup_enabled = sgqlc.types.Field(
        Boolean, graphql_name="pluginAttributesCleanupEnabled"
    )

    recursive_json_parsing_disabled = sgqlc.types.Field(
        Boolean, graphql_name="recursiveJsonParsingDisabled"
    )

    transformation_disabled = sgqlc.types.Field(
        Boolean, graphql_name="transformationDisabled"
    )

# %% [markdown]
# #### 592. `LogConfigurationsUpdateDataPartitionRuleInput`

# %% [markdown]
# An object for updating an existing data partition rule.
#
#
# Available input fields:
#
#
#
# * `description` : The description of the data partition rule.
# * `enabled` : Whether or not this data partition rule is enabled.
# * `id` : Unique data partition rule identifier.
# * `matchingCriteria` : The criteria of the data partition rule.
# * `nrql` : The NRQL to match events for this data partition rule. Logs matching this criteria will be routed to the specified data partition.

# %%
# | export
class LogConfigurationsUpdateDataPartitionRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "enabled", "id", "matching_criteria", "nrql")
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    matching_criteria = sgqlc.types.Field(
        LogConfigurationsDataPartitionRuleMatchingCriteriaInput,
        graphql_name="matchingCriteria",
    )

    nrql = sgqlc.types.Field(Nrql, graphql_name="nrql")

# %% [markdown]
# #### 593. `LogConfigurationsUpdateObfuscationActionInput`

# %% [markdown]
# Input for creating an obfuscation action on a rule being updated.
#
#
# Available input fields:
#
#
#
# * `attributes` : Attribute names for action. An empty list applies the action to all the attributes.
# * `expressionId` : Expression Id for action.
# * `method` : Obfuscation method to use.

# %%
# | export
class LogConfigurationsUpdateObfuscationActionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attributes", "expression_id", "method")
    attributes = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="attributes",
    )

    expression_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="expressionId"
    )

    method = sgqlc.types.Field(
        sgqlc.types.non_null(LogConfigurationsObfuscationMethod), graphql_name="method"
    )

# %% [markdown]
# #### 594. `LogConfigurationsUpdateObfuscationExpressionInput`

# %% [markdown]
# Input for updating an obfuscation expression.
# Null fields are left untouched by mutation.
#
#
# Available input fields:
#
#
#
# * `description` : Description of expression.
# * `id` : Expression Id.
# * `name` : Name of expression.
# * `regex` : Regex of expression.

# %%
# | export
class LogConfigurationsUpdateObfuscationExpressionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "id", "name", "regex")
    description = sgqlc.types.Field(String, graphql_name="description")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    name = sgqlc.types.Field(String, graphql_name="name")

    regex = sgqlc.types.Field(String, graphql_name="regex")

# %% [markdown]
# #### 595. `LogConfigurationsUpdateObfuscationRuleInput`

# %% [markdown]
# Input for updating an obfuscation rule.
# Null fields are left untouched by mutation.
#
#
# Available input fields:
#
#
#
# * `actions` : Actions for the rule. When non-null, this list of actions is used to replace
# the existing list of actions of the rule. The actions will be applied in the
# order specified by this list.
# * `description` : Description of rule.
# * `enabled` : Whether the rule should be applied or not to incoming data.
# * `filter` : NRQL for determining whether a given log record should have obfuscation actions applied.
# * `id` : Rule Id.
# * `name` : Name of rule.

# %%
# | export
class LogConfigurationsUpdateObfuscationRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("actions", "description", "enabled", "filter", "id", "name")
    actions = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(LogConfigurationsUpdateObfuscationActionInput)
        ),
        graphql_name="actions",
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(Boolean, graphql_name="enabled")

    filter = sgqlc.types.Field(Nrql, graphql_name="filter")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 596. `MachineLearningAddDocumentIndexConfiguration`

# %% [markdown]
# Configuration settings for adding a document index.
#
#
# Available input fields:
#
#
#
# * `characterTextSplitterOptions` : Configuration options for character-based text splitting.
# * `chunkOverlap` : Chunking overlap to use
# * `chunkSize` : Size of the chunks to be split from the document.
# * `markdownTextSplitterOptions` : Configuration options for markdown-based text splitting.
# * `textSplitterType` : Type of text splitter to be used (Character, Markdown, Token).
# * `tokenTextSplitterOptions` : Configuration options for token-based text splitting.

# %%
# | export
class MachineLearningAddDocumentIndexConfiguration(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "character_text_splitter_options",
        "chunk_overlap",
        "chunk_size",
        "markdown_text_splitter_options",
        "text_splitter_type",
        "token_text_splitter_options",
    )
    character_text_splitter_options = sgqlc.types.Field(
        "MachineLearningCharacterTextSplitterOptionsInput",
        graphql_name="characterTextSplitterOptions",
    )

    chunk_overlap = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="chunkOverlap"
    )

    chunk_size = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="chunkSize")

    markdown_text_splitter_options = sgqlc.types.Field(
        "MachineLearningMarkdownTextSplitterOptionsInput",
        graphql_name="markdownTextSplitterOptions",
    )

    text_splitter_type = sgqlc.types.Field(
        MachineLearningTextSplitterType, graphql_name="textSplitterType"
    )

    token_text_splitter_options = sgqlc.types.Field(
        "MachineLearningTokenTextSplitterOptionsInput",
        graphql_name="tokenTextSplitterOptions",
    )

# %% [markdown]
# #### 597. `MachineLearningCharacterTextSplitterOptionsInput`

# %% [markdown]
# Options for character-based text splitting.
#
#
# Available input fields:
#
#
#
# * `isSeparatorRegex` : Is the separator a regex
# * `separator` : Character to split text on

# %%
# | export
class MachineLearningCharacterTextSplitterOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("is_separator_regex", "separator")
    is_separator_regex = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="isSeparatorRegex"
    )

    separator = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="separator"
    )

# %% [markdown]
# #### 598. `MachineLearningFilterBy`

# %% [markdown]
# Options to filter query data
#
#
# Available input fields:
#
#
#
# * `key` : Allowed filter keys
# * `operator` : Operator to use
# * `value` : Value to filter by

# %%
# | export
class MachineLearningFilterBy(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "operator", "value")
    key = sgqlc.types.Field(
        sgqlc.types.non_null(MachineLearningFilterByKeys), graphql_name="key"
    )

    operator = sgqlc.types.Field(
        sgqlc.types.non_null(MachineLearningOperator), graphql_name="operator"
    )

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 599. `MachineLearningIndexOptions`

# %% [markdown]
# Options to manually index tool
#
#
# Available input fields:
#
#
#
# * `indexAll` : Should index from beginning of time
# * `knowledgeCategory` : Knowledge category to apply to new indexes

# %%
# | export
class MachineLearningIndexOptions(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("index_all", "knowledge_category")
    index_all = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="indexAll"
    )

    knowledge_category = sgqlc.types.Field(String, graphql_name="knowledgeCategory")

# %% [markdown]
# #### 600. `MachineLearningMarkdownTextSplitterOptionsInput`

# %% [markdown]
# Options for markdown-based text splitting.
#
#
# Available input fields:
#
#
#
# * `headersToSplitOn` : Headers to split text on
# * `returnEachLine` : Whether splitter should return each line

# %%
# | export
class MachineLearningMarkdownTextSplitterOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("headers_to_split_on", "return_each_line")
    headers_to_split_on = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)),
        graphql_name="headersToSplitOn",
    )

    return_each_line = sgqlc.types.Field(
        sgqlc.types.non_null(Boolean), graphql_name="returnEachLine"
    )

# %% [markdown]
# #### 601. `MachineLearningTokenTextSplitterOptionsInput`

# %% [markdown]
# Options for token-based text splitting.
#
#
# Available input fields:
#
#
#
# * `encodingName` : Specifies the encoding to be used for token splitting.

# %%
# | export
class MachineLearningTokenTextSplitterOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("encoding_name",)
    encoding_name = sgqlc.types.Field(
        sgqlc.types.non_null(MachineLearningEncodingName), graphql_name="encodingName"
    )

# %% [markdown]
# #### 602. `MetricNormalizationCreateRuleInput`

# %% [markdown]
# Input object used to represent the rule to be created
#
#
# Available input fields:
#
#
#
# * `action` : Customer rule action.
# * `applicationGuid` : Application GUID
# * `enabled` : Is rule enabled?
# * `evalOrder` : Rule evaluation order
# * `matchExpression` : Metric Match Expression.
# * `notes` : Notes.
# * `replacement` : Metric Replacement Expression.
# * `terminateChain` : Whether it terminates the evaluation chain or not

# %%
# | export
class MetricNormalizationCreateRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "action",
        "application_guid",
        "enabled",
        "eval_order",
        "match_expression",
        "notes",
        "replacement",
        "terminate_chain",
    )
    action = sgqlc.types.Field(
        sgqlc.types.non_null(MetricNormalizationCustomerRuleAction),
        graphql_name="action",
    )

    application_guid = sgqlc.types.Field(EntityGuid, graphql_name="applicationGuid")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    eval_order = sgqlc.types.Field(Int, graphql_name="evalOrder")

    match_expression = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="matchExpression"
    )

    notes = sgqlc.types.Field(String, graphql_name="notes")

    replacement = sgqlc.types.Field(String, graphql_name="replacement")

    terminate_chain = sgqlc.types.Field(Boolean, graphql_name="terminateChain")

# %% [markdown]
# #### 603. `MetricNormalizationEditRuleInput`

# %% [markdown]
# Input object used to represent the rule to be created
#
#
# Available input fields:
#
#
#
# * `action` : Rule action.
# * `enabled` : Is rule enabled?
# * `evalOrder` : Rule evaluation order
# * `id` : Rule Id.
# * `matchExpression` : Metric Match Expression.
# * `notes` : Notes.
# * `replacement` : Metric Replacement Expression.
# * `terminateChain` : Whether it terminates the evaluation chain or not

# %%
# | export
class MetricNormalizationEditRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "action",
        "enabled",
        "eval_order",
        "id",
        "match_expression",
        "notes",
        "replacement",
        "terminate_chain",
    )
    action = sgqlc.types.Field(
        sgqlc.types.non_null(MetricNormalizationCustomerRuleAction),
        graphql_name="action",
    )

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    eval_order = sgqlc.types.Field(Int, graphql_name="evalOrder")

    id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="id")

    match_expression = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="matchExpression"
    )

    notes = sgqlc.types.Field(String, graphql_name="notes")

    replacement = sgqlc.types.Field(String, graphql_name="replacement")

    terminate_chain = sgqlc.types.Field(Boolean, graphql_name="terminateChain")

# %% [markdown]
# #### 604. `MultiTenantAuthorizationGrantAuthenticationDomainIdInputFilter`

# %% [markdown]
# Filters grants by authentication domain id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGrantAuthenticationDomainIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 605. `MultiTenantAuthorizationGrantDataAccessPolicyIdInputFilter`

# %% [markdown]
# Filters grants by data access policy id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGrantDataAccessPolicyIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(sgqlc.types.list_of(ID), graphql_name="in")

# %% [markdown]
# #### 606. `MultiTenantAuthorizationGrantFilterInputExpression`

# %% [markdown]
# Provides all the available filters on a grant
#
#
# Available input fields:
#
#
#
# * `authenticationDomainId` : The authentication domain id of the grant
# * `dataAccessPolicyId` : The data access policy id of the grant
# * `grantee` : The the Grantee for the grant. This is used to filter grants by the details of the Grantee.
# * `groupId` : The group id of the grant
# * `id` : The id of the grant
# * `organizationId` : The organization id the grant belongs to
# * `roleId` : The role id of the grant
# * `scopeId` : the scope id of the grant
# * `scopeType` : The scope type of the grant
# * `scopeV2Type` : The v2 scope type of the grant

# %%
# | export
class MultiTenantAuthorizationGrantFilterInputExpression(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "authentication_domain_id",
        "data_access_policy_id",
        "grantee",
        "group_id",
        "id",
        "organization_id",
        "role_id",
        "scope_id",
        "scope_type",
        "scope_v2_type",
    )
    authentication_domain_id = sgqlc.types.Field(
        MultiTenantAuthorizationGrantAuthenticationDomainIdInputFilter,
        graphql_name="authenticationDomainId",
    )

    data_access_policy_id = sgqlc.types.Field(
        MultiTenantAuthorizationGrantDataAccessPolicyIdInputFilter,
        graphql_name="dataAccessPolicyId",
    )

    grantee = sgqlc.types.Field(
        "MultiTenantAuthorizationGranteeInputFilter", graphql_name="grantee"
    )

    group_id = sgqlc.types.Field(
        "MultiTenantAuthorizationGrantGroupIdInputFilter", graphql_name="groupId"
    )

    id = sgqlc.types.Field(
        "MultiTenantAuthorizationGrantIdInputFilter", graphql_name="id"
    )

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("MultiTenantAuthorizationGrantOrganizationIdInputFilter"),
        graphql_name="organizationId",
    )

    role_id = sgqlc.types.Field(
        "MultiTenantAuthorizationGrantRoleIdInputFilter", graphql_name="roleId"
    )

    scope_id = sgqlc.types.Field(
        "MultiTenantAuthorizationGrantScopeIdInputFilter", graphql_name="scopeId"
    )

    scope_type = sgqlc.types.Field(
        "MultiTenantAuthorizationGrantScopeTypeInputFilter", graphql_name="scopeType"
    )

    scope_v2_type = sgqlc.types.Field(
        "MultiTenantAuthorizationGrantScopeTypeV2InputFilter",
        graphql_name="scopeV2Type",
    )

# %% [markdown]
# #### 607. `MultiTenantAuthorizationGrantGroupIdInputFilter`

# %% [markdown]
# Filters on grants group id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGrantGroupIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 608. `MultiTenantAuthorizationGrantIdInputFilter`

# %% [markdown]
# Fitlers on grants id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation

# %%
# | export
class MultiTenantAuthorizationGrantIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(Int, graphql_name="eq")

# %% [markdown]
# #### 609. `MultiTenantAuthorizationGrantOrganizationIdInputFilter`

# %% [markdown]
# Filters on the grants organization id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation

# %%
# | export
class MultiTenantAuthorizationGrantOrganizationIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 610. `MultiTenantAuthorizationGrantRoleIdInputFilter`

# %% [markdown]
# Filters on the grants role id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGrantRoleIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(Int, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Int)), graphql_name="in"
    )

# %% [markdown]
# #### 611. `MultiTenantAuthorizationGrantScopeIdInputFilter`

# %% [markdown]
# Filters on the grants scope id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGrantScopeIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(String, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="in"
    )

# %% [markdown]
# #### 612. `MultiTenantAuthorizationGrantScopeTypeInputFilter`

# %% [markdown]
# Filters on the grants scope type
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation

# %%
# | export
class MultiTenantAuthorizationGrantScopeTypeInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(MultiTenantAuthorizationGrantScopeEnum, graphql_name="eq")

# %% [markdown]
# #### 613. `MultiTenantAuthorizationGrantScopeTypeV2InputFilter`

# %% [markdown]
# Filters on the grants v2 scope type
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation

# %%
# | export
class MultiTenantAuthorizationGrantScopeTypeV2InputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 614. `MultiTenantAuthorizationGrantSortInput`

# %% [markdown]
# Provides the sorting options for grants
#
#
# Available input fields:
#
#
#
# * `direction` : The direction which the field should be sorted
# * `key` : The field to be sorted

# %%
# | export
class MultiTenantAuthorizationGrantSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        MultiTenantAuthorizationSortDirectionEnum, graphql_name="direction"
    )

    key = sgqlc.types.Field(
        sgqlc.types.non_null(MultiTenantAuthorizationGrantSortEnum), graphql_name="key"
    )

# %% [markdown]
# #### 615. `MultiTenantAuthorizationGranteeIdInputFilter`

# %% [markdown]
# Filters on the grants scope id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGranteeIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 616. `MultiTenantAuthorizationGranteeInputFilter`

# %% [markdown]
# Filters on the grantee
#
#
# Available input fields:
#
#
#
# * `granteeId` : Filters on the grantee id
# * `granteeType` : Filters on the grantee type

# %%
# | export
class MultiTenantAuthorizationGranteeInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("grantee_id", "grantee_type")
    grantee_id = sgqlc.types.Field(
        MultiTenantAuthorizationGranteeIdInputFilter, graphql_name="granteeId"
    )

    grantee_type = sgqlc.types.Field(
        "MultiTenantAuthorizationGranteeTypeInputFilter", graphql_name="granteeType"
    )

# %% [markdown]
# #### 617. `MultiTenantAuthorizationGranteeTypeInputFilter`

# %% [markdown]
# Filters on the grants scope id
#
#
# Available input fields:
#
#
#
# * `eq` : Performs an equals operation
# * `in` : Performs an in operation

# %%
# | export
class MultiTenantAuthorizationGranteeTypeInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(MultiTenantAuthorizationGranteeTypeEnum, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(MultiTenantAuthorizationGranteeTypeEnum)
        ),
        graphql_name="in",
    )

# %% [markdown]
# #### 618. `MultiTenantAuthorizationPermissionFilter`

# %% [markdown]
# Provides all the available filters on permissions
#
#
# Available input fields:
#
#
#
# * `roleId` : Filter permissions by role id
# * `scope` : Filter permissions by scope

# %%
# | export
class MultiTenantAuthorizationPermissionFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("role_id", "scope")
    role_id = sgqlc.types.Field(
        "MultiTenantAuthorizationPermissionFilterRoleIdInput", graphql_name="roleId"
    )

    scope = sgqlc.types.Field(
        "MultiTenantAuthorizationPermissionFilterScopeInput", graphql_name="scope"
    )

# %% [markdown]
# #### 619. `MultiTenantAuthorizationPermissionFilterRoleIdInput`

# %% [markdown]
# Filter permissions by role id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationPermissionFilterRoleIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 620. `MultiTenantAuthorizationPermissionFilterScopeInput`

# %% [markdown]
# Filter permissions by scope
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationPermissionFilterScopeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 621. `MultiTenantAuthorizationRoleFilterInputExpression`

# %% [markdown]
# Provides all the available filters on a role
#
#
# Available input fields:
#
#
#
# * `groupId` : The group id the role has been granted to
# * `id` : The id of the role
# * `name` : The name of the role
# * `organizationId` : The organization id the role belongs to
# * `scope` : The scope of the role
# * `scopeV2` : The scope of the role
# * `type` : The type of the role

# %%
# | export
class MultiTenantAuthorizationRoleFilterInputExpression(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "group_id",
        "id",
        "name",
        "organization_id",
        "scope",
        "scope_v2",
        "type",
    )
    group_id = sgqlc.types.Field(
        "MultiTenantAuthorizationRoleGroupIdInputFilter", graphql_name="groupId"
    )

    id = sgqlc.types.Field(
        "MultiTenantAuthorizationRoleIdInputFilter", graphql_name="id"
    )

    name = sgqlc.types.Field(
        "MultiTenantAuthorizationRoleNameInputFilter", graphql_name="name"
    )

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("MultiTenantAuthorizationRoleOrganizationIdInputFilter"),
        graphql_name="organizationId",
    )

    scope = sgqlc.types.Field(
        "MultiTenantAuthorizationRoleScopeInputFilter", graphql_name="scope"
    )

    scope_v2 = sgqlc.types.Field(
        "MultiTenantAuthorizationRoleScopeV2InputFilter", graphql_name="scopeV2"
    )

    type = sgqlc.types.Field(
        "MultiTenantAuthorizationRoleTypeInputFilter", graphql_name="type"
    )

# %% [markdown]
# #### 622. `MultiTenantAuthorizationRoleGroupIdInputFilter`

# %% [markdown]
# Provides all the available filters on the group id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation
# * `in` : A list of group IDs

# %%
# | export
class MultiTenantAuthorizationRoleGroupIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 623. `MultiTenantAuthorizationRoleIdInputFilter`

# %% [markdown]
# Provides all the available filters on the role id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationRoleIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(Int, graphql_name="eq")

# %% [markdown]
# #### 624. `MultiTenantAuthorizationRoleNameInputFilter`

# %% [markdown]
# Provides all the available filters on the role name
#
#
# Available input fields:
#
#
#
# * `contains` : performs a contains operation
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationRoleNameInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 625. `MultiTenantAuthorizationRoleOrganizationIdInputFilter`

# %% [markdown]
# Provides all the available filters on the organization id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationRoleOrganizationIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 626. `MultiTenantAuthorizationRoleScopeInputFilter`

# %% [markdown]
# Provides all the available filters on the role scope
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationRoleScopeInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(MultiTenantAuthorizationRoleScopeEnum, graphql_name="eq")

# %% [markdown]
# #### 627. `MultiTenantAuthorizationRoleScopeV2InputFilter`

# %% [markdown]
# Provides all the available filters on the role scope
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationRoleScopeV2InputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 628. `MultiTenantAuthorizationRoleSortInput`

# %% [markdown]
# Provides the field and direction the result should be sorted
#
#
# Available input fields:
#
#
#
# * `direction` : The direction the field should be sorted
# * `key` : The field which should be sorted

# %%
# | export
class MultiTenantAuthorizationRoleSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        MultiTenantAuthorizationSortDirectionEnum, graphql_name="direction"
    )

    key = sgqlc.types.Field(
        sgqlc.types.non_null(MultiTenantAuthorizationRoleSortEnum), graphql_name="key"
    )

# %% [markdown]
# #### 629. `MultiTenantAuthorizationRoleTypeInputFilter`

# %% [markdown]
# Provides all the available filters on the role type
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class MultiTenantAuthorizationRoleTypeInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(MultiTenantAuthorizationRoleTypeEnum, graphql_name="eq")

# %% [markdown]
# #### 630. `MultiTenantIdentityAllowsCapabilityInput`

# %% [markdown]
# The input object representing parameters for the allowed capability filter
#
#
# Available input fields:
#
#
#
# * `in` : A list of capabilities. If set, groups with atleast one of the given capabilities granted on them for the user will be returned. Otherwise, only groups with read access granted are returned.

# %%
# | export
class MultiTenantIdentityAllowsCapabilityInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("in_",)
    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(MultiTenantIdentityCapability)),
        graphql_name="in",
    )

# %% [markdown]
# #### 631. `MultiTenantIdentityAuthenticationDomainIdInput`

# %% [markdown]
# The input object representing parameters for the authentication domain ID filter
#
#
# Available input fields:
#
#
#
# * `eq` : An authentication domain ID

# %%
# | export
class MultiTenantIdentityAuthenticationDomainIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 632. `MultiTenantIdentityEmailVerificationStateInput`

# %% [markdown]
# Available filtering types for email verification states
#
#
# Available input fields:
#
#
#
# * `pending` : An email verification state

# %%
# | export
class MultiTenantIdentityEmailVerificationStateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("pending",)
    pending = sgqlc.types.Field(Boolean, graphql_name="pending")

# %% [markdown]
# #### 633. `MultiTenantIdentityGroupFilterInput`

# %% [markdown]
# The input object representing the filter parameters for groups
#
#
# Available input fields:
#
#
#
# * `allowsCapability` : Filter groups by capabilities
# * `authenticationDomainId` : Filter groups by authentication domain
# * `id` : Filter groups by ID
# * `members` : Filter groups that contain specific members
# * `name` : Filter groups by display name
# * `organizationId` : An organization ID to filter groups by

# %%
# | export
class MultiTenantIdentityGroupFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "allows_capability",
        "authentication_domain_id",
        "id",
        "members",
        "name",
        "organization_id",
    )
    allows_capability = sgqlc.types.Field(
        MultiTenantIdentityAllowsCapabilityInput, graphql_name="allowsCapability"
    )

    authentication_domain_id = sgqlc.types.Field(
        MultiTenantIdentityAuthenticationDomainIdInput,
        graphql_name="authenticationDomainId",
    )

    id = sgqlc.types.Field("MultiTenantIdentityGroupIdInput", graphql_name="id")

    members = sgqlc.types.Field(
        "MultiTenantIdentityGroupMemberIdInput", graphql_name="members"
    )

    name = sgqlc.types.Field("MultiTenantIdentityGroupNameInput", graphql_name="name")

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("MultiTenantIdentityOrganizationIdInput"),
        graphql_name="organizationId",
    )

# %% [markdown]
# #### 634. `MultiTenantIdentityGroupIdInput`

# %% [markdown]
# The input object representing parameters for the ID input filter
#
#
# Available input fields:
#
#
#
# * `eq` : A group ID

# %%
# | export
class MultiTenantIdentityGroupIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 635. `MultiTenantIdentityGroupMemberIdInput`

# %% [markdown]
# The input object representing parameters for the Members filter
#
#
# Available input fields:
#
#
#
# * `contains` : A list of user IDs. A group will be returned if all listed users are members.
# * `excludes` : A list of user IDS. A group will be returned if no listed users are members.

# %%
# | export
class MultiTenantIdentityGroupMemberIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "excludes")
    contains = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="contains"
    )

    excludes = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="excludes"
    )

# %% [markdown]
# #### 636. `MultiTenantIdentityGroupNameInput`

# %% [markdown]
# The input object representing parameters for the name filter
#
#
# Available input fields:
#
#
#
# * `contains` : Part of a group name
# * `eq` : A group name

# %%
# | export
class MultiTenantIdentityGroupNameInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 637. `MultiTenantIdentityGroupSortInput`

# %% [markdown]
# The input object representing the sort parameters for groups
#
#
# Available input fields:
#
#
#
# * `direction` : Order by which to sort groups
# * `key` : Group attribute to sort on

# %%
# | export
class MultiTenantIdentityGroupSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        MultiTenantIdentitySortDirection, graphql_name="direction"
    )

    key = sgqlc.types.Field(MultiTenantIdentitySortKeyEnum, graphql_name="key")

# %% [markdown]
# #### 638. `MultiTenantIdentityGroupUserFilterInput`

# %% [markdown]
# The input object representing the filter parameters for user groups
#
#
# Available input fields:
#
#
#
# * `id` : Filter users by IDs

# %%
# | export
class MultiTenantIdentityGroupUserFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field("MultiTenantIdentityUserIdInput", graphql_name="id")

# %% [markdown]
# #### 639. `MultiTenantIdentityOrganizationIdInput`

# %% [markdown]
# The input object representing parameters for the organization ID filter
#
#
# Available input fields:
#
#
#
# * `eq` : An organization ID

# %%
# | export
class MultiTenantIdentityOrganizationIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 640. `MultiTenantIdentityPendingUpgradeRequestInput`

# %% [markdown]
# Available filtering types for pending upgrade requests
#
#
# Available input fields:
#
#
#
# * `exists` : Whether a request exists or not

# %%
# | export
class MultiTenantIdentityPendingUpgradeRequestInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exists",)
    exists = sgqlc.types.Field(Boolean, graphql_name="exists")

# %% [markdown]
# #### 641. `MultiTenantIdentityUserEmailInput`

# %% [markdown]
# Filters by user email address
#
#
# Available input fields:
#
#
#
# * `contains` : Part of an email address
# * `eq` : An email address

# %%
# | export
class MultiTenantIdentityUserEmailInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 642. `MultiTenantIdentityUserFilterInput`

# %% [markdown]
# Filter users
#
#
# Available input fields:
#
#
#
# * `authenticationDomainId` : Filter users by authentication domain
# * `email` : Filter users by email address
# * `emailVerificationState` : Filter users by email verification state
# * `groupId` : Filter users by group id
# * `id` : Filter users by id
# * `name` : Filter users by name
# * `pendingUpgradeRequest` : Filter users by pending upgrade request

# %%
# | export
class MultiTenantIdentityUserFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "authentication_domain_id",
        "email",
        "email_verification_state",
        "group_id",
        "id",
        "name",
        "pending_upgrade_request",
    )
    authentication_domain_id = sgqlc.types.Field(
        sgqlc.types.non_null(MultiTenantIdentityAuthenticationDomainIdInput),
        graphql_name="authenticationDomainId",
    )

    email = sgqlc.types.Field(MultiTenantIdentityUserEmailInput, graphql_name="email")

    email_verification_state = sgqlc.types.Field(
        MultiTenantIdentityEmailVerificationStateInput,
        graphql_name="emailVerificationState",
    )

    group_id = sgqlc.types.Field(
        "MultiTenantIdentityUserGroupIdInput", graphql_name="groupId"
    )

    id = sgqlc.types.Field("MultiTenantIdentityUserIdInput", graphql_name="id")

    name = sgqlc.types.Field("MultiTenantIdentityUserNameInput", graphql_name="name")

    pending_upgrade_request = sgqlc.types.Field(
        MultiTenantIdentityPendingUpgradeRequestInput,
        graphql_name="pendingUpgradeRequest",
    )

# %% [markdown]
# #### 643. `MultiTenantIdentityUserGroupIdInput`

# %% [markdown]
# Filters by group id
#
#
# Available input fields:
#
#
#
# * `eq` : A group id
# * `in` : A list of group IDs
# * `not` : Filter users not in group

# %%
# | export
class MultiTenantIdentityUserGroupIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_", "not_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

    not_ = sgqlc.types.Field(
        "MultiTenantIdentityUserNotGroupIdInput", graphql_name="not"
    )

# %% [markdown]
# #### 644. `MultiTenantIdentityUserIdInput`

# %% [markdown]
# Filters by user id
#
#
# Available input fields:
#
#
#
# * `eq` : A user id
# * `in` : A list of user IDs

# %%
# | export
class MultiTenantIdentityUserIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 645. `MultiTenantIdentityUserNameInput`

# %% [markdown]
# Filters by user name
#
#
# Available input fields:
#
#
#
# * `contains` : Part of a user name
# * `eq` : A user name

# %%
# | export
class MultiTenantIdentityUserNameInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 646. `MultiTenantIdentityUserNotGroupIdInput`

# %% [markdown]
# Filters by group id
#
#
# Available input fields:
#
#
#
# * `eq` : A group id

# %%
# | export
class MultiTenantIdentityUserNotGroupIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 647. `MultiTenantIdentityUserSortInput`

# %% [markdown]
# Sort users
#
#
# Available input fields:
#
#
#
# * `direction` : Direction to sort in
# * `key` : User attribute to sort on

# %%
# | export
class MultiTenantIdentityUserSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        MultiTenantIdentitySortDirection, graphql_name="direction"
    )

    key = sgqlc.types.Field(MultiTenantIdentityUserSortKey, graphql_name="key")

# %% [markdown]
# #### 648. `NerdStorageScopeInput`

# %% [markdown]
# The data access level and ID for the selected scope.
#
#
# Available input fields:
#
#
#
# * `id` : The ID for the selected scope.
# * `name` : The NerdStorage data access level.

# %%
# | export
class NerdStorageScopeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    name = sgqlc.types.Field(
        sgqlc.types.non_null(NerdStorageScope), graphql_name="name"
    )

# %% [markdown]
# #### 649. `NerdStorageVaultScope`

# %% [markdown]
# The NerdStorageVault data access level.
#
#
# Available input fields:
#
#
#
# * `actor` : A NerdStorageVault data access level for the current user.

# %%
# | export
class NerdStorageVaultScope(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("actor",)
    actor = sgqlc.types.Field(NerdStorageVaultActorScope, graphql_name="actor")

# %% [markdown]
# #### 650. `NerdStorageVaultWriteSecretInput`

# %% [markdown]
# The data to be stored in NerdStorageVault.
#
#
# Available input fields:
#
#
#
# * `key` : The unique identifier of the secret.
# * `value` : The value of the secret.

# %%
# | export
class NerdStorageVaultWriteSecretInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="value")

# %% [markdown]
# #### 651. `NerdpackAllowListInput`

# %% [markdown]
# Input data for allow list handling.
#
#
# Available input fields:
#
#
#
# * `accountIds` : List of accounts that will be allow to subscribe. They must belong to the user's authorized account list.

# %%
# | export
class NerdpackAllowListInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids",)
    account_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(Int)), graphql_name="accountIds"
    )

# %% [markdown]
# #### 652. `NerdpackCreationInput`

# %% [markdown]
# Input data for creating a new nerdpack.
#
#
# Available input fields:
#
#
#
# * `ownerAccount` : Nerdpack owner account ID. If not provided it will use the account ID specified in the header.

# %%
# | export
class NerdpackCreationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("owner_account",)
    owner_account = sgqlc.types.Field(Int, graphql_name="ownerAccount")

# %% [markdown]
# #### 653. `NerdpackDataFilter`

# %% [markdown]
# Data to filter subscribable nerdpack list.
#
#
# Available input fields:
#
#
#
# * `accountId` : ID of the account to be subscribed.
# * `subscriptionModel` : Nerdpack subscription model to filter.
# * `tag` : Tag the account may subscribe to.

# %%
# | export
class NerdpackDataFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "subscription_model", "tag")
    account_id = sgqlc.types.Field(Int, graphql_name="accountId")

    subscription_model = sgqlc.types.Field(
        NerdpackSubscriptionModel, graphql_name="subscriptionModel"
    )

    tag = sgqlc.types.Field(NerdpackTagName, graphql_name="tag")

# %% [markdown]
# #### 654. `NerdpackOverrideVersionRules`

# %% [markdown]
# Attributes to match a specific nerdpack versions.
#
#
# Available input fields:
#
#
#
# * `nerdpackId` : Nerdpack uuid.
# * `tag` : Nerdpack version tag.
# * `version` : Semver-compliant Nerdpack version.

# %%
# | export
class NerdpackOverrideVersionRules(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("nerdpack_id", "tag", "version")
    nerdpack_id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="nerdpackId")

    tag = sgqlc.types.Field(NerdpackTagName, graphql_name="tag")

    version = sgqlc.types.Field(SemVer, graphql_name="version")

# %% [markdown]
# #### 655. `NerdpackRemoveVersionTagInput`

# %% [markdown]
# Input data that identifies nerdpack tag.
#
#
# Available input fields:
#
#
#
# * `tag` : Tag name.

# %%
# | export
class NerdpackRemoveVersionTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("tag",)
    tag = sgqlc.types.Field(NerdpackTagName, graphql_name="tag")

# %% [markdown]
# #### 656. `NerdpackSubscribeAccountsInput`

# %% [markdown]
# New subscriptions input.
#
#
# Available input fields:
#
#
#
# * `accountIds` : List of accounts to be subscribed.
# * `tag` : Tag of the Nerdpack version to be subscribed to.

# %%
# | export
class NerdpackSubscribeAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids", "tag")
    account_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accountIds",
    )

    tag = sgqlc.types.Field(sgqlc.types.non_null(NerdpackTagName), graphql_name="tag")

# %% [markdown]
# #### 657. `NerdpackTagVersionInput`

# %% [markdown]
# Input data for nerdpack version tagging.
#
#
# Available input fields:
#
#
#
# * `tag` : Tag to be added to the version.
# * `version` : Nerdpack version.

# %%
# | export
class NerdpackTagVersionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("tag", "version")
    tag = sgqlc.types.Field(NerdpackTagName, graphql_name="tag")

    version = sgqlc.types.Field(SemVer, graphql_name="version")

# %% [markdown]
# #### 658. `NerdpackUnsubscribeAccountsInput`

# %% [markdown]
# Data of accounts to be unsubscribed.
#
#
# Available input fields:
#
#
#
# * `accountIds` : List of accounts to be unsubscribed.

# %%
# | export
class NerdpackUnsubscribeAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids",)
    account_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accountIds",
    )

# %% [markdown]
# #### 659. `NerdpackVersionFilter`

# %% [markdown]
# Attributes to filter a list of nerdpack versions. Restrictions: 'tags' attribute cannot combined with other attributes.
#
#
# Available input fields:
#
#
#
# * `fallback` : Fallback version to return if no version matches the given filters. No version is returned by default.
# * `tag` : Get a version with the specified tag.
# * `tags` : Get the versions with a tag from the tag list.
# * `version` : Nerdpack version.

# %%
# | export
class NerdpackVersionFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("fallback", "tag", "tags", "version")
    fallback = sgqlc.types.Field(NerdpackVersionFilterFallback, graphql_name="fallback")

    tag = sgqlc.types.Field(NerdpackTagName, graphql_name="tag")

    tags = sgqlc.types.Field(sgqlc.types.list_of(NerdpackTagName), graphql_name="tags")

    version = sgqlc.types.Field(SemVer, graphql_name="version")

# %% [markdown]
# #### 660. `Nr1CatalogCommunityContactChannelInput`

# %% [markdown]
# Details about the contact channel where users can get support via the web
#
#
# Available input fields:
#
#
#
# * `url` : The URL linking to the website where users can get web support

# %%
# | export
class Nr1CatalogCommunityContactChannelInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("url",)
    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 661. `Nr1CatalogEmailContactChannelInput`

# %% [markdown]
# Details about the contact channel where users can get support via email
#
#
# Available input fields:
#
#
#
# * `address` : The email address where users can get email support

# %%
# | export
class Nr1CatalogEmailContactChannelInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("address",)
    address = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="address")

# %% [markdown]
# #### 662. `Nr1CatalogIssuesContactChannelInput`

# %% [markdown]
# Details about the contact channel where users can get support via the repository issues page
#
#
# Available input fields:
#
#
#
# * `url` : The URL linking the repository issues page where users can get support

# %%
# | export
class Nr1CatalogIssuesContactChannelInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("url",)
    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 663. `Nr1CatalogSearchFilter`

# %% [markdown]
# Criteria for applying filters to a search
#
#
# Available input fields:
#
#
#
# * `categories` : Filter the search results that match any in a list of category terms
# * `category` : Filter the search results by a particular category
# * `components` : Filter the search results that contain a set of component types
# * `keywords` : Filter the search results to those that match all keywords in the list
# * `recipeNames` : Filter the search results by install recipe name. This will be applied in an OR fashion. Schema is defined in the Open Install Library's recipe spec: https://github.com/newrelic/open-install-library/blob/main/docs/recipe-spec/recipe-spec.md#schema-definition.
# * `types` : Filter the search results that are of a specific type

# %%
# | export
class Nr1CatalogSearchFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "categories",
        "category",
        "components",
        "keywords",
        "recipe_names",
        "types",
    )
    categories = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="categories"
    )

    category = sgqlc.types.Field(String, graphql_name="category")

    components = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Nr1CatalogSearchComponentType)),
        graphql_name="components",
    )

    keywords = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="keywords"
    )

    recipe_names = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="recipeNames"
    )

    types = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(Nr1CatalogSearchResultType)),
        graphql_name="types",
    )

# %% [markdown]
# #### 664. `Nr1CatalogSubmitMetadataInput`

# %% [markdown]
# Metadata associated with the Nerdpack that will be available in the New Relic One Catalog
#
#
# Available input fields:
#
#
#
# * `additionalInfo` : Additional information relevant for the Nerdpack
# * `categoryTerms` : A list of terms for category grouping when filtering and searching the Nerdpack
# * `details` : A long form description used in the catalog to detail the functionality of the Nerdpack
# * `documentation` : Additional documentation relevant for the Nerdpack
# * `keywords` : A list of keywords for filtering and searching the Nerdpack
# * `repository` : A URL that links to the repository where the source code for this Nerdpack can be found
# * `support` : Support channels where users can contact you to get support for the Nerdpack
# * `tagline` : A tagline for the Nerdpack
# * `version` : The version of the Nerdpack that will be associated with this metadata
# * `whatsNew` : A description of changes describing what changed for this version of the Nerdpack

# %%
# | export
class Nr1CatalogSubmitMetadataInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "additional_info",
        "category_terms",
        "details",
        "documentation",
        "keywords",
        "repository",
        "support",
        "tagline",
        "version",
        "whats_new",
    )
    additional_info = sgqlc.types.Field(String, graphql_name="additionalInfo")

    category_terms = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="categoryTerms"
    )

    details = sgqlc.types.Field(String, graphql_name="details")

    documentation = sgqlc.types.Field(String, graphql_name="documentation")

    keywords = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="keywords"
    )

    repository = sgqlc.types.Field(String, graphql_name="repository")

    support = sgqlc.types.Field("Nr1CatalogSupportInput", graphql_name="support")

    tagline = sgqlc.types.Field(String, graphql_name="tagline")

    version = sgqlc.types.Field(sgqlc.types.non_null(SemVer), graphql_name="version")

    whats_new = sgqlc.types.Field(String, graphql_name="whatsNew")

# %% [markdown]
# #### 665. `Nr1CatalogSupportInput`

# %% [markdown]
# A container specifying the various types support channels
#
#
# Available input fields:
#
#
#
# * `community` : A support channel where users can get support via the community
# * `email` : A support channel where users can get support via email
# * `issues` : A support channel where users can get support via issues

# %%
# | export
class Nr1CatalogSupportInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("community", "email", "issues")
    community = sgqlc.types.Field(
        Nr1CatalogCommunityContactChannelInput, graphql_name="community"
    )

    email = sgqlc.types.Field(Nr1CatalogEmailContactChannelInput, graphql_name="email")

    issues = sgqlc.types.Field(
        Nr1CatalogIssuesContactChannelInput, graphql_name="issues"
    )

# %% [markdown]
# #### 666. `NrqlDropRulesCreateDropRuleInput`

# %% [markdown]
# Details needed to create a NRQL drop rule.
#
#
# Available input fields:
#
#
#
# * `action` : The type of drop rule you want. This changes the way your NRQL string is interpreted.
# * `description` : Additional information about the rule.
# * `nrql` : The NRQL string used to match data you want to take the specified action on.

# %%
# | export
class NrqlDropRulesCreateDropRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("action", "description", "nrql")
    action = sgqlc.types.Field(
        sgqlc.types.non_null(NrqlDropRulesAction), graphql_name="action"
    )

    description = sgqlc.types.Field(String, graphql_name="description")

    nrql = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="nrql")

# %% [markdown]
# #### 667. `NrqlQueryOptions`

# %% [markdown]
# Additional options for NRQL queries.
#
#
# Available input fields:
#
#
#
# * `eventNamespaces` : Limit the NRQL query to return results from the chosen Event Namespaces.
#
# You must supply at least 1 valid event namespace when using this option.
# Invalid event namespaces will be filtered out.
#
# If omitted, the default list will be `["Default"]`
#
# For more details about Event Namespaces, visit our [docs](https://docs.newrelic.com/docs/accounts/original-accounts-billing/original-product-based-pricing/introduction-new-relic-subscription-usage-data/#namespace).

# %%
# | export
class NrqlQueryOptions(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("event_namespaces",)
    event_namespaces = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)),
        graphql_name="eventNamespaces",
    )

# %% [markdown]
# #### 668. `OrganizationAccountFilterInput`

# %% [markdown]
# A filter for Accounts
#
#
# Available input fields:
#
#
#
# * `id` : Filter by account ID
# * `name` : Filter by Account Name
# * `organizationId` : Filter by organization ID
# * `sharingMode` : Filter by Sharing Mode
# * `status` : Filter by an account status. By default filters to active accounts.

# %%
# | export
class OrganizationAccountFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name", "organization_id", "sharing_mode", "status")
    id = sgqlc.types.Field("OrganizationAccountIdFilterInput", graphql_name="id")

    name = sgqlc.types.Field("OrganizationAccountNameFilterInput", graphql_name="name")

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("OrganizationAccountOrganizationIdFilterInput"),
        graphql_name="organizationId",
    )

    sharing_mode = sgqlc.types.Field(
        "OrganizationAccountSharingModeFilterInput", graphql_name="sharingMode"
    )

    status = sgqlc.types.Field(
        "OrganizationAccountStatusFilterInput", graphql_name="status"
    )

# %% [markdown]
# #### 669. `OrganizationAccountIdFilterInput`

# %% [markdown]
# A filter for an AccountID
#
#
# Available input fields:
#
#
#
# * `eq` : An Account ID

# %%
# | export
class OrganizationAccountIdFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(Int, graphql_name="eq")

# %% [markdown]
# #### 670. `OrganizationAccountIdInput`

# %% [markdown]
# Provides the operations available on the account id
#
#
# Available input fields:
#
#
#
# * `eq` : An account id

# %%
# | export
class OrganizationAccountIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="eq")

# %% [markdown]
# #### 671. `OrganizationAccountNameFilterInput`

# %% [markdown]
# A filter for Account name
#
#
# Available input fields:
#
#
#
# * `contains` : Search text for an account name

# %%
# | export
class OrganizationAccountNameFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains",)
    contains = sgqlc.types.Field(String, graphql_name="contains")

# %% [markdown]
# #### 672. `OrganizationAccountOrganizationIdFilterInput`

# %% [markdown]
# A filter for OrganizationID
#
#
# Available input fields:
#
#
#
# * `eq` : An Organization ID

# %%
# | export
class OrganizationAccountOrganizationIdFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 673. `OrganizationAccountShareFilterInput`

# %% [markdown]
# A filter for account shares
#
#
# Available input fields:
#
#
#
# * `accountId` : Filter by account id
# * `limitingDataAccessPolicyId` : Filter by limiting data access policy id
# * `targetId` : Filter by target id

# %%
# | export
class OrganizationAccountShareFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "limiting_data_access_policy_id", "target_id")
    account_id = sgqlc.types.Field(
        sgqlc.types.non_null(OrganizationAccountIdInput), graphql_name="accountId"
    )

    limiting_data_access_policy_id = sgqlc.types.Field(
        "OrganizationLimitingDataAccessPolicyIdInput",
        graphql_name="limitingDataAccessPolicyId",
    )

    target_id = sgqlc.types.Field("OrganizationTargetIdInput", graphql_name="targetId")

# %% [markdown]
# #### 674. `OrganizationAccountShareSortInput`

# %% [markdown]
# Sort key and direction for account shares
#
#
# Available input fields:
#
#
#
# * `direction` : Direction to sort in
# * `key` : Account share attribute to sort on

# %%
# | export
class OrganizationAccountShareSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        OrganizationAccountShareSortDirectionEnum, graphql_name="direction"
    )

    key = sgqlc.types.Field(OrganizationAccountShareSortKeyEnum, graphql_name="key")

# %% [markdown]
# #### 675. `OrganizationAccountSharingModeFilterInput`

# %% [markdown]
# A filter for Sharing Mode
#
#
# Available input fields:
#
#
#
# * `eq` : A Sharing Mode for the account.

# %%
# | export
class OrganizationAccountSharingModeFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(OrganizationSharingMode, graphql_name="eq")

# %% [markdown]
# #### 676. `OrganizationAccountSortInput`

# %% [markdown]
# Sort key and direction for accounts
#
#
# Available input fields:
#
#
#
# * `direction` : Direction to sort in
# * `key` : Account share attribute to sort on

# %%
# | export
class OrganizationAccountSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        OrganizationAccountSortDirectionEnum, graphql_name="direction"
    )

    key = sgqlc.types.Field(OrganizationAccountSortKeyEnum, graphql_name="key")

# %% [markdown]
# #### 677. `OrganizationAccountStatusFilterInput`

# %% [markdown]
# A filter for Account Status
#
#
# Available input fields:
#
#
#
# * `eq` : An account status

# %%
# | export
class OrganizationAccountStatusFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(OrganizationAccountStatus, graphql_name="eq")

# %% [markdown]
# #### 678. `OrganizationAuthenticationDomainFilterInput`

# %% [markdown]
# A filter for authentication domains
#
#
# Available input fields:
#
#
#
# * `id` : Filter authentication domains by id
# * `name` : Filter authentication domains by name
# * `organizationId` : Filter authentication domains by organization

# %%
# | export
class OrganizationAuthenticationDomainFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name", "organization_id")
    id = sgqlc.types.Field("OrganizationIdInput", graphql_name="id")

    name = sgqlc.types.Field("OrganizationNameInput", graphql_name="name")

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("OrganizationOrganizationIdInput"),
        graphql_name="organizationId",
    )

# %% [markdown]
# #### 679. `OrganizationAuthenticationDomainSortInput`

# %% [markdown]
# Sort key and direction for authentication domains
#
#
# Available input fields:
#
#
#
# * `direction` : Direction to sort in
# * `key` : Authentication domain attribute to sort on

# %%
# | export
class OrganizationAuthenticationDomainSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        OrganizationSortDirectionEnum, graphql_name="direction"
    )

    key = sgqlc.types.Field(OrganizationSortKeyEnum, graphql_name="key")

# %% [markdown]
# #### 680. `OrganizationContractCustomerIdInputFilter`

# %% [markdown]
# Provides all the available filters on the customer id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationContractCustomerIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 681. `OrganizationContractOrganizationIdInputFilter`

# %% [markdown]
# Provides all the available filters on the organization id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationContractOrganizationIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 682. `OrganizationCreateOrganizationInput`

# %% [markdown]
# Attributes belonging to the organization to create.
#
#
# Available input fields:
#
#
#
# * `name` : The name for the new organization.

# %%
# | export
class OrganizationCreateOrganizationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name",)
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 683. `OrganizationCreateSharedAccountInput`

# %% [markdown]
# Attributes for creating a shared account.
#
#
# Available input fields:
#
#
#
# * `accountId` : The id of the account to be shared
# * `limitingDataAccessPolicyId` : The id of the limiting data access policy
# * `limitingRoleId` : The id of the limiting role
# * `name` : The name of the shared account
# * `targetOrganizationId` : The id of the target organization

# %%
# | export
class OrganizationCreateSharedAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "account_id",
        "limiting_data_access_policy_id",
        "limiting_role_id",
        "name",
        "target_organization_id",
    )
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    limiting_data_access_policy_id = sgqlc.types.Field(
        ID, graphql_name="limitingDataAccessPolicyId"
    )

    limiting_role_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="limitingRoleId"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    target_organization_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="targetOrganizationId"
    )

# %% [markdown]
# #### 684. `OrganizationCustomerContractFilterInput`

# %% [markdown]
# A filter for customer contracts
#
#
# Available input fields:
#
#
#
# * `customerId` : The id of the customer
# * `organizationId` : The id of the organization

# %%
# | export
class OrganizationCustomerContractFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("customer_id", "organization_id")
    customer_id = sgqlc.types.Field(
        OrganizationContractCustomerIdInputFilter, graphql_name="customerId"
    )

    organization_id = sgqlc.types.Field(
        OrganizationContractOrganizationIdInputFilter, graphql_name="organizationId"
    )

# %% [markdown]
# #### 685. `OrganizationCustomerOrganizationFilterInput`

# %% [markdown]
# A filter for customer organizations
#
#
# Available input fields:
#
#
#
# * `accountId` : The id of the owned account
# * `authenticationDomainId` : The id of the authentication domain
# * `customerId` : The id of the customer
# * `id` : The id of the organization
# * `name` : The name of the organization

# %%
# | export
class OrganizationCustomerOrganizationFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "account_id",
        "authentication_domain_id",
        "customer_id",
        "id",
        "name",
    )
    account_id = sgqlc.types.Field(
        "OrganizationOrganizationAccountIdInputFilter", graphql_name="accountId"
    )

    authentication_domain_id = sgqlc.types.Field(
        "OrganizationOrganizationAuthenticationDomainIdInputFilter",
        graphql_name="authenticationDomainId",
    )

    customer_id = sgqlc.types.Field(
        "OrganizationOrganizationCustomerIdInputFilter", graphql_name="customerId"
    )

    id = sgqlc.types.Field("OrganizationOrganizationIdInputFilter", graphql_name="id")

    name = sgqlc.types.Field(
        "OrganizationOrganizationNameInputFilter", graphql_name="name"
    )

# %% [markdown]
# #### 686. `OrganizationIdInput`

# %% [markdown]
# Provides the operations available on the id
#
#
# Available input fields:
#
#
#
# * `eq` : An authentication domain id

# %%
# | export
class OrganizationIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 687. `OrganizationLimitingDataAccessPolicyIdInput`

# %% [markdown]
# Provides the operations available on the limiting data access policy id
#
#
# Available input fields:
#
#
#
# * `eq` : A data access policy id

# %%
# | export
class OrganizationLimitingDataAccessPolicyIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 688. `OrganizationMembersOrganizationMemberAuthenticationDomainIdFilter`

# %% [markdown]
# Filter for Organization Members Authentication Domain Id
#
#
# Available input fields:
#
#
#
# * `eq` : An Authentication Domain Id

# %%
# | export
class OrganizationMembersOrganizationMemberAuthenticationDomainIdFilter(
    sgqlc.types.Input
):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 689. `OrganizationMembersOrganizationMemberFilter`

# %% [markdown]
# Filter for Organization Members
#
#
# Available input fields:
#
#
#
# * `authenticationDomainId` : Authentication Domain Id filter
# * `organizationId` : Organization Id filter
# * `search` : Filter string that searches name
# * `type` : Member type filter

# %%
# | export
class OrganizationMembersOrganizationMemberFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("authentication_domain_id", "organization_id", "search", "type")
    authentication_domain_id = sgqlc.types.Field(
        OrganizationMembersOrganizationMemberAuthenticationDomainIdFilter,
        graphql_name="authenticationDomainId",
    )

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null(
            "OrganizationMembersOrganizationMemberOrganizationIdFilter"
        ),
        graphql_name="organizationId",
    )

    search = sgqlc.types.Field(
        "OrganizationMembersOrganizationMemberSearchFilter", graphql_name="search"
    )

    type = sgqlc.types.Field(
        "OrganizationMembersOrganizationMemberTypeFilter", graphql_name="type"
    )

# %% [markdown]
# #### 690. `OrganizationMembersOrganizationMemberOrganizationIdFilter`

# %% [markdown]
# Filter for Organization Members Organization Id
#
#
# Available input fields:
#
#
#
# * `eq` : An Organization Id

# %%
# | export
class OrganizationMembersOrganizationMemberOrganizationIdFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 691. `OrganizationMembersOrganizationMemberSearchFilter`

# %% [markdown]
# Filter for Organization Members Search
#
#
# Available input fields:
#
#
#
# * `contains` : A piece of an Organization Member Name. This will be a text search.

# %%
# | export
class OrganizationMembersOrganizationMemberSearchFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains",)
    contains = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="contains")

# %% [markdown]
# #### 692. `OrganizationMembersOrganizationMemberTypeFilter`

# %% [markdown]
# Filter for Organization Members Type
#
#
# Available input fields:
#
#
#
# * `in` : A list of Organization Member Types. This will match on any type in the list.

# %%
# | export
class OrganizationMembersOrganizationMemberTypeFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("in_",)
    in_ = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(
                sgqlc.types.non_null(OrganizationMembersOrganizationMemberType)
            )
        ),
        graphql_name="in",
    )

# %% [markdown]
# #### 693. `OrganizationNameInput`

# %% [markdown]
# Provides the operations available on the name
#
#
# Available input fields:
#
#
#
# * `contains` : Part of an authentication domain name
# * `eq` : An authentication domain name

# %%
# | export
class OrganizationNameInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 694. `OrganizationNewManagedAccountInput`

# %% [markdown]
# Attributes for creating a new managed account.
#
#
# Available input fields:
#
#
#
# * `name` : The name of the new account to be created.
# * `regionCode` : The region-code for the account to be created.

# %%
# | export
class OrganizationNewManagedAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "region_code")
    name = sgqlc.types.Field(String, graphql_name="name")

    region_code = sgqlc.types.Field(
        OrganizationRegionCodeEnum, graphql_name="regionCode"
    )

# %% [markdown]
# #### 695. `OrganizationOrganizationAccountIdInputFilter`

# %% [markdown]
# Provides all the available filters on the account id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationAccountIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(Int, graphql_name="eq")

# %% [markdown]
# #### 696. `OrganizationOrganizationAuthenticationDomainIdInputFilter`

# %% [markdown]
# Provides all the available filters on the authentication domain id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationAuthenticationDomainIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 697. `OrganizationOrganizationCreateAsyncResultFilterInput`

# %% [markdown]
# A filter for organization create job results
#
#
# Available input fields:
#
#
#
# * `customerId` : Filter organization create job results by customer ID
# * `jobId` : Filter oganization create job results by id
# * `status` : Filter organization create job results by status

# %%
# | export
class OrganizationOrganizationCreateAsyncResultFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("customer_id", "job_id", "status")
    customer_id = sgqlc.types.Field(
        "OrganizationOrganizationCreateJobCustomerIdInput", graphql_name="customerId"
    )

    job_id = sgqlc.types.Field(
        "OrganizationOrganizationCreateJobIdInput", graphql_name="jobId"
    )

    status = sgqlc.types.Field(
        "OrganizationOrganizationCreateJobStatusInput", graphql_name="status"
    )

# %% [markdown]
# #### 698. `OrganizationOrganizationCreateJobCustomerIdInput`

# %% [markdown]
# The customer id search for jobs
#
#
# Available input fields:
#
#
#
# * `eq` : A customer id to search for jobs in

# %%
# | export
class OrganizationOrganizationCreateJobCustomerIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 699. `OrganizationOrganizationCreateJobIdInput`

# %% [markdown]
# The id of the job to retrieve
#
#
# Available input fields:
#
#
#
# * `eq` : An organization create job id
# * `in` : A set of job ids to search for

# %%
# | export
class OrganizationOrganizationCreateJobIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 700. `OrganizationOrganizationCreateJobStatusInput`

# %% [markdown]
# The status of the jobs to search for
#
#
# Available input fields:
#
#
#
# * `eq` : a job status to search for
# * `in` : a set of job statuses to search for

# %%
# | export
class OrganizationOrganizationCreateJobStatusInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(
        OrganizationOrganizationCreateJobStatusEnum, graphql_name="eq"
    )

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(OrganizationOrganizationCreateJobStatusEnum)
        ),
        graphql_name="in",
    )

# %% [markdown]
# #### 701. `OrganizationOrganizationCustomerIdInputFilter`

# %% [markdown]
# Provides all the available filters on the customer id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationCustomerIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 702. `OrganizationOrganizationGroupFilterInput`

# %% [markdown]
# A filter for organization groups
#
#
# Available input fields:
#
#
#
# * `id` : The id of the organization group
# * `name` : The name of the organization group
# * `organizationId` : The ID of the organization

# %%
# | export
class OrganizationOrganizationGroupFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name", "organization_id")
    id = sgqlc.types.Field(
        "OrganizationOrganizationGroupIdInputFilter", graphql_name="id"
    )

    name = sgqlc.types.Field(
        "OrganizationOrganizationGroupNameInputFilter", graphql_name="name"
    )

    organization_id = sgqlc.types.Field(
        "OrganizationOrganizationGroupOrganizationIdInputFilter",
        graphql_name="organizationId",
    )

# %% [markdown]
# #### 703. `OrganizationOrganizationGroupIdInputFilter`

# %% [markdown]
# Provides all the available filters on the organization group id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationGroupIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 704. `OrganizationOrganizationGroupNameInputFilter`

# %% [markdown]
# Provides all the available filters on the organization group name
#
#
# Available input fields:
#
#
#
# * `contains` : performs a contains operation
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationGroupNameInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 705. `OrganizationOrganizationGroupOrganizationIdInputFilter`

# %% [markdown]
# Provides all the available filters on the organization group organization id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationGroupOrganizationIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 706. `OrganizationOrganizationIdInput`

# %% [markdown]
# Provides the operations available on the organization id
#
#
# Available input fields:
#
#
#
# * `eq` : An organization id

# %%
# | export
class OrganizationOrganizationIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 707. `OrganizationOrganizationIdInputFilter`

# %% [markdown]
# Provides all the available filters on the organization id
#
#
# Available input fields:
#
#
#
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationIdInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 708. `OrganizationOrganizationNameInputFilter`

# %% [markdown]
# Provides all the available filters on the organization name
#
#
# Available input fields:
#
#
#
# * `contains` : performs a contains operation
# * `eq` : performs an equals operation

# %%
# | export
class OrganizationOrganizationNameInputFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 709. `OrganizationProvisioningProductInput`

# %% [markdown]
# A product.
#
#
# Available input fields:
#
#
#
# * `id` : Unique id for Product
# * `name` : Product name
# * `unitsOfMeasure` : An array of unit and quantity for a product

# %%
# | export
class OrganizationProvisioningProductInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name", "units_of_measure")
    id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="id")

    name = sgqlc.types.Field(String, graphql_name="name")

    units_of_measure = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null("OrganizationProvisioningUnitOfMeasureInput")
        ),
        graphql_name="unitsOfMeasure",
    )

# %% [markdown]
# #### 710. `OrganizationProvisioningUnitOfMeasureInput`

# %% [markdown]
# UOM or unit of measure used to know what a product charges for, such as events, hosts, CUs, etc.
#
#
# Available input fields:
#
#
#
# * `quantity` : Amount of unit
# * `unit` : Unit, such as events, hosts, CUs, etc

# %%
# | export
class OrganizationProvisioningUnitOfMeasureInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("quantity", "unit")
    quantity = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="quantity")

    unit = sgqlc.types.Field(
        sgqlc.types.non_null(OrganizationProvisioningUnit), graphql_name="unit"
    )

# %% [markdown]
# #### 711. `OrganizationRevokeSharedAccountInput`

# %% [markdown]
# Attributes for revoking an account share.
#
#
# Available input fields:
#
#
#
# * `id` : The id of the account share to be revoked

# %%
# | export
class OrganizationRevokeSharedAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

# %% [markdown]
# #### 712. `OrganizationSharedAccountInput`

# %% [markdown]
# Attributes for creating an account share.
#
#
# Available input fields:
#
#
#
# * `accountId` : The id of the account to share with new organization
# * `limitingRoleId` : The limiting role id the new organization will be granted on for the shared account

# %%
# | export
class OrganizationSharedAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "limiting_role_id")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    limiting_role_id = sgqlc.types.Field(Int, graphql_name="limitingRoleId")

# %% [markdown]
# #### 713. `OrganizationTargetIdInput`

# %% [markdown]
# Provides the operations available on the target id
#
#
# Available input fields:
#
#
#
# * `eq` : An organization id

# %%
# | export
class OrganizationTargetIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 714. `OrganizationUpdateInput`

# %% [markdown]
# Attributes for updating an organization.
#
#
# Available input fields:
#
#
#
# * `name` : The new name for the organization.

# %%
# | export
class OrganizationUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name",)
    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 715. `OrganizationUpdateSharedAccountInput`

# %% [markdown]
# Attributes for updating an account share.
#
#
# Available input fields:
#
#
#
# * `id` : The id of the account share to be updated
# * `limitingDataAccessPolicyId` : The id of the limiting data access policy. Use `null` to remove a data access policy id from the account share.
# * `limitingRoleId` : The id of the limiting role to be updated

# %%
# | export
class OrganizationUpdateSharedAccountInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "limiting_data_access_policy_id", "limiting_role_id")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    limiting_data_access_policy_id = sgqlc.types.Field(
        ID, graphql_name="limitingDataAccessPolicyId"
    )

    limiting_role_id = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="limitingRoleId"
    )

# %% [markdown]
# #### 716. `QueryHistoryQueryHistoryOptionsInput`

# %% [markdown]
# Input condition to select query records.
#
#
# Available input fields:
#
#
#
# * `limit` : Total number of query records to be returned.

# %%
# | export
class QueryHistoryQueryHistoryOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("limit",)
    limit = sgqlc.types.Field(Int, graphql_name="limit")

# %% [markdown]
# #### 717. `ReferenceEntityCreateRepositoryInput`

# %% [markdown]
# Information needed to create a repository entity.
#
#
# Available input fields:
#
#
#
# * `accountId` : The account id this repository will live under.
# * `name` : The name of the repository.
# * `url` : The url of the repository.

# %%
# | export
class ReferenceEntityCreateRepositoryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "name", "url")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    url = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="url")

# %% [markdown]
# #### 718. `SecretsManagementBooleanFilter`

# %% [markdown]
# Filter for boolean fields
#
#
# Available input fields:
#
#
#
# * `eq` : Equals filter for boolean

# %%
# | export
class SecretsManagementBooleanFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(Boolean, graphql_name="eq")

# %% [markdown]
# #### 719. `SecretsManagementScope`

# %% [markdown]
# The scope of the secret
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the scope
# * `type` : The type of scope

# %%
# | export
class SecretsManagementScope(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(SecretsManagementScopeType), graphql_name="type"
    )

# %% [markdown]
# #### 720. `SecretsManagementScopeFilter`

# %% [markdown]
# Filter for scope fields
#
#
# Available input fields:
#
#
#
# * `eq` : Equals filter for scope

# %%
# | export
class SecretsManagementScopeFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(
        sgqlc.types.non_null(SecretsManagementScope), graphql_name="eq"
    )

# %% [markdown]
# #### 721. `SecretsManagementSecretsCollectionFilter`

# %% [markdown]
# Filter for Secrets Query
#
#
# Available input fields:
#
#
#
# * `deleted` : The isDeleted filter to only query deleted secrets or non-deleted secrets
# * `namespace` : The namespace filter criteria
# * `scope` : The scope filter criteria

# %%
# | export
class SecretsManagementSecretsCollectionFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("deleted", "namespace", "scope")
    deleted = sgqlc.types.Field(SecretsManagementBooleanFilter, graphql_name="deleted")

    namespace = sgqlc.types.Field(
        "SecretsManagementStringFilter", graphql_name="namespace"
    )

    scope = sgqlc.types.Field(
        sgqlc.types.non_null(SecretsManagementScopeFilter), graphql_name="scope"
    )

# %% [markdown]
# #### 722. `SecretsManagementSecretsCollectionSort`

# %% [markdown]
# Sort input for secrets collection
#
#
# Available input fields:
#
#
#
# * `direction` : Sort direction
# * `key` : Sort key

# %%
# | export
class SecretsManagementSecretsCollectionSort(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(
        sgqlc.types.non_null(SecretsManagementSortDirection), graphql_name="direction"
    )

    key = sgqlc.types.Field(
        sgqlc.types.non_null(SecretsManagementSortKey), graphql_name="key"
    )

# %% [markdown]
# #### 723. `SecretsManagementStringFilter`

# %% [markdown]
# Filter for string fields
#
#
# Available input fields:
#
#
#
# * `eq` : Equals filter for string

# %%
# | export
class SecretsManagementStringFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 724. `SecretsManagementTagInput`

# %% [markdown]
# An input tag of key value pair, used to create secret metadata
#
#
# Available input fields:
#
#
#
# * `key` : The key of the input tag
# * `value` : The value of the input tag

# %%
# | export
class SecretsManagementTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 725. `ServiceLevelEventsCreateInput`

# %% [markdown]
# The events that define the SLI.
#
#
# Available input fields:
#
#
#
# * `accountId` : The New Relic account ID where the events are fetched from.
# * `badEvents` : The definition of bad events.
# * `goodEvents` : The definition of good events.
# * `validEvents` : The definition of valid events.

# %%
# | export
class ServiceLevelEventsCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_id", "bad_events", "good_events", "valid_events")
    account_id = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="accountId")

    bad_events = sgqlc.types.Field(
        "ServiceLevelEventsQueryCreateInput", graphql_name="badEvents"
    )

    good_events = sgqlc.types.Field(
        "ServiceLevelEventsQueryCreateInput", graphql_name="goodEvents"
    )

    valid_events = sgqlc.types.Field(
        sgqlc.types.non_null("ServiceLevelEventsQueryCreateInput"),
        graphql_name="validEvents",
    )

# %% [markdown]
# #### 726. `ServiceLevelEventsQueryCreateInput`

# %% [markdown]
# The query that represents the events to fetch.
#
#
# Available input fields:
#
#
#
# * `from` : The NRDB event to fetch the data from.
# * `select` : The NRQL SELECT clause to aggregate events. Default is COUNT(*).
# * `where` : The NRQL condition to filter the events.

# %%
# | export
class ServiceLevelEventsQueryCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("from_", "select", "where")
    from_ = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="from")

    select = sgqlc.types.Field(
        "ServiceLevelEventsQuerySelectCreateInput", graphql_name="select"
    )

    where = sgqlc.types.Field(Nrql, graphql_name="where")

# %% [markdown]
# #### 727. `ServiceLevelEventsQuerySelectCreateInput`

# %% [markdown]
# The NRQL SELECT clause to aggregate events.
#
#
# Available input fields:
#
#
#
# * `attribute` : The attribute used in the selected function. Only use it in combination with the SUM, GET_FIELD and GET_CDF_COUNT functions.
# * `function` : The function to use in the SELECT clause.
# * `threshold` : The threshold used in the selected function. Only use it in combination with the GET_CDF_COUNT function.

# %%
# | export
class ServiceLevelEventsQuerySelectCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute", "function", "threshold")
    attribute = sgqlc.types.Field(String, graphql_name="attribute")

    function = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelEventsQuerySelectFunction),
        graphql_name="function",
    )

    threshold = sgqlc.types.Field(Float, graphql_name="threshold")

# %% [markdown]
# #### 728. `ServiceLevelEventsQuerySelectUpdateInput`

# %% [markdown]
# The NRQL SELECT clause to aggregate events.
#
#
# Available input fields:
#
#
#
# * `attribute` : The attribute used in the selected function. Only use it in combination with the SUM, GET_FIELD and GET_CDF_COUNT functions.
# * `function` : The function to use in the SELECT clause.
# * `threshold` : The threshold used in the selected function. Only use it in combination with the GET_CDF_COUNT function.

# %%
# | export
class ServiceLevelEventsQuerySelectUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute", "function", "threshold")
    attribute = sgqlc.types.Field(String, graphql_name="attribute")

    function = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelEventsQuerySelectFunction),
        graphql_name="function",
    )

    threshold = sgqlc.types.Field(Float, graphql_name="threshold")

# %% [markdown]
# #### 729. `ServiceLevelEventsQueryUpdateInput`

# %% [markdown]
# The query that represents the events to fetch.
#
#
# Available input fields:
#
#
#
# * `from` : The NRDB event to fetch the data from.
# * `select` : The NRQL SELECT clause to aggregate events. Default is COUNT(*).
# * `where` : The NRQL condition to filter the events.

# %%
# | export
class ServiceLevelEventsQueryUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("from_", "select", "where")
    from_ = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="from")

    select = sgqlc.types.Field(
        ServiceLevelEventsQuerySelectUpdateInput, graphql_name="select"
    )

    where = sgqlc.types.Field(Nrql, graphql_name="where")

# %% [markdown]
# #### 730. `ServiceLevelEventsUpdateInput`

# %% [markdown]
# The events that define the SLI.
#
#
# Available input fields:
#
#
#
# * `badEvents` : The definition of bad events.
# * `goodEvents` : The definition of good events.
# * `validEvents` : The definition of valid events.

# %%
# | export
class ServiceLevelEventsUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("bad_events", "good_events", "valid_events")
    bad_events = sgqlc.types.Field(
        ServiceLevelEventsQueryUpdateInput, graphql_name="badEvents"
    )

    good_events = sgqlc.types.Field(
        ServiceLevelEventsQueryUpdateInput, graphql_name="goodEvents"
    )

    valid_events = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelEventsQueryUpdateInput),
        graphql_name="validEvents",
    )

# %% [markdown]
# #### 731. `ServiceLevelIndicatorCreateInput`

# %% [markdown]
# The input object that represents the SLI that will be created.
#
#
# Available input fields:
#
#
#
# * `description` : The description of the SLI.
# * `events` : The events that define the SLI.
# * `name` : The name of the SLI.
# * `objectives` : A list of objective definitions.
# * `slug` : [DEPRECATED] The slug is deprecated and it will be removed from the schema as soon as possible.

# %%
# | export
class ServiceLevelIndicatorCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "events", "name", "objectives", "slug")
    description = sgqlc.types.Field(String, graphql_name="description")

    events = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelEventsCreateInput), graphql_name="events"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    objectives = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("ServiceLevelObjectiveCreateInput")),
        graphql_name="objectives",
    )

    slug = sgqlc.types.Field(String, graphql_name="slug")

# %% [markdown]
# #### 732. `ServiceLevelIndicatorUpdateInput`

# %% [markdown]
# The input object that represents the SLI that will be updated.
#
#
# Available input fields:
#
#
#
# * `description` : The description of the SLI.
# * `events` : The events that define the SLI.
# * `name` : The name of the SLI.
# * `objectives` : A list of objective definitions.

# %%
# | export
class ServiceLevelIndicatorUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "events", "name", "objectives")
    description = sgqlc.types.Field(String, graphql_name="description")

    events = sgqlc.types.Field(ServiceLevelEventsUpdateInput, graphql_name="events")

    name = sgqlc.types.Field(String, graphql_name="name")

    objectives = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("ServiceLevelObjectiveUpdateInput")),
        graphql_name="objectives",
    )

# %% [markdown]
# #### 733. `ServiceLevelObjectiveCreateInput`

# %% [markdown]
# The input object that represents an objective definition.
#
#
# Available input fields:
#
#
#
# * `description` : The description of the SLO.
# * `name` : The name of the SLO.
# * `target` : The target percentage of the SLO. Maximum value is 100.
# * `timeWindow` : The time window configuration of the SLO.

# %%
# | export
class ServiceLevelObjectiveCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "target", "time_window")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    target = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="target")

    time_window = sgqlc.types.Field(
        sgqlc.types.non_null("ServiceLevelObjectiveTimeWindowCreateInput"),
        graphql_name="timeWindow",
    )

# %% [markdown]
# #### 734. `ServiceLevelObjectiveRollingTimeWindowCreateInput`

# %% [markdown]
# The rolling time window configuration of the SLO.
#
#
# Available input fields:
#
#
#
# * `count` : The count of time units. Accepted values are 1, 7 and 28 days.
# * `unit` : The time unit.

# %%
# | export
class ServiceLevelObjectiveRollingTimeWindowCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("count", "unit")
    count = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="count")

    unit = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelObjectiveRollingTimeWindowUnit),
        graphql_name="unit",
    )

# %% [markdown]
# #### 735. `ServiceLevelObjectiveRollingTimeWindowUpdateInput`

# %% [markdown]
# The rolling time window configuration of the SLO.
#
#
# Available input fields:
#
#
#
# * `count` : The count of time units. Accepted values are 1, 7 and 28 days.
# * `unit` : The time unit.

# %%
# | export
class ServiceLevelObjectiveRollingTimeWindowUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("count", "unit")
    count = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="count")

    unit = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelObjectiveRollingTimeWindowUnit),
        graphql_name="unit",
    )

# %% [markdown]
# #### 736. `ServiceLevelObjectiveTimeWindowCreateInput`

# %% [markdown]
# The time window configuration of the SLO.
#
#
# Available input fields:
#
#
#
# * `rolling` : The rolling time window configuration of the SLO.

# %%
# | export
class ServiceLevelObjectiveTimeWindowCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("rolling",)
    rolling = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelObjectiveRollingTimeWindowCreateInput),
        graphql_name="rolling",
    )

# %% [markdown]
# #### 737. `ServiceLevelObjectiveTimeWindowUpdateInput`

# %% [markdown]
# The time window configuration of the SLO.
#
#
# Available input fields:
#
#
#
# * `rolling` : The rolling time window configuration of the SLO.

# %%
# | export
class ServiceLevelObjectiveTimeWindowUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("rolling",)
    rolling = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelObjectiveRollingTimeWindowUpdateInput),
        graphql_name="rolling",
    )

# %% [markdown]
# #### 738. `ServiceLevelObjectiveUpdateInput`

# %% [markdown]
# The input object that represents an objective definition.
#
#
# Available input fields:
#
#
#
# * `description` : The description of the SLO.
# * `name` : The name of the SLO.
# * `target` : The target percentage of the SLO. Maximum value is 100.
# * `timeWindow` : The time window configuration of the SLO.

# %%
# | export
class ServiceLevelObjectiveUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "target", "time_window")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(String, graphql_name="name")

    target = sgqlc.types.Field(sgqlc.types.non_null(Float), graphql_name="target")

    time_window = sgqlc.types.Field(
        sgqlc.types.non_null(ServiceLevelObjectiveTimeWindowUpdateInput),
        graphql_name="timeWindow",
    )

# %% [markdown]
# #### 739. `SessionsClientTypeFilter`

# %% [markdown]
# Input for filtering by ClientType.
#
#
# Available input fields:
#
#
#
# * `eq` : Filter by client type.

# %%
# | export
class SessionsClientTypeFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(SessionsClientType, graphql_name="eq")

# %% [markdown]
# #### 740. `SessionsSessionFilter`

# %% [markdown]
# Input for filtering sessions.
#
#
# Available input fields:
#
#
#
# * `clientType` : Filter by client type.

# %%
# | export
class SessionsSessionFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("client_type",)
    client_type = sgqlc.types.Field(SessionsClientTypeFilter, graphql_name="clientType")

# %% [markdown]
# #### 741. `SortCriterionWithDirection`

# %% [markdown]
# Possible entity sorting criterion with direction
#
#
# Available input fields:
#
#
#
# * `attribute` : Sort entities by attribute. Mutally exclusive with the `tag` argument
# * `direction` : The direction to sort results
# * `tag` : Sort entities by tag. Mutally exclusive with the `attribute` argument

# %%
# | export
class SortCriterionWithDirection(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("attribute", "direction", "tag")
    attribute = sgqlc.types.Field(EntitySearchSortCriteria, graphql_name="attribute")

    direction = sgqlc.types.Field(SortBy, graphql_name="direction")

    tag = sgqlc.types.Field(String, graphql_name="tag")

# %% [markdown]
# #### 742. `StreamingExportAwsInput`

# %% [markdown]
# AWS input parameters for a new streaming rule
#
#
# Available input fields:
#
#
#
# * `awsAccountId` : The AWS account to which the target firehose belongs
# * `deliveryStreamName` : The name of the delivery stream to write events to
# * `region` : The AWS region the delivery stream is located in
# * `role` : The role configured for New Relic to assume

# %%
# | export
class StreamingExportAwsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("aws_account_id", "delivery_stream_name", "region", "role")
    aws_account_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="awsAccountId"
    )

    delivery_stream_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="deliveryStreamName"
    )

    region = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="region")

    role = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="role")

# %% [markdown]
# #### 743. `StreamingExportAzureInput`

# %% [markdown]
# Azure input parameters for a new streaming rule
#
#
# Available input fields:
#
#
#
# * `eventHubConnectionString` : Connection string that has access to the specific Event Hub
# * `eventHubName` : The name of Event Hub to write events to

# %%
# | export
class StreamingExportAzureInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("event_hub_connection_string", "event_hub_name")
    event_hub_connection_string = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="eventHubConnectionString"
    )

    event_hub_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="eventHubName"
    )

# %% [markdown]
# #### 744. `StreamingExportGcpInput`

# %% [markdown]
# GCP input parameters for a new streaming rule
#
#
# Available input fields:
#
#
#
# * `gcpProjectId` : gcp project id
# * `pubsubTopicId` : pub sub topic id

# %%
# | export
class StreamingExportGcpInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("gcp_project_id", "pubsub_topic_id")
    gcp_project_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="gcpProjectId"
    )

    pubsub_topic_id = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="pubsubTopicId"
    )

# %% [markdown]
# #### 745. `StreamingExportRuleInput`

# %% [markdown]
# The input parameters for a new streaming rule
#
#
# Available input fields:
#
#
#
# * `description` : Additional information about the rule
# * `name` : The name of this export rule
# * `nrql` : NRQL to select the telemetry data to export
# * `payloadCompression` : Whether to compress payloads before sending them out, and what compression format to use if enabled

# %%
# | export
class StreamingExportRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "name", "nrql", "payload_compression")
    description = sgqlc.types.Field(String, graphql_name="description")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    nrql = sgqlc.types.Field(sgqlc.types.non_null(Nrql), graphql_name="nrql")

    payload_compression = sgqlc.types.Field(
        StreamingExportPayloadCompression, graphql_name="payloadCompression"
    )

# %% [markdown]
# #### 746. `SyntheticsCreateBrokenLinksMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Broken Links monitor
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs. The only accepted values are runtimeType: NODE_API & runtimeTypeVersion: 16.10
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor
# * `uri` : The uri the monitor runs against

# %%
# | export
class SyntheticsCreateBrokenLinksMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "apdex_target",
        "locations",
        "name",
        "period",
        "runtime",
        "status",
        "tags",
        "uri",
    )
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsLocationsInput"), graphql_name="locations"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    runtime = sgqlc.types.Field(
        "SyntheticsExtendedTypeMonitorRuntimeInput", graphql_name="runtime"
    )

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

    uri = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="uri")

# %% [markdown]
# #### 747. `SyntheticsCreateCertCheckMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Cert Check monitor
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `domain` : The domain of the host that will have its certificate checked
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `numberDaysToFailBeforeCertExpires` : The desired number of remaining days until the certificate expires to trigger a monitor failure
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs. The only accepted values are runtimeType: NODE_API & runtimeTypeVersion: 16.10
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsCreateCertCheckMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "apdex_target",
        "domain",
        "locations",
        "name",
        "number_days_to_fail_before_cert_expires",
        "period",
        "runtime",
        "status",
        "tags",
    )
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    domain = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="domain")

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsLocationsInput"), graphql_name="locations"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    number_days_to_fail_before_cert_expires = sgqlc.types.Field(
        sgqlc.types.non_null(Int), graphql_name="numberDaysToFailBeforeCertExpires"
    )

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    runtime = sgqlc.types.Field(
        "SyntheticsExtendedTypeMonitorRuntimeInput", graphql_name="runtime"
    )

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

# %% [markdown]
# #### 748. `SyntheticsCreateScriptApiMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Script Api monitor
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs
# * `script` : The script that the monitor runs
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsCreateScriptApiMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "apdex_target",
        "locations",
        "name",
        "period",
        "runtime",
        "script",
        "status",
        "tags",
    )
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsScriptedMonitorLocationsInput"),
        graphql_name="locations",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    runtime = sgqlc.types.Field("SyntheticsRuntimeInput", graphql_name="runtime")

    script = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="script")

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

# %% [markdown]
# #### 749. `SyntheticsCreateScriptBrowserMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Script Browser monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `browsers` : The browser(s) that the monitor will use to run jobs
# * `devices` : The devices that the monitor will use to run jobs
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs
# * `script` : The script that the monitor runs
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsCreateScriptBrowserMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "browsers",
        "devices",
        "locations",
        "name",
        "period",
        "runtime",
        "script",
        "status",
        "tags",
    )
    advanced_options = sgqlc.types.Field(
        "SyntheticsScriptBrowserMonitorAdvancedOptionsInput",
        graphql_name="advancedOptions",
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    browsers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsBrowser), graphql_name="browsers"
    )

    devices = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsDevice), graphql_name="devices"
    )

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsScriptedMonitorLocationsInput"),
        graphql_name="locations",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    runtime = sgqlc.types.Field("SyntheticsRuntimeInput", graphql_name="runtime")

    script = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="script")

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

# %% [markdown]
# #### 750. `SyntheticsCreateSimpleBrowserMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Simple Browser monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `browsers` : The browser(s) that the monitor will use to run jobs
# * `devices` : The devices that the monitor will use to run jobs
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor
# * `uri` : The uri the monitor runs against

# %%
# | export
class SyntheticsCreateSimpleBrowserMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "browsers",
        "devices",
        "locations",
        "name",
        "period",
        "runtime",
        "status",
        "tags",
        "uri",
    )
    advanced_options = sgqlc.types.Field(
        "SyntheticsSimpleBrowserMonitorAdvancedOptionsInput",
        graphql_name="advancedOptions",
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    browsers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsBrowser), graphql_name="browsers"
    )

    devices = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsDevice), graphql_name="devices"
    )

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsLocationsInput"), graphql_name="locations"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    runtime = sgqlc.types.Field("SyntheticsRuntimeInput", graphql_name="runtime")

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

    uri = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="uri")

# %% [markdown]
# #### 751. `SyntheticsCreateSimpleMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Simple (ping) monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor
# * `uri` : The uri the monitor runs against

# %%
# | export
class SyntheticsCreateSimpleMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "locations",
        "name",
        "period",
        "status",
        "tags",
        "uri",
    )
    advanced_options = sgqlc.types.Field(
        "SyntheticsSimpleMonitorAdvancedOptionsInput", graphql_name="advancedOptions"
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsLocationsInput"), graphql_name="locations"
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

    uri = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="uri")

# %% [markdown]
# #### 752. `SyntheticsCreateStepMonitorInput`

# %% [markdown]
# The monitor input values needed to create a Step monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `browsers` : The browser(s) that the monitor will use to run jobs
# * `devices` : The devices that the monitor will use to run jobs
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs. The only accepted values are runtimeType: CHROME_BROWSER & runtimeTypeVersion: 100
# * `status` : The run state of the monitor
# * `steps` : The steps that make up the script the monitor will run
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsCreateStepMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "browsers",
        "devices",
        "locations",
        "name",
        "period",
        "runtime",
        "status",
        "steps",
        "tags",
    )
    advanced_options = sgqlc.types.Field(
        "SyntheticsStepMonitorAdvancedOptionsInput", graphql_name="advancedOptions"
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    browsers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsBrowser), graphql_name="browsers"
    )

    devices = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsDevice), graphql_name="devices"
    )

    locations = sgqlc.types.Field(
        sgqlc.types.non_null("SyntheticsScriptedMonitorLocationsInput"),
        graphql_name="locations",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    period = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorPeriod), graphql_name="period"
    )

    runtime = sgqlc.types.Field(
        "SyntheticsExtendedTypeMonitorRuntimeInput", graphql_name="runtime"
    )

    status = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorStatus), graphql_name="status"
    )

    steps = sgqlc.types.Field(
        sgqlc.types.non_null(
            sgqlc.types.list_of(sgqlc.types.non_null("SyntheticsStepInput"))
        ),
        graphql_name="steps",
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of("SyntheticsTag"), graphql_name="tags")

# %% [markdown]
# #### 753. `SyntheticsCustomHeaderInput`

# %% [markdown]
# Custom header input for monitor jobs
#
#
# Available input fields:
#
#
#
# * `name` : Header name
# * `value` : Header value

# %%
# | export
class SyntheticsCustomHeaderInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "value")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 754. `SyntheticsDateWindowEndConfig`

# %% [markdown]
# Configuration options for when a monitor downtime should end
#
#
# Available input fields:
#
#
#
# * `onDate` : End the monitor downtime on a particular date
# * `onRepeat` : End the monitor downtime after a set number of occurrences

# %%
# | export
class SyntheticsDateWindowEndConfig(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("on_date", "on_repeat")
    on_date = sgqlc.types.Field(Date, graphql_name="onDate")

    on_repeat = sgqlc.types.Field(Int, graphql_name="onRepeat")

# %% [markdown]
# #### 755. `SyntheticsDaysOfWeek`

# %% [markdown]
# Configuration options for a monthly monitor downtime that runs on days of the week
#
#
# Available input fields:
#
#
#
# * `ordinalDayOfMonth` : Which occurrence of the day selected within the month
# * `weekDay` : Which day of the week the monitor downtime runs

# %%
# | export
class SyntheticsDaysOfWeek(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ordinal_day_of_month", "week_day")
    ordinal_day_of_month = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorDowntimeDayOfMonthOrdinal),
        graphql_name="ordinalDayOfMonth",
    )

    week_day = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsMonitorDowntimeWeekDays), graphql_name="weekDay"
    )

# %% [markdown]
# #### 756. `SyntheticsDeviceEmulationInput`

# %% [markdown]
# Information related to device browser emulation
#
#
# Available input fields:
#
#
#
# * `deviceOrientation` : The device orientation the user would like to represent
# * `deviceType` : The device type that a user can select

# %%
# | export
class SyntheticsDeviceEmulationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("device_orientation", "device_type")
    device_orientation = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsDeviceOrientation),
        graphql_name="deviceOrientation",
    )

    device_type = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsDeviceType), graphql_name="deviceType"
    )

# %% [markdown]
# #### 757. `SyntheticsExtendedTypeMonitorRuntimeInput`

# %% [markdown]
# Input to determine which runtime the step monitor will run
#
#
# Available input fields:
#
#
#
# * `runtimeType` : The runtime type that the monitor will run.
# * `runtimeTypeVersion` : The specific version of the runtime type selected.

# %%
# | export
class SyntheticsExtendedTypeMonitorRuntimeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("runtime_type", "runtime_type_version")
    runtime_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="runtimeType"
    )

    runtime_type_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="runtimeTypeVersion"
    )

# %% [markdown]
# #### 758. `SyntheticsLocationsInput`

# %% [markdown]
# The location(s) from which a non-scripted monitor runs
#
#
# Available input fields:
#
#
#
# * `private` : Existing private location(s) in which the monitor will run
# * `public` : Publicly available location(s) in which the monitor will run. For formatting tips, see [this link](https://docs.newrelic.com/docs/apis/nerdgraph/examples/nerdgraph-synthetics-tutorial/#location-field)

# %%
# | export
class SyntheticsLocationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("private", "public")
    private = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="private")

    public = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="public")

# %% [markdown]
# #### 759. `SyntheticsMonitorDowntimeDailyConfig`

# %% [markdown]
# Configuration options for a monitor downtime that runs daily
#
#
# Available input fields:
#
#
#
# * `endRepeat` : Configuration options if the customer wants the monitor to end at a specific date
# * `endTime` : The date and time in which the monitor downtime will end
# * `startTime` : The date and time in which the monitor downtime will begin
# * `timezone` : The timezone the time values will be in

# %%
# | export
class SyntheticsMonitorDowntimeDailyConfig(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("end_repeat", "end_time", "start_time", "timezone")
    end_repeat = sgqlc.types.Field(
        SyntheticsDateWindowEndConfig, graphql_name="endRepeat"
    )

    end_time = sgqlc.types.Field(NaiveDateTime, graphql_name="endTime")

    start_time = sgqlc.types.Field(NaiveDateTime, graphql_name="startTime")

    timezone = sgqlc.types.Field(String, graphql_name="timezone")

# %% [markdown]
# #### 760. `SyntheticsMonitorDowntimeMonthlyConfig`

# %% [markdown]
# Configuration options for a monitor downtime that runs monthly
#
#
# Available input fields:
#
#
#
# * `endRepeat` : Configuration options if the customer wants the monitor to end at a specific date
# * `endTime` : The date and time in which the monitor downtime will end
# * `frequency` : Configuration options for which days of the month a monitor downtime will occur
# * `startTime` : The date and time in which the monitor downtime will begin
# * `timezone` : The timezone the time values will be in

# %%
# | export
class SyntheticsMonitorDowntimeMonthlyConfig(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("end_repeat", "end_time", "frequency", "start_time", "timezone")
    end_repeat = sgqlc.types.Field(
        SyntheticsDateWindowEndConfig, graphql_name="endRepeat"
    )

    end_time = sgqlc.types.Field(NaiveDateTime, graphql_name="endTime")

    frequency = sgqlc.types.Field(
        "SyntheticsMonitorDowntimeMonthlyFrequency", graphql_name="frequency"
    )

    start_time = sgqlc.types.Field(NaiveDateTime, graphql_name="startTime")

    timezone = sgqlc.types.Field(String, graphql_name="timezone")

# %% [markdown]
# #### 761. `SyntheticsMonitorDowntimeMonthlyFrequency`

# %% [markdown]
# Configuration options for when a monthly monitor downtime should run
#
#
# Available input fields:
#
#
#
# * `daysOfMonth` : Which dates a monitor downtime is run (only 1 of these can be selected)
# * `daysOfWeek` : Which weekdays in the month the monitor downtime will run (only 1 of these can be selected)

# %%
# | export
class SyntheticsMonitorDowntimeMonthlyFrequency(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("days_of_month", "days_of_week")
    days_of_month = sgqlc.types.Field(
        sgqlc.types.list_of(Int), graphql_name="daysOfMonth"
    )

    days_of_week = sgqlc.types.Field(SyntheticsDaysOfWeek, graphql_name="daysOfWeek")

# %% [markdown]
# #### 762. `SyntheticsMonitorDowntimeOnceConfig`

# %% [markdown]
# Configuration options for a monitor downtime that runs once
#
#
# Available input fields:
#
#
#
# * `endTime` : The date and time in which the monitor downtime will end
# * `startTime` : The date and time in which the monitor downtime will begin
# * `timezone` : The timezone the time values will be in

# %%
# | export
class SyntheticsMonitorDowntimeOnceConfig(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("end_time", "start_time", "timezone")
    end_time = sgqlc.types.Field(NaiveDateTime, graphql_name="endTime")

    start_time = sgqlc.types.Field(NaiveDateTime, graphql_name="startTime")

    timezone = sgqlc.types.Field(String, graphql_name="timezone")

# %% [markdown]
# #### 763. `SyntheticsMonitorDowntimeWeeklyConfig`

# %% [markdown]
# Configuration options for a monitor downtime that runs weekly
#
#
# Available input fields:
#
#
#
# * `endRepeat` : Configuration options if the customer wants the monitor to end at a specific date
# * `endTime` : The date and time in which the monitor downtime will end
# * `maintenanceDays` : Configuration options if the customer wants the monitor to end at a specific date
# * `startTime` : The date and time in which the monitor downtime will begin
# * `timezone` : The timezone the time values will be in

# %%
# | export
class SyntheticsMonitorDowntimeWeeklyConfig(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "end_repeat",
        "end_time",
        "maintenance_days",
        "start_time",
        "timezone",
    )
    end_repeat = sgqlc.types.Field(
        SyntheticsDateWindowEndConfig, graphql_name="endRepeat"
    )

    end_time = sgqlc.types.Field(NaiveDateTime, graphql_name="endTime")

    maintenance_days = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsMonitorDowntimeWeekDays),
        graphql_name="maintenanceDays",
    )

    start_time = sgqlc.types.Field(NaiveDateTime, graphql_name="startTime")

    timezone = sgqlc.types.Field(String, graphql_name="timezone")

# %% [markdown]
# #### 764. `SyntheticsPrivateLocationInput`

# %% [markdown]
# Information realating to a private location
#
#
# Available input fields:
#
#
#
# * `guid` : The unique identifier for the Synthetics private location in New Relic
# * `vsePassword` : The location's Verified Script Execution password (Only necessary if Verified Script Execution is enabled for the location)

# %%
# | export
class SyntheticsPrivateLocationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("guid", "vse_password")
    guid = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="guid")

    vse_password = sgqlc.types.Field(SecureValue, graphql_name="vsePassword")

# %% [markdown]
# #### 765. `SyntheticsRuntimeInput`

# %% [markdown]
# Input to determine which runtime the monitor will run
#
#
# Available input fields:
#
#
#
# * `runtimeType` : The runtime type that the monitor will run
# * `runtimeTypeVersion` : The specific version of the runtime type selected
# * `scriptLanguage` : The programing language that should execute the script

# %%
# | export
class SyntheticsRuntimeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("runtime_type", "runtime_type_version", "script_language")
    runtime_type = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="runtimeType"
    )

    runtime_type_version = sgqlc.types.Field(
        sgqlc.types.non_null(SemVer), graphql_name="runtimeTypeVersion"
    )

    script_language = sgqlc.types.Field(String, graphql_name="scriptLanguage")

# %% [markdown]
# #### 766. `SyntheticsScriptBrowserMonitorAdvancedOptionsInput`

# %% [markdown]
# The advanced options inputs available for a Script Browser monitor
#
#
# Available input fields:
#
#
#
# * `deviceEmulation` : Emulate a device
# * `enableScreenshotOnFailureAndScript` : Capture a screenshot during job execution

# %%
# | export
class SyntheticsScriptBrowserMonitorAdvancedOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("device_emulation", "enable_screenshot_on_failure_and_script")
    device_emulation = sgqlc.types.Field(
        SyntheticsDeviceEmulationInput, graphql_name="deviceEmulation"
    )

    enable_screenshot_on_failure_and_script = sgqlc.types.Field(
        Boolean, graphql_name="enableScreenshotOnFailureAndScript"
    )

# %% [markdown]
# #### 767. `SyntheticsScriptedMonitorLocationsInput`

# %% [markdown]
# The location(s) from which the scripted monitor runs.
#
#
# Available input fields:
#
#
#
# * `private` : The private location(s) that the monitor will run jobs from
# * `public` : The public location(s) that the monitor will run jobs from

# %%
# | export
class SyntheticsScriptedMonitorLocationsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("private", "public")
    private = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(SyntheticsPrivateLocationInput)),
        graphql_name="private",
    )

    public = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="public"
    )

# %% [markdown]
# #### 768. `SyntheticsSimpleBrowserMonitorAdvancedOptionsInput`

# %% [markdown]
# The advanced options inputs available for a Simple Browser monitor
#
#
# Available input fields:
#
#
#
# * `customHeaders` : Custom headers to use in monitor job
# * `deviceEmulation` : Emulate a device
# * `enableScreenshotOnFailureAndScript` : Capture a screenshot during job execution
# * `responseValidationText` : Validation text for monitor to search for at given URI
# * `useTlsValidation` : Monitor should validate SSL certificate chain

# %%
# | export
class SyntheticsSimpleBrowserMonitorAdvancedOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "custom_headers",
        "device_emulation",
        "enable_screenshot_on_failure_and_script",
        "response_validation_text",
        "use_tls_validation",
    )
    custom_headers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsCustomHeaderInput), graphql_name="customHeaders"
    )

    device_emulation = sgqlc.types.Field(
        SyntheticsDeviceEmulationInput, graphql_name="deviceEmulation"
    )

    enable_screenshot_on_failure_and_script = sgqlc.types.Field(
        Boolean, graphql_name="enableScreenshotOnFailureAndScript"
    )

    response_validation_text = sgqlc.types.Field(
        String, graphql_name="responseValidationText"
    )

    use_tls_validation = sgqlc.types.Field(Boolean, graphql_name="useTlsValidation")

# %% [markdown]
# #### 769. `SyntheticsSimpleMonitorAdvancedOptionsInput`

# %% [markdown]
# The advanced options inputs available for a Simple (ping) monitor
#
#
# Available input fields:
#
#
#
# * `customHeaders` : Custom headers to use in monitor job
# * `redirectIsFailure` : Categorize redirects during a monitor job as a failure
# * `responseValidationText` : Validation text for monitor to search for at given URI
# * `shouldBypassHeadRequest` : Monitor should skip default HEAD request and instead use GET verb in check
# * `useTlsValidation` : Monitor should validate SSL certificate chain

# %%
# | export
class SyntheticsSimpleMonitorAdvancedOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "custom_headers",
        "redirect_is_failure",
        "response_validation_text",
        "should_bypass_head_request",
        "use_tls_validation",
    )
    custom_headers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsCustomHeaderInput), graphql_name="customHeaders"
    )

    redirect_is_failure = sgqlc.types.Field(Boolean, graphql_name="redirectIsFailure")

    response_validation_text = sgqlc.types.Field(
        String, graphql_name="responseValidationText"
    )

    should_bypass_head_request = sgqlc.types.Field(
        Boolean, graphql_name="shouldBypassHeadRequest"
    )

    use_tls_validation = sgqlc.types.Field(Boolean, graphql_name="useTlsValidation")

# %% [markdown]
# #### 770. `SyntheticsStepInput`

# %% [markdown]
# A step that will be added to the monitor script
#
#
# Available input fields:
#
#
#
# * `ordinal` : The position of the step within the script ranging from 1-100.
# * `type` : The type of step to be added to the script
# * `values` : The metadata values related to the step

# %%
# | export
class SyntheticsStepInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("ordinal", "type", "values")
    ordinal = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="ordinal")

    type = sgqlc.types.Field(
        sgqlc.types.non_null(SyntheticsStepType), graphql_name="type"
    )

    values = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(String)), graphql_name="values"
    )

# %% [markdown]
# #### 771. `SyntheticsStepMonitorAdvancedOptionsInput`

# %% [markdown]
# The advanced options inputs available for a Step monitor
#
#
# Available input fields:
#
#
#
# * `enableScreenshotOnFailureAndScript` : Capture a screenshot during job execution

# %%
# | export
class SyntheticsStepMonitorAdvancedOptionsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enable_screenshot_on_failure_and_script",)
    enable_screenshot_on_failure_and_script = sgqlc.types.Field(
        Boolean, graphql_name="enableScreenshotOnFailureAndScript"
    )

# %% [markdown]
# #### 772. `SyntheticsTag`

# %% [markdown]
# Tag entries for the monitor
#
#
# Available input fields:
#
#
#
# * `key` : Name of the tag key
# * `values` : Values associated with the tag key

# %%
# | export
class SyntheticsTag(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "values")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(String)), graphql_name="values"
    )

# %% [markdown]
# #### 773. `SyntheticsUpdateBrokenLinksMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a Broken Links monitor
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs. The only accepted values are runtimeType: NODE_API & runtimeTypeVersion: 16.10
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor
# * `uri` : The uri the monitor runs against

# %%
# | export
class SyntheticsUpdateBrokenLinksMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "apdex_target",
        "locations",
        "name",
        "period",
        "runtime",
        "status",
        "tags",
        "uri",
    )
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    locations = sgqlc.types.Field(SyntheticsLocationsInput, graphql_name="locations")

    name = sgqlc.types.Field(String, graphql_name="name")

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    runtime = sgqlc.types.Field(
        SyntheticsExtendedTypeMonitorRuntimeInput, graphql_name="runtime"
    )

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

    uri = sgqlc.types.Field(String, graphql_name="uri")

# %% [markdown]
# #### 774. `SyntheticsUpdateCertCheckMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a Cert Check monitor
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `domain` : The domain of the host that will have its certificate checked
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `numberDaysToFailBeforeCertExpires` : The desired number of remaining days until the certificate expires to trigger a monitor failure
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs. The only accepted values are runtimeType: NODE_API & runtimeTypeVersion: 16.10
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsUpdateCertCheckMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "apdex_target",
        "domain",
        "locations",
        "name",
        "number_days_to_fail_before_cert_expires",
        "period",
        "runtime",
        "status",
        "tags",
    )
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    domain = sgqlc.types.Field(String, graphql_name="domain")

    locations = sgqlc.types.Field(SyntheticsLocationsInput, graphql_name="locations")

    name = sgqlc.types.Field(String, graphql_name="name")

    number_days_to_fail_before_cert_expires = sgqlc.types.Field(
        Int, graphql_name="numberDaysToFailBeforeCertExpires"
    )

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    runtime = sgqlc.types.Field(
        SyntheticsExtendedTypeMonitorRuntimeInput, graphql_name="runtime"
    )

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

# %% [markdown]
# #### 775. `SyntheticsUpdateScriptApiMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a Script Api monitor
#
#
# Available input fields:
#
#
#
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs
# * `script` : The script that the monitor runs
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsUpdateScriptApiMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "apdex_target",
        "locations",
        "name",
        "period",
        "runtime",
        "script",
        "status",
        "tags",
    )
    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    locations = sgqlc.types.Field(
        SyntheticsScriptedMonitorLocationsInput, graphql_name="locations"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    runtime = sgqlc.types.Field(SyntheticsRuntimeInput, graphql_name="runtime")

    script = sgqlc.types.Field(String, graphql_name="script")

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

# %% [markdown]
# #### 776. `SyntheticsUpdateScriptBrowserMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a Script Browser monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `browsers` : The browser(s) that the monitor will use to run jobs
# * `devices` : The device(s) that the monitor will use to run jobs
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs
# * `script` : The script that the monitor runs
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsUpdateScriptBrowserMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "browsers",
        "devices",
        "locations",
        "name",
        "period",
        "runtime",
        "script",
        "status",
        "tags",
    )
    advanced_options = sgqlc.types.Field(
        SyntheticsScriptBrowserMonitorAdvancedOptionsInput,
        graphql_name="advancedOptions",
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    browsers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsBrowser), graphql_name="browsers"
    )

    devices = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsDevice), graphql_name="devices"
    )

    locations = sgqlc.types.Field(
        SyntheticsScriptedMonitorLocationsInput, graphql_name="locations"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    runtime = sgqlc.types.Field(SyntheticsRuntimeInput, graphql_name="runtime")

    script = sgqlc.types.Field(String, graphql_name="script")

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

# %% [markdown]
# #### 777. `SyntheticsUpdateSimpleBrowserMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a Simple Browser monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `browsers` : The browser(s) that the monitor will use to run jobs
# * `devices` : The devices that the monitor will use to run jobs
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor
# * `uri` : The uri the monitor runs against

# %%
# | export
class SyntheticsUpdateSimpleBrowserMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "browsers",
        "devices",
        "locations",
        "name",
        "period",
        "runtime",
        "status",
        "tags",
        "uri",
    )
    advanced_options = sgqlc.types.Field(
        SyntheticsSimpleBrowserMonitorAdvancedOptionsInput,
        graphql_name="advancedOptions",
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    browsers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsBrowser), graphql_name="browsers"
    )

    devices = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsDevice), graphql_name="devices"
    )

    locations = sgqlc.types.Field(SyntheticsLocationsInput, graphql_name="locations")

    name = sgqlc.types.Field(String, graphql_name="name")

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    runtime = sgqlc.types.Field(SyntheticsRuntimeInput, graphql_name="runtime")

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

    uri = sgqlc.types.Field(String, graphql_name="uri")

# %% [markdown]
# #### 778. `SyntheticsUpdateSimpleMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a simple (ping) monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `status` : The run state of the monitor
# * `tags` : The tags that will be associated with the monitor
# * `uri` : The uri the monitor runs against

# %%
# | export
class SyntheticsUpdateSimpleMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "locations",
        "name",
        "period",
        "status",
        "tags",
        "uri",
    )
    advanced_options = sgqlc.types.Field(
        SyntheticsSimpleMonitorAdvancedOptionsInput, graphql_name="advancedOptions"
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    locations = sgqlc.types.Field(SyntheticsLocationsInput, graphql_name="locations")

    name = sgqlc.types.Field(String, graphql_name="name")

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

    uri = sgqlc.types.Field(String, graphql_name="uri")

# %% [markdown]
# #### 779. `SyntheticsUpdateStepMonitorInput`

# %% [markdown]
# The monitor values that can be updated on a Step monitor
#
#
# Available input fields:
#
#
#
# * `advancedOptions` : The monitor advanced options
# * `apdexTarget` : The monitor's Apdex target used to populate SLA reports
# * `browsers` : The browser(s) that the monitor will use to run jobs
# * `devices` : The devices that the monitor will use to run jobs
# * `locations` : The locations the monitor will run from
# * `name` : The human readable identifier for the monitor
# * `period` : The interval at which the monitor runs in minutes
# * `runtime` : The runtime that the monitor will use to run jobs. The only accepted values are runtimeType: CHROME_BROWSER & runtimeTypeVersion: 100
# * `status` : The run state of the monitor
# * `steps` : The steps that make up the script the monitor will run
# * `tags` : The tags that will be associated with the monitor

# %%
# | export
class SyntheticsUpdateStepMonitorInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "advanced_options",
        "apdex_target",
        "browsers",
        "devices",
        "locations",
        "name",
        "period",
        "runtime",
        "status",
        "steps",
        "tags",
    )
    advanced_options = sgqlc.types.Field(
        SyntheticsStepMonitorAdvancedOptionsInput, graphql_name="advancedOptions"
    )

    apdex_target = sgqlc.types.Field(Float, graphql_name="apdexTarget")

    browsers = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsBrowser), graphql_name="browsers"
    )

    devices = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsDevice), graphql_name="devices"
    )

    locations = sgqlc.types.Field(
        SyntheticsScriptedMonitorLocationsInput, graphql_name="locations"
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    period = sgqlc.types.Field(SyntheticsMonitorPeriod, graphql_name="period")

    runtime = sgqlc.types.Field(
        SyntheticsExtendedTypeMonitorRuntimeInput, graphql_name="runtime"
    )

    status = sgqlc.types.Field(SyntheticsMonitorStatus, graphql_name="status")

    steps = sgqlc.types.Field(
        sgqlc.types.list_of(SyntheticsStepInput), graphql_name="steps"
    )

    tags = sgqlc.types.Field(sgqlc.types.list_of(SyntheticsTag), graphql_name="tags")

# %% [markdown]
# #### 780. `SystemIdentityClientIdFilter`

# %% [markdown]
# The system identity client_id
#
#
# Available input fields:
#
#
#
# * `eq` : A client_id

# %%
# | export
class SystemIdentityClientIdFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(ID, graphql_name="eq")

# %% [markdown]
# #### 781. `SystemIdentityGroupFilter`

# %% [markdown]
# Filter for System Identity Groups
#
#
# Available input fields:
#
#
#
# * `id` : System Identity Group Id
# * `name` : System Identity Group Name
# * `organizationId` : OrganizationId

# %%
# | export
class SystemIdentityGroupFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "name", "organization_id")
    id = sgqlc.types.Field("SystemIdentityGroupIdFilter", graphql_name="id")

    name = sgqlc.types.Field("SystemIdentityGroupNameFilter", graphql_name="name")

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("SystemIdentityOrganizationIdFilter"),
        graphql_name="organizationId",
    )

# %% [markdown]
# #### 782. `SystemIdentityGroupIdFilter`

# %% [markdown]
# Filter for System Identity Group Id
#
#
# Available input fields:
#
#
#
# * `eq` : A System Identity Group Id
# * `in` : A list of System Identity Group Ids

# %%
# | export
class SystemIdentityGroupIdFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(String, graphql_name="eq")

    in_ = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="in")

# %% [markdown]
# #### 783. `SystemIdentityGroupNameFilter`

# %% [markdown]
# Filter for System Identity Group Name
#
#
# Available input fields:
#
#
#
# * `contains` : A piece of a System Identity Group Name. This will be a text search.
# * `eq` : A  Group Name. This will be an exact match.

# %%
# | export
class SystemIdentityGroupNameFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 784. `SystemIdentityIdentityFilter`

# %% [markdown]
# Filter for System Identity
#
#
# Available input fields:
#
#
#
# * `clientId` : The client_id of the system identity
# * `id` : The id of the system identity
# * `name` : The name of the system identity
# * `organizationId` : The id of the organization
# * `type` : The type of the system identity

# %%
# | export
class SystemIdentityIdentityFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("client_id", "id", "name", "organization_id", "type")
    client_id = sgqlc.types.Field(SystemIdentityClientIdFilter, graphql_name="clientId")

    id = sgqlc.types.Field("SystemIdentityIdentityIdFilter", graphql_name="id")

    name = sgqlc.types.Field("SystemIdentityNameFilter", graphql_name="name")

    organization_id = sgqlc.types.Field(
        sgqlc.types.non_null("SystemIdentityOrganizationIdFilter"),
        graphql_name="organizationId",
    )

    type = sgqlc.types.Field(SystemIdentityIdentityType, graphql_name="type")

# %% [markdown]
# #### 785. `SystemIdentityIdentityIdFilter`

# %% [markdown]
# A system identity id
#
#
# Available input fields:
#
#
#
# * `eq` : An id
# * `in` : A list of ids

# %%
# | export
class SystemIdentityIdentityIdFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="in")

# %% [markdown]
# #### 786. `SystemIdentityIdentitySort`

# %% [markdown]
# Sort system identities
#
#
# Available input fields:
#
#
#
# * `field` : Sort field with key and direction

# %%
# | export
class SystemIdentityIdentitySort(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("field",)
    field = sgqlc.types.Field("SystemIdentityIdentitySortField", graphql_name="field")

# %% [markdown]
# #### 787. `SystemIdentityIdentitySortField`

# %% [markdown]
# Sort system identities key and direction
#
#
# Available input fields:
#
#
#
# * `direction` : Sort order
# * `key` : Key to sort system identities by

# %%
# | export
class SystemIdentityIdentitySortField(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(SystemIdentitySortOrder, graphql_name="direction")

    key = sgqlc.types.Field(SystemIdentityIdentitySortFieldKey, graphql_name="key")

# %% [markdown]
# #### 788. `SystemIdentityNameFilter`

# %% [markdown]
# A system identity name
#
#
# Available input fields:
#
#
#
# * `contains` : contains search
# * `eq` : equal search

# %%
# | export
class SystemIdentityNameFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 789. `SystemIdentityOrganizationIdFilter`

# %% [markdown]
# An organization id
#
#
# Available input fields:
#
#
#
# * `eq` : An organization id

# %%
# | export
class SystemIdentityOrganizationIdFilter(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="eq")

# %% [markdown]
# #### 790. `TaggingTagInput`

# %% [markdown]
# An object that represents a tag key-values pair.
#
#
# Available input fields:
#
#
#
# * `key` : The tag key.
# * `values` : The tag values.

# %%
# | export
class TaggingTagInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "values")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    values = sgqlc.types.Field(sgqlc.types.list_of(String), graphql_name="values")

# %% [markdown]
# #### 791. `TaggingTagValueInput`

# %% [markdown]
# An object that represents a tag key-value pair
#
#
# Available input fields:
#
#
#
# * `key` : The tag key.
# * `value` : The tag value.

# %%
# | export
class TaggingTagValueInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="value")

# %% [markdown]
# #### 792. `TimeWindowInput`

# %% [markdown]
# Represents a time window input.
#
#
# Available input fields:
#
#
#
# * `endTime` : The end time of the time window the number of milliseconds since the Unix epoch.
# * `startTime` : The start time of the time window the number of milliseconds since the Unix epoch.

# %%
# | export
class TimeWindowInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("end_time", "start_time")
    end_time = sgqlc.types.Field(
        sgqlc.types.non_null(EpochMilliseconds), graphql_name="endTime"
    )

    start_time = sgqlc.types.Field(
        sgqlc.types.non_null(EpochMilliseconds), graphql_name="startTime"
    )

# %% [markdown]
# #### 793. `UserManagementCreateGroup`

# %% [markdown]
# The input object representing the group being created
#
#
# Available input fields:
#
#
#
# * `authenticationDomainId` : The id of the authentication domain the group will belong to
# * `displayName` : The name of the group

# %%
# | export
class UserManagementCreateGroup(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("authentication_domain_id", "display_name")
    authentication_domain_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="authenticationDomainId"
    )

    display_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="displayName"
    )

# %% [markdown]
# #### 794. `UserManagementCreateUser`

# %% [markdown]
# The input object representing the user being created
#
#
# Available input fields:
#
#
#
# * `authenticationDomainId` : The authentication domain id for the user to be created under.
# * `email` : The email address of the user to be created.
# * `name` : The name of the user to be created.
# * `userType` : The user type for the user to be created.

# %%
# | export
class UserManagementCreateUser(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("authentication_domain_id", "email", "name", "user_type")
    authentication_domain_id = sgqlc.types.Field(
        sgqlc.types.non_null(ID), graphql_name="authenticationDomainId"
    )

    email = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="email")

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    user_type = sgqlc.types.Field(
        UserManagementRequestedTierName, graphql_name="userType"
    )

# %% [markdown]
# #### 795. `UserManagementDeleteGroup`

# %% [markdown]
# The input object representing the group to remove
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the group being removed.

# %%
# | export
class UserManagementDeleteGroup(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

# %% [markdown]
# #### 796. `UserManagementDeleteUser`

# %% [markdown]
# The input object representing the user being deleted
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the user to be deleted

# %%
# | export
class UserManagementDeleteUser(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

# %% [markdown]
# #### 797. `UserManagementDisplayNameInput`

# %% [markdown]
# Available filtering types for group display names
#
#
# Available input fields:
#
#
#
# * `contains` : Part of a display name
# * `eq` : A display name

# %%
# | export
class UserManagementDisplayNameInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 798. `UserManagementEmailInput`

# %% [markdown]
# Available filtering types for email addresses
#
#
# Available input fields:
#
#
#
# * `contains` : Part of a user email
# * `eq` : A user email

# %%
# | export
class UserManagementEmailInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 799. `UserManagementEmailVerificationStateInput`

# %% [markdown]
# Available filtering types for email verification states
#
#
# Available input fields:
#
#
#
# * `pending` : An email verification state

# %%
# | export
class UserManagementEmailVerificationStateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("pending",)
    pending = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="pending")

# %% [markdown]
# #### 800. `UserManagementGroupFilterInput`

# %% [markdown]
# The input object representing the filter parameters for groups
#
#
# Available input fields:
#
#
#
# * `displayName` : Filter groups by display name
# * `id` : Filter groups by group ID

# %%
# | export
class UserManagementGroupFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("display_name", "id")
    display_name = sgqlc.types.Field(
        UserManagementDisplayNameInput, graphql_name="displayName"
    )

    id = sgqlc.types.Field("UserManagementGroupIdInput", graphql_name="id")

# %% [markdown]
# #### 801. `UserManagementGroupIdInput`

# %% [markdown]
# Available filtering types for group IDs
#
#
# Available input fields:
#
#
#
# * `eq` : A group ID
# * `in` : An array of group IDs

# %%
# | export
class UserManagementGroupIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 802. `UserManagementGroupSortInput`

# %% [markdown]
# The input object representing the sort parameters for groups
#
#
# Available input fields:
#
#
#
# * `direction` : Sort groups in this direction
# * `key` : Sort groups by this key

# %%
# | export
class UserManagementGroupSortInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("direction", "key")
    direction = sgqlc.types.Field(UserManagementSortDirection, graphql_name="direction")

    key = sgqlc.types.Field(UserManagementGroupSortKey, graphql_name="key")

# %% [markdown]
# #### 803. `UserManagementNameInput`

# %% [markdown]
# Available filtering types for names
#
#
# Available input fields:
#
#
#
# * `contains` : Part of a user name
# * `eq` : A user name

# %%
# | export
class UserManagementNameInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("contains", "eq")
    contains = sgqlc.types.Field(String, graphql_name="contains")

    eq = sgqlc.types.Field(String, graphql_name="eq")

# %% [markdown]
# #### 804. `UserManagementPendingUpgradeRequestInput`

# %% [markdown]
# Available filtering types for pending upgrade requests
#
#
# Available input fields:
#
#
#
# * `exists` : Whether a request exists or not

# %%
# | export
class UserManagementPendingUpgradeRequestInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("exists",)
    exists = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="exists")

# %% [markdown]
# #### 805. `UserManagementTypeInput`

# %% [markdown]
# Available filtering types for user type
#
#
# Available input fields:
#
#
#
# * `eq` : A user type

# %%
# | export
class UserManagementTypeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq",)
    eq = sgqlc.types.Field(
        sgqlc.types.non_null(UserManagementTypeEnum), graphql_name="eq"
    )

# %% [markdown]
# #### 806. `UserManagementUpdateGroup`

# %% [markdown]
# The input object representing the group being updated
#
#
# Available input fields:
#
#
#
# * `displayName` : The name of the group
# * `id` : The id of the group to update

# %%
# | export
class UserManagementUpdateGroup(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("display_name", "id")
    display_name = sgqlc.types.Field(
        sgqlc.types.non_null(String), graphql_name="displayName"
    )

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

# %% [markdown]
# #### 807. `UserManagementUpdateUser`

# %% [markdown]
# The input object representing the user being updated
#
#
# Available input fields:
#
#
#
# * `email` : The new email address to be updated on the user
# * `id` : The ID of the user to be updated
# * `name` : The full name of the user to be updated
# * `timeZone` : The user time zone to be updated, in IANA zoneinfo format, e.g. 'America/Chicago'
# * `userType` : The new user type to be updated on the user

# %%
# | export
class UserManagementUpdateUser(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("email", "id", "name", "time_zone", "user_type")
    email = sgqlc.types.Field(String, graphql_name="email")

    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

    name = sgqlc.types.Field(String, graphql_name="name")

    time_zone = sgqlc.types.Field(String, graphql_name="timeZone")

    user_type = sgqlc.types.Field(
        UserManagementRequestedTierName, graphql_name="userType"
    )

# %% [markdown]
# #### 808. `UserManagementUserFilterInput`

# %% [markdown]
# The input object representing the filter parameters for users
#
#
# Available input fields:
#
#
#
# * `email` : Filter users by email address
# * `emailVerificationState` : Filter users by email verification state
# * `id` : Filter users by user ID
# * `name` : Filter users by name
# * `pendingUpgradeRequest` : Filter users by pending upgrade request
# * `type` : Filter users by type

# %%
# | export
class UserManagementUserFilterInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "email",
        "email_verification_state",
        "id",
        "name",
        "pending_upgrade_request",
        "type",
    )
    email = sgqlc.types.Field(UserManagementEmailInput, graphql_name="email")

    email_verification_state = sgqlc.types.Field(
        UserManagementEmailVerificationStateInput, graphql_name="emailVerificationState"
    )

    id = sgqlc.types.Field("UserManagementUserIdInput", graphql_name="id")

    name = sgqlc.types.Field(UserManagementNameInput, graphql_name="name")

    pending_upgrade_request = sgqlc.types.Field(
        UserManagementPendingUpgradeRequestInput, graphql_name="pendingUpgradeRequest"
    )

    type = sgqlc.types.Field(UserManagementTypeInput, graphql_name="type")

# %% [markdown]
# #### 809. `UserManagementUserIdInput`

# %% [markdown]
# Available filtering types for user IDs
#
#
# Available input fields:
#
#
#
# * `eq` : A user ID
# * `in` : An array of user IDs

# %%
# | export
class UserManagementUserIdInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("eq", "in_")
    eq = sgqlc.types.Field(ID, graphql_name="eq")

    in_ = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="in"
    )

# %% [markdown]
# #### 810. `UserManagementUsersGroupsInput`

# %% [markdown]
# The input object representing the group(s) and user(s) to update.
#
#
# Available input fields:
#
#
#
# * `groupIds` : The id of the group(s) to add the user(s) to. Max: 10
# * `userIds` : The id of the user(s) to be added to the group(s). Max: 50

# %%
# | export
class UserManagementUsersGroupsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("group_ids", "user_ids")
    group_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(ID))),
        graphql_name="groupIds",
    )

    user_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(ID))),
        graphql_name="userIds",
    )

# %% [markdown]
# #### 811. `UsersUserSearchQuery`

# %% [markdown]
# Query object for UserSearch.
#
#
# Available input fields:
#
#
#
# * `scope` : The scope to filter the search response by.

# %%
# | export
class UsersUserSearchQuery(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("scope",)
    scope = sgqlc.types.Field("UsersUserSearchScope", graphql_name="scope")

# %% [markdown]
# #### 812. `UsersUserSearchScope`

# %% [markdown]
# Different scopes that can be used to filter the returned users.
#
#
# Available input fields:
#
#
#
# * `email` : Filter by string that will partially match a User's `email`.  Same as `name` it will partially match and case is ignored.
# * `name` : Filter by string that will partially match a User's `name`. So argument `name='Ste'` will match `name='Steve'` and case is ignored so `name='Koester'` would also match.
# * `search` : Will match both a User's `email` and `name`.  So argument `search='ple'`  will match `name='Johnny Appleseed'` and `email='mary@example.com'`.
# * `userIds` : List of up to 1000 userIds to filter by. Will only return data for users with ids that match the full ID, no partial matching. (so 2 ids provided will yield at most 2 users)

# %%
# | export
class UsersUserSearchScope(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("email", "name", "search", "user_ids")
    email = sgqlc.types.Field(String, graphql_name="email")

    name = sgqlc.types.Field(String, graphql_name="name")

    search = sgqlc.types.Field(String, graphql_name="search")

    user_ids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(ID)), graphql_name="userIds"
    )

# %% [markdown]
# #### 813. `WhatsNewContentSearchQuery`

# %% [markdown]
# A query that represents a criteria for searching news.
#
#
# Available input fields:
#
#
#
# * `contentType` : Criteria to narrow the scope of the search to a specific type of news.
# * `unreadOnly` : Criteria to narrow the scope of the search to only those news that are unread by the current user.

# %%
# | export
class WhatsNewContentSearchQuery(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("content_type", "unread_only")
    content_type = sgqlc.types.Field(WhatsNewContentType, graphql_name="contentType")

    unread_only = sgqlc.types.Field(Boolean, graphql_name="unreadOnly")

# %% [markdown]
# #### 814. `WorkflowAutomationCreateScheduleDefinitionInput`

# %% [markdown]
# Input for creating a schedule
#
#
# Available input fields:
#
#
#
# * `name` : Name of the workflow definition
# * `scopeType` : Scope type of the workflow definition. Defaults to ACCOUNT.
# * `version` : Version of the workflow definition

# %%
# | export
class WorkflowAutomationCreateScheduleDefinitionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "scope_type", "version")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope_type = sgqlc.types.Field(
        WorkflowAutomationScopeType, graphql_name="scopeType"
    )

    version = sgqlc.types.Field(sgqlc.types.non_null(Int), graphql_name="version")

# %% [markdown]
# #### 815. `WorkflowAutomationCreateWorkflowDefinitionInput`

# %% [markdown]
# Input for creating a workflow definition
#
#
# Available input fields:
#
#
#
# * `yaml` : The yaml string for the workflow definition

# %%
# | export
class WorkflowAutomationCreateWorkflowDefinitionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("yaml",)
    yaml = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="yaml")

# %% [markdown]
# #### 816. `WorkflowAutomationDeleteScheduleInput`

# %% [markdown]
# Delete the schedule input
#
#
# Available input fields:
#
#
#
# * `id` : The ID for the schedule

# %%
# | export
class WorkflowAutomationDeleteScheduleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id",)
    id = sgqlc.types.Field(sgqlc.types.non_null(ID), graphql_name="id")

# %% [markdown]
# #### 817. `WorkflowAutomationDeleteWorkflowDefinitionInput`

# %% [markdown]
# Input for deleting a workflow definition
#
#
# Available input fields:
#
#
#
# * `name` : The name of the workflow definition

# %%
# | export
class WorkflowAutomationDeleteWorkflowDefinitionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name",)
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

# %% [markdown]
# #### 818. `WorkflowAutomationScopeInput`

# %% [markdown]
# The scope input for workflow definitions
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the scope input
# * `type` : The type of the scope input. Defaults to ACCOUNT.

# %%
# | export
class WorkflowAutomationScopeInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(WorkflowAutomationScopeType, graphql_name="type")

# %% [markdown]
# #### 819. `WorkflowAutomationSignalInput`

# %% [markdown]
# Input type for signaling workflow runs
#
#
# Available input fields:
#
#
#
# * `key` : Input key
# * `value` : Input value

# %%
# | export
class WorkflowAutomationSignalInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(
        sgqlc.types.non_null(WorkflowAutomationRawWorkflowInputValue),
        graphql_name="value",
    )

# %% [markdown]
# #### 820. `WorkflowAutomationStartWorkflowRunDefinitionInput`

# %% [markdown]
# Input for starting a workflow
#
#
# Available input fields:
#
#
#
# * `name` : Name of the workflow definition
# * `scopeType` : Scope type of the workflow definition. Defaults to ACCOUNT.
# * `version` : Version of the workflow definition

# %%
# | export
class WorkflowAutomationStartWorkflowRunDefinitionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name", "scope_type", "version")
    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope_type = sgqlc.types.Field(
        WorkflowAutomationScopeType, graphql_name="scopeType"
    )

    version = sgqlc.types.Field(Int, graphql_name="version")

# %% [markdown]
# #### 821. `WorkflowAutomationTag`

# %% [markdown]
# Input for tags.
#
#
# Available input fields:
#
#
#
# * `key` : The key or name of the tag.
# * `values` : The list of values of the tag.

# %%
# | export
class WorkflowAutomationTag(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "values")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    values = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(String))),
        graphql_name="values",
    )

# %% [markdown]
# #### 822. `WorkflowAutomationUpdateWorkflowDefinitionInput`

# %% [markdown]
# Input for updating a workflow definition
#
#
# Available input fields:
#
#
#
# * `yaml` : The yaml string for the workflow definition

# %%
# | export
class WorkflowAutomationUpdateWorkflowDefinitionInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("yaml",)
    yaml = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="yaml")

# %% [markdown]
# #### 823. `WorkflowAutomationWorkflowDefinitionValidationInput`

# %% [markdown]
# Input for validating a workflow definition
#
#
# Available input fields:
#
#
#
# * `yaml` : The yaml string for the workflow definition

# %%
# | export
class WorkflowAutomationWorkflowDefinitionValidationInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("yaml",)
    yaml = sgqlc.types.Field(sgqlc.types.non_null(SecureValue), graphql_name="yaml")

# %% [markdown]
# #### 824. `WorkflowAutomationWorkflowRunInput`

# %% [markdown]
# Input type for workflow run
#
#
# Available input fields:
#
#
#
# * `key` : Input key
# * `value` : Input value

# %%
# | export
class WorkflowAutomationWorkflowRunInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("key", "value")
    key = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="key")

    value = sgqlc.types.Field(
        sgqlc.types.non_null(WorkflowAutomationRawWorkflowInputValue),
        graphql_name="value",
    )

# %% [markdown]
# #### 825. `WorkflowAutomationWorkflowRunOptions`

# %% [markdown]
# Options for workflow runs
#
#
# Available input fields:
#
#
#
# * `logLevel` : The log level for workflow runs. Defaults to INFO.

# %%
# | export
class WorkflowAutomationWorkflowRunOptions(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("log_level",)
    log_level = sgqlc.types.Field(
        WorkflowAutomationWorkflowLogLevel, graphql_name="logLevel"
    )

# %% [markdown]
# #### 826. `WorkflowAutomationWorkflowRunScope`

# %% [markdown]
# The scope for workflow runs
#
#
# Available input fields:
#
#
#
# * `id` : The ID of the workflow scope
# * `type` : The type of the workflow scope. Defaults to ACCOUNT.

# %%
# | export
class WorkflowAutomationWorkflowRunScope(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "type")
    id = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="id")

    type = sgqlc.types.Field(
        WorkflowAutomationWorkflowRunScopeType, graphql_name="type"
    )

# %% [markdown]
# #### 827. `WorkloadAutomaticStatusInput`

# %% [markdown]
# An input object used to represent an automatic status configuration. If not provided, a status configuration will be created by default.
#
#
# Available input fields:
#
#
#
# * `enabled` : Whether the automatic status configuration is enabled or not.
# * `remainingEntitiesRule` : An additional meta-rule that can consider all entities that haven't been evaluated by any other rule.
# * `rules` : A list of rules.

# %%
# | export
class WorkloadAutomaticStatusInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled", "remaining_entities_rule", "rules")
    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    remaining_entities_rule = sgqlc.types.Field(
        "WorkloadRemainingEntitiesRuleInput", graphql_name="remainingEntitiesRule"
    )

    rules = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("WorkloadRegularRuleInput")),
        graphql_name="rules",
    )

# %% [markdown]
# #### 828. `WorkloadCreateInput`

# %% [markdown]
# The input object used to represent the workload to be created.
#
#
# Available input fields:
#
#
#
# * `description` : Relevant information about the workload.
# * `entityGuids` : A list of entity GUIDs composing the workload.
# * `entitySearchQueries` : A list of entity search queries used to retrieve the entities that compose the workload.
# * `name` : The name of the workload.
# * `scopeAccounts` : Accounts that will be used to get entities from.
# * `statusConfig` : The configuration that defines how the status of the workload is calculated.

# %%
# | export
class WorkloadCreateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "entity_guids",
        "entity_search_queries",
        "name",
        "scope_accounts",
        "status_config",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_search_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("WorkloadEntitySearchQueryInput")),
        graphql_name="entitySearchQueries",
    )

    name = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="name")

    scope_accounts = sgqlc.types.Field(
        "WorkloadScopeAccountsInput", graphql_name="scopeAccounts"
    )

    status_config = sgqlc.types.Field(
        "WorkloadStatusConfigInput", graphql_name="statusConfig"
    )

# %% [markdown]
# #### 829. `WorkloadDuplicateInput`

# %% [markdown]
# The input object used to represent the workload duplicate.
#
#
# Available input fields:
#
#
#
# * `name` : The name of the workload duplicate. If the name isn't specified, the name + ' copy' of the source workload is used to compose the new name.

# %%
# | export
class WorkloadDuplicateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("name",)
    name = sgqlc.types.Field(String, graphql_name="name")

# %% [markdown]
# #### 830. `WorkloadEntitySearchQueryInput`

# %% [markdown]
# The input object used to represent the entity search query to be created.
#
#
# Available input fields:
#
#
#
# * `query` : The entity search query that is used to perform the search of a group of entities.

# %%
# | export
class WorkloadEntitySearchQueryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("query",)
    query = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="query")

# %% [markdown]
# #### 831. `WorkloadRegularRuleInput`

# %% [markdown]
# The input object used to represent a rule.
#
#
# Available input fields:
#
#
#
# * `entityGuids` : A list of entity GUIDs composing the rule.
# * `entitySearchQueries` : A list of entity search queries used to retrieve the entities that compose the rule.
# * `rollup` : The input object used to represent a rollup strategy.

# %%
# | export
class WorkloadRegularRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_guids", "entity_search_queries", "rollup")
    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_search_queries = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(WorkloadEntitySearchQueryInput)),
        graphql_name="entitySearchQueries",
    )

    rollup = sgqlc.types.Field(
        sgqlc.types.non_null("WorkloadRollupInput"), graphql_name="rollup"
    )

# %% [markdown]
# #### 832. `WorkloadRemainingEntitiesRuleInput`

# %% [markdown]
# The input object used to represent a remaining entities rule.
#
#
# Available input fields:
#
#
#
# * `rollup` : The input object used to represent a rollup strategy.

# %%
# | export
class WorkloadRemainingEntitiesRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("rollup",)
    rollup = sgqlc.types.Field(
        sgqlc.types.non_null("WorkloadRemainingEntitiesRuleRollupInput"),
        graphql_name="rollup",
    )

# %% [markdown]
# #### 833. `WorkloadRemainingEntitiesRuleRollupInput`

# %% [markdown]
# The input object used to represent a rollup strategy.
#
#
# Available input fields:
#
#
#
# * `groupBy` : The grouping to be applied to the remaining entities.
# * `strategy` : The rollup strategy that is applied to a group of entities.
# * `thresholdType` : Type of threshold defined for the rule. This is an optional field that only applies when strategy is WORST_STATUS_WINS. Use a threshold to roll up the worst status only after a certain amount of entities are not operational.
# * `thresholdValue` : Threshold value defined for the rule. This optional field is used in combination with thresholdType. If the threshold type is null, the threshold value will be ignored.

# %%
# | export
class WorkloadRemainingEntitiesRuleRollupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("group_by", "strategy", "threshold_type", "threshold_value")
    group_by = sgqlc.types.Field(
        sgqlc.types.non_null(WorkloadGroupRemainingEntitiesRuleBy),
        graphql_name="groupBy",
    )

    strategy = sgqlc.types.Field(
        sgqlc.types.non_null(WorkloadRollupStrategy), graphql_name="strategy"
    )

    threshold_type = sgqlc.types.Field(
        WorkloadRuleThresholdType, graphql_name="thresholdType"
    )

    threshold_value = sgqlc.types.Field(Int, graphql_name="thresholdValue")

# %% [markdown]
# #### 834. `WorkloadRollupInput`

# %% [markdown]
# The input object used to represent a rollup strategy.
#
#
# Available input fields:
#
#
#
# * `strategy` : The rollup strategy that is applied to a group of entities.
# * `thresholdType` : Type of threshold defined for the rule. This is an optional field that only applies when strategy is WORST_STATUS_WINS. Use a threshold to roll up the worst status only after a certain amount of entities are not operational.
# * `thresholdValue` : Threshold value defined for the rule. This optional field is used in combination with thresholdType. If the threshold type is null, the threshold value will be ignored.

# %%
# | export
class WorkloadRollupInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("strategy", "threshold_type", "threshold_value")
    strategy = sgqlc.types.Field(
        sgqlc.types.non_null(WorkloadRollupStrategy), graphql_name="strategy"
    )

    threshold_type = sgqlc.types.Field(
        WorkloadRuleThresholdType, graphql_name="thresholdType"
    )

    threshold_value = sgqlc.types.Field(Int, graphql_name="thresholdValue")

# %% [markdown]
# #### 835. `WorkloadScopeAccountsInput`

# %% [markdown]
# The input object containing accounts that will be used to get entities from.
#
#
# Available input fields:
#
#
#
# * `accountIds` : A list of accounts that will be used to get entities from.

# %%
# | export
class WorkloadScopeAccountsInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("account_ids",)
    account_ids = sgqlc.types.Field(
        sgqlc.types.non_null(sgqlc.types.list_of(sgqlc.types.non_null(Int))),
        graphql_name="accountIds",
    )

# %% [markdown]
# #### 836. `WorkloadStaticStatusInput`

# %% [markdown]
# The input object used to represent the configuration of a static status.
#
#
# Available input fields:
#
#
#
# * `description` : A description that provides additional details about the status of the workload.
# * `enabled` : Whether the static status configuration is enabled or not.
# * `status` : The status of the workload.
# * `summary` : A short description of the status of the workload.

# %%
# | export
class WorkloadStaticStatusInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "enabled", "status", "summary")
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    status = sgqlc.types.Field(
        sgqlc.types.non_null(WorkloadStatusValueInput), graphql_name="status"
    )

    summary = sgqlc.types.Field(String, graphql_name="summary")

# %% [markdown]
# #### 837. `WorkloadStatusConfigInput`

# %% [markdown]
# The input object used to provide the configuration that defines how the status of the workload is calculated.
#
#
# Available input fields:
#
#
#
# * `automatic` : An input object used to represent an automatic status configuration.
# * `static` : A list of static status configurations. You can only configure one static status for a workload.

# %%
# | export
class WorkloadStatusConfigInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("automatic", "static")
    automatic = sgqlc.types.Field(
        WorkloadAutomaticStatusInput, graphql_name="automatic"
    )

    static = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(WorkloadStaticStatusInput)),
        graphql_name="static",
    )

# %% [markdown]
# #### 838. `WorkloadUpdateAutomaticStatusInput`

# %% [markdown]
# An input object used to represent an automatic status configuration.
#
#
# Available input fields:
#
#
#
# * `enabled` : Whether the automatic status configuration is enabled or not.
# * `remainingEntitiesRule` : An additional meta-rule that can consider all entities that haven't been evaluated by any other rule.
# * `rules` : A list of rules.

# %%
# | export
class WorkloadUpdateAutomaticStatusInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("enabled", "remaining_entities_rule", "rules")
    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    remaining_entities_rule = sgqlc.types.Field(
        WorkloadRemainingEntitiesRuleInput, graphql_name="remainingEntitiesRule"
    )

    rules = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null("WorkloadUpdateRegularRuleInput")),
        graphql_name="rules",
    )

# %% [markdown]
# #### 839. `WorkloadUpdateCollectionEntitySearchQueryInput`

# %% [markdown]
# The input object used to represent the entity search query to be updated.
#
#
# Available input fields:
#
#
#
# * `id` : The unique identifier of the entity search query to be updated. If not provided, a new entity search query is created.
# * `query` : The entity search query that is used to perform the search of a group of entities.

# %%
# | export
class WorkloadUpdateCollectionEntitySearchQueryInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("id", "query")
    id = sgqlc.types.Field(Int, graphql_name="id")

    query = sgqlc.types.Field(sgqlc.types.non_null(String), graphql_name="query")

# %% [markdown]
# #### 840. `WorkloadUpdateInput`

# %% [markdown]
# The input object used to identify the workload to be updated and the new values.
#
#
# Available input fields:
#
#
#
# * `description` : Relevant information about the workload.
# * `entityGuids` : A list of entity GUIDs composing the workload.
# * `entitySearchQueries` : A list of entity search queries used to retrieve the groups of entities that compose the workload.
# * `name` : The name of the workload.
# * `scopeAccounts` : Accounts that will be used to get entities from.
# * `statusConfig` : The configuration that defines how the status of the workload is calculated.

# %%
# | export
class WorkloadUpdateInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = (
        "description",
        "entity_guids",
        "entity_search_queries",
        "name",
        "scope_accounts",
        "status_config",
    )
    description = sgqlc.types.Field(String, graphql_name="description")

    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_search_queries = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(WorkloadUpdateCollectionEntitySearchQueryInput)
        ),
        graphql_name="entitySearchQueries",
    )

    name = sgqlc.types.Field(String, graphql_name="name")

    scope_accounts = sgqlc.types.Field(
        WorkloadScopeAccountsInput, graphql_name="scopeAccounts"
    )

    status_config = sgqlc.types.Field(
        "WorkloadUpdateStatusConfigInput", graphql_name="statusConfig"
    )

# %% [markdown]
# #### 841. `WorkloadUpdateRegularRuleInput`

# %% [markdown]
# The input object used to represent a rule.
#
#
# Available input fields:
#
#
#
# * `entityGuids` : A list of entity GUIDs composing the rule.
# * `entitySearchQueries` : A list of entity search queries used to retrieve the groups of entities that compose the rule.
# * `id` : The unique identifier of the rule to be updated. If not provided, a new rule is created.
# * `rollup` : The input object used to represent a roll-up strategy.

# %%
# | export
class WorkloadUpdateRegularRuleInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("entity_guids", "entity_search_queries", "id", "rollup")
    entity_guids = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(EntityGuid)),
        graphql_name="entityGuids",
    )

    entity_search_queries = sgqlc.types.Field(
        sgqlc.types.list_of(
            sgqlc.types.non_null(WorkloadUpdateCollectionEntitySearchQueryInput)
        ),
        graphql_name="entitySearchQueries",
    )

    id = sgqlc.types.Field(Int, graphql_name="id")

    rollup = sgqlc.types.Field(
        sgqlc.types.non_null(WorkloadRollupInput), graphql_name="rollup"
    )

# %% [markdown]
# #### 842. `WorkloadUpdateStaticStatusInput`

# %% [markdown]
# The input object used to represent the configuration of a static status.
#
#
# Available input fields:
#
#
#
# * `description` : A description that provides additional details about the status of the workload.
# * `enabled` : Whether the static status configuration is enabled or not.
# * `id` : The unique identifier of the static status to be updated. If not provided, a new static status is created.
# * `status` : The status of the workload.
# * `summary` : A short description of the static status.

# %%
# | export
class WorkloadUpdateStaticStatusInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("description", "enabled", "id", "status", "summary")
    description = sgqlc.types.Field(String, graphql_name="description")

    enabled = sgqlc.types.Field(sgqlc.types.non_null(Boolean), graphql_name="enabled")

    id = sgqlc.types.Field(Int, graphql_name="id")

    status = sgqlc.types.Field(
        sgqlc.types.non_null(WorkloadStatusValueInput), graphql_name="status"
    )

    summary = sgqlc.types.Field(String, graphql_name="summary")

# %% [markdown]
# #### 843. `WorkloadUpdateStatusConfigInput`

# %% [markdown]
# The input object used to provide the configuration that defines how the status of the workload is calculated.
#
#
# Available input fields:
#
#
#
# * `automatic` : An input object used to represent an automatic status configuration.
# * `static` : A list of static status configurations. You can only configure one static status for a workload.

# %%
# | export
class WorkloadUpdateStatusConfigInput(sgqlc.types.Input):
    __schema__ = nerdgraph
    __field_names__ = ("automatic", "static")
    automatic = sgqlc.types.Field(
        WorkloadUpdateAutomaticStatusInput, graphql_name="automatic"
    )

    static = sgqlc.types.Field(
        sgqlc.types.list_of(sgqlc.types.non_null(WorkloadUpdateStaticStatusInput)),
        graphql_name="static",
    )
